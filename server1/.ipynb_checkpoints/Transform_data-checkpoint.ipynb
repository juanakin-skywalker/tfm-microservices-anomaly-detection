# %%
from timescale import TimescaleDBManager
from dotenv import load_dotenv
from sqlalchemy import create_engine

# %%
def obtener_datos_ejecucion_metrica(execution_name, metric_name, engine):
    """
    Extrae todos los registros de una ejecución y métrica específica.
    """
    SQL = """
        SELECT time,instance,grupo,job,tags,label,metric_value
        FROM metricas 
        WHERE execution_name = %s 
          AND metric_name = %s
        ORDER BY time ASC
    """
    
    # Ejecutamos la consulta pasando los parámetros de forma segura
    df = pd.read_sql(SQL, engine, params=(execution_name, metric_name))
    
    # Convertimos la columna time a formato datetime
    df['time'] = pd.to_datetime(df['time'])
    df         = df.sort_values('time')


    inicio_global = df['time'].min()
    df['tiempo_relativo'] = (df['time'] - inicio_global).dt.total_seconds()
        
    return df

# %%
def interpolar(df_serie,INTERVALO_VALOR):
    
    # --- 1. CONFIGURACIÓN ---
    INTERVALO_VALOR = 5
    INTERVALO_MUESTREO = f'{INTERVALO_VALOR}s'
    
    # --- 2. PREPARACIÓN ---
    # Aseguramos que 'time' es datetime y ordenamos
    df_serie['time'] = pd.to_datetime(df_serie['time'])
    df_serie = df_serie.sort_values('time')
    
    # Filtramos solo las columnas que nos interesan
    cols_a_mantener = ['time', 'metric_value', 'grupo', 'instance', 'job', 'label','tags']
    cols_numericas = ['metric_value']  # Ajusta si tienes más columnas numéricas
    cols_texto = ['grupo', 'instance', 'job', 'label', 'tags']
    
    df_filtrado = df_serie[cols_a_mantener].copy()
    df_filtrado['metric_value'] = df_filtrado['metric_value'].astype(float)
    
    # --- 3. PROCESAMIENTO ---
    # Establecemos el índice temporal
    df_indexado = df_filtrado.set_index('time').sort_index()
    
    # AJUSTE: Calculamos el final redondeando al siguiente múltiplo de 5 segundos
    # Esto asegura que si tu último punto es 799, el rango llegue hasta 800
    inicio = df_indexado.index.min()
    ultimo_timestamp = df_indexado.index.max()
    # Calculamos cuánto falta para el siguiente múltiplo de 5s
    segundos_faltantes = INTERVALO_VALOR - (ultimo_timestamp.second % INTERVALO_VALOR)
    fin = df_indexado.index.max().ceil(INTERVALO_MUESTREO) + pd.Timedelta(seconds=INTERVALO_VALOR)
    
    
    rango_muestreo = pd.date_range(start=inicio, end=fin, freq=INTERVALO_MUESTREO)
    
    # Creamos un DataFrame destino con el índice regular
    df_target = pd.DataFrame(index=rango_muestreo)
    
    df_fusionado = df_target.join(df_indexado, how='outer')
    df_fusionado[cols_numericas] = df_fusionado[cols_numericas].interpolate(method='time')
    df_fusionado[cols_texto] = df_fusionado[cols_texto].ffill()
    df_final = df_fusionado.loc[df_target.index]
    inicio_global = df_final.index.min()
    df_final['tiempo_relativo'] = (df_final.index - inicio_global).total_seconds()
    return df_final

# %%
INTERVALO_MUESTREO = 5
load_dotenv()
user_env        = os.getenv("USER_DB")
pass_env        = os.getenv("PASS_DB")
host_env        = os.getenv("HOST_DB", "localhost")
port_env        = os.getenv("DB_PORT_EXPOSED", "5432")
db_env          = os.getenv("NAME_DB", "tfm_db")
FOLDER_SALIDA   = os.getenv("FOLDER_SALIDA")
FOLDER_TMP      = os.getenv("FOLDER_TMP")

SEED            = os.getenv("SEED")

db = TimescaleDBManager(
    user=user_env,
    password=pass_env,
    host=host_env,
    port=port_env,
    dbname=db_env
)
db.conectar()
conexion_postgresql = db.connection

#esto es para usar una conexion postgrews para pandas que da un warning indicando que solo esta testeado para sqlalchemy
engine = create_engine(f'postgresql+psycopg2://{user_env}:{pass_env}@{host_env}:{port_env}/{db_env}')
# Out:
# 🔌 [OK] Conexión establecida con TimescaleDB.

# %%
SQL='select distinct(execution_name) from metricas'
df_metric_name = pd.read_sql(SQL, engine)
lista_execution_name=df_metric_name['execution_name'].to_list()

# %%
#recuperamos datos calculados previamente para realizar la transformacion del dataset original
df_ejecuciones_outlier = pd.read_parquet(f'{FOLDER_SALIDA}/df_ejecuciones_outlier.parquet')
df_analisis_metricas = pd.read_parquet(f'{FOLDER_SALIDA}/analisis_metricas.parquet')
lista_metricas_sel=df_analisis_metricas[   df_analisis_metricas['metric_name_sel']!=''  ]['metric_name'].tolist()


ruta_archivo = f'{FOLDER_SALIDA}/lista_ejecuciones_descartadas.json'
with open(ruta_archivo, "r", encoding="utf-8") as f:
    lista_ejecuciones_descartadas = json.load(f)

# %%
set_descartadas = set(lista_ejecuciones_descartadas)
lista_ejecuciones_sel = [x for x in lista_execution_name if x not in set_descartadas]

# %%
len(lista_ejecuciones_sel)
# Out:
# 1732

# %%
una_ejecucion=lista_ejecuciones_sel[0]

# %%
una_ejecucion
# Out:
# 'light-oauth2-data-1719592986.tar'

# %%
N_ejecucion=0
for una_ejecucion in lista_ejecuciones_sel:
    N_ejecucion+=1
    lista_df_procesados = []
    for una_metrica in lista_metricas_sel:
        df_sel = df_analisis_metricas[df_analisis_metricas['metric_name'] == una_metrica]
        clasificacion = df_sel.iloc[0]['clasificacion']
        if clasificacion=='diff':
            nombre_metrica = una_metrica+'_diff'
        else:
            nombre_metrica    = una_metrica
        print(f'execution_name = {una_ejecucion}   |  metric_name = {una_metrica}'.ljust(200),end='\r')
        df_serie        = obtener_datos_ejecucion_metrica(una_ejecucion, una_metrica, engine)
        df_procesado = (
            interpolar(df_serie, INTERVALO_MUESTREO)
            .reset_index()
            .rename(columns={'index': 'time'})
            .drop(columns=['tiempo_relativo'], errors='ignore')
        )
        df_procesado['metric_name'] = nombre_metrica
        if clasificacion == 'diff':
            df_procesado['metric_value'] = df_procesado['metric_value'].diff().fillna(0)
        lista_df_procesados.append(df_procesado)
    
    
    #obtenemos esta metrica que se vio que prsenta muchos NaN en anomalias, asi que puede servir para detectarlas
    #crearemos una metrica _isnan que sera 1 si hay valor NaN
    #modificaremos la metrica original para sustituir los NaN por valores medios
    una_metrica = 'prometheus_target_sync_length_seconds'
    df_serie    = obtener_datos_ejecucion_metrica(una_ejecucion, una_metrica, engine)
    
    
    #creamos metrica _isnan
    df_serie2  = df_serie.copy()
    df_serie2['metric_value'] = df_serie2['metric_value'].isna().astype(int)
    df_procesado = (
        interpolar(df_serie2, INTERVALO_MUESTREO)
        .reset_index()
        .rename(columns={'index': 'time'})
        .drop(columns=['tiempo_relativo'], errors='ignore')
    )
    df_procesado['metric_name'] = nombre_metrica+'_isnan'
    lista_df_procesados.append(df_procesado)
    
    
    mediana = df_serie['metric_value'].median()
    
    # Rellenamos los NaN con ese valor
    df_serie['metric_value'] = df_serie['metric_value'].fillna(mediana)
    
    
    #creamos la metrica _mod rellenando con la media
    df_procesado = (
        interpolar(df_serie, INTERVALO_MUESTREO)
        .reset_index()
        .rename(columns={'index': 'time'})
        .drop(columns=['tiempo_relativo'], errors='ignore')
    )
    df_procesado['metric_name'] = nombre_metrica+'_mod'
    lista_df_procesados.append(df_procesado)
    df_final = pd.concat(lista_df_procesados, ignore_index=True)
    
    df_final = df_final.sort_values(by=['time', 'metric_name', 'instance', 'grupo'])
    fichero_parquet=f'{FOLDER_TMP}/df_transformado({una_ejecucion}).parquet'
    df_final.to_parquet(fichero_parquet, index=False,engine='fastparquet')
    
    print(f'Exportado datos a fichero ({fichero_parquet})    N_ejecucion = {N_ejecucion:4d}',end='\r')
# Out:
# Exportado datos a fichero (./tmp/df_transformado(light-oauth2-data-1719592986.tar).parquet)    N_ejecucion =    1
# Exportado datos a fichero (./tmp/df_transformado(light-oauth2-data-1719594842.tar).parquet)    N_ejecucion =    2
# Exportado datos a fichero (./tmp/df_transformado(light-oauth2-data-1719598443.tar).parquet)    N_ejecucion =    3
# Exportado datos a fichero (./tmp/df_transformado(light-oauth2-data-1719602043.tar).parquet)    N_ejecucion =    4
# Exportado datos a fichero (./tmp/df_transformado(light-oauth2-data-1719605644.tar).parquet)    N_ejecucion =    5
# Exportado datos a fichero (./tmp/df_transformado(light-oauth2-data-1719609252.tar).parquet)    N_ejecucion =    6
# Exportado datos a fichero (./tmp/df_transformado(light-oauth2-data-1719612853.tar).parquet)    N_ejecucion =    7
# Exportado datos a fichero (./tmp/df_transformado(light-oauth2-data-1719616455.tar).parquet)    N_ejecucion =    8
# Exportado datos a fichero (./tmp/df_transformado(light-oauth2-data-1719620054.tar).parquet)    N_ejecucion =    9
# Exportado datos a fichero (./tmp/df_transformado(light-oauth2-data-1719623651.tar).parquet)    N_ejecucion =   10
# Exportado datos a fichero (./tmp/df_transformado(light-oauth2-data-1719627249.tar).parquet)    N_ejecucion =   11
# Exportado datos a fichero (./tmp/df_transformado(light-oauth2-data-1719630850.tar).parquet)    N_ejecucion =   12
# Exportado datos a fichero (./tmp/df_transformado(light-oauth2-data-1719634445.tar).parquet)    N_ejecucion =   13
# Exportado datos a fichero (./tmp/df_transformado(light-oauth2-data-1719638049.tar).parquet)    N_ejecucion =   14
# Exportado datos a fichero (./tmp/df_transformado(light-oauth2-data-1719641644.tar).parquet)    N_ejecucion =   15
# Exportado datos a fichero (./tmp/df_transformado(light-oauth2-data-1719645240.tar).parquet)    N_ejecucion =   16
# Exportado datos a fichero (./tmp/df_transformado(light-oauth2-data-1719648844.tar).parquet)    N_ejecucion =   17
# Exportado datos a fichero (./tmp/df_transformado(light-oauth2-data-1719652445.tar).parquet)    N_ejecucion =   18
# Exportado datos a fichero (./tmp/df_transformado(light-oauth2-data-1719656045.tar).parquet)    N_ejecucion =   19
# Exportado datos a fichero (./tmp/df_transformado(light-oauth2-data-1719659641.tar).parquet)    N_ejecucion =   20
# Exportado datos a fichero (./tmp/df_transformado(light-oauth2-data-1719663242.tar).parquet)    N_ejecucion =   21
# Exportado datos a fichero (./tmp/df_transformado(light-oauth2-data-1719666847.tar).parquet)    N_ejecucion =   22
# Exportado datos a fichero (./tmp/df_transformado(light-oauth2-data-1719670442.tar).parquet)    N_ejecucion =   23
# Exportado datos a fichero (./tmp/df_transformado(light-oauth2-data-1719674040.tar).parquet)    N_ejecucion =   24
# Exportado datos a fichero (./tmp/df_transformado(light-oauth2-data-1719677642.tar).parquet)    N_ejecucion =   25
# Exportado datos a fichero (./tmp/df_transformado(light-oauth2-data-1719681245.tar).parquet)    N_ejecucion =   26
# Exportado datos a fichero (./tmp/df_transformado(light-oauth2-data-1719684842.tar).parquet)    N_ejecucion =   27
# Exportado datos a fichero (./tmp/df_transformado(light-oauth2-data-1719688444.tar).parquet)    N_ejecucion =   28
# Exportado datos a fichero (./tmp/df_transformado(light-oauth2-data-1719692043.tar).parquet)    N_ejecucion =   29
# Exportado datos a fichero (./tmp/df_transformado(light-oauth2-data-1719695646.tar).parquet)    N_ejecucion =   30
# Exportado datos a fichero (./tmp/df_transformado(light-oauth2-data-1719699247.tar).parquet)    N_ejecucion =   31
# Exportado datos a fichero (./tmp/df_transformado(light-oauth2-data-1719702853.tar).parquet)    N_ejecucion =   32
# Exportado datos a fichero (./tmp/df_transformado(light-oauth2-data-1719706446.tar).parquet)    N_ejecucion =   33
# Exportado datos a fichero (./tmp/df_transformado(light-oauth2-data-1719710046.tar).parquet)    N_ejecucion =   34
# Exportado datos a fichero (./tmp/df_transformado(light-oauth2-data-1719713643.tar).parquet)    N_ejecucion =   35
# Exportado datos a fichero (./tmp/df_transformado(light-oauth2-data-1719717245.tar).parquet)    N_ejecucion =   36
# Exportado datos a fichero (./tmp/df_transformado(light-oauth2-data-1719720841.tar).parquet)    N_ejecucion =   37
# Exportado datos a fichero (./tmp/df_transformado(light-oauth2-data-1719724442.tar).parquet)    N_ejecucion =   38
# Exportado datos a fichero (./tmp/df_transformado(light-oauth2-data-1719728041.tar).parquet)    N_ejecucion =   39
# Exportado datos a fichero (./tmp/df_transformado(light-oauth2-data-1719731644.tar).parquet)    N_ejecucion =   40
# Exportado datos a fichero (./tmp/df_transformado(light-oauth2-data-1719735242.tar).parquet)    N_ejecucion =   41
# Exportado datos a fichero (./tmp/df_transformado(light-oauth2-data-1719738840.tar).parquet)    N_ejecucion =   42
# Exportado datos a fichero (./tmp/df_transformado(light-oauth2-data-1719742444.tar).parquet)    N_ejecucion =   43
# Exportado datos a fichero (./tmp/df_transformado(light-oauth2-data-1719746045.tar).parquet)    N_ejecucion =   44
# Exportado datos a fichero (./tmp/df_transformado(light-oauth2-data-1719749643.tar).parquet)    N_ejecucion =   45
# Exportado datos a fichero (./tmp/df_transformado(light-oauth2-data-1719753243.tar).parquet)    N_ejecucion =   46
# Exportado datos a fichero (./tmp/df_transformado(light-oauth2-data-1719756844.tar).parquet)    N_ejecucion =   47
# Exportado datos a fichero (./tmp/df_transformado(light-oauth2-data-1719760443.tar).parquet)    N_ejecucion =   48
# Exportado datos a fichero (./tmp/df_transformado(light-oauth2-data-1719764044.tar).parquet)    N_ejecucion =   49
# Exportado datos a fichero (./tmp/df_transformado(light-oauth2-data-1719767643.tar).parquet)    N_ejecucion =   50
# Exportado datos a fichero (./tmp/df_transformado(light-oauth2-data-1719771248.tar).parquet)    N_ejecucion =   51
# Exportado datos a fichero (./tmp/df_transformado(light-oauth2-data-1719774843.tar).parquet)    N_ejecucion =   52
# Exportado datos a fichero (./tmp/df_transformado(light-oauth2-data-1719778443.tar).parquet)    N_ejecucion =   53
# Exportado datos a fichero (./tmp/df_transformado(light-oauth2-data-1719782050.tar).parquet)    N_ejecucion =   54
# Exportado datos a fichero (./tmp/df_transformado(light-oauth2-data-1719785649.tar).parquet)    N_ejecucion =   55
# Exportado datos a fichero (./tmp/df_transformado(light-oauth2-data-1719789250.tar).parquet)    N_ejecucion =   56
# Exportado datos a fichero (./tmp/df_transformado(light-oauth2-data-1719792847.tar).parquet)    N_ejecucion =   57
# Exportado datos a fichero (./tmp/df_transformado(light-oauth2-data-1719796447.tar).parquet)    N_ejecucion =   58
# Exportado datos a fichero (./tmp/df_transformado(light-oauth2-data-1719800041.tar).parquet)    N_ejecucion =   59
# Exportado datos a fichero (./tmp/df_transformado(light-oauth2-data-1719803643.tar).parquet)    N_ejecucion =   60
# Exportado datos a fichero (./tmp/df_transformado(light-oauth2-data-1719807243.tar).parquet)    N_ejecucion =   61
# Exportado datos a fichero (./tmp/df_transformado(light-oauth2-data-1719810843.tar).parquet)    N_ejecucion =   62
# Exportado datos a fichero (./tmp/df_transformado(light-oauth2-data-1719814445.tar).parquet)    N_ejecucion =   63
# Exportado datos a fichero (./tmp/df_transformado(light-oauth2-data-1719818047.tar).parquet)    N_ejecucion =   64
# Exportado datos a fichero (./tmp/df_transformado(light-oauth2-data-1719821644.tar).parquet)    N_ejecucion =   65
# Exportado datos a fichero (./tmp/df_transformado(light-oauth2-data-1719825245.tar).parquet)    N_ejecucion =   66
# Exportado datos a fichero (./tmp/df_transformado(light-oauth2-data-1719828844.tar).parquet)    N_ejecucion =   67
# Exportado datos a fichero (./tmp/df_transformado(light-oauth2-data-1719832445.tar).parquet)    N_ejecucion =   68
# Exportado datos a fichero (./tmp/df_transformado(light-oauth2-data-1719836047.tar).parquet)    N_ejecucion =   69
# Exportado datos a fichero (./tmp/df_transformado(light-oauth2-data-1719839646.tar).parquet)    N_ejecucion =   70
# Exportado datos a fichero (./tmp/df_transformado(light-oauth2-data-1719843244.tar).parquet)    N_ejecucion =   71
# Exportado datos a fichero (./tmp/df_transformado(light-oauth2-data-1719846844.tar).parquet)    N_ejecucion =   72
# Exportado datos a fichero (./tmp/df_transformado(light-oauth2-data-1719850446.tar).parquet)    N_ejecucion =   73
# Exportado datos a fichero (./tmp/df_transformado(light-oauth2-data-1719854043.tar).parquet)    N_ejecucion =   74
# Exportado datos a fichero (./tmp/df_transformado(light-oauth2-data-1719857643.tar).parquet)    N_ejecucion =   75
# Exportado datos a fichero (./tmp/df_transformado(light-oauth2-data-1719861244.tar).parquet)    N_ejecucion =   76
# Exportado datos a fichero (./tmp/df_transformado(light-oauth2-data-1719864843.tar).parquet)    N_ejecucion =   77
# Exportado datos a fichero (./tmp/df_transformado(light-oauth2-data-1719868449.tar).parquet)    N_ejecucion =   78
# Exportado datos a fichero (./tmp/df_transformado(light-oauth2-data-1719872049.tar).parquet)    N_ejecucion =   79
# Exportado datos a fichero (./tmp/df_transformado(light-oauth2-data-1719875649.tar).parquet)    N_ejecucion =   80
# Exportado datos a fichero (./tmp/df_transformado(light-oauth2-data-1719879248.tar).parquet)    N_ejecucion =   81
# Exportado datos a fichero (./tmp/df_transformado(light-oauth2-data-1719882853.tar).parquet)    N_ejecucion =   82
# Exportado datos a fichero (./tmp/df_transformado(light-oauth2-data-1719886443.tar).parquet)    N_ejecucion =   83
# Exportado datos a fichero (./tmp/df_transformado(light-oauth2-data-1719890043.tar).parquet)    N_ejecucion =   84
# Exportado datos a fichero (./tmp/df_transformado(light-oauth2-data-1719893644.tar).parquet)    N_ejecucion =   85
# Exportado datos a fichero (./tmp/df_transformado(light-oauth2-data-1719897248.tar).parquet)    N_ejecucion =   86
# Exportado datos a fichero (./tmp/df_transformado(light-oauth2-data-1719900846.tar).parquet)    N_ejecucion =   87
# Exportado datos a fichero (./tmp/df_transformado(light-oauth2-data-1719904443.tar).parquet)    N_ejecucion =   88
# Exportado datos a fichero (./tmp/df_transformado(light-oauth2-data-1719908048.tar).parquet)    N_ejecucion =   89
# Exportado datos a fichero (./tmp/df_transformado(light-oauth2-data-1719911645.tar).parquet)    N_ejecucion =   90
# Exportado datos a fichero (./tmp/df_transformado(light-oauth2-data-1719915245.tar).parquet)    N_ejecucion =   91
# Exportado datos a fichero (./tmp/df_transformado(light-oauth2-data-1719918846.tar).parquet)    N_ejecucion =   92
# Exportado datos a fichero (./tmp/df_transformado(light-oauth2-data-1719922445.tar).parquet)    N_ejecucion =   93
# Exportado datos a fichero (./tmp/df_transformado(light-oauth2-data-1719926044.tar).parquet)    N_ejecucion =   94
# Exportado datos a fichero (./tmp/df_transformado(light-oauth2-data-1719929641.tar).parquet)    N_ejecucion =   95
# Exportado datos a fichero (./tmp/df_transformado(light-oauth2-data-1719933244.tar).parquet)    N_ejecucion =   96
# Exportado datos a fichero (./tmp/df_transformado(light-oauth2-data-1719936845.tar).parquet)    N_ejecucion =   97
# Exportado datos a fichero (./tmp/df_transformado(light-oauth2-data-1719940445.tar).parquet)    N_ejecucion =   98
# Exportado datos a fichero (./tmp/df_transformado(light-oauth2-data-1719944049.tar).parquet)    N_ejecucion =   99
# Exportado datos a fichero (./tmp/df_transformado(light-oauth2-data-1719947646.tar).parquet)    N_ejecucion =  100
# Exportado datos a fichero (./tmp/df_transformado(light-oauth2-data-1719951243.tar).parquet)    N_ejecucion =  101
# Exportado datos a fichero (./tmp/df_transformado(light-oauth2-data-1719954849.tar).parquet)    N_ejecucion =  102
# Exportado datos a fichero (./tmp/df_transformado(light-oauth2-data-1719958450.tar).parquet)    N_ejecucion =  103
# Exportado datos a fichero (./tmp/df_transformado(light-oauth2-data-1719962050.tar).parquet)    N_ejecucion =  104
# Exportado datos a fichero (./tmp/df_transformado(light-oauth2-data-1719965648.tar).parquet)    N_ejecucion =  105
# Exportado datos a fichero (./tmp/df_transformado(light-oauth2-data-1719969251.tar).parquet)    N_ejecucion =  106
# Exportado datos a fichero (./tmp/df_transformado(light-oauth2-data-1719972846.tar).parquet)    N_ejecucion =  107
# Exportado datos a fichero (./tmp/df_transformado(light-oauth2-data-1719976443.tar).parquet)    N_ejecucion =  108
# Exportado datos a fichero (./tmp/df_transformado(light-oauth2-data-1719980045.tar).parquet)    N_ejecucion =  109
# Exportado datos a fichero (./tmp/df_transformado(light-oauth2-data-1719983645.tar).parquet)    N_ejecucion =  110
# Exportado datos a fichero (./tmp/df_transformado(light-oauth2-data-1719987249.tar).parquet)    N_ejecucion =  111
# Exportado datos a fichero (./tmp/df_transformado(light-oauth2-data-1719990847.tar).parquet)    N_ejecucion =  112
# Exportado datos a fichero (./tmp/df_transformado(light-oauth2-data-1719994445.tar).parquet)    N_ejecucion =  113
# Exportado datos a fichero (./tmp/df_transformado(light-oauth2-data-1719998045.tar).parquet)    N_ejecucion =  114
# Exportado datos a fichero (./tmp/df_transformado(light-oauth2-data-1720001645.tar).parquet)    N_ejecucion =  115
# Exportado datos a fichero (./tmp/df_transformado(light-oauth2-data-1720005244.tar).parquet)    N_ejecucion =  116
# Exportado datos a fichero (./tmp/df_transformado(light-oauth2-data-1720008846.tar).parquet)    N_ejecucion =  117
# Exportado datos a fichero (./tmp/df_transformado(light-oauth2-data-1720012450.tar).parquet)    N_ejecucion =  118
# Exportado datos a fichero (./tmp/df_transformado(light-oauth2-data-1720016041.tar).parquet)    N_ejecucion =  119
# Exportado datos a fichero (./tmp/df_transformado(light-oauth2-data-1720019645.tar).parquet)    N_ejecucion =  120
# Exportado datos a fichero (./tmp/df_transformado(light-oauth2-data-1720023245.tar).parquet)    N_ejecucion =  121
# Exportado datos a fichero (./tmp/df_transformado(light-oauth2-data-1720026845.tar).parquet)    N_ejecucion =  122
# Exportado datos a fichero (./tmp/df_transformado(light-oauth2-data-1720030447.tar).parquet)    N_ejecucion =  123
# Exportado datos a fichero (./tmp/df_transformado(light-oauth2-data-1720034045.tar).parquet)    N_ejecucion =  124
# Exportado datos a fichero (./tmp/df_transformado(light-oauth2-data-1720037647.tar).parquet)    N_ejecucion =  125
# Exportado datos a fichero (./tmp/df_transformado(light-oauth2-data-1720041249.tar).parquet)    N_ejecucion =  126
# Exportado datos a fichero (./tmp/df_transformado(light-oauth2-data-1720044850.tar).parquet)    N_ejecucion =  127
# Exportado datos a fichero (./tmp/df_transformado(light-oauth2-data-1720048451.tar).parquet)    N_ejecucion =  128
# Exportado datos a fichero (./tmp/df_transformado(light-oauth2-data-1720052048.tar).parquet)    N_ejecucion =  129
# Exportado datos a fichero (./tmp/df_transformado(light-oauth2-data-1720055650.tar).parquet)    N_ejecucion =  130
# Exportado datos a fichero (./tmp/df_transformado(light-oauth2-data-1720059243.tar).parquet)    N_ejecucion =  131
# Exportado datos a fichero (./tmp/df_transformado(light-oauth2-data-1720062845.tar).parquet)    N_ejecucion =  132
# Exportado datos a fichero (./tmp/df_transformado(light-oauth2-data-1720066444.tar).parquet)    N_ejecucion =  133
# Exportado datos a fichero (./tmp/df_transformado(light-oauth2-data-1720070044.tar).parquet)    N_ejecucion =  134
# Exportado datos a fichero (./tmp/df_transformado(light-oauth2-data-1720073652.tar).parquet)    N_ejecucion =  135
# Exportado datos a fichero (./tmp/df_transformado(light-oauth2-data-1720077249.tar).parquet)    N_ejecucion =  136
# Exportado datos a fichero (./tmp/df_transformado(light-oauth2-data-1720080843.tar).parquet)    N_ejecucion =  137
# Exportado datos a fichero (./tmp/df_transformado(light-oauth2-data-1720084449.tar).parquet)    N_ejecucion =  138
# Exportado datos a fichero (./tmp/df_transformado(light-oauth2-data-1720088047.tar).parquet)    N_ejecucion =  139
# Exportado datos a fichero (./tmp/df_transformado(light-oauth2-data-1720091646.tar).parquet)    N_ejecucion =  140
# Exportado datos a fichero (./tmp/df_transformado(light-oauth2-data-1720095244.tar).parquet)    N_ejecucion =  141
# Exportado datos a fichero (./tmp/df_transformado(light-oauth2-data-1720098845.tar).parquet)    N_ejecucion =  142
# Exportado datos a fichero (./tmp/df_transformado(light-oauth2-data-1720102445.tar).parquet)    N_ejecucion =  143
# Exportado datos a fichero (./tmp/df_transformado(light-oauth2-data-1720106043.tar).parquet)    N_ejecucion =  144
# Exportado datos a fichero (./tmp/df_transformado(light-oauth2-data-1720109648.tar).parquet)    N_ejecucion =  145
# Exportado datos a fichero (./tmp/df_transformado(light-oauth2-data-1720113245.tar).parquet)    N_ejecucion =  146
# Exportado datos a fichero (./tmp/df_transformado(light-oauth2-data-1720116844.tar).parquet)    N_ejecucion =  147
# Exportado datos a fichero (./tmp/df_transformado(light-oauth2-data-1720120447.tar).parquet)    N_ejecucion =  148
# Exportado datos a fichero (./tmp/df_transformado(light-oauth2-data-1720124043.tar).parquet)    N_ejecucion =  149
# Exportado datos a fichero (./tmp/df_transformado(light-oauth2-data-1720127648.tar).parquet)    N_ejecucion =  150
# Exportado datos a fichero (./tmp/df_transformado(light-oauth2-data-1720131248.tar).parquet)    N_ejecucion =  151
# Exportado datos a fichero (./tmp/df_transformado(light-oauth2-data-1720134848.tar).parquet)    N_ejecucion =  152
# Exportado datos a fichero (./tmp/df_transformado(light-oauth2-data-1720138444.tar).parquet)    N_ejecucion =  153
# Exportado datos a fichero (./tmp/df_transformado(light-oauth2-data-1720142050.tar).parquet)    N_ejecucion =  154
# Exportado datos a fichero (./tmp/df_transformado(light-oauth2-data-1720145647.tar).parquet)    N_ejecucion =  155
# Exportado datos a fichero (./tmp/df_transformado(light-oauth2-data-1720149242.tar).parquet)    N_ejecucion =  156
# Exportado datos a fichero (./tmp/df_transformado(light-oauth2-data-1720152848.tar).parquet)    N_ejecucion =  157
# Exportado datos a fichero (./tmp/df_transformado(light-oauth2-data-1720156450.tar).parquet)    N_ejecucion =  158
# Exportado datos a fichero (./tmp/df_transformado(light-oauth2-data-1720160044.tar).parquet)    N_ejecucion =  159
# Exportado datos a fichero (./tmp/df_transformado(light-oauth2-data-1720163645.tar).parquet)    N_ejecucion =  160
# Exportado datos a fichero (./tmp/df_transformado(light-oauth2-data-1720167247.tar).parquet)    N_ejecucion =  161
# Exportado datos a fichero (./tmp/df_transformado(light-oauth2-data-1720170845.tar).parquet)    N_ejecucion =  162
# Exportado datos a fichero (./tmp/df_transformado(light-oauth2-data-1720174445.tar).parquet)    N_ejecucion =  163
# Exportado datos a fichero (./tmp/df_transformado(light-oauth2-data-1720178048.tar).parquet)    N_ejecucion =  164
# Exportado datos a fichero (./tmp/df_transformado(light-oauth2-data-1720181644.tar).parquet)    N_ejecucion =  165
# Exportado datos a fichero (./tmp/df_transformado(light-oauth2-data-1720185247.tar).parquet)    N_ejecucion =  166
# Exportado datos a fichero (./tmp/df_transformado(light-oauth2-data-1720188845.tar).parquet)    N_ejecucion =  167
# Exportado datos a fichero (./tmp/df_transformado(light-oauth2-data-1720192447.tar).parquet)    N_ejecucion =  168
# Exportado datos a fichero (./tmp/df_transformado(light-oauth2-data-1720196047.tar).parquet)    N_ejecucion =  169
# Exportado datos a fichero (./tmp/df_transformado(light-oauth2-data-1720199646.tar).parquet)    N_ejecucion =  170
# Exportado datos a fichero (./tmp/df_transformado(light-oauth2-data-1720203236.tar).parquet)    N_ejecucion =  171
# Exportado datos a fichero (./tmp/df_transformado(light-oauth2-data-1720206843.tar).parquet)    N_ejecucion =  172
# Exportado datos a fichero (./tmp/df_transformado(light-oauth2-data-1720210444.tar).parquet)    N_ejecucion =  173
# Exportado datos a fichero (./tmp/df_transformado(light-oauth2-data-1720214052.tar).parquet)    N_ejecucion =  174
# Exportado datos a fichero (./tmp/df_transformado(light-oauth2-data-1720217652.tar).parquet)    N_ejecucion =  175
# Exportado datos a fichero (./tmp/df_transformado(light-oauth2-data-1720221244.tar).parquet)    N_ejecucion =  176
# Exportado datos a fichero (./tmp/df_transformado(light-oauth2-data-1720224852.tar).parquet)    N_ejecucion =  177
# Exportado datos a fichero (./tmp/df_transformado(light-oauth2-data-1720228454.tar).parquet)    N_ejecucion =  178
# Exportado datos a fichero (./tmp/df_transformado(light-oauth2-data-1720232048.tar).parquet)    N_ejecucion =  179
# Exportado datos a fichero (./tmp/df_transformado(light-oauth2-data-1720235646.tar).parquet)    N_ejecucion =  180
# Exportado datos a fichero (./tmp/df_transformado(light-oauth2-data-1720239250.tar).parquet)    N_ejecucion =  181
# Exportado datos a fichero (./tmp/df_transformado(light-oauth2-data-1720242847.tar).parquet)    N_ejecucion =  182
# Exportado datos a fichero (./tmp/df_transformado(light-oauth2-data-1720246448.tar).parquet)    N_ejecucion =  183
# Exportado datos a fichero (./tmp/df_transformado(light-oauth2-data-1720250050.tar).parquet)    N_ejecucion =  184
# Exportado datos a fichero (./tmp/df_transformado(light-oauth2-data-1720253649.tar).parquet)    N_ejecucion =  185
# Exportado datos a fichero (./tmp/df_transformado(light-oauth2-data-1720257246.tar).parquet)    N_ejecucion =  186
# Exportado datos a fichero (./tmp/df_transformado(light-oauth2-data-1720260846.tar).parquet)    N_ejecucion =  187
# Exportado datos a fichero (./tmp/df_transformado(light-oauth2-data-1720264444.tar).parquet)    N_ejecucion =  188
# Exportado datos a fichero (./tmp/df_transformado(light-oauth2-data-1720268044.tar).parquet)    N_ejecucion =  189
# Exportado datos a fichero (./tmp/df_transformado(light-oauth2-data-1720271645.tar).parquet)    N_ejecucion =  190
# Exportado datos a fichero (./tmp/df_transformado(light-oauth2-data-1720275247.tar).parquet)    N_ejecucion =  191
# Exportado datos a fichero (./tmp/df_transformado(light-oauth2-data-1720278846.tar).parquet)    N_ejecucion =  192
# Exportado datos a fichero (./tmp/df_transformado(light-oauth2-data-1720282446.tar).parquet)    N_ejecucion =  193
# Exportado datos a fichero (./tmp/df_transformado(light-oauth2-data-1720286046.tar).parquet)    N_ejecucion =  194
# Exportado datos a fichero (./tmp/df_transformado(light-oauth2-data-1720289643.tar).parquet)    N_ejecucion =  195
# Exportado datos a fichero (./tmp/df_transformado(light-oauth2-data-1720293245.tar).parquet)    N_ejecucion =  196
# Exportado datos a fichero (./tmp/df_transformado(light-oauth2-data-1720296845.tar).parquet)    N_ejecucion =  197
# Exportado datos a fichero (./tmp/df_transformado(light-oauth2-data-1720300451.tar).parquet)    N_ejecucion =  198
# Exportado datos a fichero (./tmp/df_transformado(light-oauth2-data-1720304049.tar).parquet)    N_ejecucion =  199
# Exportado datos a fichero (./tmp/df_transformado(light-oauth2-data-1720307658.tar).parquet)    N_ejecucion =  200
# Exportado datos a fichero (./tmp/df_transformado(light-oauth2-data-1720311251.tar).parquet)    N_ejecucion =  201
# Exportado datos a fichero (./tmp/df_transformado(light-oauth2-data-1720314851.tar).parquet)    N_ejecucion =  202
# Exportado datos a fichero (./tmp/df_transformado(light-oauth2-data-1720318446.tar).parquet)    N_ejecucion =  203
# Exportado datos a fichero (./tmp/df_transformado(light-oauth2-data-1720322044.tar).parquet)    N_ejecucion =  204
# Exportado datos a fichero (./tmp/df_transformado(light-oauth2-data-1720325646.tar).parquet)    N_ejecucion =  205
# Exportado datos a fichero (./tmp/df_transformado(light-oauth2-data-1720329244.tar).parquet)    N_ejecucion =  206
# Exportado datos a fichero (./tmp/df_transformado(light-oauth2-data-1720332841.tar).parquet)    N_ejecucion =  207
# Exportado datos a fichero (./tmp/df_transformado(light-oauth2-data-1720336447.tar).parquet)    N_ejecucion =  208
# Exportado datos a fichero (./tmp/df_transformado(light-oauth2-data-1720340042.tar).parquet)    N_ejecucion =  209
# Exportado datos a fichero (./tmp/df_transformado(light-oauth2-data-1720343645.tar).parquet)    N_ejecucion =  210
# Exportado datos a fichero (./tmp/df_transformado(light-oauth2-data-1720347244.tar).parquet)    N_ejecucion =  211
# Exportado datos a fichero (./tmp/df_transformado(light-oauth2-data-1720350846.tar).parquet)    N_ejecucion =  212
# Exportado datos a fichero (./tmp/df_transformado(light-oauth2-data-1720354444.tar).parquet)    N_ejecucion =  213
# Exportado datos a fichero (./tmp/df_transformado(light-oauth2-data-1720358050.tar).parquet)    N_ejecucion =  214
# Exportado datos a fichero (./tmp/df_transformado(light-oauth2-data-1720361644.tar).parquet)    N_ejecucion =  215
# Exportado datos a fichero (./tmp/df_transformado(light-oauth2-data-1720365244.tar).parquet)    N_ejecucion =  216
# Exportado datos a fichero (./tmp/df_transformado(light-oauth2-data-1720368844.tar).parquet)    N_ejecucion =  217
# Exportado datos a fichero (./tmp/df_transformado(light-oauth2-data-1720372448.tar).parquet)    N_ejecucion =  218
# Exportado datos a fichero (./tmp/df_transformado(light-oauth2-data-1720376047.tar).parquet)    N_ejecucion =  219
# Exportado datos a fichero (./tmp/df_transformado(light-oauth2-data-1720379645.tar).parquet)    N_ejecucion =  220
# Exportado datos a fichero (./tmp/df_transformado(light-oauth2-data-1720383242.tar).parquet)    N_ejecucion =  221
# Exportado datos a fichero (./tmp/df_transformado(light-oauth2-data-1720386850.tar).parquet)    N_ejecucion =  222
# Exportado datos a fichero (./tmp/df_transformado(light-oauth2-data-1720390450.tar).parquet)    N_ejecucion =  223
# Exportado datos a fichero (./tmp/df_transformado(light-oauth2-data-1720394053.tar).parquet)    N_ejecucion =  224
# Exportado datos a fichero (./tmp/df_transformado(light-oauth2-data-1720397649.tar).parquet)    N_ejecucion =  225
# Exportado datos a fichero (./tmp/df_transformado(light-oauth2-data-1720401250.tar).parquet)    N_ejecucion =  226
# Exportado datos a fichero (./tmp/df_transformado(light-oauth2-data-1720404847.tar).parquet)    N_ejecucion =  227
# Exportado datos a fichero (./tmp/df_transformado(light-oauth2-data-1720408447.tar).parquet)    N_ejecucion =  228
# Exportado datos a fichero (./tmp/df_transformado(light-oauth2-data-1720412046.tar).parquet)    N_ejecucion =  229
# Exportado datos a fichero (./tmp/df_transformado(light-oauth2-data-1720415646.tar).parquet)    N_ejecucion =  230
# Exportado datos a fichero (./tmp/df_transformado(light-oauth2-data-1720419248.tar).parquet)    N_ejecucion =  231
# Exportado datos a fichero (./tmp/df_transformado(light-oauth2-data-1720422844.tar).parquet)    N_ejecucion =  232
# Exportado datos a fichero (./tmp/df_transformado(light-oauth2-data-1720426446.tar).parquet)    N_ejecucion =  233
# Exportado datos a fichero (./tmp/df_transformado(light-oauth2-data-1720430044.tar).parquet)    N_ejecucion =  234
# Exportado datos a fichero (./tmp/df_transformado(light-oauth2-data-1720433650.tar).parquet)    N_ejecucion =  235
# Exportado datos a fichero (./tmp/df_transformado(light-oauth2-data-1720437246.tar).parquet)    N_ejecucion =  236
# Exportado datos a fichero (./tmp/df_transformado(light-oauth2-data-1720440845.tar).parquet)    N_ejecucion =  237
# Exportado datos a fichero (./tmp/df_transformado(light-oauth2-data-1720444444.tar).parquet)    N_ejecucion =  238
# ...
# Exportado datos a fichero (./tmp/df_transformado(light-oauth2-data-1725585292.tar).parquet)    N_ejecucion = 1653
# Exportado datos a fichero (./tmp/df_transformado(light-oauth2-data-1725588896.tar).parquet)    N_ejecucion = 1654
# Exportado datos a fichero (./tmp/df_transformado(light-oauth2-data-1725592488.tar).parquet)    N_ejecucion = 1655
# Exportado datos a fichero (./tmp/df_transformado(light-oauth2-data-1725596091.tar).parquet)    N_ejecucion = 1656
# Exportado datos a fichero (./tmp/df_transformado(light-oauth2-data-1725599698.tar).parquet)    N_ejecucion = 1657
# Exportado datos a fichero (./tmp/df_transformado(light-oauth2-data-1725603305.tar).parquet)    N_ejecucion = 1658
# Exportado datos a fichero (./tmp/df_transformado(light-oauth2-data-1725606912.tar).parquet)    N_ejecucion = 1659
# Exportado datos a fichero (./tmp/df_transformado(light-oauth2-data-1725610500.tar).parquet)    N_ejecucion = 1660
# Exportado datos a fichero (./tmp/df_transformado(light-oauth2-data-1725614103.tar).parquet)    N_ejecucion = 1661
# Exportado datos a fichero (./tmp/df_transformado(light-oauth2-data-1725617700.tar).parquet)    N_ejecucion = 1662
# Exportado datos a fichero (./tmp/df_transformado(light-oauth2-data-1725621299.tar).parquet)    N_ejecucion = 1663
# Exportado datos a fichero (./tmp/df_transformado(light-oauth2-data-1725624899.tar).parquet)    N_ejecucion = 1664
# Exportado datos a fichero (./tmp/df_transformado(light-oauth2-data-1725628495.tar).parquet)    N_ejecucion = 1665
# Exportado datos a fichero (./tmp/df_transformado(light-oauth2-data-1725632089.tar).parquet)    N_ejecucion = 1666
# Exportado datos a fichero (./tmp/df_transformado(light-oauth2-data-1725635691.tar).parquet)    N_ejecucion = 1667
# Exportado datos a fichero (./tmp/df_transformado(light-oauth2-data-1725639292.tar).parquet)    N_ejecucion = 1668
# Exportado datos a fichero (./tmp/df_transformado(light-oauth2-data-1725642894.tar).parquet)    N_ejecucion = 1669
# Exportado datos a fichero (./tmp/df_transformado(light-oauth2-data-1725646495.tar).parquet)    N_ejecucion = 1670
# Exportado datos a fichero (./tmp/df_transformado(light-oauth2-data-1725650093.tar).parquet)    N_ejecucion = 1671
# Exportado datos a fichero (./tmp/df_transformado(light-oauth2-data-1725653694.tar).parquet)    N_ejecucion = 1672
# Exportado datos a fichero (./tmp/df_transformado(light-oauth2-data-1725657319.tar).parquet)    N_ejecucion = 1673
# Exportado datos a fichero (./tmp/df_transformado(light-oauth2-data-1725660938.tar).parquet)    N_ejecucion = 1674
# Exportado datos a fichero (./tmp/df_transformado(light-oauth2-data-1725664517.tar).parquet)    N_ejecucion = 1675
# Exportado datos a fichero (./tmp/df_transformado(light-oauth2-data-1725668109.tar).parquet)    N_ejecucion = 1676
# Exportado datos a fichero (./tmp/df_transformado(light-oauth2-data-1725671714.tar).parquet)    N_ejecucion = 1677
# Exportado datos a fichero (./tmp/df_transformado(light-oauth2-data-1725675301.tar).parquet)    N_ejecucion = 1678
# Exportado datos a fichero (./tmp/df_transformado(light-oauth2-data-1725678896.tar).parquet)    N_ejecucion = 1679
# Exportado datos a fichero (./tmp/df_transformado(light-oauth2-data-1725682510.tar).parquet)    N_ejecucion = 1680
# Exportado datos a fichero (./tmp/df_transformado(light-oauth2-data-1725686082.tar).parquet)    N_ejecucion = 1681
# Exportado datos a fichero (./tmp/df_transformado(light-oauth2-data-1725689692.tar).parquet)    N_ejecucion = 1682
# Exportado datos a fichero (./tmp/df_transformado(light-oauth2-data-1725693282.tar).parquet)    N_ejecucion = 1683
# Exportado datos a fichero (./tmp/df_transformado(light-oauth2-data-1725696891.tar).parquet)    N_ejecucion = 1684
# Exportado datos a fichero (./tmp/df_transformado(light-oauth2-data-1725700496.tar).parquet)    N_ejecucion = 1685
# Exportado datos a fichero (./tmp/df_transformado(light-oauth2-data-1725704096.tar).parquet)    N_ejecucion = 1686
# Exportado datos a fichero (./tmp/df_transformado(light-oauth2-data-1725707682.tar).parquet)    N_ejecucion = 1687
# Exportado datos a fichero (./tmp/df_transformado(light-oauth2-data-1725711292.tar).parquet)    N_ejecucion = 1688
# Exportado datos a fichero (./tmp/df_transformado(light-oauth2-data-1725714910.tar).parquet)    N_ejecucion = 1689
# Exportado datos a fichero (./tmp/df_transformado(light-oauth2-data-1725718493.tar).parquet)    N_ejecucion = 1690
# Exportado datos a fichero (./tmp/df_transformado(light-oauth2-data-1725722091.tar).parquet)    N_ejecucion = 1691
# Exportado datos a fichero (./tmp/df_transformado(light-oauth2-data-1725725699.tar).parquet)    N_ejecucion = 1692
# Exportado datos a fichero (./tmp/df_transformado(light-oauth2-data-1725729296.tar).parquet)    N_ejecucion = 1693
# Exportado datos a fichero (./tmp/df_transformado(light-oauth2-data-1725732897.tar).parquet)    N_ejecucion = 1694
# Exportado datos a fichero (./tmp/df_transformado(light-oauth2-data-1725736492.tar).parquet)    N_ejecucion = 1695
# Exportado datos a fichero (./tmp/df_transformado(light-oauth2-data-1725740098.tar).parquet)    N_ejecucion = 1696
# Exportado datos a fichero (./tmp/df_transformado(light-oauth2-data-1725743702.tar).parquet)    N_ejecucion = 1697
# Exportado datos a fichero (./tmp/df_transformado(light-oauth2-data-1725747295.tar).parquet)    N_ejecucion = 1698
# Exportado datos a fichero (./tmp/df_transformado(light-oauth2-data-1725750888.tar).parquet)    N_ejecucion = 1699
# Exportado datos a fichero (./tmp/df_transformado(light-oauth2-data-1725754487.tar).parquet)    N_ejecucion = 1700
# Exportado datos a fichero (./tmp/df_transformado(light-oauth2-data-1725758085.tar).parquet)    N_ejecucion = 1701
# Exportado datos a fichero (./tmp/df_transformado(light-oauth2-data-1725761702.tar).parquet)    N_ejecucion = 1702
# Exportado datos a fichero (./tmp/df_transformado(light-oauth2-data-1725765281.tar).parquet)    N_ejecucion = 1703
# Exportado datos a fichero (./tmp/df_transformado(light-oauth2-data-1725768887.tar).parquet)    N_ejecucion = 1704
# Exportado datos a fichero (./tmp/df_transformado(light-oauth2-data-1725772496.tar).parquet)    N_ejecucion = 1705
# Exportado datos a fichero (./tmp/df_transformado(light-oauth2-data-1725776095.tar).parquet)    N_ejecucion = 1706
# Exportado datos a fichero (./tmp/df_transformado(light-oauth2-data-1725779696.tar).parquet)    N_ejecucion = 1707
# Exportado datos a fichero (./tmp/df_transformado(light-oauth2-data-1725783292.tar).parquet)    N_ejecucion = 1708
# Exportado datos a fichero (./tmp/df_transformado(light-oauth2-data-1725786898.tar).parquet)    N_ejecucion = 1709
# Exportado datos a fichero (./tmp/df_transformado(light-oauth2-data-1725790495.tar).parquet)    N_ejecucion = 1710
# Exportado datos a fichero (./tmp/df_transformado(light-oauth2-data-1725794091.tar).parquet)    N_ejecucion = 1711
# Exportado datos a fichero (./tmp/df_transformado(light-oauth2-data-1725797698.tar).parquet)    N_ejecucion = 1712
# Exportado datos a fichero (./tmp/df_transformado(light-oauth2-data-1725801294.tar).parquet)    N_ejecucion = 1713
# Exportado datos a fichero (./tmp/df_transformado(light-oauth2-data-1725804888.tar).parquet)    N_ejecucion = 1714
# Exportado datos a fichero (./tmp/df_transformado(light-oauth2-data-1725808486.tar).parquet)    N_ejecucion = 1715
# Exportado datos a fichero (./tmp/df_transformado(light-oauth2-data-1725812092.tar).parquet)    N_ejecucion = 1716
# Exportado datos a fichero (./tmp/df_transformado(light-oauth2-data-1725815704.tar).parquet)    N_ejecucion = 1717
# Exportado datos a fichero (./tmp/df_transformado(light-oauth2-data-1725819289.tar).parquet)    N_ejecucion = 1718
# Exportado datos a fichero (./tmp/df_transformado(light-oauth2-data-1725822893.tar).parquet)    N_ejecucion = 1719
# Exportado datos a fichero (./tmp/df_transformado(light-oauth2-data-1725826493.tar).parquet)    N_ejecucion = 1720
# Exportado datos a fichero (./tmp/df_transformado(light-oauth2-data-1725830108.tar).parquet)    N_ejecucion = 1721
# Exportado datos a fichero (./tmp/df_transformado(light-oauth2-data-1725833703.tar).parquet)    N_ejecucion = 1722
# Exportado datos a fichero (./tmp/df_transformado(light-oauth2-data-1725837302.tar).parquet)    N_ejecucion = 1723
# Exportado datos a fichero (./tmp/df_transformado(light-oauth2-data-1725840904.tar).parquet)    N_ejecucion = 1724
# Exportado datos a fichero (./tmp/df_transformado(light-oauth2-data-1725844489.tar).parquet)    N_ejecucion = 1725
# Exportado datos a fichero (./tmp/df_transformado(light-oauth2-data-1725848096.tar).parquet)    N_ejecucion = 1726
# Exportado datos a fichero (./tmp/df_transformado(light-oauth2-data-1725851689.tar).parquet)    N_ejecucion = 1727
# Exportado datos a fichero (./tmp/df_transformado(light-oauth2-data-1725855291.tar).parquet)    N_ejecucion = 1728
# Exportado datos a fichero (./tmp/df_transformado(light-oauth2-data-1725858922.tar).parquet)    N_ejecucion = 1729
# Exportado datos a fichero (./tmp/df_transformado(light-oauth2-data-1725862507.tar).parquet)    N_ejecucion = 1730
# Exportado datos a fichero (./tmp/df_transformado(light-oauth2-data-1725866154.tar).parquet)    N_ejecucion = 1731
# Exportado datos a fichero (./tmp/df_transformado(light-oauth2-data-1725869703.tar).parquet)    N_ejecucion = 1732

# %%
# Out:
# ./tmp/df_transformado(light-oauth2-data-1719592986.tar).parquet
