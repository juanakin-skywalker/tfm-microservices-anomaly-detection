# %%
from timescale import TimescaleDBManager
from dotenv import load_dotenv
from sqlalchemy import create_engine
import pandas as pd
import os
from sklearn.model_selection import train_test_split
from sklearn.ensemble import IsolationForest
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay
from sklearn.metrics import classification_report
import matplotlib.pyplot as plt
import numpy as np

# %%
load_dotenv()
user_env        = os.getenv("USER_DB")
pass_env        = os.getenv("PASS_DB")
host_env        = os.getenv("HOST_DB", "localhost")
port_env        = os.getenv("DB_PORT_EXPOSED", "5432")
db_env          = os.getenv("NAME_DB", "tfm_db")
FOLDER_SALIDA   = os.getenv("FOLDER_SALIDA")
FOLDER_TMP      = os.getenv("FOLDER_TMP")

SEED            = 1 #int(os.getenv("SEED"))

db = TimescaleDBManager(
    user=user_env,
    password=pass_env,
    host=host_env,
    port=port_env,
    dbname=db_env
)
db.conectar()
conexion_postgresql = db.connection

#esto es para usar una conexion postgrews para pandas que da un warning indicando que solo esta testeado para sqlalchemy
engine = create_engine(f'postgresql+psycopg2://{user_env}:{pass_env}@{host_env}:{port_env}/{db_env}')
# Out:
# 🔌 [OK] Conexión establecida con TimescaleDB.

# %%
SQL='select * from vectores'
df = pd.read_sql(SQL, engine)

# %%
lista_label = df['label'].unique().tolist()

# %%
len(lista_label)
# Out:
# 54

# %%
df_result=df[ ['vector_id','execution_name','label'] ].copy()
df_result['split_type'] = 'unknown'

# %%
df_result
# Out:
#        vector_id                    execution_name  \
# 0             54  light-oauth2-data-1719592986.tar
# 1             55  light-oauth2-data-1719592986.tar
# 2             56  light-oauth2-data-1719592986.tar
# 3             57  light-oauth2-data-1719592986.tar
# 4             58  light-oauth2-data-1719592986.tar
# ...          ...                               ...
# 90185      90239  light-oauth2-data-1725866154.tar
# 90186      90240  light-oauth2-data-1725866154.tar
# 90187      90241  light-oauth2-data-1725866154.tar
# 90188      90242  light-oauth2-data-1725866154.tar
# 90189      90243  light-oauth2-data-1725866154.tar
#
#                                     label split_type
# 0                                 correct    unknown
# 1                                 correct    unknown
# 2                                 correct    unknown
# 3                                 correct    unknown
# 4                                 correct    unknown
# ...                                   ...        ...
# 90185             delete_user_404_no_user    unknown
# 90186  update_password_401_wrong_password    unknown
# 90187  update_password_404_user_not_found    unknown
# 90188       update_password_400_not_match    unknown
# 90189       update_password_400_not_match    unknown
#
# [90190 rows x 4 columns]

# %% [markdown]
# # <span style="color:#2ca02c">1. Separamos conjutnos de train, val y test</span>

# %% [markdown]
# <span style="color:#2ca02c">Por cada label dividimos los datos en train, val y test</span>

# %%
dic_idx_train = {}
dic_idx_resto = {}
dic_idx_val   = {}
dic_idx_test  = {}

# %%
for label in lista_label:
    indices = df[ df['label']== label ].index.values
    idx_train, idx_resto = train_test_split(indices   , test_size=0.4 , random_state=SEED)
    idx_val,   idx_test  = train_test_split(idx_resto , test_size=0.5 , random_state=SEED)
    df_result.loc[idx_train , 'split_type'] = 'train'
    df_result.loc[idx_val   , 'split_type'] = 'val'
    df_result.loc[idx_test  , 'split_type'] = 'test'
    dic_idx_train[label] = idx_train
    dic_idx_resto[label] = idx_resto
    dic_idx_val[label]   = idx_val
    dic_idx_test[label]  = idx_test

df_reparto = pd.DataFrame({
    'Cantidad': df_result['split_type'].value_counts(),
    'Porcentaje (%)': (df_result['split_type'].value_counts(normalize=True) * 100).round(2)
})

print("Reparto porcentual de los datos:")
display(df_reparto)
# Out:
# Reparto porcentual de los datos:
#             Cantidad  Porcentaje (%)
# split_type
# train          54093           59.98
# test           18058           20.02
# val            18039           20.00

# %%
df_result
# Out:
#        vector_id                    execution_name  \
# 0             54  light-oauth2-data-1719592986.tar
# 1             55  light-oauth2-data-1719592986.tar
# 2             56  light-oauth2-data-1719592986.tar
# 3             57  light-oauth2-data-1719592986.tar
# 4             58  light-oauth2-data-1719592986.tar
# ...          ...                               ...
# 90185      90239  light-oauth2-data-1725866154.tar
# 90186      90240  light-oauth2-data-1725866154.tar
# 90187      90241  light-oauth2-data-1725866154.tar
# 90188      90242  light-oauth2-data-1725866154.tar
# 90189      90243  light-oauth2-data-1725866154.tar
#
#                                     label split_type
# 0                                 correct      train
# 1                                 correct      train
# 2                                 correct      train
# 3                                 correct      train
# 4                                 correct       test
# ...                                   ...        ...
# 90185             delete_user_404_no_user      train
# 90186  update_password_401_wrong_password      train
# 90187  update_password_404_user_not_found      train
# 90188       update_password_400_not_match       test
# 90189       update_password_400_not_match        val
#
# [90190 rows x 4 columns]

# %%
# indices_correct = df[ df['label']=='correct'].index.values
# idx_correct_train, idx_correct_resto = train_test_split(indices_correct, test_size=0.4, random_state=SEED)
# idx_correct_val, idx_correct_test    = train_test_split(idx_correct_resto, test_size=0.5, random_state=SEED)
# df_result.loc[idx_correct_train , 'split_type'] = 'train'
# df_result.loc[idx_correct_val   , 'split_type'] = 'val'
# df_result.loc[idx_correct_test  , 'split_type'] = 'test'

# %% [markdown]
# <span style="color:#2ca02c"> Convetimos los vectores del df en una matriz, seran los datos que pasemos a los algoritmo   </span>

# %%
X_matrix = np.array(df['vector'].tolist())
X_matrix.shape
# Out:
# (90190, 118)

# %%
#idx_correct_train = df_result[(df_result['label'] == 'correct') & (df_result['split_type'] == 'train')].index.tolist()

# %% [markdown]
# # <span style="color:#2ca02c">2. Usamos Isolation Forest (IF) para </span>

# %% [markdown]
# <span style="color:#2ca02c"> Entrenamos IF con los datos del split 'train' y label 'correct'   </span>

# %%
idx_correct_train = dic_idx_train['correct']
idx_correct_val   = dic_idx_val['correct']
idx_correct_test  = dic_idx_test['correct']

# %%
len(idx_correct_train)
# Out:
# 10231

# %%
idx_correct_val
# Out:
# array([34000, 37762, 10740, ..., 33631, 13467, 82984], shape=(3410,))

# %%
idx_correct_test
# Out:
# array([86473, 34997, 32123, ...,  3455, 65582, 21996], shape=(3411,))

# %%
#X_correct = df[ df['label']=='correct']['vector']

# %%
#X_correct_matrix = np.array(X_correct.tolist())

# %%
#X_correct_matrix.shape

# %%
X_matrix.shape
# Out:
# (90190, 118)

# %%
X_correct_train = X_matrix[idx_correct_train]
X_correct_test  = X_matrix[idx_correct_test]

# %%
model = IsolationForest(
    n_estimators=200, 
    max_samples='auto', 
    contamination='auto', 
    random_state=42
)

# %%
model.fit(X_correct_train)
# Out:
# IsolationForest(n_estimators=200, random_state=42)

# %%
scores = model.decision_function(X_correct_test)

# %%
Y_pred = model.predict(X_correct_test)

# %%
Y_pred
# Out:
# array([ 1,  1, -1, ...,  1,  1,  1], shape=(3411,))

# %%
 df.loc[idx_correct_test].shape
# Out:
# (3411, 5)

# %%
len(Y_pred)
# Out:
# 3411

# %%
df.shape
# Out:
# (90190, 5)

# %%
df_result = pd.DataFrame({
    't_rel': df.loc[idx_correct_test, 't_rel'],
    'execution_name': df.loc[idx_correct_test, 'execution_name'],
    'label': df.loc[idx_correct_test, 'label'],
    'score': scores,
    'Y_pred': Y_pred
})

# %%
scores.shape
# Out:
# (3411,)

# %%
df_result.loc[idx_correct_test, 'result_test1'] = Y_pred
df_result.loc[idx_correct_test, 'score_test1']  = scores

# %%
len(Y_pred)
# Out:
# 3411

# %%
df_result
# Out:
#        t_rel                    execution_name    label     score  Y_pred  \
# 86473   10.0  light-oauth2-data-1725621299.tar  correct  0.066495       1
# 34997   45.0  light-oauth2-data-1722010447.tar  correct  0.073341       1
# 32123   45.0  light-oauth2-data-1721812449.tar  correct -0.012510      -1
# 57393   20.0  light-oauth2-data-1723637676.tar  correct  0.106536       1
# 54983   50.0  light-oauth2-data-1723464883.tar  correct  0.029702       1
# ...      ...                               ...      ...       ...     ...
# 58032    5.0  light-oauth2-data-1723680877.tar  correct  0.075545       1
# 49000   50.0  light-oauth2-data-1723032856.tar  correct  0.079840       1
# 3455    20.0  light-oauth2-data-1719828844.tar  correct  0.111800       1
# 65582   25.0  light-oauth2-data-1724199279.tar  correct  0.128147       1
# 21996   25.0  light-oauth2-data-1721114046.tar  correct  0.095529       1
#
#        result_test1  score_test1
# 86473           1.0     0.066495
# 34997           1.0     0.073341
# 32123          -1.0    -0.012510
# 57393           1.0     0.106536
# 54983           1.0     0.029702
# ...             ...          ...
# 58032           1.0     0.075545
# 49000           1.0     0.079840
# 3455            1.0     0.111800
# 65582           1.0     0.128147
# 21996           1.0     0.095529
#
# [3411 rows x 7 columns]

# %%
tabla_resultados = pd.crosstab(
    df_result.loc[idx_correct_test, 'label'], 
    df_result.loc[idx_correct_test, 'result_test1'],
    rownames=['Etiqueta Real'], 
    colnames=['Predicción Modelo']
)

# %%
tabla_resultados
# Out:
# Predicción Modelo  -1.0   1.0
# Etiqueta Real
# correct             114  3297

# %% [markdown]
# <span style="color:#2ca02c"> El modelo identifica como anomalia el 3% de los datos normales que se le proporcionan en el test  </span>

# %%
N_datos_test_por_anomalia = int( len(idx_correct_test)  / (len(lista_label)-1) )

# %%
N_datos_test_por_anomalia
# Out:
# 64

# %%
idx_test =idx_correct_test.copy()
for label in lista_label:
    if label=='correct':
        continue
    if len(dic_idx_test[label])<N_datos_test_por_anomalia:
        idx_test = np.concatenate((idx_test, dic_idx_test[label]))
    else:
        #idx_test.extend(dic_idx_test[label][:N_datos_test_por_anomalia])
        # Corrección: pon los dos arrays dentro de un paréntesis
        idx_test = np.concatenate((idx_test, dic_idx_test[label][:N_datos_test_por_anomalia]))

# %%
len(idx_test)
# Out:
# 6781

# %%
X_test  = X_matrix[idx_test]

# %%
scores = model.decision_function(X_test)

# %%
Y_pred = model.predict(X_test)

# %%
Y_pred
# Out:
# array([ 1,  1, -1, ..., -1, -1, -1], shape=(6781,))

# %%
 df.loc[idx_test].shape
# Out:
# (6781, 5)

# %%
len(Y_pred)
# Out:
# 6781

# %%
df.shape
# Out:
# (90190, 5)

# %%
df_result = pd.DataFrame({
    't_rel': df.loc[idx_test, 't_rel'],
    'execution_name': df.loc[idx_correct_test, 'execution_name'],
    'label': df.loc[idx_test, 'label'],
    'score': scores,
    'Y_pred': Y_pred
})

# %%
scores.shape
# Out:
# (6781,)

# %%
df_result.loc[idx_test, 'result_test2'] = Y_pred
df_result.loc[idx_test, 'score_test2']  = scores

# %%
df_result
# Out:
#        t_rel                    execution_name  \
# 4       25.0  light-oauth2-data-1719592986.tar
# 6       35.0  light-oauth2-data-1719592986.tar
# 107     15.0  light-oauth2-data-1719598443.tar
# 159     15.0  light-oauth2-data-1719602043.tar
# 165     45.0  light-oauth2-data-1719602043.tar
# ...      ...                               ...
# 90132   40.0  light-oauth2-data-1725866154.tar
# 90136   80.0                               NaN
# 90137  105.0                               NaN
# 90147  255.0                               NaN
# 90188  850.0                               NaN
#
#                                    label     score  Y_pred  result_test2  \
# 4                                correct  0.066495       1           1.0
# 6                                correct  0.073341       1           1.0
# 107                              correct -0.012510      -1           1.0
# 159                              correct  0.106536       1           1.0
# 165                              correct  0.029702       1           1.0
# ...                                  ...       ...     ...           ...
# 90132                            correct -0.135521      -1           1.0
# 90136  register_client_400_clientProfile -0.133915      -1          -1.0
# 90137       update_client_400_clientType -0.127787      -1          -1.0
# 90147         update_service_404_user_id -0.120145      -1          -1.0
# 90188      update_password_400_not_match -0.111339      -1          -1.0
#
#        score_test2
# 4         0.069642
# 6         0.091165
# 107       0.096981
# 159       0.104907
# 165       0.088011
# ...            ...
# 90132     0.047179
# 90136    -0.135640
# 90137    -0.089032
# 90147    -0.097647
# 90188    -0.152126
#
# [6781 rows x 7 columns]

# %%
tabla_resultados = pd.crosstab(
    df_result.loc[idx_test, 'label'], 
    df_result.loc[idx_test, 'result_test2'],
    rownames=['Etiqueta Real'], 
    colnames=['Predicción Modelo']
)

# %%
tabla_resultados
# Out:
# Predicción Modelo                              -1.0   1.0
# Etiqueta Real
# access_token_auth_header_error_401               64     0
# access_token_authorization_form_401              64     0
# access_token_client_id_not_found_404             64     0
# access_token_client_secret_wrong_401             64     0
# access_token_form_urlencoded_400                 64     0
# access_token_illegal_grant_type_400              64     0
# access_token_missing_authorization_header_400    64     0
# authorization_code_client_id_missing_400         64     0
# authorization_code_invalid_client_id_404         64     0
# authorization_code_invalid_password_401          64     0
# authorization_code_missing_response_type_400     64     0
# authorization_code_response_not_code_400         64     0
# code_challenge_invalid_format_pkce_400           64     0
# code_challenge_too_long_pkce_400                 64     0
# code_challenge_too_short_pkce_400                64     0
# code_verifier_missing_pkce_400                   64     0
# code_verifier_too_long_pkce_400                  64     0
# code_verifier_too_short_pkce_400                 64     0
# correct                                         114  3297
# delete_client_404_no_client                      64     0
# delete_service_404_no_service                    64     0
# delete_token_404                                 64     0
# delete_user_404_no_user                          64     0
# get_client_404_no_client                         64     0
# get_client_page_400_no_page                      64     0
# get_service_404_no_service                       64     0
# get_service_page_400_no_page                     64     0
# get_token_404                                    64     0
# get_token_page_400_no_page                       64     0
# get_user_404_no_user                             64     0
# get_user_page_400_no_page                        64     0
# invalid_code_challenge_method_pkce_400           64     0
# invalid_code_verifier_format_PKCE_400            64     0
# register_client_400_clientProfile                42     0
# register_client_400_clientType                   64     0
# register_client_404_no_user                      64     0
# register_service_400_service_id                  64     0
# register_service_400_service_type                64     0
# register_service_404_no_user                     64     0
# register_user_400_email_exists                   64     0
# register_user_400_no_password                    64     0
# register_user_400_password_no_match              64     0
# register_user_400_user_exists                    64     0
# update_client_400_clientProfile                  64     0
# update_client_400_clientType                     64     0
# update_client_404_clientId                       64     0
# update_client_404_ownerId                        64     0
# update_password_400_not_match                    64     0
# update_password_401_wrong_password               64     0
# update_password_404_user_not_found               64     0
# update_service_404_service_id                    64     0
# update_service_404_user_id                       64     0
# update_user_404_no_user                          64     0
# verification_failed_pkce_400                     64     0

# %%
y_true = df_result.loc[idx_test, 'label'].apply(lambda x: 1 if x == 'correct' else -1)
y_pred = df_result.loc[idx_test, 'result_test2']

# 2. Generar la matriz
cm = confusion_matrix(y_true, y_pred, labels=[1, -1])

# 3. Visualizarla
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=['Normal (1)', 'Anomalía (-1)'])
disp.plot(cmap='Blues')
plt.title('Matriz de Confusión - Isolation Forest')
plt.show()

# %%
reporte = classification_report(y_true, y_pred, target_names=['Anomalía', 'Normal'])
print(reporte)
# Out:
#               precision    recall  f1-score   support
#
#     Anomalía       0.97      1.00      0.98      3370
#       Normal       1.00      0.97      0.98      3411
#
#     accuracy                           0.98      6781
#    macro avg       0.98      0.98      0.98      6781
# weighted avg       0.98      0.98      0.98      6781
