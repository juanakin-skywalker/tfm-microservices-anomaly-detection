# %%
from timescale import TimescaleDBManager
from dotenv import load_dotenv
from sqlalchemy import create_engine
import pandas as pd
import os
from sklearn.model_selection import train_test_split
from sklearn.ensemble import IsolationForest
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay,accuracy_score, precision_score, recall_score, f1_score
from sklearn.metrics import classification_report
from sklearn.metrics import roc_auc_score, roc_curve, RocCurveDisplay
from sklearn.inspection import permutation_importance
import matplotlib.pyplot as plt
import numpy as np
import joblib
import json
import re

# %%
load_dotenv()
user_env        = os.getenv("USER_DB")
pass_env        = os.getenv("PASS_DB")
host_env        = os.getenv("HOST_DB", "localhost")
port_env        = os.getenv("DB_PORT_EXPOSED", "5432")
db_env          = os.getenv("NAME_DB", "tfm_db")
FOLDER_SALIDA   = os.getenv("FOLDER_SALIDA")
FOLDER_TMP      = os.getenv("FOLDER_TMP")

SEED            = int(os.getenv("SEED"))

db = TimescaleDBManager(
    user=user_env,
    password=pass_env,
    host=host_env,
    port=port_env,
    dbname=db_env
)
db.conectar()
conexion_postgresql = db.connection

#esto es para usar una conexion postgrews para pandas que da un warning indicando que solo esta testeado para sqlalchemy
engine = create_engine(f'postgresql+psycopg2://{user_env}:{pass_env}@{host_env}:{port_env}/{db_env}')
# Out:
# [OK] Conexión establecida con TimescaleDB.

# %%
tabla_origen = 'vectores_logs'
tabla_split  = 'vectores_logs_split'
filename_lista_metric_name_vector = f'{FOLDER_SALIDA}/lista_metricas_filtradas_ord(metricas_logs).json'

# %%
SQL=f'select * from {tabla_origen}'
df = pd.read_sql(SQL, engine)

# %%
lista_label = df['label'].unique().tolist()

# %%
lista_label
# Out:
# ['correct',
#  'register_client_400_clientProfile',
#  'register_client_404_no_user',
#  'update_client_400_clientProfile',
#  'update_client_404_ownerId',
#  'delete_client_404_no_client',
#  'get_client_404_no_client',
#  'register_service_400_service_type',
#  'update_service_404_user_id',
#  'delete_service_404_no_service',
#  'get_service_404_no_service',
#  'authorization_code_invalid_password_401',
#  'authorization_code_missing_response_type_400',
#  'authorization_code_client_id_missing_400',
#  'access_token_illegal_grant_type_400',
#  'access_token_client_secret_wrong_401',
#  'access_token_auth_header_error_401',
#  'access_token_form_urlencoded_400',
#  'invalid_code_challenge_method_pkce_400',
#  'code_challenge_too_long_pkce_400',
#  'code_challenge_invalid_format_pkce_400',
#  'invalid_code_verifier_format_PKCE_400',
#  'code_verifier_too_long_pkce_400',
#  'code_verifier_missing_pkce_400',
#  'get_token_404',
#  'delete_token_404',
#  'register_user_400_user_exists',
#  'register_user_400_email_exists',
#  'register_user_400_no_password',
#  'update_user_404_no_user',
#  'get_user_page_400_no_page',
#  'delete_user_404_no_user',
#  'update_password_401_wrong_password',
#  'update_password_400_not_match',
#  'register_client_400_clientType',
#  'update_client_400_clientType',
#  'update_client_404_clientId',
#  'register_service_404_no_user',
#  'get_service_page_400_no_page',
#  'authorization_code_response_not_code_400',
#  'access_token_client_id_not_found_404',
#  'access_token_missing_authorization_header_400',
#  'code_challenge_too_short_pkce_400',
#  'register_user_400_password_no_match',
#  'get_user_404_no_user',
#  'register_service_400_service_id',
#  'update_service_404_service_id',
#  'access_token_authorization_form_401',
#  'code_verifier_too_short_pkce_400',
#  'verification_failed_pkce_400',
#  'get_token_page_400_no_page',
#  'update_password_404_user_not_found',
#  'get_client_page_400_no_page',
#  'authorization_code_invalid_client_id_404']

# %%
df
# Out:
#        vector_id                    execution_name  \
# 0         115150  light-oauth2-data-1719592986.tar
# 1         115151  light-oauth2-data-1719592986.tar
# 2         115152  light-oauth2-data-1719592986.tar
# 3         115153  light-oauth2-data-1719592986.tar
# 4         115154  light-oauth2-data-1719592986.tar
# ...          ...                               ...
# 44121     159271  light-oauth2-data-1722744859.tar
# 44122     159272  light-oauth2-data-1722744859.tar
# 44123     159273  light-oauth2-data-1722744859.tar
# 44124     159274  light-oauth2-data-1722744859.tar
# 44125     159275  light-oauth2-data-1722744859.tar
#
#                                     label  t_rel  \
# 0                                 correct    0.0
# 1                                 correct    5.0
# 2                                 correct   10.0
# 3                                 correct   15.0
# 4                                 correct   20.0
# ...                                   ...    ...
# 44121                get_user_404_no_user  720.0
# 44122             delete_user_404_no_user  745.0
# 44123  update_password_401_wrong_password  760.0
# 44124  update_password_404_user_not_found  775.0
# 44125       update_password_400_not_match  790.0
#
#                                                   vector
# 0      [-0.9134434576509867, -1.8855995326138877, -1....
# 1      [-0.4776722668450114, -1.1433692806739915, -1....
# 2      [-0.2597866714420238, 0.41147512640699835, 0.5...
# 3      [2.790611664199803, 2.2670507562567392, 1.6855...
# 4      [-0.04190107603903613, 0.7122063491757494, -0....
# ...                                                  ...
# 44121  [-1.258481261360296, 0.816227745785484, -1.261...
# 44122  [-1.0003312590299789, -0.5531925976138607, -0....
# 44123  [-1.0003312590299789, 0.12230622648447075, 0.1...
# 44124  [-1.1294062601951376, -1.1427188440996774, -1....
# 44125  [-1.258481261360296, 0.4416329433309547, -1.11...
#
# [44126 rows x 5 columns]

# %%
df_result=df[ ['vector_id','execution_name','label'] ].copy()
#df_result['split_type'] = 'unknown'

# %%
df_result
# Out:
#        vector_id                    execution_name  \
# 0         115150  light-oauth2-data-1719592986.tar
# 1         115151  light-oauth2-data-1719592986.tar
# 2         115152  light-oauth2-data-1719592986.tar
# 3         115153  light-oauth2-data-1719592986.tar
# 4         115154  light-oauth2-data-1719592986.tar
# ...          ...                               ...
# 44121     159271  light-oauth2-data-1722744859.tar
# 44122     159272  light-oauth2-data-1722744859.tar
# 44123     159273  light-oauth2-data-1722744859.tar
# 44124     159274  light-oauth2-data-1722744859.tar
# 44125     159275  light-oauth2-data-1722744859.tar
#
#                                     label
# 0                                 correct
# 1                                 correct
# 2                                 correct
# 3                                 correct
# 4                                 correct
# ...                                   ...
# 44121                get_user_404_no_user
# 44122             delete_user_404_no_user
# 44123  update_password_401_wrong_password
# 44124  update_password_404_user_not_found
# 44125       update_password_400_not_match
#
# [44126 rows x 3 columns]

# %%
filename_lista_metric_name_vector
# Out:
# 'result/lista_metricas_filtradas_ord(metricas_logs).json'

# %%
with open(filename_lista_metric_name_vector, "r", encoding="utf-8") as f:
    lista_metric_name_vector = json.load(f)

# %%
len(lista_metric_name_vector)
# Out:
# 331

# %%
filename_lista_metric_name_vector
# Out:
# 'result/lista_metricas_filtradas_ord(metricas_logs).json'

# %% [markdown]
# # <span style="color:#2ca02c">1. Recuperamos separación ya hecha en conjuntos de train, val y test</span>

# %%
SQL=f'select * from {tabla_split}'
df_split = pd.read_sql(SQL, engine)

# %%
df_result = pd.merge(df_result, df_split, on="vector_id", how="inner")

# %%
df_result
# Out:
#        vector_id                    execution_name  \
# 0         115150  light-oauth2-data-1719592986.tar
# 1         115151  light-oauth2-data-1719592986.tar
# 2         115152  light-oauth2-data-1719592986.tar
# 3         115153  light-oauth2-data-1719592986.tar
# 4         115154  light-oauth2-data-1719592986.tar
# ...          ...                               ...
# 44121     159271  light-oauth2-data-1722744859.tar
# 44122     159272  light-oauth2-data-1722744859.tar
# 44123     159273  light-oauth2-data-1722744859.tar
# 44124     159274  light-oauth2-data-1722744859.tar
# 44125     159275  light-oauth2-data-1722744859.tar
#
#                                     label split_type
# 0                                 correct       test
# 1                                 correct      train
# 2                                 correct      train
# 3                                 correct      train
# 4                                 correct      train
# ...                                   ...        ...
# 44121                get_user_404_no_user      train
# 44122             delete_user_404_no_user      train
# 44123  update_password_401_wrong_password      train
# 44124  update_password_404_user_not_found      train
# 44125       update_password_400_not_match      train
#
# [44126 rows x 4 columns]

# %%
dic_idx_train = {}
#dic_idx_resto = {}
dic_idx_val   = {}
dic_idx_test  = {}

# %%
for label in lista_label:
    idx_train = df_result[  (df_result['label']==label) & (df_result['split_type'] == 'train') ].index.values
    idx_val   = df_result[  (df_result['label']==label) & (df_result['split_type'] == 'val'  ) ].index.values
    idx_test  = df_result[  (df_result['label']==label) & (df_result['split_type'] == 'test') ].index.values
    dic_idx_train[label] = idx_train
    dic_idx_val[label]   = idx_val
    dic_idx_test[label]  = idx_test

# %%
df_result
# Out:
#        vector_id                    execution_name  \
# 0         115150  light-oauth2-data-1719592986.tar
# 1         115151  light-oauth2-data-1719592986.tar
# 2         115152  light-oauth2-data-1719592986.tar
# 3         115153  light-oauth2-data-1719592986.tar
# 4         115154  light-oauth2-data-1719592986.tar
# ...          ...                               ...
# 44121     159271  light-oauth2-data-1722744859.tar
# 44122     159272  light-oauth2-data-1722744859.tar
# 44123     159273  light-oauth2-data-1722744859.tar
# 44124     159274  light-oauth2-data-1722744859.tar
# 44125     159275  light-oauth2-data-1722744859.tar
#
#                                     label split_type
# 0                                 correct       test
# 1                                 correct      train
# 2                                 correct      train
# 3                                 correct      train
# 4                                 correct      train
# ...                                   ...        ...
# 44121                get_user_404_no_user      train
# 44122             delete_user_404_no_user      train
# 44123  update_password_401_wrong_password      train
# 44124  update_password_404_user_not_found      train
# 44125       update_password_400_not_match      train
#
# [44126 rows x 4 columns]

# %% [markdown]
# <span style="color:#2ca02c"> Convetimos los vectores del df en una matriz, seran los datos que pasemos a los algoritmo   </span>

# %%
X_matrix = np.array(df['vector'].tolist())
X_matrix.shape
# Out:
# (44126, 993)

# %% [markdown]
# # <span style="color:#2ca02c">2. Usamos Isolation Forest (IF) para identificar anomalias</span>

# %% [markdown]
# <span style="color:#2ca02c"> Entrenamos IF con los datos del split 'train' y label 'correct'   </span>

# %%
idx_correct_train = dic_idx_train['correct']
idx_correct_val   = dic_idx_val['correct']
idx_correct_test  = dic_idx_test['correct']

# %%
N_datos_test_por_anomalia = int( len(idx_correct_test)  / (len(lista_label)-1) )

# %%
idx_test = idx_correct_test.copy()
idx_val  = idx_correct_val.copy()
for label in lista_label:
    if label=='correct':
        continue
    if len(dic_idx_test[label])<N_datos_test_por_anomalia:
        idx_test = np.concatenate((idx_test , dic_idx_test[label]))
        idx_val  = np.concatenate((idx_val  , dic_idx_val[label]))
    else:
        #idx_test.extend(dic_idx_test[label][:N_datos_test_por_anomalia])
        # Corrección: pon los dos arrays dentro de un paréntesis
        idx_test = np.concatenate((idx_test , dic_idx_test[label][:N_datos_test_por_anomalia]))
        idx_val  = np.concatenate((idx_val  , dic_idx_val[label][:N_datos_test_por_anomalia]))
        
X_test  = X_matrix[idx_test]
X_val   = X_matrix[idx_val]

# %%
X_correct_train = X_matrix[idx_correct_train]
X_correct_test  = X_matrix[idx_correct_test]

# %%
len(idx_correct_train)
# Out:
# 5297

# %% [markdown]
# ### <span style="color:#2ca02c">2.1. Probamos IF(3 puntos) con varios parametros contaminacion</span>

# %%
df_result = pd.DataFrame({
    't_rel': df.loc[idx_test, 't_rel'],
    'execution_name': df.loc[idx_test, 'execution_name'],
    'label': df.loc[idx_test, 'label']
})

N = 0
lista_result=[]
for contaminacion in [0.02, 0.015, 0.01, 0.008, 0.006, 0.004, 0.0035, 0.003, 0.002, 0.001, 0.0005]:
    N += 1
    model = IsolationForest(
        n_estimators=200, 
        max_samples='auto', 
        #contamination=contaminacion,        
        contamination='auto', 
        random_state=SEED
    )
    model.fit(X_correct_train)
    scores = model.decision_function(X_test)
    Y_pred = model.predict(X_test)

    model_name = f'IF(3 puntos contaminacion={contaminacion})_metricas_logs'
    joblib.dump(model, f'{FOLDER_SALIDA}/models/{model_name}.joblib')
    
    df_result[f'result_({model_name})'] = float('nan')
    df_result[f'scores_({model_name})'] = float('nan')
    df_result.loc[idx_test, f'result_({model_name})'] = Y_pred
    df_result.loc[idx_test, f'scores_({model_name})'] = scores
    
    # Mapeo: 1 para Anomalía (Positivo) y 0 para Normal (Negativo)
    y_true = df_result.loc[idx_test, 'label'].apply(lambda x: 0 if x == 'correct' else 1)
    #y_pred = df_result.loc[idx_test, f'result_({model_name})'].apply(lambda x: 0 if x == 1 else 1)
    y_pred = df_result.loc[idx_test, f'result_({model_name})'].map({1: 0, -1: 1})

    
    # Invertimos los scores para que valores más altos correspondan a la anomalía
    y_scores_roc = -scores 
    roc_auc = roc_auc_score(y_true, y_scores_roc)

    # 1. Componentes de la matriz de confusión
    cm = confusion_matrix(y_true, y_pred, labels=[0, 1])
    tn, fp, fn, tp = cm.ravel()
    
    # 2. Cálculo de métricas
    acc = accuracy_score(y_true, y_pred)
    precision = precision_score(y_true, y_pred, zero_division=0)
    recall = recall_score(y_true, y_pred, zero_division=0)
    specificity = tn / (tn + fp) if (tn + fp) > 0 else 0
    f1 = f1_score(y_true, y_pred, zero_division=0)
    
    print(f'Accuracy    = {acc}')
    print(f'Precision   = {precision}')
    print(f'Recall      = {recall}')
    print(f'Specificity = {specificity}')
    print(f'F1          = {f1}')
    
    parametros = {'contaminacion': contaminacion}
    
    # 3. Guardar en un diccionario de registro
    reg_resultado_algoritmo = {
        'test_name': model_name,
        'parametros': json.dumps(parametros),
        'TP': int(tp),
        'FP': int(fp),
        'TN': int(tn),
        'FN': int(fn),
        'accuracy': float(acc),
        'precision': float(precision),
        'recall': float(recall),
        'specificity': float(specificity),
        'f1_score': float(f1),
        'roc_auc': float(roc_auc)
    }
    lista_result.append(reg_resultado_algoritmo)
    
    # 4. Visualización conjunta (Matriz de Confusión a la izquierda, Curva ROC a la derecha)
    fig, axes = plt.subplots(1, 2, figsize=(12, 5))
    
    # Gráfica izquierda: Matriz de Confusión
    disp_cm = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=['Normal (0)', 'Anomalía (1)'])
    disp_cm.plot(ax=axes[0], cmap='Blues', colorbar=False)
    axes[0].set_title(f'Matriz de Confusión\n{model_name}')
    
    # Gráfica derecha: Curva ROC
    RocCurveDisplay.from_predictions(
        y_true, 
        y_scores_roc, 
        ax=axes[1], 
        name=f'IF (AUC = {roc_auc:.3f})'
    )
    axes[1].plot([0, 1], [0, 1], 'k--', label='Aleatorio (AUC = 0.5)')
    axes[1].set_title(f'Curva ROC\n{model_name}')
    axes[1].legend(loc='lower right')
    
    plt.tight_layout()
    plt.show()

    paquete = {
        'model_name' : model_name,
        'model'      : model,
        'parametros' : {'contaminacion':contaminacion},
        'resultado'  : {'accuracy':acc,'precision':precision,'recall':recall,'f1':f1,'specificity':specificity}
    }
    joblib.dump(paquete, f'{FOLDER_SALIDA}/models/{model_name}.joblib')
    
# DataFrame global final
df_anomaly_detection_summary = pd.DataFrame(lista_result)
# Out:
# Accuracy    = 0.5027027027027027
# Precision   = 0.6666666666666666
# Recall      = 0.0011435105774728416
# Specificity = 0.9994337485843715
# F1          = 0.00228310502283105
# Accuracy    = 0.5027027027027027
# Precision   = 0.6666666666666666
# Recall      = 0.0011435105774728416
# Specificity = 0.9994337485843715
# F1          = 0.00228310502283105
# Accuracy    = 0.5027027027027027
# Precision   = 0.6666666666666666
# Recall      = 0.0011435105774728416
# Specificity = 0.9994337485843715
# F1          = 0.00228310502283105
# Accuracy    = 0.5027027027027027
# Precision   = 0.6666666666666666
# Recall      = 0.0011435105774728416
# Specificity = 0.9994337485843715
# F1          = 0.00228310502283105
# Accuracy    = 0.5027027027027027
# Precision   = 0.6666666666666666
# Recall      = 0.0011435105774728416
# Specificity = 0.9994337485843715
# F1          = 0.00228310502283105
# Accuracy    = 0.5027027027027027
# Precision   = 0.6666666666666666
# Recall      = 0.0011435105774728416
# Specificity = 0.9994337485843715
# F1          = 0.00228310502283105
# Accuracy    = 0.5027027027027027
# Precision   = 0.6666666666666666
# Recall      = 0.0011435105774728416
# Specificity = 0.9994337485843715
# F1          = 0.00228310502283105
# Accuracy    = 0.5027027027027027
# Precision   = 0.6666666666666666
# Recall      = 0.0011435105774728416
# Specificity = 0.9994337485843715
# F1          = 0.00228310502283105
# Accuracy    = 0.5027027027027027
# Precision   = 0.6666666666666666
# Recall      = 0.0011435105774728416
# Specificity = 0.9994337485843715
# F1          = 0.00228310502283105
# Accuracy    = 0.5027027027027027
# Precision   = 0.6666666666666666
# Recall      = 0.0011435105774728416
# Specificity = 0.9994337485843715
# F1          = 0.00228310502283105
# Accuracy    = 0.5027027027027027
# Precision   = 0.6666666666666666
# Recall      = 0.0011435105774728416
# Specificity = 0.9994337485843715
# F1          = 0.00228310502283105

# %% [markdown]
# ### <span style="color:#2ca02c">2.2. Probamos IF(3 puntos) ajustando umbral de decision con indice de Youden</span>

# %%
df_result=df.copy()

# %%
with open(filename_lista_metric_name_vector, "r", encoding="utf-8") as f:
    lista_metric_name_vector = json.load(f)

# %%
X_matrix.shape
# Out:
# (44126, 993)

# %%
df_result=df[ ['vector_id','execution_name','label'] ].copy()

# %%
# 4. Recortamos los datos de entrenamiento y test con este nuevo subconjunto
X_correct_train = X_matrix[idx_correct_train]
X_correct_test  = X_matrix[idx_correct_test]
X_test          = X_matrix[idx_test]
X_val           = X_matrix[idx_val]

# %%
model_name = f'IF(3 puntos umbral indice Youden)_metricas_logs'
N += 1

# 2. Entrenar el Isolation Forest
model = IsolationForest(
    n_estimators=200, 
    max_samples='auto', 
    contamination='auto',        
    random_state=SEED
)
model.fit(X_correct_train)


#usamos el conjunto de validacion para obtener curva ROC y establecer el umbral de decision usnado indice de Youden
#y_true = df_result.iloc[idx_val]['label'].apply(lambda x: 0 if x == 'correct' else 1)
y_true = df_result.loc[idx_val, 'label'].apply(lambda x: 0 if x == 'correct' else 1)
scores = model.decision_function(X_val)
y_scores_roc = -scores  
roc_auc = roc_auc_score(y_true, y_scores_roc)
fpr, tpr, thresholds = roc_curve(y_true, y_scores_roc)
optimal_idx = np.argmax(tpr - fpr)
optimal_threshold = thresholds[optimal_idx]

#calcumamos la prediccion para el conjunto de test
y_true = df_result.loc[idx_test, 'label'].apply(lambda x: 0 if x == 'correct' else 1)
scores = model.decision_function(X_test)
y_scores_roc = -scores  
roc_auc = roc_auc_score(y_true, y_scores_roc)
fpr, tpr, thresholds = roc_curve(y_true, y_scores_roc)
y_pred = (y_scores_roc >= optimal_threshold).astype(int)



# Guardar en el DataFrame global
df_result[f'result_({model_name})'] = float('nan')
df_result[f'scores_({model_name})'] = float('nan')
df_result.loc[idx_test, f'result_({model_name})'] = y_pred
df_result.loc[idx_test, f'scores_({model_name})'] = scores

# 6. Métricas y matriz de confusión
cm = confusion_matrix(y_true, y_pred, labels=[0, 1])
tn, fp, fn, tp = cm.ravel()

acc = accuracy_score(y_true, y_pred)
precision = precision_score(y_true, y_pred, zero_division=0)
recall = recall_score(y_true, y_pred, zero_division=0)
specificity = tn / (tn + fp) if (tn + fp) > 0 else 0
f1 = f1_score(y_true, y_pred, zero_division=0)

print(f'--- {model_name} (Umbral Youden: {optimal_threshold:.4f}) ---')
print(f'Accuracy    = {acc}')
print(f'Precision   = {precision}')
print(f'Recall      = {recall}')
print(f'Specificity = {specificity}')    
print(f'F1          = {f1}')

parametros = {'contaminacion': contaminacion, 'metodo': 'youden', 'umbral_youden': float(optimal_threshold)}

reg_resultado_algoritmo = {
    'test_name': model_name,
    'parametros': json.dumps(parametros),
    'TP': int(tp), 'FP': int(fp), 'TN': int(tn), 'FN': int(fn),
    'accuracy': float(acc),
    'precision': float(precision),
    'recall': float(recall),
    'specificity': float(specificity),
    'f1_score': float(f1),
    'roc_auc': float(roc_auc)
}
lista_result.append(reg_resultado_algoritmo)

# 7. Visualización
fig, axes = plt.subplots(1, 2, figsize=(12, 5))

disp_cm = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=['Normal (0)', 'Anomalía (1)'])
disp_cm.plot(ax=axes[0], cmap='Blues', colorbar=False)
axes[0].set_title(f'Matriz de Confusión \n{model_name}')

RocCurveDisplay.from_predictions(y_true, y_scores_roc, ax=axes[1], name=f'IF (AUC = {roc_auc:.3f})')
axes[1].plot([0, 1], [0, 1], 'k--', label='Aleatorio (AUC = 0.5)')
axes[1].set_title(f'Curva ROC\n{model_name}')
axes[1].legend(loc='lower right')

plt.tight_layout()
plt.show()

paquete = {
    'model_name' : model_name,
    'model'      : model,
    'parametros' : {'contaminacion':contaminacion,'threshold':optimal_threshold},
    'resultado'  : {'accuracy':acc,'precision':precision,'recall':recall,'f1':f1,'specificity':specificity}
}
joblib.dump(paquete, f'{FOLDER_SALIDA}/models/{model_name}.joblib')
# Out:
# --- IF(3 puntos umbral indice Youden)_metricas_logs (Umbral Youden: -0.1234) ---
# Accuracy    = 0.6022759601706971
# Precision   = 0.565168956554029
# Recall      = 0.8702115494568324
# Specificity = 0.3369195922989808
# F1          = 0.6852769022962629
# ['result/models/IF(3 puntos umbral indice Youden)_metricas_logs.joblib']

# %% [markdown]
# ## <span style="color:#2ca02c">2.3.Probamos IF(1 puntos seleccionado cada punto) con varios parametros contaminacion</span>

# %%
with open(filename_lista_metric_name_vector, "r", encoding="utf-8") as f:
    lista_metric_name_vector = json.load(f)

# %%
X_matrix.shape
# Out:
# (44126, 993)

# %%
df_result=df[ ['vector_id','execution_name','label'] ].copy()

# %%
# 1. Elige el tercio que quieres extraer (1, 2 o 3)
tercio_deseado = 2  # Cambia esto a 1, 2 o según convenga

# 2. Calculamos los tamaños y los índices de inicio y fin
num_columnas_total = X_matrix.shape[1]
tercio_n = num_columnas_total // 3  # División entera

inicio_idx = (tercio_deseado - 1) * tercio_n

# Para el último tercio (tercio 3), nos aseguramos de coger hasta el final por si hay decimales sobrantes en la división entera
if tercio_deseado == 3:
    fin_idx = num_columnas_total
else:
    fin_idx = tercio_deseado * tercio_n

print(f"Total de columnas: {num_columnas_total}")
print(f"Extrayendo el tercio {tercio_deseado} (desde la columna {inicio_idx} hasta la {fin_idx})")

# 3. Seleccionamos el tercio correspondiente de las columnas en la matriz global
X_matrix_reducida = X_matrix[:, inicio_idx:fin_idx]

# 4. Recortamos los datos de entrenamiento y test con este nuevo subconjunto
X_correct_train = X_matrix_reducida[idx_correct_train]
X_correct_test  = X_matrix_reducida[idx_correct_test]
X_test          = X_matrix_reducida[idx_test]
X_val           = X_matrix_reducida[idx_val]

# 5. Ajustamos también el vector de nombres de las características para que coincida exactamente
lista_metric_name_vector = lista_metric_name_vector[inicio_idx:fin_idx]
# Out:
# Total de columnas: 993
# Extrayendo el tercio 2 (desde la columna 331 hasta la 662)

# %%
X_matrix_reducida.shape
# Out:
# (44126, 331)

# %%
df_result = pd.DataFrame({
    't_rel': df.loc[idx_test, 't_rel'],
    'execution_name': df.loc[idx_test, 'execution_name'],
    'label': df.loc[idx_test, 'label']
})

N = 0
lista_result=[]
for contaminacion in [0.02, 0.015, 0.01, 0.008, 0.006, 0.004, 0.0035, 0.003, 0.002, 0.001, 0.0005]:
    N += 1
    model = IsolationForest(
        n_estimators=200, 
        max_samples='auto', 
        #contamination=contaminacion,        
        contamination='auto', 
        random_state=SEED
    )
    model.fit(X_correct_train)
    scores = model.decision_function(X_test)
    Y_pred = model.predict(X_test)

    model_name = f'IF(1 punto tercio={tercio_deseado}  contaminacion={contaminacion})_metricas_logs'
    joblib.dump(model, f'{FOLDER_SALIDA}/models/{model_name}.joblib')
    
    df_result[f'result_({model_name})'] = float('nan')
    df_result[f'scores_({model_name})'] = float('nan')
    df_result.loc[idx_test, f'result_({model_name})'] = Y_pred
    df_result.loc[idx_test, f'scores_({model_name})'] = scores
    
    # Mapeo: 1 para Anomalía (Positivo) y 0 para Normal (Negativo)
    y_true = df_result.loc[idx_test, 'label'].apply(lambda x: 0 if x == 'correct' else 1)
    #y_pred = df_result.loc[idx_test, f'result_({model_name})'].apply(lambda x: 0 if x == 1 else 1)
    y_pred = df_result.loc[idx_test, f'result_({model_name})'].map({1: 0, -1: 1})

    
    # Invertimos los scores para que valores más altos correspondan a la anomalía
    y_scores_roc = -scores 
    roc_auc = roc_auc_score(y_true, y_scores_roc)

    # 1. Componentes de la matriz de confusión
    cm = confusion_matrix(y_true, y_pred, labels=[0, 1])
    tn, fp, fn, tp = cm.ravel()
    
    # 2. Cálculo de métricas
    acc = accuracy_score(y_true, y_pred)
    precision = precision_score(y_true, y_pred, zero_division=0)
    recall = recall_score(y_true, y_pred, zero_division=0)
    specificity = tn / (tn + fp) if (tn + fp) > 0 else 0
    f1 = f1_score(y_true, y_pred, zero_division=0)
    
    print(f'Accuracy    = {acc}')
    print(f'Precision   = {precision}')
    print(f'Recall      = {recall}')
    print(f'Specificity = {specificity}')
    print(f'F1          = {f1}')
    
    parametros = {'contaminacion': contaminacion}
    
    # 3. Guardar en un diccionario de registro
    reg_resultado_algoritmo = {
        'test_name': model_name,
        'parametros': json.dumps(parametros),
        'TP': int(tp),
        'FP': int(fp),
        'TN': int(tn),
        'FN': int(fn),
        'accuracy': float(acc),
        'precision': float(precision),
        'recall': float(recall),
        'specificity': float(specificity),
        'f1_score': float(f1),
        'roc_auc': float(roc_auc)
    }
    lista_result.append(reg_resultado_algoritmo)
    
    # 4. Visualización conjunta (Matriz de Confusión a la izquierda, Curva ROC a la derecha)
    fig, axes = plt.subplots(1, 2, figsize=(12, 5))
    
    # Gráfica izquierda: Matriz de Confusión
    disp_cm = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=['Normal (0)', 'Anomalía (1)'])
    disp_cm.plot(ax=axes[0], cmap='Blues', colorbar=False)
    axes[0].set_title(f'Matriz de Confusión\n{model_name}')
    
    # Gráfica derecha: Curva ROC
    RocCurveDisplay.from_predictions(
        y_true, 
        y_scores_roc, 
        ax=axes[1], 
        name=f'IF (AUC = {roc_auc:.3f})'
    )
    axes[1].plot([0, 1], [0, 1], 'k--', label='Aleatorio (AUC = 0.5)')
    axes[1].set_title(f'Curva ROC\n{model_name}')
    axes[1].legend(loc='lower right')
    
    plt.tight_layout()
    plt.show()

    paquete = {
        'model_name' : model_name,
        'model'      : model,
        'parametros' : {'contaminacion':contaminacion},
        'resultado'  : {'accuracy':acc,'precision':precision,'recall':recall,'f1':f1,'specificity':specificity}
    }
    joblib.dump(paquete, f'{FOLDER_SALIDA}/models/{model_name}.joblib')
    
# DataFrame global final
df_anomaly_detection_summary = pd.DataFrame(lista_result)
# Out:
# Accuracy    = 0.5027027027027027
# Precision   = 0.6666666666666666
# Recall      = 0.0011435105774728416
# Specificity = 0.9994337485843715
# F1          = 0.00228310502283105
# Accuracy    = 0.5027027027027027
# Precision   = 0.6666666666666666
# Recall      = 0.0011435105774728416
# Specificity = 0.9994337485843715
# F1          = 0.00228310502283105
# Accuracy    = 0.5027027027027027
# Precision   = 0.6666666666666666
# Recall      = 0.0011435105774728416
# Specificity = 0.9994337485843715
# F1          = 0.00228310502283105
# Accuracy    = 0.5027027027027027
# Precision   = 0.6666666666666666
# Recall      = 0.0011435105774728416
# Specificity = 0.9994337485843715
# F1          = 0.00228310502283105
# Accuracy    = 0.5027027027027027
# Precision   = 0.6666666666666666
# Recall      = 0.0011435105774728416
# Specificity = 0.9994337485843715
# F1          = 0.00228310502283105
# Accuracy    = 0.5027027027027027
# Precision   = 0.6666666666666666
# Recall      = 0.0011435105774728416
# Specificity = 0.9994337485843715
# F1          = 0.00228310502283105
# Accuracy    = 0.5027027027027027
# Precision   = 0.6666666666666666
# Recall      = 0.0011435105774728416
# Specificity = 0.9994337485843715
# F1          = 0.00228310502283105
# Accuracy    = 0.5027027027027027
# Precision   = 0.6666666666666666
# Recall      = 0.0011435105774728416
# Specificity = 0.9994337485843715
# F1          = 0.00228310502283105
# Accuracy    = 0.5027027027027027
# Precision   = 0.6666666666666666
# Recall      = 0.0011435105774728416
# Specificity = 0.9994337485843715
# F1          = 0.00228310502283105
# Accuracy    = 0.5027027027027027
# Precision   = 0.6666666666666666
# Recall      = 0.0011435105774728416
# Specificity = 0.9994337485843715
# F1          = 0.00228310502283105
# Accuracy    = 0.5027027027027027
# Precision   = 0.6666666666666666
# Recall      = 0.0011435105774728416
# Specificity = 0.9994337485843715
# F1          = 0.00228310502283105

# %% [markdown]
# ### <span style="color:#2ca02c">2.4. Probamos IF(1 puntos seleccionado cada punto) ajustando umbral de decision con indice de Youden</span>

# %%
with open(filename_lista_metric_name_vector, "r", encoding="utf-8") as f:
    lista_metric_name_vector = json.load(f)

# %%
X_matrix.shape
# Out:
# (44126, 993)

# %%
df_result=df[ ['vector_id','execution_name','label'] ].copy()

# %%
# 1. Elige el tercio que quieres extraer (1, 2 o 3)
tercio_deseado = 2  # Cambia esto a 1, 2 o según convenga

# 2. Calculamos los tamaños y los índices de inicio y fin
num_columnas_total = X_matrix.shape[1]
tercio_n = num_columnas_total // 3  # División entera

inicio_idx = (tercio_deseado - 1) * tercio_n

# Para el último tercio (tercio 3), nos aseguramos de coger hasta el final por si hay decimales sobrantes en la división entera
if tercio_deseado == 3:
    fin_idx = num_columnas_total
else:
    fin_idx = tercio_deseado * tercio_n

print(f"Total de columnas: {num_columnas_total}")
print(f"Extrayendo el tercio {tercio_deseado} (desde la columna {inicio_idx} hasta la {fin_idx})")

# 3. Seleccionamos el tercio correspondiente de las columnas en la matriz global
X_matrix_reducida = X_matrix[:, inicio_idx:fin_idx]

# 4. Recortamos los datos de entrenamiento y test con este nuevo subconjunto
X_correct_train = X_matrix_reducida[idx_correct_train]
X_correct_test  = X_matrix_reducida[idx_correct_test]
X_test          = X_matrix_reducida[idx_test]
X_val           = X_matrix_reducida[idx_val]

# 5. Ajustamos también el vector de nombres de las características para que coincida exactamente
lista_metric_name_vector = lista_metric_name_vector[inicio_idx:fin_idx]
# Out:
# Total de columnas: 993
# Extrayendo el tercio 2 (desde la columna 331 hasta la 662)

# %%
X_matrix_reducida.shape
# Out:
# (44126, 331)

# %%
model_name = f'IF(1 punto umbral tercio ={tercio_deseado}     indice Youden)_metricas_logs'
N += 1

# 2. Entrenar el Isolation Forest
model = IsolationForest(
    n_estimators=200, 
    max_samples='auto', 
    contamination='auto',        
    random_state=SEED
)
model.fit(X_correct_train)


#usamos el conjunto de validacion para obtener curva ROC y establecer el umbral de decision usnado indice de Youden
#y_true = df_result.iloc[idx_val]['label'].apply(lambda x: 0 if x == 'correct' else 1)
y_true = df_result.loc[idx_val, 'label'].apply(lambda x: 0 if x == 'correct' else 1)
scores = model.decision_function(X_val)
y_scores_roc = -scores  
roc_auc = roc_auc_score(y_true, y_scores_roc)
fpr, tpr, thresholds = roc_curve(y_true, y_scores_roc)
optimal_idx = np.argmax(tpr - fpr)
optimal_threshold = thresholds[optimal_idx]

#calcumamos la prediccion para el conjunto de test
y_true = df_result.loc[idx_test, 'label'].apply(lambda x: 0 if x == 'correct' else 1)
scores = model.decision_function(X_test)
y_scores_roc = -scores  
roc_auc = roc_auc_score(y_true, y_scores_roc)
fpr, tpr, thresholds = roc_curve(y_true, y_scores_roc)
y_pred = (y_scores_roc >= optimal_threshold).astype(int)



# Guardar en el DataFrame global
df_result[f'result_({model_name})'] = float('nan')
df_result[f'scores_({model_name})'] = float('nan')
df_result.loc[idx_test, f'result_({model_name})'] = y_pred
df_result.loc[idx_test, f'scores_({model_name})'] = scores

# 6. Métricas y matriz de confusión
cm = confusion_matrix(y_true, y_pred, labels=[0, 1])
tn, fp, fn, tp = cm.ravel()

acc = accuracy_score(y_true, y_pred)
precision = precision_score(y_true, y_pred, zero_division=0)
recall = recall_score(y_true, y_pred, zero_division=0)
specificity = tn / (tn + fp) if (tn + fp) > 0 else 0
f1 = f1_score(y_true, y_pred, zero_division=0)

print(f'--- {model_name} (Umbral Youden: {optimal_threshold:.4f}) ---')
print(f'Accuracy    = {acc}')
print(f'Precision   = {precision}')
print(f'Recall      = {recall}')
print(f'Specificity = {specificity}')    
print(f'F1          = {f1}')

parametros = {'contaminacion': contaminacion, 'metodo': 'youden', 'umbral_youden': float(optimal_threshold)}

reg_resultado_algoritmo = {
    'test_name': model_name,
    'parametros': json.dumps(parametros),
    'TP': int(tp), 'FP': int(fp), 'TN': int(tn), 'FN': int(fn),
    'accuracy': float(acc),
    'precision': float(precision),
    'recall': float(recall),
    'specificity': float(specificity),
    'f1_score': float(f1),
    'roc_auc': float(roc_auc)
}
lista_result.append(reg_resultado_algoritmo)

# 7. Visualización
fig, axes = plt.subplots(1, 2, figsize=(12, 5))

disp_cm = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=['Normal (0)', 'Anomalía (1)'])
disp_cm.plot(ax=axes[0], cmap='Blues', colorbar=False)
axes[0].set_title(f'Matriz de Confusión \n{model_name}')

RocCurveDisplay.from_predictions(y_true, y_scores_roc, ax=axes[1], name=f'IF (AUC = {roc_auc:.3f})')
axes[1].plot([0, 1], [0, 1], 'k--', label='Aleatorio (AUC = 0.5)')
axes[1].set_title(f'Curva ROC\n{model_name}')
axes[1].legend(loc='lower right')

plt.tight_layout()
plt.show()

paquete = {
    'model_name' : model_name,
    'model'      : model,
    'parametros' : {'contaminacion':contaminacion,'threshold':optimal_threshold},
    'resultado'  : {'accuracy':acc,'precision':precision,'recall':recall,'f1':f1,'specificity':specificity}
}
joblib.dump(paquete, f'{FOLDER_SALIDA}/models/{model_name}.joblib')
# Out:
# --- IF(1 punto umbral tercio =2     indice Youden)_metricas_logs (Umbral Youden: -0.1117) ---
# Accuracy    = 0.7081081081081081
# Precision   = 0.6580673371228684
# Recall      = 0.8604917095483133
# Specificity = 0.5571913929784824
# F1          = 0.7457879088206145
# ['result/models/IF(1 punto umbral tercio =2     indice Youden)_metricas_logs.joblib']

# %% [markdown]
# ## <span style="color:#2ca02c">2.5.Probamos IF(1 puntos de 3 intervalos) con varios parametros contaminacion</span>

# %%
with open(filename_lista_metric_name_vector, "r", encoding="utf-8") as f:
    lista_metric_name_vector = json.load(f)

# %%
X_matrix.shape
# Out:
# (44126, 993)

# %%
df_result=df[ ['vector_id','execution_name','label'] ].copy()

# %%
# 1. Calculamos los tamaños de los tercios
num_columnas_total = X_matrix.shape[1]
tercio_n = num_columnas_total // 3

# Definimos los límites de los 3 tercios
inicio_1, fin_1 = 0, tercio_n
inicio_2, fin_2 = tercio_n, tercio_n * 2
inicio_3, fin_3 = tercio_n * 2, num_columnas_total  # Coge el resto hasta el final por si acaso

# 2. Extraemos cada tercio como una submatriz
t1 = X_matrix[:, inicio_1:fin_1]
t2 = X_matrix[:, inicio_2:fin_2]
t3 = X_matrix[:, inicio_3:fin_3]

# 3. Sumamos las columnas homólogas de los tres tercios (columna i del tercio 1 + columna i del tercio 2 + columna i del tercio 3)
# Como t1, t2 y t3 tienen exactamente la misma forma (n_filas, tercio_n), la suma de NumPy los alinea automáticamente.
X_matrix_reducida = t1 + t2 + t3

print(f"Total de columnas originales: {num_columnas_total}")
print(f"Columnas por tercio: {tercio_n}")
print(f"Nueva forma de X_matrix_reducida: {X_matrix_reducida.shape}")

# 4. Recortamos los datos de entrenamiento y test con esta nueva matriz reducida
X_correct_train = X_matrix_reducida[idx_correct_train]
X_correct_test  = X_matrix_reducida[idx_correct_test]
X_test          = X_matrix_reducida[idx_test]
X_val           = X_matrix_reducida[idx_val]

# 5. Ajustamos la lista de nombres de métricas cogiendo el patrón del primer tercio (o renombrándolas)
# Esto asume que el nombre de la característica i en el tercio 1 corresponde al mismo concepto que en los otros tercios
lista_metric_name_vector = lista_metric_name_vector[inicio_1:fin_1]
# Out:
# Total de columnas originales: 993
# Columnas por tercio: 331
# Nueva forma de X_matrix_reducida: (44126, 331)

# %%
X_matrix_reducida.shape
# Out:
# (44126, 331)

# %%
df_result = pd.DataFrame({
    't_rel': df.loc[idx_test, 't_rel'],
    'execution_name': df.loc[idx_test, 'execution_name'],
    'label': df.loc[idx_test, 'label']
})

N = 0
lista_result=[]
for contaminacion in [0.02, 0.015, 0.01, 0.008, 0.006, 0.004, 0.0035, 0.003, 0.002, 0.001, 0.0005]:
    N += 1
    model = IsolationForest(
        n_estimators=200, 
        max_samples='auto', 
        #contamination=contaminacion,        
        contamination='auto', 
        random_state=SEED
    )
    model.fit(X_correct_train)
    scores = model.decision_function(X_test)
    Y_pred = model.predict(X_test)

    model_name = f'IF(1 punto tercio={tercio_deseado}  contaminacion={contaminacion})_metricas_logs'
    joblib.dump(model, f'{FOLDER_SALIDA}/models/{model_name}.joblib')
    
    df_result[f'result_({model_name})'] = float('nan')
    df_result[f'scores_({model_name})'] = float('nan')
    df_result.loc[idx_test, f'result_({model_name})'] = Y_pred
    df_result.loc[idx_test, f'scores_({model_name})'] = scores
    
    # Mapeo: 1 para Anomalía (Positivo) y 0 para Normal (Negativo)
    y_true = df_result.loc[idx_test, 'label'].apply(lambda x: 0 if x == 'correct' else 1)
    #y_pred = df_result.loc[idx_test, f'result_({model_name})'].apply(lambda x: 0 if x == 1 else 1)
    y_pred = df_result.loc[idx_test, f'result_({model_name})'].map({1: 0, -1: 1})

    
    # Invertimos los scores para que valores más altos correspondan a la anomalía
    y_scores_roc = -scores 
    roc_auc = roc_auc_score(y_true, y_scores_roc)

    # 1. Componentes de la matriz de confusión
    cm = confusion_matrix(y_true, y_pred, labels=[0, 1])
    tn, fp, fn, tp = cm.ravel()
    
    # 2. Cálculo de métricas
    acc = accuracy_score(y_true, y_pred)
    precision = precision_score(y_true, y_pred, zero_division=0)
    recall = recall_score(y_true, y_pred, zero_division=0)
    specificity = tn / (tn + fp) if (tn + fp) > 0 else 0
    f1 = f1_score(y_true, y_pred, zero_division=0)
    
    print(f'Accuracy    = {acc}')
    print(f'Precision   = {precision}')
    print(f'Recall      = {recall}')
    print(f'Specificity = {specificity}')
    print(f'F1          = {f1}')
    
    parametros = {'contaminacion': contaminacion}
    
    # 3. Guardar en un diccionario de registro
    reg_resultado_algoritmo = {
        'test_name': model_name,
        'parametros': json.dumps(parametros),
        'TP': int(tp),
        'FP': int(fp),
        'TN': int(tn),
        'FN': int(fn),
        'accuracy': float(acc),
        'precision': float(precision),
        'recall': float(recall),
        'specificity': float(specificity),
        'f1_score': float(f1),
        'roc_auc': float(roc_auc)
    }
    lista_result.append(reg_resultado_algoritmo)
    
    # 4. Visualización conjunta (Matriz de Confusión a la izquierda, Curva ROC a la derecha)
    fig, axes = plt.subplots(1, 2, figsize=(12, 5))
    
    # Gráfica izquierda: Matriz de Confusión
    disp_cm = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=['Normal (0)', 'Anomalía (1)'])
    disp_cm.plot(ax=axes[0], cmap='Blues', colorbar=False)
    axes[0].set_title(f'Matriz de Confusión\n{model_name}')
    
    # Gráfica derecha: Curva ROC
    RocCurveDisplay.from_predictions(
        y_true, 
        y_scores_roc, 
        ax=axes[1], 
        name=f'IF (AUC = {roc_auc:.3f})'
    )
    axes[1].plot([0, 1], [0, 1], 'k--', label='Aleatorio (AUC = 0.5)')
    axes[1].set_title(f'Curva ROC\n{model_name}')
    axes[1].legend(loc='lower right')
    
    plt.tight_layout()
    plt.show()

    paquete = {
        'model_name' : model_name,
        'model'      : model,
        'parametros' : {'contaminacion':contaminacion},
        'resultado'  : {'accuracy':acc,'precision':precision,'recall':recall,'f1':f1,'specificity':specificity}
    }
    joblib.dump(paquete, f'{FOLDER_SALIDA}/models/{model_name}.joblib')
    
# DataFrame global final
df_anomaly_detection_summary = pd.DataFrame(lista_result)
# Out:
# Accuracy    = 0.5024182076813656
# Precision   = 0.5
# Recall      = 0.0011435105774728416
# Specificity = 0.9988674971687429
# F1          = 0.0022818026240730175
# Accuracy    = 0.5024182076813656
# Precision   = 0.5
# Recall      = 0.0011435105774728416
# Specificity = 0.9988674971687429
# F1          = 0.0022818026240730175
# Accuracy    = 0.5024182076813656
# Precision   = 0.5
# Recall      = 0.0011435105774728416
# Specificity = 0.9988674971687429
# F1          = 0.0022818026240730175
# Accuracy    = 0.5024182076813656
# Precision   = 0.5
# Recall      = 0.0011435105774728416
# Specificity = 0.9988674971687429
# F1          = 0.0022818026240730175
# Accuracy    = 0.5024182076813656
# Precision   = 0.5
# Recall      = 0.0011435105774728416
# Specificity = 0.9988674971687429
# F1          = 0.0022818026240730175
# Accuracy    = 0.5024182076813656
# Precision   = 0.5
# Recall      = 0.0011435105774728416
# Specificity = 0.9988674971687429
# F1          = 0.0022818026240730175
# Accuracy    = 0.5024182076813656
# Precision   = 0.5
# Recall      = 0.0011435105774728416
# Specificity = 0.9988674971687429
# F1          = 0.0022818026240730175
# Accuracy    = 0.5024182076813656
# Precision   = 0.5
# Recall      = 0.0011435105774728416
# Specificity = 0.9988674971687429
# F1          = 0.0022818026240730175
# Accuracy    = 0.5024182076813656
# Precision   = 0.5
# Recall      = 0.0011435105774728416
# Specificity = 0.9988674971687429
# F1          = 0.0022818026240730175
# Accuracy    = 0.5024182076813656
# Precision   = 0.5
# Recall      = 0.0011435105774728416
# Specificity = 0.9988674971687429
# F1          = 0.0022818026240730175
# Accuracy    = 0.5024182076813656
# Precision   = 0.5
# Recall      = 0.0011435105774728416
# Specificity = 0.9988674971687429
# F1          = 0.0022818026240730175

# %% [markdown]
# ### <span style="color:#2ca02c">2.6. Probamos IF(1 puntos de 3 intervalos)  ajustando umbral de decision con indice de Youden</span>

# %%
with open(filename_lista_metric_name_vector, "r", encoding="utf-8") as f:
    lista_metric_name_vector = json.load(f)

# %%
X_matrix.shape
# Out:
# (44126, 993)

# %%
df_result=df[ ['vector_id','execution_name','label'] ].copy()

# %%
# 1. Calculamos los tamaños de los tercios
num_columnas_total = X_matrix.shape[1]
tercio_n = num_columnas_total // 3

# Definimos los límites de los 3 tercios
inicio_1, fin_1 = 0, tercio_n
inicio_2, fin_2 = tercio_n, tercio_n * 2
inicio_3, fin_3 = tercio_n * 2, num_columnas_total  # Coge el resto hasta el final por si acaso

# 2. Extraemos cada tercio como una submatriz
t1 = X_matrix[:, inicio_1:fin_1]
t2 = X_matrix[:, inicio_2:fin_2]
t3 = X_matrix[:, inicio_3:fin_3]

# 3. Sumamos las columnas homólogas de los tres tercios (columna i del tercio 1 + columna i del tercio 2 + columna i del tercio 3)
# Como t1, t2 y t3 tienen exactamente la misma forma (n_filas, tercio_n), la suma de NumPy los alinea automáticamente.
X_matrix_reducida = t1 + t2 + t3

print(f"Total de columnas originales: {num_columnas_total}")
print(f"Columnas por tercio: {tercio_n}")
print(f"Nueva forma de X_matrix_reducida: {X_matrix_reducida.shape}")

# 4. Recortamos los datos de entrenamiento y test con esta nueva matriz reducida
X_correct_train = X_matrix_reducida[idx_correct_train]
X_correct_test  = X_matrix_reducida[idx_correct_test]
X_test          = X_matrix_reducida[idx_test]
X_val           = X_matrix_reducida[idx_val]

# 5. Ajustamos la lista de nombres de métricas cogiendo el patrón del primer tercio (o renombrándolas)
# Esto asume que el nombre de la característica i en el tercio 1 corresponde al mismo concepto que en los otros tercios
lista_metric_name_vector = lista_metric_name_vector[inicio_1:fin_1]
# Out:
# Total de columnas originales: 993
# Columnas por tercio: 331
# Nueva forma de X_matrix_reducida: (44126, 331)

# %%
X_matrix_reducida.shape
# Out:
# (44126, 331)

# %%
model_name = f'IF(1 punto 3 intervalos     indice Youden)_metricas_logs'
N += 1

# 2. Entrenar el Isolation Forest
model = IsolationForest(
    n_estimators=200, 
    max_samples='auto', 
    contamination='auto',        
    random_state=SEED
)
model.fit(X_correct_train)


#usamos el conjunto de validacion para obtener curva ROC y establecer el umbral de decision usnado indice de Youden
#y_true = df_result.iloc[idx_val]['label'].apply(lambda x: 0 if x == 'correct' else 1)
y_true = df_result.loc[idx_val, 'label'].apply(lambda x: 0 if x == 'correct' else 1)
scores = model.decision_function(X_val)
y_scores_roc = -scores  
roc_auc = roc_auc_score(y_true, y_scores_roc)
fpr, tpr, thresholds = roc_curve(y_true, y_scores_roc)
optimal_idx = np.argmax(tpr - fpr)
optimal_threshold = thresholds[optimal_idx]

#calcumamos la prediccion para el conjunto de test
y_true = df_result.loc[idx_test, 'label'].apply(lambda x: 0 if x == 'correct' else 1)
scores = model.decision_function(X_test)
y_scores_roc = -scores  
roc_auc = roc_auc_score(y_true, y_scores_roc)
fpr, tpr, thresholds = roc_curve(y_true, y_scores_roc)
y_pred = (y_scores_roc >= optimal_threshold).astype(int)



# Guardar en el DataFrame global
df_result[f'result_({model_name})'] = float('nan')
df_result[f'scores_({model_name})'] = float('nan')
df_result.loc[idx_test, f'result_({model_name})'] = y_pred
df_result.loc[idx_test, f'scores_({model_name})'] = scores

# 6. Métricas y matriz de confusión
cm = confusion_matrix(y_true, y_pred, labels=[0, 1])
tn, fp, fn, tp = cm.ravel()

acc = accuracy_score(y_true, y_pred)
precision = precision_score(y_true, y_pred, zero_division=0)
recall = recall_score(y_true, y_pred, zero_division=0)
specificity = tn / (tn + fp) if (tn + fp) > 0 else 0
f1 = f1_score(y_true, y_pred, zero_division=0)

print(f'--- {model_name} (Umbral Youden: {optimal_threshold:.4f}) ---')
print(f'Accuracy    = {acc}')
print(f'Precision   = {precision}')
print(f'Recall      = {recall}')
print(f'Specificity = {specificity}')    
print(f'F1          = {f1}')

parametros = {'contaminacion': contaminacion, 'metodo': 'youden', 'umbral_youden': float(optimal_threshold)}

reg_resultado_algoritmo = {
    'test_name': model_name,
    'parametros': json.dumps(parametros),
    'TP': int(tp), 'FP': int(fp), 'TN': int(tn), 'FN': int(fn),
    'accuracy': float(acc),
    'precision': float(precision),
    'recall': float(recall),
    'specificity': float(specificity),
    'f1_score': float(f1),
    'roc_auc': float(roc_auc)
}
lista_result.append(reg_resultado_algoritmo)

# 7. Visualización
fig, axes = plt.subplots(1, 2, figsize=(12, 5))

disp_cm = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=['Normal (0)', 'Anomalía (1)'])
disp_cm.plot(ax=axes[0], cmap='Blues', colorbar=False)
axes[0].set_title(f'Matriz de Confusión \n{model_name}')

RocCurveDisplay.from_predictions(y_true, y_scores_roc, ax=axes[1], name=f'IF (AUC = {roc_auc:.3f})')
axes[1].plot([0, 1], [0, 1], 'k--', label='Aleatorio (AUC = 0.5)')
axes[1].set_title(f'Curva ROC\n{model_name}')
axes[1].legend(loc='lower right')

plt.tight_layout()
plt.show()

paquete = {
    'model_name' : model_name,
    'model'      : model,
    'parametros' : {'contaminacion':contaminacion,'threshold':optimal_threshold},
    'resultado'  : {'accuracy':acc,'precision':precision,'recall':recall,'f1':f1,'specificity':specificity}
}
joblib.dump(paquete, f'{FOLDER_SALIDA}/models/{model_name}.joblib')
# Out:
# --- IF(1 punto 3 intervalos     indice Youden)_metricas_logs (Umbral Youden: -0.0866) ---
# Accuracy    = 0.8008534850640113
# Precision   = 0.7422632794457275
# Recall      = 0.9188107489994283
# Specificity = 0.6840317100792752
# F1          = 0.8211548288196219
# ['result/models/IF(1 punto 3 intervalos     indice Youden)_metricas_logs.joblib']

# %% [markdown]
# ## <span style="color:#2ca02c">2.7. Analisis de importancia de features para conseguir un modelo de detecion de a nomalias con menos caracteristicas</span>

# %% [markdown]
# <span style="color:#2ca02c">Usamos el modelo de 1 punto y 3 intervalos con umbral calculado con indice de Youden</span>

# %%
from sklearn.metrics import f1_score, make_scorer

# Definimos una métrica personalizada para F1 que maneje el binarizado de Isolation Forest (1 y -1)
def custom_f1_score(y_true, y_pred_raw):
    # Convertimos las salidas -1/1 del predict del IsolationForest a 0/1
    y_pred_bin = [0 if x == 1 else 1 for x in y_pred_raw]
    return f1_score(y_true, y_pred_bin, zero_division=0)

f1_scorer = make_scorer(custom_f1_score)

# Ejecutamos la importancia usando el scorer personalizado
result = permutation_importance(
    model, X_test, y_true, 
    scoring=f1_scorer,
    n_repeats=10, 
    random_state=SEED, 
    n_jobs=1
)

# Creamos el DataFrame de importancia
df_importancia = pd.DataFrame({
    'Caracteristica': lista_metric_name_vector,
    'Importancia': result.importances_mean
}).sort_values(by='Importancia', ascending=False)

# %%
print(df_importancia.head(40))
# Out:
#                        Caracteristica  Importancia
# 54   light-oauth2-oauth2-client-1(63)     0.002168
# 147     light-oauth2-oauth2-key-1(24)     0.002168
# 53   light-oauth2-oauth2-client-1(62)     0.002053
# 56   light-oauth2-oauth2-client-1(65)     0.001140
# 105    light-oauth2-oauth2-code-1(47)     0.001140
# 120    light-oauth2-oauth2-code-1(61)     0.001140
# 181  light-oauth2-oauth2-service-1(0)     0.001140
# 107    light-oauth2-oauth2-code-1(49)     0.001140
# 212  light-oauth2-oauth2-token-1(125)     0.001140
# 144     light-oauth2-oauth2-key-1(20)     0.001140
# 39   light-oauth2-oauth2-client-1(49)     0.001140
# 116    light-oauth2-oauth2-code-1(57)     0.001140
# 94     light-oauth2-oauth2-code-1(34)     0.001140
# 155     light-oauth2-oauth2-key-1(35)     0.001140
# 272   light-oauth2-oauth2-token-1(47)     0.001140
# 104    light-oauth2-oauth2-code-1(46)     0.001140
# 149     light-oauth2-oauth2-key-1(27)     0.001026
# 23   light-oauth2-oauth2-client-1(33)     0.001026
# 99     light-oauth2-oauth2-code-1(39)     0.001026
# 290   light-oauth2-oauth2-token-1(63)     0.001026
# 106    light-oauth2-oauth2-code-1(48)     0.001026
# 285   light-oauth2-oauth2-token-1(59)     0.001026
# 61    light-oauth2-oauth2-client-1(7)     0.001026
# 80     light-oauth2-oauth2-code-1(19)     0.001026
# 175      light-oauth2-oauth2-key-1(9)     0.001026
# 103    light-oauth2-oauth2-code-1(45)     0.001026
# 139     light-oauth2-oauth2-key-1(14)     0.001026
# 283   light-oauth2-oauth2-token-1(57)     0.001026
# 148     light-oauth2-oauth2-key-1(25)     0.001026
# 123    light-oauth2-oauth2-code-1(64)     0.001026
# 14   light-oauth2-oauth2-client-1(24)     0.000912
# 36   light-oauth2-oauth2-client-1(46)     0.000912
# 3    light-oauth2-oauth2-client-1(11)     0.000912
# 70    light-oauth2-oauth2-client-1(8)     0.000912
# 19   light-oauth2-oauth2-client-1(29)     0.000912
# 35   light-oauth2-oauth2-client-1(45)     0.000912
# 312   light-oauth2-oauth2-token-1(83)     0.000912
# 277   light-oauth2-oauth2-token-1(51)     0.000912
# 115    light-oauth2-oauth2-code-1(56)     0.000911
# 110    light-oauth2-oauth2-code-1(51)     0.000911

# %%
X_matrix_acumulado=X_matrix_reducida.copy()

# %%
lista_result = []

contaminacion = 0.002  # Esto no sirve para nada ya que calcularemos el umbral de decisión aparte
resultados_loop_features = []

for n_feat in range(50, 312):
    # 1. Selección de datos reducidos por importancia
    lista_idx_reducida_IF = df_importancia.head(n_feat).index.tolist()
    
    X_matrix_reducida = X_matrix_acumulado[:, lista_idx_reducida_IF]
    X_correct_train   = X_matrix_reducida[idx_correct_train]
    X_val             = X_matrix_reducida[idx_val]
    X_test            = X_matrix_reducida[idx_test]

    # 2. Entrenamiento del modelo
    model = IsolationForest(
        n_estimators=200, 
        max_samples='auto', 
        contamination=contaminacion,        
        random_state=SEED
    )
    model.fit(X_correct_train)

    model_name = f'IF(umbral con indice de Youden)_{n_feat}_features(metricas_logs)'
    joblib.dump(model, f'{FOLDER_SALIDA}/models/{model_name}.joblib')
    
    # 3. Cálculo del umbral óptimo usando el conjunto de VALIDACIÓN (idx_val)
    y_true_val = df_result.loc[idx_val, 'label'].apply(lambda x: 0 if x == 'correct' else 1)
    scores_val = model.decision_function(X_val)
    y_scores_val_roc = -scores_val  
    
    fpr_val, tpr_val, thresholds_val = roc_curve(y_true_val, y_scores_val_roc)
    optimal_idx = np.argmax(tpr_val - fpr_val)
    optimal_threshold = thresholds_val[optimal_idx]

    # 4. Predicción y evaluación sobre el conjunto de TEST (idx_test) usando el umbral de validación
    y_true = df_result.loc[idx_test, 'label'].apply(lambda x: 0 if x == 'correct' else 1)
    scores = model.decision_function(X_test)
    y_scores_roc = -scores  
    
    y_pred = (y_scores_roc >= optimal_threshold).astype(int)
    roc_auc = roc_auc_score(y_true, y_scores_roc)

    # Guardamos los scores y predicciones en el DataFrame global
    # df_result[f'result_({model_name})'] = float('nan')
    # df_result[f'scores_({model_name})'] = float('nan')
    # df_result.loc[idx_test, f'result_({model_name})'] = y_pred
    # df_result.loc[idx_test, f'scores_({model_name})'] = scores
    
    # 5. Componentes de la matriz de confusión y métricas
    cm = confusion_matrix(y_true, y_pred, labels=[0, 1])
    tn, fp, fn, tp = cm.ravel()
    
    acc = accuracy_score(y_true, y_pred)
    precision = precision_score(y_true, y_pred, zero_division=0)
    recall = recall_score(y_true, y_pred, zero_division=0)
    specificity = tn / (tn + fp) if (tn + fp) > 0 else 0
    f1 = f1_score(y_true, y_pred, zero_division=0)
    
    print(
        f'[{model_name}] -> Acc: {acc:.4f} | Prec: {precision:.4f} | '
        f'Rec: {recall:.4f} | Spec: {specificity:.4f} | F1: {f1:.4f} | AUC: {roc_auc:.4f}'
    )
    
    parametros = {'n_feat': n_feat, 'contaminacion': contaminacion, 'umbral_youden': float(optimal_threshold)}
    
    # 6. Registro de resultados
    reg_resultado_algoritmo = {
        'test_name': model_name,
        'parametros': json.dumps(parametros),
        'TP': int(tp),
        'FP': int(fp),
        'TN': int(tn),
        'FN': int(fn),
        'accuracy': float(acc),
        'precision': float(precision),
        'recall': float(recall),
        'specificity': float(specificity),
        'f1_score': float(f1),
        'roc_auc': float(roc_auc)
    }
    lista_result.append(reg_resultado_algoritmo)
    
    paquete = {
        'model_name'     : model_name,
        'model'          : model,
        'parametros'     : {'contaminacion': contaminacion, 'threshold': optimal_threshold},
        'lista_features' : df_importancia['Caracteristica'][:n_feat],
        'resultado'      : {'accuracy': acc, 'precision': precision, 'recall': recall, 'f1': f1, 'specificity': specificity}
    }
    joblib.dump(paquete, f'{FOLDER_SALIDA}/models/{model_name}.joblib')

# %%
with pd.option_context('display.max_rows', None):
    display(df_result_algoritmos)
# Out:
#                                              test_name  \
# 0    IF(umbral con indice de Youden)_50_features(me...
# 1    IF(umbral con indice de Youden)_51_features(me...
# 2    IF(umbral con indice de Youden)_52_features(me...
# 3    IF(umbral con indice de Youden)_53_features(me...
# 4    IF(umbral con indice de Youden)_54_features(me...
# 5    IF(umbral con indice de Youden)_55_features(me...
# 6    IF(umbral con indice de Youden)_56_features(me...
# 7    IF(umbral con indice de Youden)_57_features(me...
# 8    IF(umbral con indice de Youden)_58_features(me...
# 9    IF(umbral con indice de Youden)_59_features(me...
# 10   IF(umbral con indice de Youden)_60_features(me...
# 11   IF(umbral con indice de Youden)_61_features(me...
# 12   IF(umbral con indice de Youden)_62_features(me...
# 13   IF(umbral con indice de Youden)_63_features(me...
# 14   IF(umbral con indice de Youden)_64_features(me...
# 15   IF(umbral con indice de Youden)_65_features(me...
# 16   IF(umbral con indice de Youden)_66_features(me...
# 17   IF(umbral con indice de Youden)_67_features(me...
# 18   IF(umbral con indice de Youden)_68_features(me...
# 19   IF(umbral con indice de Youden)_69_features(me...
# 20   IF(umbral con indice de Youden)_70_features(me...
# 21   IF(umbral con indice de Youden)_71_features(me...
# 22   IF(umbral con indice de Youden)_72_features(me...
# 23   IF(umbral con indice de Youden)_73_features(me...
# 24   IF(umbral con indice de Youden)_74_features(me...
# 25   IF(umbral con indice de Youden)_75_features(me...
# 26   IF(umbral con indice de Youden)_76_features(me...
# 27   IF(umbral con indice de Youden)_77_features(me...
# 28   IF(umbral con indice de Youden)_78_features(me...
# 29   IF(umbral con indice de Youden)_79_features(me...
# 30   IF(umbral con indice de Youden)_80_features(me...
# 31   IF(umbral con indice de Youden)_81_features(me...
# 32   IF(umbral con indice de Youden)_82_features(me...
# 33   IF(umbral con indice de Youden)_83_features(me...
# 34   IF(umbral con indice de Youden)_84_features(me...
# 35   IF(umbral con indice de Youden)_85_features(me...
# 36   IF(umbral con indice de Youden)_86_features(me...
# 37   IF(umbral con indice de Youden)_87_features(me...
# 38   IF(umbral con indice de Youden)_88_features(me...
# 39   IF(umbral con indice de Youden)_89_features(me...
# 40   IF(umbral con indice de Youden)_90_features(me...
# 41   IF(umbral con indice de Youden)_91_features(me...
# 42   IF(umbral con indice de Youden)_92_features(me...
# 43   IF(umbral con indice de Youden)_93_features(me...
# 44   IF(umbral con indice de Youden)_94_features(me...
# 45   IF(umbral con indice de Youden)_95_features(me...
# 46   IF(umbral con indice de Youden)_96_features(me...
# 47   IF(umbral con indice de Youden)_97_features(me...
# 48   IF(umbral con indice de Youden)_98_features(me...
# 49   IF(umbral con indice de Youden)_99_features(me...
# 50   IF(umbral con indice de Youden)_100_features(m...
# 51   IF(umbral con indice de Youden)_101_features(m...
# 52   IF(umbral con indice de Youden)_102_features(m...
# 53   IF(umbral con indice de Youden)_103_features(m...
# 54   IF(umbral con indice de Youden)_104_features(m...
# 55   IF(umbral con indice de Youden)_105_features(m...
# 56   IF(umbral con indice de Youden)_106_features(m...
# 57   IF(umbral con indice de Youden)_107_features(m...
# 58   IF(umbral con indice de Youden)_108_features(m...
# 59   IF(umbral con indice de Youden)_109_features(m...
# 60   IF(umbral con indice de Youden)_110_features(m...
# 61   IF(umbral con indice de Youden)_111_features(m...
# 62   IF(umbral con indice de Youden)_112_features(m...
# 63   IF(umbral con indice de Youden)_113_features(m...
# 64   IF(umbral con indice de Youden)_114_features(m...
# 65   IF(umbral con indice de Youden)_115_features(m...
# 66   IF(umbral con indice de Youden)_116_features(m...
# 67   IF(umbral con indice de Youden)_117_features(m...
# 68   IF(umbral con indice de Youden)_118_features(m...
# 69   IF(umbral con indice de Youden)_119_features(m...
# 70   IF(umbral con indice de Youden)_120_features(m...
# 71   IF(umbral con indice de Youden)_121_features(m...
# 72   IF(umbral con indice de Youden)_122_features(m...
# 73   IF(umbral con indice de Youden)_123_features(m...
# 74   IF(umbral con indice de Youden)_124_features(m...
# 75   IF(umbral con indice de Youden)_125_features(m...
# 76   IF(umbral con indice de Youden)_126_features(m...
# 77   IF(umbral con indice de Youden)_127_features(m...
# 78   IF(umbral con indice de Youden)_128_features(m...
# 79   IF(umbral con indice de Youden)_129_features(m...
# 80   IF(umbral con indice de Youden)_130_features(m...
# 81   IF(umbral con indice de Youden)_131_features(m...
# 82   IF(umbral con indice de Youden)_132_features(m...
# 83   IF(umbral con indice de Youden)_133_features(m...
# 84   IF(umbral con indice de Youden)_134_features(m...
# 85   IF(umbral con indice de Youden)_135_features(m...
# 86   IF(umbral con indice de Youden)_136_features(m...
# 87   IF(umbral con indice de Youden)_137_features(m...
# 88   IF(umbral con indice de Youden)_138_features(m...
# 89   IF(umbral con indice de Youden)_139_features(m...
# 90   IF(umbral con indice de Youden)_140_features(m...
# 91   IF(umbral con indice de Youden)_141_features(m...
# 92   IF(umbral con indice de Youden)_142_features(m...
# 93   IF(umbral con indice de Youden)_143_features(m...
# 94   IF(umbral con indice de Youden)_144_features(m...
# 95   IF(umbral con indice de Youden)_145_features(m...
# 96   IF(umbral con indice de Youden)_146_features(m...
# 97   IF(umbral con indice de Youden)_147_features(m...
# 98   IF(umbral con indice de Youden)_148_features(m...
# 99   IF(umbral con indice de Youden)_149_features(m...
# 100  IF(umbral con indice de Youden)_150_features(m...
# 101  IF(umbral con indice de Youden)_151_features(m...
# 102  IF(umbral con indice de Youden)_152_features(m...
# 103  IF(umbral con indice de Youden)_153_features(m...
# 104  IF(umbral con indice de Youden)_154_features(m...
# 105  IF(umbral con indice de Youden)_155_features(m...
# 106  IF(umbral con indice de Youden)_156_features(m...
# 107  IF(umbral con indice de Youden)_157_features(m...
# 108  IF(umbral con indice de Youden)_158_features(m...
# 109  IF(umbral con indice de Youden)_159_features(m...
# 110  IF(umbral con indice de Youden)_160_features(m...
# 111  IF(umbral con indice de Youden)_161_features(m...
# 112  IF(umbral con indice de Youden)_162_features(m...
# 113  IF(umbral con indice de Youden)_163_features(m...
# 114  IF(umbral con indice de Youden)_164_features(m...
# 115  IF(umbral con indice de Youden)_165_features(m...
# 116  IF(umbral con indice de Youden)_166_features(m...
# 117  IF(umbral con indice de Youden)_167_features(m...
# 118  IF(umbral con indice de Youden)_168_features(m...
# 119  IF(umbral con indice de Youden)_169_features(m...
# 120  IF(umbral con indice de Youden)_170_features(m...
# 121  IF(umbral con indice de Youden)_171_features(m...
# 122  IF(umbral con indice de Youden)_172_features(m...
# 123  IF(umbral con indice de Youden)_173_features(m...
# 124  IF(umbral con indice de Youden)_174_features(m...
# 125  IF(umbral con indice de Youden)_175_features(m...
# 126  IF(umbral con indice de Youden)_176_features(m...
# 127  IF(umbral con indice de Youden)_177_features(m...
# 128  IF(umbral con indice de Youden)_178_features(m...
# 129  IF(umbral con indice de Youden)_179_features(m...
# 130  IF(umbral con indice de Youden)_180_features(m...
# 131  IF(umbral con indice de Youden)_181_features(m...
# 132  IF(umbral con indice de Youden)_182_features(m...
# 133  IF(umbral con indice de Youden)_183_features(m...
# 134  IF(umbral con indice de Youden)_184_features(m...
# 135  IF(umbral con indice de Youden)_185_features(m...
# 136  IF(umbral con indice de Youden)_186_features(m...
# 137  IF(umbral con indice de Youden)_187_features(m...
# 138  IF(umbral con indice de Youden)_188_features(m...
# 139  IF(umbral con indice de Youden)_189_features(m...
# 140  IF(umbral con indice de Youden)_190_features(m...
# 141  IF(umbral con indice de Youden)_191_features(m...
# 142  IF(umbral con indice de Youden)_192_features(m...
# 143  IF(umbral con indice de Youden)_193_features(m...
# 144  IF(umbral con indice de Youden)_194_features(m...
# 145  IF(umbral con indice de Youden)_195_features(m...
# 146  IF(umbral con indice de Youden)_196_features(m...
# 147  IF(umbral con indice de Youden)_197_features(m...
# 148  IF(umbral con indice de Youden)_198_features(m...
# 149  IF(umbral con indice de Youden)_199_features(m...
# 150  IF(umbral con indice de Youden)_200_features(m...
# 151  IF(umbral con indice de Youden)_201_features(m...
# 152  IF(umbral con indice de Youden)_202_features(m...
# 153  IF(umbral con indice de Youden)_203_features(m...
# 154  IF(umbral con indice de Youden)_204_features(m...
# 155  IF(umbral con indice de Youden)_205_features(m...
# 156  IF(umbral con indice de Youden)_206_features(m...
# 157  IF(umbral con indice de Youden)_207_features(m...
# 158  IF(umbral con indice de Youden)_208_features(m...
# 159  IF(umbral con indice de Youden)_209_features(m...
# 160  IF(umbral con indice de Youden)_210_features(m...
# 161  IF(umbral con indice de Youden)_211_features(m...
# 162  IF(umbral con indice de Youden)_212_features(m...
# 163  IF(umbral con indice de Youden)_213_features(m...
# 164  IF(umbral con indice de Youden)_214_features(m...
# 165  IF(umbral con indice de Youden)_215_features(m...
# 166  IF(umbral con indice de Youden)_216_features(m...
# 167  IF(umbral con indice de Youden)_217_features(m...
# 168  IF(umbral con indice de Youden)_218_features(m...
# 169  IF(umbral con indice de Youden)_219_features(m...
# 170  IF(umbral con indice de Youden)_220_features(m...
# 171  IF(umbral con indice de Youden)_221_features(m...
# 172  IF(umbral con indice de Youden)_222_features(m...
# 173  IF(umbral con indice de Youden)_223_features(m...
# 174  IF(umbral con indice de Youden)_224_features(m...
# 175  IF(umbral con indice de Youden)_225_features(m...
# 176  IF(umbral con indice de Youden)_226_features(m...
# 177  IF(umbral con indice de Youden)_227_features(m...
# 178  IF(umbral con indice de Youden)_228_features(m...
# 179  IF(umbral con indice de Youden)_229_features(m...
# 180  IF(umbral con indice de Youden)_230_features(m...
# 181  IF(umbral con indice de Youden)_231_features(m...
# 182  IF(umbral con indice de Youden)_232_features(m...
# 183  IF(umbral con indice de Youden)_233_features(m...
# 184  IF(umbral con indice de Youden)_234_features(m...
# 185  IF(umbral con indice de Youden)_235_features(m...
# 186  IF(umbral con indice de Youden)_236_features(m...
# 187  IF(umbral con indice de Youden)_237_features(m...
# 188  IF(umbral con indice de Youden)_238_features(m...
# 189  IF(umbral con indice de Youden)_239_features(m...
# 190  IF(umbral con indice de Youden)_240_features(m...
# 191  IF(umbral con indice de Youden)_241_features(m...
# 192  IF(umbral con indice de Youden)_242_features(m...
# 193  IF(umbral con indice de Youden)_243_features(m...
# 194  IF(umbral con indice de Youden)_244_features(m...
# 195  IF(umbral con indice de Youden)_245_features(m...
# 196  IF(umbral con indice de Youden)_246_features(m...
# 197  IF(umbral con indice de Youden)_247_features(m...
# 198  IF(umbral con indice de Youden)_248_features(m...
# 199  IF(umbral con indice de Youden)_249_features(m...
# 200  IF(umbral con indice de Youden)_250_features(m...
# 201  IF(umbral con indice de Youden)_251_features(m...
# 202  IF(umbral con indice de Youden)_252_features(m...
# 203  IF(umbral con indice de Youden)_253_features(m...
# 204  IF(umbral con indice de Youden)_254_features(m...
# 205  IF(umbral con indice de Youden)_255_features(m...
# 206  IF(umbral con indice de Youden)_256_features(m...
# 207  IF(umbral con indice de Youden)_257_features(m...
# 208  IF(umbral con indice de Youden)_258_features(m...
# 209  IF(umbral con indice de Youden)_259_features(m...
# 210  IF(umbral con indice de Youden)_260_features(m...
# 211  IF(umbral con indice de Youden)_261_features(m...
# 212  IF(umbral con indice de Youden)_262_features(m...
# 213  IF(umbral con indice de Youden)_263_features(m...
# 214  IF(umbral con indice de Youden)_264_features(m...
# 215  IF(umbral con indice de Youden)_265_features(m...
# 216  IF(umbral con indice de Youden)_266_features(m...
# 217  IF(umbral con indice de Youden)_267_features(m...
# 218  IF(umbral con indice de Youden)_268_features(m...
# 219  IF(umbral con indice de Youden)_269_features(m...
# 220  IF(umbral con indice de Youden)_270_features(m...
# 221  IF(umbral con indice de Youden)_271_features(m...
# 222  IF(umbral con indice de Youden)_272_features(m...
# 223  IF(umbral con indice de Youden)_273_features(m...
# 224  IF(umbral con indice de Youden)_274_features(m...
# 225  IF(umbral con indice de Youden)_275_features(m...
# 226  IF(umbral con indice de Youden)_276_features(m...
# 227  IF(umbral con indice de Youden)_277_features(m...
# 228  IF(umbral con indice de Youden)_278_features(m...
# 229  IF(umbral con indice de Youden)_279_features(m...
# 230  IF(umbral con indice de Youden)_280_features(m...
# 231  IF(umbral con indice de Youden)_281_features(m...
# 232  IF(umbral con indice de Youden)_282_features(m...
# 233  IF(umbral con indice de Youden)_283_features(m...
# 234  IF(umbral con indice de Youden)_284_features(m...
# 235  IF(umbral con indice de Youden)_285_features(m...
# 236  IF(umbral con indice de Youden)_286_features(m...
# 237  IF(umbral con indice de Youden)_287_features(m...
# 238  IF(umbral con indice de Youden)_288_features(m...
# 239  IF(umbral con indice de Youden)_289_features(m...
# 240  IF(umbral con indice de Youden)_290_features(m...
# 241  IF(umbral con indice de Youden)_291_features(m...
# 242  IF(umbral con indice de Youden)_292_features(m...
# 243  IF(umbral con indice de Youden)_293_features(m...
# 244  IF(umbral con indice de Youden)_294_features(m...
# 245  IF(umbral con indice de Youden)_295_features(m...
# 246  IF(umbral con indice de Youden)_296_features(m...
# 247  IF(umbral con indice de Youden)_297_features(m...
# 248  IF(umbral con indice de Youden)_298_features(m...
# 249  IF(umbral con indice de Youden)_299_features(m...
# 250  IF(umbral con indice de Youden)_300_features(m...
# 251  IF(umbral con indice de Youden)_301_features(m...
# 252  IF(umbral con indice de Youden)_302_features(m...
# 253  IF(umbral con indice de Youden)_303_features(m...
# 254  IF(umbral con indice de Youden)_304_features(m...
# 255  IF(umbral con indice de Youden)_305_features(m...
# 256  IF(umbral con indice de Youden)_306_features(m...
# 257  IF(umbral con indice de Youden)_307_features(m...
# 258  IF(umbral con indice de Youden)_308_features(m...
# 259  IF(umbral con indice de Youden)_309_features(m...
# 260  IF(umbral con indice de Youden)_310_features(m...
# 261  IF(umbral con indice de Youden)_311_features(m...
#
#                                             parametros    TP    FP    TN   FN  \
# 0    {"n_feat": 50, "contaminacion": 0.002, "umbral...  1446   966   800  303
# 1    {"n_feat": 51, "contaminacion": 0.002, "umbral...  1365   951   815  384
# 2    {"n_feat": 52, "contaminacion": 0.002, "umbral...  1502  1107   659  247
# 3    {"n_feat": 53, "contaminacion": 0.002, "umbral...  1467  1103   663  282
# 4    {"n_feat": 54, "contaminacion": 0.002, "umbral...  1416   868   898  333
# 5    {"n_feat": 55, "contaminacion": 0.002, "umbral...  1473   915   851  276
# 6    {"n_feat": 56, "contaminacion": 0.002, "umbral...  1529   845   921  220
# 7    {"n_feat": 57, "contaminacion": 0.002, "umbral...  1577   564  1202  172
# 8    {"n_feat": 58, "contaminacion": 0.002, "umbral...  1532   672  1094  217
# 9    {"n_feat": 59, "contaminacion": 0.002, "umbral...  1561   589  1177  188
# 10   {"n_feat": 60, "contaminacion": 0.002, "umbral...  1513   768   998  236
# 11   {"n_feat": 61, "contaminacion": 0.002, "umbral...  1545   605  1161  204
# 12   {"n_feat": 62, "contaminacion": 0.002, "umbral...  1523   632  1134  226
# 13   {"n_feat": 63, "contaminacion": 0.002, "umbral...  1492   791   975  257
# 14   {"n_feat": 64, "contaminacion": 0.002, "umbral...  1579   520  1246  170
# 15   {"n_feat": 65, "contaminacion": 0.002, "umbral...  1562   444  1322  187
# 16   {"n_feat": 66, "contaminacion": 0.002, "umbral...  1547   571  1195  202
# 17   {"n_feat": 67, "contaminacion": 0.002, "umbral...  1636   549  1217  113
# 18   {"n_feat": 68, "contaminacion": 0.002, "umbral...  1667   432  1334   82
# 19   {"n_feat": 69, "contaminacion": 0.002, "umbral...  1603   507  1259  146
# 20   {"n_feat": 70, "contaminacion": 0.002, "umbral...  1614   454  1312  135
# 21   {"n_feat": 71, "contaminacion": 0.002, "umbral...  1587   533  1233  162
# 22   {"n_feat": 72, "contaminacion": 0.002, "umbral...  1543   642  1124  206
# 23   {"n_feat": 73, "contaminacion": 0.002, "umbral...  1591   451  1315  158
# 24   {"n_feat": 74, "contaminacion": 0.002, "umbral...  1595   613  1153  154
# 25   {"n_feat": 75, "contaminacion": 0.002, "umbral...  1593   717  1049  156
# 26   {"n_feat": 76, "contaminacion": 0.002, "umbral...  1620   454  1312  129
# 27   {"n_feat": 77, "contaminacion": 0.002, "umbral...  1585   693  1073  164
# 28   {"n_feat": 78, "contaminacion": 0.002, "umbral...  1544   499  1267  205
# 29   {"n_feat": 79, "contaminacion": 0.002, "umbral...  1634   508  1258  115
# 30   {"n_feat": 80, "contaminacion": 0.002, "umbral...  1557   520  1246  192
# 31   {"n_feat": 81, "contaminacion": 0.002, "umbral...  1638   456  1310  111
# 32   {"n_feat": 82, "contaminacion": 0.002, "umbral...  1623   401  1365  126
# 33   {"n_feat": 83, "contaminacion": 0.002, "umbral...  1613   461  1305  136
# 34   {"n_feat": 84, "contaminacion": 0.002, "umbral...  1609   383  1383  140
# 35   {"n_feat": 85, "contaminacion": 0.002, "umbral...  1645   549  1217  104
# 36   {"n_feat": 86, "contaminacion": 0.002, "umbral...  1592   424  1342  157
# 37   {"n_feat": 87, "contaminacion": 0.002, "umbral...  1628   473  1293  121
# 38   {"n_feat": 88, "contaminacion": 0.002, "umbral...  1640   537  1229  109
# 39   {"n_feat": 89, "contaminacion": 0.002, "umbral...  1614   376  1390  135
# 40   {"n_feat": 90, "contaminacion": 0.002, "umbral...  1616   425  1341  133
# 41   {"n_feat": 91, "contaminacion": 0.002, "umbral...  1644   401  1365  105
# 42   {"n_feat": 92, "contaminacion": 0.002, "umbral...  1631   440  1326  118
# 43   {"n_feat": 93, "contaminacion": 0.002, "umbral...  1644   428  1338  105
# 44   {"n_feat": 94, "contaminacion": 0.002, "umbral...  1684   334  1432   65
# 45   {"n_feat": 95, "contaminacion": 0.002, "umbral...  1651   512  1254   98
# 46   {"n_feat": 96, "contaminacion": 0.002, "umbral...  1666   375  1391   83
# 47   {"n_feat": 97, "contaminacion": 0.002, "umbral...  1645   360  1406  104
# 48   {"n_feat": 98, "contaminacion": 0.002, "umbral...  1679   366  1400   70
# 49   {"n_feat": 99, "contaminacion": 0.002, "umbral...  1682   334  1432   67
# 50   {"n_feat": 100, "contaminacion": 0.002, "umbra...  1633   385  1381  116
# 51   {"n_feat": 101, "contaminacion": 0.002, "umbra...  1586   333  1433  163
# 52   {"n_feat": 102, "contaminacion": 0.002, "umbra...  1688   310  1456   61
# 53   {"n_feat": 103, "contaminacion": 0.002, "umbra...  1689   368  1398   60
# 54   {"n_feat": 104, "contaminacion": 0.002, "umbra...  1668   397  1369   81
# 55   {"n_feat": 105, "contaminacion": 0.002, "umbra...  1674   321  1445   75
# 56   {"n_feat": 106, "contaminacion": 0.002, "umbra...  1680   329  1437   69
# 57   {"n_feat": 107, "contaminacion": 0.002, "umbra...  1597   414  1352  152
# 58   {"n_feat": 108, "contaminacion": 0.002, "umbra...  1657   407  1359   92
# 59   {"n_feat": 109, "contaminacion": 0.002, "umbra...  1675   396  1370   74
# 60   {"n_feat": 110, "contaminacion": 0.002, "umbra...  1612   437  1329  137
# 61   {"n_feat": 111, "contaminacion": 0.002, "umbra...  1641   371  1395  108
# 62   {"n_feat": 112, "contaminacion": 0.002, "umbra...  1607   496  1270  142
# 63   {"n_feat": 113, "contaminacion": 0.002, "umbra...  1623   416  1350  126
# 64   {"n_feat": 114, "contaminacion": 0.002, "umbra...  1685   466  1300   64
# 65   {"n_feat": 115, "contaminacion": 0.002, "umbra...  1638   414  1352  111
# 66   {"n_feat": 116, "contaminacion": 0.002, "umbra...  1618   390  1376  131
# 67   {"n_feat": 117, "contaminacion": 0.002, "umbra...  1603   448  1318  146
# 68   {"n_feat": 118, "contaminacion": 0.002, "umbra...  1664   394  1372   85
# 69   {"n_feat": 119, "contaminacion": 0.002, "umbra...  1634   474  1292  115
# 70   {"n_feat": 120, "contaminacion": 0.002, "umbra...  1617   367  1399  132
# 71   {"n_feat": 121, "contaminacion": 0.002, "umbra...  1639   512  1254  110
# 72   {"n_feat": 122, "contaminacion": 0.002, "umbra...  1653   465  1301   96
# 73   {"n_feat": 123, "contaminacion": 0.002, "umbra...  1643   399  1367  106
# 74   {"n_feat": 124, "contaminacion": 0.002, "umbra...  1639   493  1273  110
# 1. Selección de datos reducidos por importancia (102 features)
lista_idx_reducida_IF = df_importancia.head(n_feat).index.tolist()
lista_nombres_features = df_importancia.loc[lista_idx_reducida_IF, 'Caracteristica'].tolist()

X_matrix_reducida = X_matrix_acumulado[:, lista_idx_reducida_IF]
X_correct_train   = X_matrix_reducida[idx_correct_train]
X_val             = X_matrix_reducida[idx_val]
X_test            = X_matrix_reducida[idx_test]

# 2. Entrenamiento del modelo
model = IsolationForest(
    n_estimators=200, 
    max_samples='auto', 
    contamination=contaminacion,        
    random_state=SEED
)
model.fit(X_correct_train)

# 3. Cálculo del umbral óptimo usando el conjunto de VALIDACIÓN (idx_val)
y_true_val = df_result.loc[idx_val, 'label'].apply(lambda x: 0 if x == 'correct' else 1)
scores_val = model.decision_function(X_val)
y_scores_val_roc = -scores_val  

fpr_val, tpr_val, thresholds_val = roc_curve(y_true_val, y_scores_val_roc)
optimal_idx = np.argmax(tpr_val - fpr_val)
optimal_threshold = thresholds_val[optimal_idx]

# 4. Predicción y evaluación sobre el conjunto de TEST (idx_test) usando el umbral de validación
y_true = df_result.loc[idx_test, 'label'].apply(lambda x: 0 if x == 'correct' else 1)
scores = model.decision_function(X_test)
y_scores_roc = -scores  

y_pred = (y_scores_roc >= optimal_threshold).astype(int)
roc_auc = roc_auc_score(y_true, y_scores_roc)
fpr, tpr, thresholds = roc_curve(y_true, y_scores_roc)

# Guardamos los scores y predicciones en el DataFrame global sin fragmentarlo
nuevas_columnas = {}
s_res = pd.Series(float('nan'), index=df_result.index)
s_res.loc[idx_test] = y_pred
nuevas_columnas[f'result_({model_name})'] = s_res

s_sco = pd.Series(float('nan'), index=df_result.index)
s_sco.loc[idx_test] = scores
nuevas_columnas[f'scores_({model_name})'] = s_sco

df_result = pd.concat([df_result, pd.DataFrame(nuevas_columnas)], axis=1)

# 5. Componentes de la matriz de confusión y métricas
cm = confusion_matrix(y_true, y_pred, labels=[0, 1])
tn, fp, fn, tp = cm.ravel()

acc = accuracy_score(y_true, y_pred)
precision = precision_score(y_true, y_pred, zero_division=0)
recall = recall_score(y_true, y_pred, zero_division=0)
specificity = tn / (tn + fp) if (tn + fp) > 0 else 0
f1 = f1_score(y_true, y_pred, zero_division=0)

print(
    f'[{model_name}] -> Acc: {acc:.4f} | Prec: {precision:.4f} | '
    f'Rec: {recall:.4f} | Spec: {specificity:.4f} | F1: {f1:.4f} | AUC: {roc_auc:.4f}'
)

parametros = {
    'n_feat': n_feat, 
    'contaminacion': contaminacion, 
    'umbral_youden': float(optimal_threshold),
    'features_usadas': lista_nombres_features
}

# 6. Registro de resultados
reg_resultado_algoritmo = {
    'test_name': model_name,
    'parametros': json.dumps(parametros),
    'TP': int(tp),
    'FP': int(fp),
    'TN': int(tn),
    'FN': int(fn),
    'accuracy': float(acc),
    'precision': float(precision),
    'recall': float(recall),
    'specificity': float(specificity),
    'f1_score': float(f1),
    'roc_auc': float(roc_auc)
}
lista_result.append(reg_resultado_algoritmo)

paquete = {
    'model_name'     : model_name,
    'model'          : model,
    'parametros'     : {'contaminacion': contaminacion, 'threshold': optimal_threshold, 'features_usadas': lista_nombres_features},
    'lista_features' : lista_nombres_features,
    'resultado'      : {'accuracy': acc, 'precision': precision, 'recall': recall, 'f1': f1, 'specificity': specificity}
}
joblib.dump(paquete, f'{FOLDER_SALIDA}/models/{model_name}.joblib')

# 7. Visualización (Matriz de confusión y Curva ROC cuadrada con rejillas secundarias)
fig, axes = plt.subplots(1, 2, figsize=(12, 5))

# Matriz de Confusión
disp_cm = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=['Normal (0)', 'Anomalía (1)'])
disp_cm.plot(ax=axes[0], cmap='Blues', colorbar=False)
axes[0].set_title(f'Matriz de Confusión \n{model_name}')
axes[0].set_aspect('equal')

# Curva ROC
axes[1].plot(fpr, tpr, label=f'IF (AUC = {roc_auc:.4f})')
axes[1].plot([0, 1], [0, 1], 'k--', label='Aleatorio (AUC = 0.5)')
axes[1].set_xlabel('False Positive Rate (Positive label: 1)')
axes[1].set_ylabel('True Positive Rate (Positive label: 1)')
axes[1].set_title(f'Curva ROC\n{model_name}')
axes[1].legend(loc='lower right')
axes[1].set_aspect('equal')

# Rejillas secundarias y principales en la curva ROC
axes[1].minorticks_on()
axes[1].grid(which='major', linestyle='-', linewidth='0.7', color='gray', alpha=0.6)
axes[1].grid(which='minor', linestyle=':', linewidth='0.5', color='lightgray', alpha=0.5)

plt.tight_layout()
plt.show()
# Out:
# [IF(umbral con indice de Youden)_102_features(metricas_logs)] -> Acc: 0.8945 | Prec: 0.8448 | Rec: 0.9651 | Spec: 0.8245 | F1: 0.9010 | AUC: 0.9139

# %%
# 1. Partimos de la lista inicial de características de tu mejor modelo (ej. 102)
features_actuales = df_importancia.head(110)['Caracteristica'].tolist()

def evaluar_features(lista_feat):
    # Obtenemos los índices originales de df_importancia para estas características
    indices = [df_importancia[df_importancia['Caracteristica'] == f].index[0] for f in lista_feat]
    X_m = X_matrix_acumulado[:, indices]
    X_train = X_m[idx_correct_train]
    X_val = X_m[idx_val]
    X_test = X_m[idx_test]
    
    model = IsolationForest(n_estimators=200, max_samples='auto', contamination=contaminacion, random_state=SEED)
    model.fit(X_train)
    
    y_true_val = df_result.loc[idx_val, 'label'].apply(lambda x: 0 if x == 'correct' else 1)
    scores_val = model.decision_function(X_val)
    fpr_val, tpr_val, thresholds_val = roc_curve(y_true_val, -scores_val)
    opt_thresh = thresholds_val[np.argmax(tpr_val - fpr_val)]
    
    y_true = df_result.loc[idx_test, 'label'].apply(lambda x: 0 if x == 'correct' else 1)
    scores = model.decision_function(X_test)
    y_pred = (-scores >= opt_thresh).astype(int)
    
    f1 = f1_score(y_true, y_pred, zero_division=0)
    acc = accuracy_score(y_true, y_pred)
    
    return f1, acc, indices

# Evaluamos el baseline inicial y guardamos la mejor combinación inicial
mejor_f1, mejor_acc, mejores_indices_historicos = evaluar_features(features_actuales)
mejores_features_historicas = features_actuales.copy()

print(f"--> Baseline con {len(features_actuales)} features | F1 inicial: {mejor_f1:.4f} | Acc inicial: {mejor_acc:.4f}\n")

intentos_sin_mejora = 0
iteracion = 0

while len(features_actuales) > 1:
    iteracion += 1
    print(f"\n--- Iteración {iteracion} (Features actuales: {len(features_actuales)}) ---",end='\r')
    
    mejor_f1_ronda = -1
    mejor_acc_ronda = -1
    mejor_candidato_features = None
    
    # Probamos a quitar CADA una de las características actuales de una en una
    for i, feat_a_quitar in enumerate(features_actuales):
        features_prueba = features_actuales.copy()
        features_prueba.pop(i)
        
        f1_test, acc_test, _ = evaluar_features(features_prueba)
        
        # Buscamos la MEJOR opción de esta ronda concreta
        if f1_test > mejor_f1_ronda:
            mejor_f1_ronda = f1_test
            mejor_acc_ronda = acc_test
            mejor_candidato_features = features_prueba

    print(f"  -> Mejor opción de esta ronda (quitando una): F1: {mejor_f1_ronda:.4f} | Acc: {mejor_acc_ronda:.4f}")

    # Actualizamos obligatoriamente las features actuales con el mejor resultado de esta ronda para seguir avanzando
    features_actuales = mejor_candidato_features

    # Comprobamos si esta ronda ha batido el récord histórico global de F1
    if mejor_f1_ronda > mejor_f1:
        mejor_f1 = mejor_f1_ronda
        mejor_acc = mejor_acc_ronda
        mejores_features_historicas = features_actuales.copy()
        intentos_sin_mejora = 0  # Reiniciamos el contador porque hubo récord histórico
        print(f"✨ ¡Nuevo récord histórico! F1: {mejor_f1:.4f} | Acc: {mejor_acc:.4f} (Features restantes: {len(features_actuales)})")
    else:
        intentos_sin_mejora += 1
        print(f"⚠️ No se supera el récord histórico ({mejor_f1:.4f}). Intentos consecutivos sin batir récord: {intentos_sin_mejora}/10")
        
        # Si acumulamos 10 iteraciones seguidas sin batir el récord histórico, paramos
        if intentos_sin_mejora >= 10:
            print(f"\n🛑 Parada anticipada: Se han acumulado 10 iteraciones sin superar el mejor F1 histórico.")
            break

# Obtenemos los índices definitivos de la mejor combinación histórica encontrada
mejores_indices_finales = [df_importancia[df_importancia['Caracteristica'] == f].index[0] for f in mejores_features_historicas]

print(f"\n==========================================")
print(f"PROCESO FINALIZADO.")
print(f"Mejor F1 histórico alcanzado: {mejor_f1:.4f} (Accuracy: {mejor_acc:.4f})")
print(f"Número de características óptimas: {len(mejores_indices_finales)}")
print(f"==========================================")

display(mejores_indices_finales)
# Out:
# --> Baseline con 110 features | F1 inicial: 0.8489 | Acc inicial: 0.8367
#
#
#   -> Mejor opción de esta ronda (quitando una): F1: 0.8921 | Acc: 0.8836
# ✨ ¡Nuevo récord histórico! F1: 0.8921 | Acc: 0.8836 (Features restantes: 109)
#
#   -> Mejor opción de esta ronda (quitando una): F1: 0.8924 | Acc: 0.8848
# ✨ ¡Nuevo récord histórico! F1: 0.8924 | Acc: 0.8848 (Features restantes: 108)
#
#   -> Mejor opción de esta ronda (quitando una): F1: 0.8951 | Acc: 0.8876
# ✨ ¡Nuevo récord histórico! F1: 0.8951 | Acc: 0.8876 (Features restantes: 107)
#
#   -> Mejor opción de esta ronda (quitando una): F1: 0.8991 | Acc: 0.8925
# ✨ ¡Nuevo récord histórico! F1: 0.8991 | Acc: 0.8925 (Features restantes: 106)
#
#   -> Mejor opción de esta ronda (quitando una): F1: 0.8768 | Acc: 0.8688
# ⚠️ No se supera el récord histórico (0.8991). Intentos consecutivos sin batir récord: 1/10
#
#   -> Mejor opción de esta ronda (quitando una): F1: 0.9030 | Acc: 0.8962
# ✨ ¡Nuevo récord histórico! F1: 0.9030 | Acc: 0.8962 (Features restantes: 104)
#
#   -> Mejor opción de esta ronda (quitando una): F1: 0.8912 | Acc: 0.8842
# ⚠️ No se supera el récord histórico (0.9030). Intentos consecutivos sin batir récord: 1/10
#
#   -> Mejor opción de esta ronda (quitando una): F1: 0.8939 | Acc: 0.8865
# ⚠️ No se supera el récord histórico (0.9030). Intentos consecutivos sin batir récord: 2/10
#
#   -> Mejor opción de esta ronda (quitando una): F1: 0.8798 | Acc: 0.8697
# ⚠️ No se supera el récord histórico (0.9030). Intentos consecutivos sin batir récord: 3/10
#
#   -> Mejor opción de esta ronda (quitando una): F1: 0.9000 | Acc: 0.8933
# ⚠️ No se supera el récord histórico (0.9030). Intentos consecutivos sin batir récord: 4/10
#
#   -> Mejor opción de esta ronda (quitando una): F1: 0.8989 | Acc: 0.8916
# ⚠️ No se supera el récord histórico (0.9030). Intentos consecutivos sin batir récord: 5/10
#
#   -> Mejor opción de esta ronda (quitando una): F1: 0.9090 | Acc: 0.9041
# ✨ ¡Nuevo récord histórico! F1: 0.9090 | Acc: 0.9041 (Features restantes: 98)
#
#   -> Mejor opción de esta ronda (quitando una): F1: 0.9069 | Acc: 0.9007
# ⚠️ No se supera el récord histórico (0.9090). Intentos consecutivos sin batir récord: 1/10
#
#   -> Mejor opción de esta ronda (quitando una): F1: 0.9117 | Acc: 0.9067
# ✨ ¡Nuevo récord histórico! F1: 0.9117 | Acc: 0.9067 (Features restantes: 96)
#
#   -> Mejor opción de esta ronda (quitando una): F1: 0.9125 | Acc: 0.9078
# ✨ ¡Nuevo récord histórico! F1: 0.9125 | Acc: 0.9078 (Features restantes: 95)
#
#   -> Mejor opción de esta ronda (quitando una): F1: 0.9046 | Acc: 0.8993
# ⚠️ No se supera el récord histórico (0.9125). Intentos consecutivos sin batir récord: 1/10
#
#   -> Mejor opción de esta ronda (quitando una): F1: 0.9051 | Acc: 0.9001
# ⚠️ No se supera el récord histórico (0.9125). Intentos consecutivos sin batir récord: 2/10
#
#   -> Mejor opción de esta ronda (quitando una): F1: 0.8938 | Acc: 0.8848
# ⚠️ No se supera el récord histórico (0.9125). Intentos consecutivos sin batir récord: 3/10
#
#   -> Mejor opción de esta ronda (quitando una): F1: 0.9106 | Acc: 0.9058
# ⚠️ No se supera el récord histórico (0.9125). Intentos consecutivos sin batir récord: 4/10
#
#   -> Mejor opción de esta ronda (quitando una): F1: 0.9155 | Acc: 0.9115
# ✨ ¡Nuevo récord histórico! F1: 0.9155 | Acc: 0.9115 (Features restantes: 90)
#
#   -> Mejor opción de esta ronda (quitando una): F1: 0.9072 | Acc: 0.9013
# ⚠️ No se supera el récord histórico (0.9155). Intentos consecutivos sin batir récord: 1/10
#
#   -> Mejor opción de esta ronda (quitando una): F1: 0.9102 | Acc: 0.9047
# ⚠️ No se supera el récord histórico (0.9155). Intentos consecutivos sin batir récord: 2/10
#
#   -> Mejor opción de esta ronda (quitando una): F1: 0.9088 | Acc: 0.9030
# ⚠️ No se supera el récord histórico (0.9155). Intentos consecutivos sin batir récord: 3/10
#
#   -> Mejor opción de esta ronda (quitando una): F1: 0.9127 | Acc: 0.9073
# ⚠️ No se supera el récord histórico (0.9155). Intentos consecutivos sin batir récord: 4/10
#
#   -> Mejor opción de esta ronda (quitando una): F1: 0.9178 | Acc: 0.9132
# ✨ ¡Nuevo récord histórico! F1: 0.9178 | Acc: 0.9132 (Features restantes: 85)
#
#   -> Mejor opción de esta ronda (quitando una): F1: 0.9060 | Acc: 0.9004
# ⚠️ No se supera el récord histórico (0.9178). Intentos consecutivos sin batir récord: 1/10
#
#   -> Mejor opción de esta ronda (quitando una): F1: 0.9204 | Acc: 0.9161
# ✨ ¡Nuevo récord histórico! F1: 0.9204 | Acc: 0.9161 (Features restantes: 83)
#
#   -> Mejor opción de esta ronda (quitando una): F1: 0.9133 | Acc: 0.9078
# ⚠️ No se supera el récord histórico (0.9204). Intentos consecutivos sin batir récord: 1/10
#
#   -> Mejor opción de esta ronda (quitando una): F1: 0.9231 | Acc: 0.9189
# ✨ ¡Nuevo récord histórico! F1: 0.9231 | Acc: 0.9189 (Features restantes: 81)
#
#   -> Mejor opción de esta ronda (quitando una): F1: 0.9078 | Acc: 0.9021
# ⚠️ No se supera el récord histórico (0.9231). Intentos consecutivos sin batir récord: 1/10
#
#   -> Mejor opción de esta ronda (quitando una): F1: 0.9212 | Acc: 0.9166
# ⚠️ No se supera el récord histórico (0.9231). Intentos consecutivos sin batir récord: 2/10
#
#   -> Mejor opción de esta ronda (quitando una): F1: 0.9255 | Acc: 0.9218
# ✨ ¡Nuevo récord histórico! F1: 0.9255 | Acc: 0.9218 (Features restantes: 78)
#
#   -> Mejor opción de esta ronda (quitando una): F1: 0.9231 | Acc: 0.9186
# ⚠️ No se supera el récord histórico (0.9255). Intentos consecutivos sin batir récord: 1/10
#
#   -> Mejor opción de esta ronda (quitando una): F1: 0.9160 | Acc: 0.9110
# ⚠️ No se supera el récord histórico (0.9255). Intentos consecutivos sin batir récord: 2/10
#
#   -> Mejor opción de esta ronda (quitando una): F1: 0.9160 | Acc: 0.9110
# ⚠️ No se supera el récord histórico (0.9255). Intentos consecutivos sin batir récord: 3/10
#
#   -> Mejor opción de esta ronda (quitando una): F1: 0.9191 | Acc: 0.9147
# ⚠️ No se supera el récord histórico (0.9255). Intentos consecutivos sin batir récord: 4/10
#
#   -> Mejor opción de esta ronda (quitando una): F1: 0.9280 | Acc: 0.9243
# ✨ ¡Nuevo récord histórico! F1: 0.9280 | Acc: 0.9243 (Features restantes: 73)
#
#   -> Mejor opción de esta ronda (quitando una): F1: 0.9135 | Acc: 0.9081
# ⚠️ No se supera el récord histórico (0.9280). Intentos consecutivos sin batir récord: 1/10
#
#   -> Mejor opción de esta ronda (quitando una): F1: 0.9274 | Acc: 0.9232
# ⚠️ No se supera el récord histórico (0.9280). Intentos consecutivos sin batir récord: 2/10
#
#   -> Mejor opción de esta ronda (quitando una): F1: 0.9212 | Acc: 0.9169
# ⚠️ No se supera el récord histórico (0.9280). Intentos consecutivos sin batir récord: 3/10
#
#   -> Mejor opción de esta ronda (quitando una): F1: 0.9195 | Acc: 0.9149
# ⚠️ No se supera el récord histórico (0.9280). Intentos consecutivos sin batir récord: 4/10
#
#   -> Mejor opción de esta ronda (quitando una): F1: 0.9208 | Acc: 0.9164
# ⚠️ No se supera el récord histórico (0.9280). Intentos consecutivos sin batir récord: 5/10
#
#   -> Mejor opción de esta ronda (quitando una): F1: 0.9228 | Acc: 0.9181
# ⚠️ No se supera el récord histórico (0.9280). Intentos consecutivos sin batir récord: 6/10
#
#   -> Mejor opción de esta ronda (quitando una): F1: 0.9225 | Acc: 0.9186
# ⚠️ No se supera el récord histórico (0.9280). Intentos consecutivos sin batir récord: 7/10
#
#   -> Mejor opción de esta ronda (quitando una): F1: 0.9254 | Acc: 0.9215
# ⚠️ No se supera el récord histórico (0.9280). Intentos consecutivos sin batir récord: 8/10
#
#   -> Mejor opción de esta ronda (quitando una): F1: 0.9208 | Acc: 0.9164
# ⚠️ No se supera el récord histórico (0.9280). Intentos consecutivos sin batir récord: 9/10
#
#   -> Mejor opción de esta ronda (quitando una): F1: 0.9282 | Acc: 0.9246
# ✨ ¡Nuevo récord histórico! F1: 0.9282 | Acc: 0.9246 (Features restantes: 63)
#
#   -> Mejor opción de esta ronda (quitando una): F1: 0.9343 | Acc: 0.9314
# ✨ ¡Nuevo récord histórico! F1: 0.9343 | Acc: 0.9314 (Features restantes: 62)
#
#   -> Mejor opción de esta ronda (quitando una): F1: 0.9297 | Acc: 0.9257
# ⚠️ No se supera el récord histórico (0.9343). Intentos consecutivos sin batir récord: 1/10
#
#   -> Mejor opción de esta ronda (quitando una): F1: 0.9234 | Acc: 0.9192
# ⚠️ No se supera el récord histórico (0.9343). Intentos consecutivos sin batir récord: 2/10
#
#   -> Mejor opción de esta ronda (quitando una): F1: 0.9295 | Acc: 0.9255
# ⚠️ No se supera el récord histórico (0.9343). Intentos consecutivos sin batir récord: 3/10
#
#   -> Mejor opción de esta ronda (quitando una): F1: 0.9343 | Acc: 0.9309
# ✨ ¡Nuevo récord histórico! F1: 0.9343 | Acc: 0.9309 (Features restantes: 58)
#
#   -> Mejor opción de esta ronda (quitando una): F1: 0.9342 | Acc: 0.9312
# ⚠️ No se supera el récord histórico (0.9343). Intentos consecutivos sin batir récord: 1/10
#
#   -> Mejor opción de esta ronda (quitando una): F1: 0.9337 | Acc: 0.9300
# ⚠️ No se supera el récord histórico (0.9343). Intentos consecutivos sin batir récord: 2/10
#
#   -> Mejor opción de esta ronda (quitando una): F1: 0.9327 | Acc: 0.9292
# ⚠️ No se supera el récord histórico (0.9343). Intentos consecutivos sin batir récord: 3/10
#
#   -> Mejor opción de esta ronda (quitando una): F1: 0.9348 | Acc: 0.9314
# ✨ ¡Nuevo récord histórico! F1: 0.9348 | Acc: 0.9314 (Features restantes: 54)
#
#   -> Mejor opción de esta ronda (quitando una): F1: 0.9347 | Acc: 0.9314
# ⚠️ No se supera el récord histórico (0.9348). Intentos consecutivos sin batir récord: 1/10
#
#   -> Mejor opción de esta ronda (quitando una): F1: 0.9351 | Acc: 0.9317
# ✨ ¡Nuevo récord histórico! F1: 0.9351 | Acc: 0.9317 (Features restantes: 52)
#
#   -> Mejor opción de esta ronda (quitando una): F1: 0.9347 | Acc: 0.9314
# ⚠️ No se supera el récord histórico (0.9351). Intentos consecutivos sin batir récord: 1/10
#
#   -> Mejor opción de esta ronda (quitando una): F1: 0.9361 | Acc: 0.9329
# ✨ ¡Nuevo récord histórico! F1: 0.9361 | Acc: 0.9329 (Features restantes: 50)
#
#   -> Mejor opción de esta ronda (quitando una): F1: 0.9407 | Acc: 0.9377
# ✨ ¡Nuevo récord histórico! F1: 0.9407 | Acc: 0.9377 (Features restantes: 49)
#
#   -> Mejor opción de esta ronda (quitando una): F1: 0.9405 | Acc: 0.9374
# ⚠️ No se supera el récord histórico (0.9407). Intentos consecutivos sin batir récord: 1/10
#
#   -> Mejor opción de esta ronda (quitando una): F1: 0.9372 | Acc: 0.9340
# ⚠️ No se supera el récord histórico (0.9407). Intentos consecutivos sin batir récord: 2/10
#
#   -> Mejor opción de esta ronda (quitando una): F1: 0.9389 | Acc: 0.9363
# ⚠️ No se supera el récord histórico (0.9407). Intentos consecutivos sin batir récord: 3/10
#
#   -> Mejor opción de esta ronda (quitando una): F1: 0.9374 | Acc: 0.9340
# ⚠️ No se supera el récord histórico (0.9407). Intentos consecutivos sin batir récord: 4/10
#
#   -> Mejor opción de esta ronda (quitando una): F1: 0.9392 | Acc: 0.9363
# ⚠️ No se supera el récord histórico (0.9407). Intentos consecutivos sin batir récord: 5/10
#
#   -> Mejor opción de esta ronda (quitando una): F1: 0.9374 | Acc: 0.9349
# ⚠️ No se supera el récord histórico (0.9407). Intentos consecutivos sin batir récord: 6/10
#
#   -> Mejor opción de esta ronda (quitando una): F1: 0.9372 | Acc: 0.9340
# ⚠️ No se supera el récord histórico (0.9407). Intentos consecutivos sin batir récord: 7/10
#
#   -> Mejor opción de esta ronda (quitando una): F1: 0.9394 | Acc: 0.9363
# ⚠️ No se supera el récord histórico (0.9407). Intentos consecutivos sin batir récord: 8/10
#
#   -> Mejor opción de esta ronda (quitando una): F1: 0.9410 | Acc: 0.9383
# ✨ ¡Nuevo récord histórico! F1: 0.9410 | Acc: 0.9383 (Features restantes: 40)
#
#   -> Mejor opción de esta ronda (quitando una): F1: 0.9440 | Acc: 0.9422
# ✨ ¡Nuevo récord histórico! F1: 0.9440 | Acc: 0.9422 (Features restantes: 39)
#
#   -> Mejor opción de esta ronda (quitando una): F1: 0.9423 | Acc: 0.9397
# ⚠️ No se supera el récord histórico (0.9440). Intentos consecutivos sin batir récord: 1/10
#
#   -> Mejor opción de esta ronda (quitando una): F1: 0.9422 | Acc: 0.9394
# ⚠️ No se supera el récord histórico (0.9440). Intentos consecutivos sin batir récord: 2/10
#
#   -> Mejor opción de esta ronda (quitando una): F1: 0.9409 | Acc: 0.9380
# ⚠️ No se supera el récord histórico (0.9440). Intentos consecutivos sin batir récord: 3/10
#
#   -> Mejor opción de esta ronda (quitando una): F1: 0.9403 | Acc: 0.9377
# ⚠️ No se supera el récord histórico (0.9440). Intentos consecutivos sin batir récord: 4/10
#
#   -> Mejor opción de esta ronda (quitando una): F1: 0.9413 | Acc: 0.9383
# ⚠️ No se supera el récord histórico (0.9440). Intentos consecutivos sin batir récord: 5/10
#
#   -> Mejor opción de esta ronda (quitando una): F1: 0.9461 | Acc: 0.9454
# ✨ ¡Nuevo récord histórico! F1: 0.9461 | Acc: 0.9454 (Features restantes: 33)
#
#   -> Mejor opción de esta ronda (quitando una): F1: 0.9413 | Acc: 0.9385
# ⚠️ No se supera el récord histórico (0.9461). Intentos consecutivos sin batir récord: 1/10
#
#   -> Mejor opción de esta ronda (quitando una): F1: 0.9470 | Acc: 0.9462
# ✨ ¡Nuevo récord histórico! F1: 0.9470 | Acc: 0.9462 (Features restantes: 31)
#
#   -> Mejor opción de esta ronda (quitando una): F1: 0.9413 | Acc: 0.9391
# ⚠️ No se supera el récord histórico (0.9470). Intentos consecutivos sin batir récord: 1/10
#
#   -> Mejor opción de esta ronda (quitando una): F1: 0.9468 | Acc: 0.9457
# ⚠️ No se supera el récord histórico (0.9470). Intentos consecutivos sin batir récord: 2/10
#
#   -> Mejor opción de esta ronda (quitando una): F1: 0.9431 | Acc: 0.9414
# ⚠️ No se supera el récord histórico (0.9470). Intentos consecutivos sin batir récord: 3/10
#
#   -> Mejor opción de esta ronda (quitando una): F1: 0.9472 | Acc: 0.9465
# ✨ ¡Nuevo récord histórico! F1: 0.9472 | Acc: 0.9465 (Features restantes: 27)
#
#   -> Mejor opción de esta ronda (quitando una): F1: 0.9606 | Acc: 0.9602
# ✨ ¡Nuevo récord histórico! F1: 0.9606 | Acc: 0.9602 (Features restantes: 26)
#
#   -> Mejor opción de esta ronda (quitando una): F1: 0.9520 | Acc: 0.9519
# ⚠️ No se supera el récord histórico (0.9606). Intentos consecutivos sin batir récord: 1/10
#
#   -> Mejor opción de esta ronda (quitando una): F1: 0.9554 | Acc: 0.9553
# ⚠️ No se supera el récord histórico (0.9606). Intentos consecutivos sin batir récord: 2/10
#
#   -> Mejor opción de esta ronda (quitando una): F1: 0.9540 | Acc: 0.9536
# ⚠️ No se supera el récord histórico (0.9606). Intentos consecutivos sin batir récord: 3/10
#
#   -> Mejor opción de esta ronda (quitando una): F1: 0.9624 | Acc: 0.9622
# ✨ ¡Nuevo récord histórico! F1: 0.9624 | Acc: 0.9622 (Features restantes: 22)
#
#   -> Mejor opción de esta ronda (quitando una): F1: 0.9625 | Acc: 0.9627
# ✨ ¡Nuevo récord histórico! F1: 0.9625 | Acc: 0.9627 (Features restantes: 21)
#
#   -> Mejor opción de esta ronda (quitando una): F1: 0.9668 | Acc: 0.9664
# ✨ ¡Nuevo récord histórico! F1: 0.9668 | Acc: 0.9664 (Features restantes: 20)
#
#   -> Mejor opción de esta ronda (quitando una): F1: 0.9634 | Acc: 0.9633
# ⚠️ No se supera el récord histórico (0.9668). Intentos consecutivos sin batir récord: 1/10
#
#   -> Mejor opción de esta ronda (quitando una): F1: 0.9696 | Acc: 0.9696
# ✨ ¡Nuevo récord histórico! F1: 0.9696 | Acc: 0.9696 (Features restantes: 18)
#
#   -> Mejor opción de esta ronda (quitando una): F1: 0.9701 | Acc: 0.9701
# ✨ ¡Nuevo récord histórico! F1: 0.9701 | Acc: 0.9701 (Features restantes: 17)
#
#   -> Mejor opción de esta ronda (quitando una): F1: 0.9721 | Acc: 0.9718
# ✨ ¡Nuevo récord histórico! F1: 0.9721 | Acc: 0.9718 (Features restantes: 16)
#
#   -> Mejor opción de esta ronda (quitando una): F1: 0.9680 | Acc: 0.9679
# ⚠️ No se supera el récord histórico (0.9721). Intentos consecutivos sin batir récord: 1/10
#
#   -> Mejor opción de esta ronda (quitando una): F1: 0.9792 | Acc: 0.9792
# ✨ ¡Nuevo récord histórico! F1: 0.9792 | Acc: 0.9792 (Features restantes: 14)
#
#   -> Mejor opción de esta ronda (quitando una): F1: 0.9761 | Acc: 0.9761
# ⚠️ No se supera el récord histórico (0.9792). Intentos consecutivos sin batir récord: 1/10
#
#   -> Mejor opción de esta ronda (quitando una): F1: 0.9886 | Acc: 0.9886
# ✨ ¡Nuevo récord histórico! F1: 0.9886 | Acc: 0.9886 (Features restantes: 12)
#
#   -> Mejor opción de esta ronda (quitando una): F1: 0.9846 | Acc: 0.9846
# ⚠️ No se supera el récord histórico (0.9886). Intentos consecutivos sin batir récord: 1/10
#
#   -> Mejor opción de esta ronda (quitando una): F1: 0.9906 | Acc: 0.9906
# ✨ ¡Nuevo récord histórico! F1: 0.9906 | Acc: 0.9906 (Features restantes: 10)
#
#   -> Mejor opción de esta ronda (quitando una): F1: 0.9863 | Acc: 0.9863
# ⚠️ No se supera el récord histórico (0.9906). Intentos consecutivos sin batir récord: 1/10
#
#   -> Mejor opción de esta ronda (quitando una): F1: 0.9931 | Acc: 0.9932
# ✨ ¡Nuevo récord histórico! F1: 0.9931 | Acc: 0.9932 (Features restantes: 8)
#
#   -> Mejor opción de esta ronda (quitando una): F1: 0.9943 | Acc: 0.9943
# ✨ ¡Nuevo récord histórico! F1: 0.9943 | Acc: 0.9943 (Features restantes: 7)
#
#   -> Mejor opción de esta ronda (quitando una): F1: 0.9934 | Acc: 0.9935
# ⚠️ No se supera el récord histórico (0.9943). Intentos consecutivos sin batir récord: 1/10
#
#   -> Mejor opción de esta ronda (quitando una): F1: 0.9886 | Acc: 0.9886
# ⚠️ No se supera el récord histórico (0.9943). Intentos consecutivos sin batir récord: 2/10
#
#   -> Mejor opción de esta ronda (quitando una): F1: 0.9892 | Acc: 0.9892
# ⚠️ No se supera el récord histórico (0.9943). Intentos consecutivos sin batir récord: 3/10
#
#   -> Mejor opción de esta ronda (quitando una): F1: 0.9878 | Acc: 0.9878
# ⚠️ No se supera el récord histórico (0.9943). Intentos consecutivos sin batir récord: 4/10
#
#   -> Mejor opción de esta ronda (quitando una): F1: 0.9839 | Acc: 0.9838
# ⚠️ No se supera el récord histórico (0.9943). Intentos consecutivos sin batir récord: 5/10
#
#   -> Mejor opción de esta ronda (quitando una): F1: 0.8941 | Acc: 0.8876
# ⚠️ No se supera el récord histórico (0.9943). Intentos consecutivos sin batir récord: 6/10
#
# ==========================================
# PROCESO FINALIZADO.
# Mejor F1 histórico alcanzado: 0.9943 (Accuracy: 0.9943)
# Número de características óptimas: 7
# ==========================================
# [np.int64(131),
#  np.int64(286),
#  np.int64(191),
#  np.int64(17),
#  np.int64(79),
#  np.int64(127),
#  np.int64(50)]

# %%
model_name = 'IF(1 punto 3 intervalos seleccion features Youden)'

# 1. Selección de datos con las 7 mejores características óptimas obtenidas
X_matrix_reducida = X_matrix_acumulado[:, mejores_indices_finales]
X_correct_train   = X_matrix_reducida[idx_correct_train]
X_val             = X_matrix_reducida[idx_val]
X_test            = X_matrix_reducida[idx_test]

# 2. Entrenar el Isolation Forest
model = IsolationForest(
    n_estimators=200, 
    max_samples='auto', 
    contamination='auto',        
    random_state=SEED
)
model.fit(X_correct_train)

# 3. Usamos el conjunto de validación para obtener el umbral de decisión usando el índice de Youden
y_true_val = df_result.loc[idx_val, 'label'].apply(lambda x: 0 if x == 'correct' else 1)
scores_val = model.decision_function(X_val)
y_scores_val_roc = -scores_val  

fpr_val, tpr_val, thresholds_val = roc_curve(y_true_val, y_scores_val_roc)
optimal_idx = np.argmax(tpr_val - fpr_val)
optimal_threshold = thresholds_val[optimal_idx]

# 4. Calculamos la predicción para el conjunto de test
y_true = df_result.loc[idx_test, 'label'].apply(lambda x: 0 if x == 'correct' else 1)
scores = model.decision_function(X_test)
y_scores_roc = -scores  

roc_auc = roc_auc_score(y_true, y_scores_roc)
fpr, tpr, thresholds = roc_curve(y_true, y_scores_roc)
y_pred = (y_scores_roc >= optimal_threshold).astype(int)

# 5. Guardar en el DataFrame global (evitando fragmentación con dict temporal)
nuevas_columnas = {}
s_res = pd.Series(float('nan'), index=df_result.index)
s_res.loc[idx_test] = y_pred
nuevas_columnas[f'result_({model_name})'] = s_res

s_sco = pd.Series(float('nan'), index=df_result.index)
s_sco.loc[idx_test] = scores
nuevas_columnas[f'scores_({model_name})'] = s_sco

df_result = pd.concat([df_result, pd.DataFrame(nuevas_columnas)], axis=1)

# 6. Métricas y matriz de confusión
cm = confusion_matrix(y_true, y_pred, labels=[0, 1])
tn, fp, fn, tp = cm.ravel()

acc = accuracy_score(y_true, y_pred)
precision = precision_score(y_true, y_pred, zero_division=0)
recall = recall_score(y_true, y_pred, zero_division=0)
specificity = tn / (tn + fp) if (tn + fp) > 0 else 0
f1 = f1_score(y_true, y_pred, zero_division=0)

print(f'--- {model_name} (Umbral Youden: {optimal_threshold:.4f}) ---')
print(f'Accuracy    = {acc:.4f}')
print(f'Precision   = {precision:.4f}')
print(f'Recall      = {recall:.4f}')
print(f'Specificity = {specificity:.4f}')    
print(f'F1          = {f1:.4f}')
print(f'AUC         = {roc_auc:.4f}')

# Obtenemos la lista de nombres de las características usadas
lista_nombres_features = df_importancia.loc[mejores_indices_finales, 'Caracteristica'].tolist()

parametros = {
    'n_feat': len(mejores_indices_finales), 
    'contaminacion': contaminacion, 
    'metodo': 'youden', 
    'umbral_youden': float(optimal_threshold),
    'features_usadas': lista_nombres_features
}

reg_resultado_algoritmo = {
    'test_name': model_name,
    'parametros': json.dumps(parametros),
    'TP': int(tp), 'FP': int(fp), 'TN': int(tn), 'FN': int(fn),
    'accuracy': float(acc),
    'precision': float(precision),
    'recall': float(recall),
    'specificity': float(specificity),
    'f1_score': float(f1),
    'roc_auc': float(roc_auc)
}
lista_result.append(reg_resultado_algoritmo)

# 7. Visualización
fig, axes = plt.subplots(1, 2, figsize=(12, 5))

# 1. Matriz de confusión
disp_cm = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=['Normal (0)', 'Anomalía (1)'])
disp_cm.plot(ax=axes[0], cmap='Blues', colorbar=False)
axes[0].set_title(f'Matriz de Confusión \n{model_name}')
axes[0].set_aspect('equal')

# 2. Curva ROC
axes[1].plot(fpr, tpr, label=f'IF (AUC = {roc_auc:.4f})')
axes[1].plot([0, 1], [0, 1], 'k--', label='Aleatorio (AUC = 0.5)')
axes[1].set_xlabel('False Positive Rate (Positive label: 1)')
axes[1].set_ylabel('True Positive Rate (Positive label: 1)')
axes[1].set_title(f'Curva ROC\n{model_name}')
axes[1].legend(loc='lower right')
axes[1].set_aspect('equal')

# Activamos las líneas divisorias secundarias en la Curva ROC
axes[1].minorticks_on()
axes[1].grid(which='major', linestyle='-', linewidth='0.7', color='gray', alpha=0.6)
axes[1].grid(which='minor', linestyle=':', linewidth='0.5', color='lightgray', alpha=0.5)

plt.tight_layout()
plt.show()

paquete = {
    'model_name'     : model_name,
    'model'          : model,
    'parametros'     : {'contaminacion': contaminacion, 'threshold': optimal_threshold, 'features_usadas': lista_nombres_features},
    'lista_features' : lista_nombres_features,
    'resultado'      : {'accuracy': acc, 'precision': precision, 'recall': recall, 'f1': f1, 'specificity': specificity}
}
joblib.dump(paquete, f'{FOLDER_SALIDA}/models/{model_name}.joblib')
# Out:
# --- IF(1 punto 3 intervalos seleccion features Youden) (Umbral Youden: 0.1005) ---
# Accuracy    = 0.9943
# Precision   = 0.9915
# Recall      = 0.9971
# Specificity = 0.9915
# F1          = 0.9943
# AUC         = 0.9998
# ['result/models/IF(1 punto 3 intervalos seleccion features Youden).joblib']

# %%
lista_nombres_features
# Out:
# ['light-oauth2-oauth2-code-1(8)',
#  'light-oauth2-oauth2-token-1(6)',
#  'light-oauth2-oauth2-token-1(1)',
#  'light-oauth2-oauth2-client-1(27)',
#  'light-oauth2-oauth2-code-1(18)',
#  'light-oauth2-oauth2-code-1(68)',
#  'light-oauth2-oauth2-client-1(6)']
