# %%
from timescale import TimescaleDBManager
from dotenv import load_dotenv
from sqlalchemy import create_engine
import pandas as pd
import os
from sklearn.model_selection import train_test_split
from sklearn.ensemble import IsolationForest
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay,accuracy_score, precision_score, recall_score, f1_score
from sklearn.metrics import classification_report
from sklearn.inspection import permutation_importance
import matplotlib.pyplot as plt
import numpy as np
import joblib
import json
import re

# %%
load_dotenv()
user_env        = os.getenv("USER_DB")
pass_env        = os.getenv("PASS_DB")
host_env        = os.getenv("HOST_DB", "localhost")
port_env        = os.getenv("DB_PORT_EXPOSED", "5432")
db_env          = os.getenv("NAME_DB", "tfm_db")
FOLDER_SALIDA   = os.getenv("FOLDER_SALIDA")
FOLDER_TMP      = os.getenv("FOLDER_TMP")

SEED            = int(os.getenv("SEED"))

db = TimescaleDBManager(
    user=user_env,
    password=pass_env,
    host=host_env,
    port=port_env,
    dbname=db_env
)
db.conectar()
conexion_postgresql = db.connection

#esto es para usar una conexion postgrews para pandas que da un warning indicando que solo esta testeado para sqlalchemy
engine = create_engine(f'postgresql+psycopg2://{user_env}:{pass_env}@{host_env}:{port_env}/{db_env}')
# Out:
# 🔌 [OK] Conexión establecida con TimescaleDB.

# %%
SQL='select * from vectores'
df = pd.read_sql(SQL, engine)

# %%
lista_label = df['label'].unique().tolist()

# %%
len(lista_label)
# Out:
# 54

# %%
df_result=df[ ['vector_id','execution_name','label'] ].copy()
df_result['split_type'] = 'unknown'

# %%
df_result
# Out:
#        vector_id                    execution_name  \
# 0          90244  light-oauth2-data-1719592986.tar
# 1          90245  light-oauth2-data-1719592986.tar
# 2          90246  light-oauth2-data-1719592986.tar
# 3          90247  light-oauth2-data-1719592986.tar
# 4          90333  light-oauth2-data-1719594842.tar
# ...          ...                               ...
# 90185     180429  light-oauth2-data-1725866154.tar
# 90186     180430  light-oauth2-data-1725866154.tar
# 90187     180431  light-oauth2-data-1725866154.tar
# 90188     180432  light-oauth2-data-1725866154.tar
# 90189     180433  light-oauth2-data-1725866154.tar
#
#                                        label split_type
# 0                                    correct    unknown
# 1                                    correct    unknown
# 2                                    correct    unknown
# 3                                    correct    unknown
# 4      invalid_code_verifier_format_PKCE_400    unknown
# ...                                      ...        ...
# 90185                delete_user_404_no_user    unknown
# 90186     update_password_401_wrong_password    unknown
# 90187     update_password_404_user_not_found    unknown
# 90188          update_password_400_not_match    unknown
# 90189          update_password_400_not_match    unknown
#
# [90190 rows x 4 columns]

# %%
filename = f'{FOLDER_SALIDA}/lista_metric_name_vector.json'

with open(filename, "r", encoding="utf-8") as f:
    lista_metric_name_vector = json.load(f)

# %% [markdown]
# # <span style="color:#2ca02c">1. Separamos conjuntos de train, val y test</span>

# %% [markdown]
# <span style="color:#2ca02c">Por cada label dividimos los datos en train, val y test</span>

# %%
dic_idx_train = {}
dic_idx_resto = {}
dic_idx_val   = {}
dic_idx_test  = {}

# %%
for label in lista_label:
    indices = df[ df['label']== label ].index.values
    idx_train, idx_resto = train_test_split(indices   , test_size=0.4 , random_state=SEED)
    idx_val,   idx_test  = train_test_split(idx_resto , test_size=0.5 , random_state=SEED)
    df_result.loc[idx_train , 'split_type'] = 'train'
    df_result.loc[idx_val   , 'split_type'] = 'val'
    df_result.loc[idx_test  , 'split_type'] = 'test'
    dic_idx_train[label] = idx_train
    dic_idx_resto[label] = idx_resto
    dic_idx_val[label]   = idx_val
    dic_idx_test[label]  = idx_test

df_reparto = pd.DataFrame({
    'Cantidad': df_result['split_type'].value_counts(),
    'Porcentaje (%)': (df_result['split_type'].value_counts(normalize=True) * 100).round(2)
})

print("Reparto porcentual de los datos:")
display(df_reparto)
# Out:
# Reparto porcentual de los datos:
#             Cantidad  Porcentaje (%)
# split_type
# train          54093           59.98
# test           18058           20.02
# val            18039           20.00

# %%
df_result
# Out:
#        vector_id                    execution_name  \
# 0          90244  light-oauth2-data-1719592986.tar
# 1          90245  light-oauth2-data-1719592986.tar
# 2          90246  light-oauth2-data-1719592986.tar
# 3          90247  light-oauth2-data-1719592986.tar
# 4          90333  light-oauth2-data-1719594842.tar
# ...          ...                               ...
# 90185     180429  light-oauth2-data-1725866154.tar
# 90186     180430  light-oauth2-data-1725866154.tar
# 90187     180431  light-oauth2-data-1725866154.tar
# 90188     180432  light-oauth2-data-1725866154.tar
# 90189     180433  light-oauth2-data-1725866154.tar
#
#                                        label split_type
# 0                                    correct       test
# 1                                    correct      train
# 2                                    correct      train
# 3                                    correct       test
# 4      invalid_code_verifier_format_PKCE_400      train
# ...                                      ...        ...
# 90185                delete_user_404_no_user      train
# 90186     update_password_401_wrong_password        val
# 90187     update_password_404_user_not_found      train
# 90188          update_password_400_not_match        val
# 90189          update_password_400_not_match       test
#
# [90190 rows x 4 columns]

# %% [markdown]
# <span style="color:#2ca02c"> Convetimos los vectores del df en una matriz, seran los datos que pasemos a los algoritmo   </span>

# %%
X_matrix = np.array(df['vector'].tolist())
X_matrix.shape
# Out:
# (90190, 354)

# %% [markdown]
# # <span style="color:#2ca02c">2. Usamos Isolation Forest (IF) para </span>

# %% [markdown]
# <span style="color:#2ca02c"> Entrenamos IF con los datos del split 'train' y label 'correct'   </span>

# %%
idx_correct_train = dic_idx_train['correct']
idx_correct_val   = dic_idx_val['correct']
idx_correct_test  = dic_idx_test['correct']

# %%
N_datos_test_por_anomalia = int( len(idx_correct_test)  / (len(lista_label)-1) )

# %%
idx_test =idx_correct_test.copy()
for label in lista_label:
    if label=='correct':
        continue
    if len(dic_idx_test[label])<N_datos_test_por_anomalia:
        idx_test = np.concatenate((idx_test, dic_idx_test[label]))
    else:
        #idx_test.extend(dic_idx_test[label][:N_datos_test_por_anomalia])
        # Corrección: pon los dos arrays dentro de un paréntesis
        idx_test = np.concatenate((idx_test, dic_idx_test[label][:N_datos_test_por_anomalia]))
        
X_test  = X_matrix[idx_test]

# %%
len(idx_correct_train)
# Out:
# 10231

# %%
idx_correct_val
# Out:
# array([65461, 62557, 89796, ..., 31467, 42793, 37650], shape=(3410,))

# %%
idx_correct_test
# Out:
# array([54453, 70322, 76171, ...,  5440, 50166, 71891], shape=(3411,))

# %%
X_matrix.shape
# Out:
# (90190, 354)

# %%
X_correct_train = X_matrix[idx_correct_train]
X_correct_test  = X_matrix[idx_correct_test]

# %%
idx_correct_test.shape
# Out:
# (3411,)

# %%
 df.loc[idx_correct_test].shape
# Out:
# (3411, 5)

# %%
df.shape
# Out:
# (90190, 5)

# %%
df_result = pd.DataFrame({
    't_rel': df.loc[idx_test, 't_rel'],
    'execution_name': df.loc[idx_correct_test, 'execution_name'],
    'label': df.loc[idx_test, 'label']
})

N = 0
lista_result=[]
for contaminacion in [0.02, 0.015, 0.01, 0.008, 0.006, 0.004, 0.0035, 0.003, 0.002, 0.001, 0.0005]:
    N += 1
    model = IsolationForest(
        n_estimators=200, 
        max_samples='auto', 
        contamination=contaminacion, 
        random_state=SEED
    )
    model.fit(X_correct_train)
    scores = model.decision_function(X_test)
    Y_pred = model.predict(X_test)

    model_name = f'IF(contaminacion={contaminacion})'
    joblib.dump(model, f'{FOLDER_SALIDA}/models/{model_name}.joblib')
    

    df_result[f'result_({model_name})'] = float('nan')
    df_result[f'scores_({model_name})'] = float('nan')
    df_result.loc[idx_test, f'result_({model_name})'] = Y_pred
    df_result.loc[idx_test, f'scores_({model_name})'] = scores
    
    # Mapeo: Anomalía (-1) pasa a ser la clase positiva (1) para las métricas, 
    # y lo normal ('correct' / 1) pasa a ser la negativa (0 o -1 dependiendo del enfoque).
    # Usaremos 1 para Anomalía (Positivo) y 0 para Normal (Negativo) para facilitar scikit-learn.
    y_true = df_result.loc[idx_test, 'label'].apply(lambda x: 0 if x == 'correct' else 1)
    y_pred = df_result.loc[idx_test, f'result_({model_name})'].apply(lambda x: 0 if x == 1 else 1)
    
    # 1. Componentes de la matriz de confusión (con anomalía = positivo = 1)
    cm = confusion_matrix(y_true, y_pred, labels=[0, 1])
    tn, fp, fn, tp = cm.ravel()
    
    # 2. Cálculo de métricas
    acc = accuracy_score(y_true, y_pred)
    precision = precision_score(y_true, y_pred, zero_division=0)
    recall = recall_score(y_true, y_pred, zero_division=0)         # Sensibilidad / True Positive Rate
    specificity = tn / (tn + fp) if (tn + fp) > 0 else 0          # True Negative Rate
    f1 = f1_score(y_true, y_pred, zero_division=0)

    parametros={'contaminacion':contaminacion}
    # 3. Guardar en un diccionario de registro
    reg_resultado_algoritmo = {

        'test_name': model_name,
        'parametros': json.dumps(parametros),
        'TP': int(tp),
        'FP': int(fp),
        'TN': int(tn),
        'FN': int(fn),
        'accuracy': float(acc),
        'precision': float(precision),
        'recall': float(recall),
        'specificity': float(specificity),
        'f1_score': float(f1)
    }
    lista_result.append(reg_resultado_algoritmo)
    
    # 4. Visualizarla (Opcional: puedes comentar el show si son muchas iteraciones)
    disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=['Normal (0)', 'Anomalía (1)'])
    disp.plot(cmap='Blues')
    plt.title(f'Matriz de Confusión - Isolation Forest\n{model_name}')
    plt.show()

# Convertir la lista de registros en un DataFrame global para revisarlos cómodamente
df_anomaly_detection_summary = pd.DataFrame(lista_result)

# %%
df_anomaly_detection_summary.to_parquet(f'{FOLDER_SALIDA}/df_anomaly_detection_IF_summary.parquet', index=False,engine='fastparquet')

# %%
df_anomaly_detection_summary
# Out:
#                    test_name                 parametros    TP  FP    TN  FN  \
# 0     IF(contaminacion=0.02)    {"contaminacion": 0.02}  3370  56  3355   0
# 1    IF(contaminacion=0.015)   {"contaminacion": 0.015}  3370  47  3364   0
# 2     IF(contaminacion=0.01)    {"contaminacion": 0.01}  3370  28  3383   0
# 3    IF(contaminacion=0.008)   {"contaminacion": 0.008}  3370  22  3389   0
# 4    IF(contaminacion=0.006)   {"contaminacion": 0.006}  3370  14  3397   0
# 5    IF(contaminacion=0.004)   {"contaminacion": 0.004}  3370   7  3404   0
# 6   IF(contaminacion=0.0035)  {"contaminacion": 0.0035}  3370   6  3405   0
# 7    IF(contaminacion=0.003)   {"contaminacion": 0.003}  3370   6  3405   0
# 8    IF(contaminacion=0.002)   {"contaminacion": 0.002}  3370   5  3406   0
# 9    IF(contaminacion=0.001)   {"contaminacion": 0.001}  3370   2  3409   0
# 10  IF(contaminacion=0.0005)  {"contaminacion": 0.0005}  3370   2  3409   0
#
#     accuracy  precision  recall  specificity  f1_score
# 0   0.991742   0.983654     1.0     0.983583  0.991760
# 1   0.993069   0.986245     1.0     0.986221  0.993075
# 2   0.995871   0.991760     1.0     0.991791  0.995863
# 3   0.996756   0.993514     1.0     0.993550  0.996747
# 4   0.997935   0.995863     1.0     0.995896  0.997927
# 5   0.998968   0.997927     1.0     0.997948  0.998963
# 6   0.999115   0.998223     1.0     0.998241  0.999111
# 7   0.999115   0.998223     1.0     0.998241  0.999111
# 8   0.999263   0.998519     1.0     0.998534  0.999259
# 9   0.999705   0.999407     1.0     0.999414  0.999703
# 10  0.999705   0.999407     1.0     0.999414  0.999703

# %%
model = joblib.load(f'{FOLDER_SALIDA}/models/IF(contaminacion=0.0005).joblib')

Y_test = df_result.loc[idx_test, 'label'].apply(lambda x: 1 if x == 'correct' else -1)

result = permutation_importance(
    model, X_test, Y_test, 
    scoring='f1',
    n_repeats=10, 
    random_state=SEED, 
    n_jobs=-1
)

# Creamos el DataFrame de importancia
df_importancia = pd.DataFrame({
    'Caracteristica': lista_metric_name_vector,
    'Importancia': result.importances_mean
}).sort_values(by='Importancia', ascending=False)

print(df_importancia.head(10))
# Out:
#                                         Caracteristica  Importancia
# 353                     scrape_series_added_mod(lag_2)          0.0
# 334       prometheus_tsdb_head_active_appenders(lag_2)          0.0
# 333  prometheus_target_interval_length_seconds_sum_...          0.0
# 332  prometheus_target_interval_length_seconds_coun...          0.0
# 331   prometheus_target_interval_length_seconds(lag_2)          0.0
# 329  prometheus_remote_storage_highest_timestamp_in...          0.0
# 328  prometheus_http_response_size_bytes_sum_diff(l...          0.0
# 327  prometheus_http_response_size_bytes_count_diff...          0.0
# 326  prometheus_http_response_size_bytes_bucket_dif...          0.0
# 325  prometheus_http_request_duration_seconds_sum_d...          0.0

# %%
df_importancia.shape
# Out:
# (354, 2)

# %%
with pd.option_context('display.max_rows', None):
    display(df_importancia)
print(df_importancia[df_importancia['Importancia']<0].shape)
lista_features_poco_importantes=df_importancia[df_importancia['Importancia']<0]['Caracteristica'].tolist()
lista_features_poco_importantes = [re.sub(r'\s*\(.*?\)', '', cadena) for cadena in lista_features_poco_importantes]
lista_features_poco_importantes = list(set(lista_features_poco_importantes))
print(len(lista_features_poco_importantes))
# Out:
#                                         Caracteristica  Importancia
# 353                     scrape_series_added_mod(lag_2)     0.000000
# 334       prometheus_tsdb_head_active_appenders(lag_2)     0.000000
# 333  prometheus_target_interval_length_seconds_sum_...     0.000000
# 332  prometheus_target_interval_length_seconds_coun...     0.000000
# 331   prometheus_target_interval_length_seconds(lag_2)     0.000000
# 329  prometheus_remote_storage_highest_timestamp_in...     0.000000
# 328  prometheus_http_response_size_bytes_sum_diff(l...     0.000000
# 327  prometheus_http_response_size_bytes_count_diff...     0.000000
# 326  prometheus_http_response_size_bytes_bucket_dif...     0.000000
# 325  prometheus_http_request_duration_seconds_sum_d...     0.000000
# 324  prometheus_http_request_duration_seconds_count...     0.000000
# 323  prometheus_http_request_duration_seconds_bucke...     0.000000
# 322  prometheus_engine_query_samples_total_diff(lag_2)     0.000000
# 321  prometheus_engine_query_duration_seconds_sum_d...     0.000000
# 32               node_memory_Committed_AS_bytes(lag_0)     0.000000
# 30              node_memory_AnonHugePages_bytes(lag_0)     0.000000
# 27                                   node_load5(lag_0)     0.000000
# 26                                   node_load1(lag_0)     0.000000
# 25                              node_intr_total(lag_0)     0.000000
# 24                        node_forks_total_diff(lag_0)     0.000000
# 23                        node_filefd_allocated(lag_0)     0.000000
# 22             node_context_switches_total_diff(lag_0)     0.000000
# 21   net_conntrack_listener_conn_closed_total_diff(...     0.000000
# 20   net_conntrack_listener_conn_accepted_total_dif...     0.000000
# 19                              go_threads_diff(lag_0)     0.000000
# 18                        go_memstats_sys_bytes(lag_0)     0.000000
# 17                  go_memstats_stack_sys_bytes(lag_0)     0.000000
# 47                node_memory_Unevictable_bytes(lag_0)     0.000000
# 46                   node_memory_SwapFree_bytes(lag_0)     0.000000
# 45                 node_memory_SwapCached_bytes(lag_0)     0.000000
# 43                      node_memory_Shmem_bytes(lag_0)     0.000000
# 41                     node_memory_Percpu_bytes(lag_0)     0.000000
# 40                 node_memory_PageTables_bytes(lag_0)     0.000000
# 39                    node_memory_Mlocked_bytes(lag_0)     0.000000
# 37               node_memory_MemAvailable_bytes(lag_0)     0.000000
# 36                     node_memory_Mapped_bytes(lag_0)     0.000000
# 33                      node_memory_Dirty_bytes(lag_0)     0.000000
# 64                     node_sockstat_TCP_orphan(lag_0)     0.000000
# 61       node_scrape_collector_duration_seconds(lag_0)     0.000000
# 60    node_schedstat_waiting_seconds_total_diff(lag_0)     0.000000
# 59         node_schedstat_timeslices_total_diff(lag_0)     0.000000
# 57                           node_procs_running(lag_0)     0.000000
# 56                           node_procs_blocked(lag_0)     0.000000
# 55                 node_network_iface_link_diff(lag_0)     0.000000
# 54                   node_network_iface_id_diff(lag_0)     0.000000
# 53                node_netstat_Tcp_OutSegs_diff(lag_0)     0.000000
# 52                 node_netstat_Tcp_InSegs_diff(lag_0)     0.000000
# 51            node_netstat_IpExt_OutOctets_diff(lag_0)     0.000000
# 50             node_netstat_IpExt_InOctets_diff(lag_0)     0.000000
# 49                  node_memory_Writeback_bytes(lag_0)     0.000000
# 80                             process_open_fds(lag_0)     0.000000
# 79               process_cpu_seconds_total_diff(lag_0)     0.000000
# 78                     node_vmstat_pswpout_diff(lag_0)     0.000000
# 77                      node_vmstat_pswpin_diff(lag_0)     0.000000
# 76                     node_vmstat_pgpgout_diff(lag_0)     0.000000
# 75                      node_vmstat_pgpgin_diff(lag_0)     0.000000
# 74                     node_vmstat_pgfault_diff(lag_0)     0.000000
# 73                  node_timex_maxerror_seconds(lag_0)     0.000000
# 72        node_timex_frequency_adjustment_ratio(lag_0)     0.000000
# 71           node_timex_estimated_error_seconds(lag_0)     0.000000
# 70                       node_time_seconds_diff(lag_0)     0.000000
# 69       node_softnet_times_squeezed_total_diff(lag_0)     0.000000
# 68            node_softnet_processed_total_diff(lag_0)     0.000000
# 67                     node_softnet_backlog_len(lag_0)     0.000000
# 65                  node_sockstat_UDP_mem_bytes(lag_0)     0.000000
# 320  prometheus_engine_query_duration_seconds_count...     0.000000
# 319                   prometheus_engine_queries(lag_2)     0.000000
# 318           process_virtual_memory_bytes_diff(lag_2)     0.000000
# 317               process_resident_memory_bytes(lag_2)     0.000000
# 316                            process_open_fds(lag_2)     0.000000
# 315              process_cpu_seconds_total_diff(lag_2)     0.000000
# 314                    node_vmstat_pswpout_diff(lag_2)     0.000000
# 313                     node_vmstat_pswpin_diff(lag_2)     0.000000
# 312                    node_vmstat_pgpgout_diff(lag_2)     0.000000
# 310                    node_vmstat_pgfault_diff(lag_2)     0.000000
# 309                 node_timex_maxerror_seconds(lag_2)     0.000000
# 308       node_timex_frequency_adjustment_ratio(lag_2)     0.000000
# 307          node_timex_estimated_error_seconds(lag_2)     0.000000
# 306                      node_time_seconds_diff(lag_2)     0.000000
# 305      node_softnet_times_squeezed_total_diff(lag_2)     0.000000
# 96   prometheus_target_interval_length_seconds_coun...     0.000000
# 93   prometheus_remote_storage_highest_timestamp_in...     0.000000
# 91   prometheus_http_response_size_bytes_count_diff...     0.000000
# 90   prometheus_http_response_size_bytes_bucket_dif...     0.000000
# 89   prometheus_http_request_duration_seconds_sum_d...     0.000000
# 88   prometheus_http_request_duration_seconds_count...     0.000000
# 87   prometheus_http_request_duration_seconds_bucke...     0.000000
# 86   prometheus_engine_query_samples_total_diff(lag_0)     0.000000
# 85   prometheus_engine_query_duration_seconds_sum_d...     0.000000
# 84   prometheus_engine_query_duration_seconds_count...     0.000000
# 83                    prometheus_engine_queries(lag_0)     0.000000
# 82            process_virtual_memory_bytes_diff(lag_0)     0.000000
# 81                process_resident_memory_bytes(lag_0)     0.000000
# 112                     scrape_duration_seconds(lag_0)     0.000000
# 111  prometheus_tsdb_wal_storage_size_bytes_diff(la...     0.000000
# 110  prometheus_tsdb_wal_page_flushes_total_diff(la...     0.000000
# 108      prometheus_tsdb_mmap_chunks_total_diff(lag_0)     0.000000
# 107  prometheus_tsdb_isolation_low_watermark_diff(l...     0.000000
# 106  prometheus_tsdb_isolation_high_watermark_diff(...     0.000000
# 105            prometheus_tsdb_head_series_diff(lag_0)     0.000000
# 103  prometheus_tsdb_head_max_time_seconds_diff(lag_0)     0.000000
# 102          prometheus_tsdb_head_max_time_diff(lag_0)     0.000000
# 101  prometheus_tsdb_head_chunks_storage_size_bytes...     0.000000
# 98        prometheus_tsdb_head_active_appenders(lag_0)     0.000000
# 97   prometheus_target_interval_length_seconds_sum_...     0.000000
# 128             go_memstats_heap_released_bytes(lag_1)     0.000000
# 127                    go_memstats_heap_objects(lag_1)     0.000000
# 126                go_memstats_heap_inuse_bytes(lag_1)     0.000000
# 125                 go_memstats_heap_idle_bytes(lag_1)     0.000000
# 123        go_memstats_buck_hash_sys_bytes_diff(lag_1)     0.000000
# 122          go_memstats_alloc_bytes_total_diff(lag_1)     0.000000
# 121                               go_goroutines(lag_1)     0.000000
# 120             go_gc_duration_seconds_sum_diff(lag_1)     0.000000
# 119           go_gc_duration_seconds_count_diff(lag_1)     0.000000
# 118                      go_gc_duration_seconds(lag_1)     0.000000
# 117                     scrape_series_added_mod(lag_0)     0.000000
# 116                   scrape_series_added_isnan(lag_0)     0.000000
# 115                         scrape_series_added(lag_0)     0.000000
# 114                 scrape_samples_scraped_diff(lag_0)     0.000000
# 113  scrape_samples_post_metric_relabeling_diff(lag_0)     0.000000
# 144                                  node_load1(lag_1)     0.000000
# 143                             node_intr_total(lag_1)     0.000000
# 141                       node_filefd_allocated(lag_1)     0.000000
# 140            node_context_switches_total_diff(lag_1)     0.000000
# 139  net_conntrack_listener_conn_closed_total_diff(...     0.000000
# 138  net_conntrack_listener_conn_accepted_total_dif...     0.000000
# 137                             go_threads_diff(lag_1)     0.000000
# 135                 go_memstats_stack_sys_bytes(lag_1)     0.000000
# 134                 go_memstats_other_sys_bytes(lag_1)     0.000000
# 133                   go_memstats_next_gc_bytes(lag_1)     0.000000
# 132            go_memstats_mspan_sys_bytes_diff(lag_1)     0.000000
# 131               go_memstats_mspan_inuse_bytes(lag_1)     0.000000
# 130              go_memstats_mallocs_total_diff(lag_1)     0.000000
# 129       go_memstats_last_gc_time_seconds_diff(lag_1)     0.000000
# 160                node_memory_SUnreclaim_bytes(lag_1)     0.000000
# 159                    node_memory_Percpu_bytes(lag_1)     0.000000
# 158                node_memory_PageTables_bytes(lag_1)     0.000000
# 157                   node_memory_Mlocked_bytes(lag_1)     0.000000
# 156                   node_memory_MemFree_bytes(lag_1)     0.000000
# 155              node_memory_MemAvailable_bytes(lag_1)     0.000000
# 154                    node_memory_Mapped_bytes(lag_1)     0.000000
# 153               node_memory_KernelStack_bytes(lag_1)     0.000000
# 150              node_memory_Committed_AS_bytes(lag_1)     0.000000
# 149                   node_memory_Buffers_bytes(lag_1)     0.000000
# 148             node_memory_AnonHugePages_bytes(lag_1)     0.000000
# 147               node_memory_Active_file_bytes(lag_1)     0.000000
# 145                                  node_load5(lag_1)     0.000000
# 176   node_schedstat_running_seconds_total_diff(lag_1)     0.000000
# 175                          node_procs_running(lag_1)     0.000000
# 174                          node_procs_blocked(lag_1)     0.000000
# 173                node_network_iface_link_diff(lag_1)     0.000000
# 172                  node_network_iface_id_diff(lag_1)     0.000000
# 171               node_netstat_Tcp_OutSegs_diff(lag_1)     0.000000
# 170                node_netstat_Tcp_InSegs_diff(lag_1)     0.000000
# 168            node_netstat_IpExt_InOctets_diff(lag_1)     0.000000
# 167                 node_memory_Writeback_bytes(lag_1)     0.000000
# 165               node_memory_Unevictable_bytes(lag_1)     0.000000
# 164                  node_memory_SwapFree_bytes(lag_1)     0.000000
# 304           node_softnet_processed_total_diff(lag_2)     0.000000
# 303                    node_softnet_backlog_len(lag_2)     0.000000
# 302                  node_sockstat_sockets_used(lag_2)     0.000000
# 301                 node_sockstat_UDP_mem_bytes(lag_2)     0.000000
# 300                    node_sockstat_TCP_orphan(lag_2)     0.000000
# 299                 node_sockstat_TCP_mem_bytes(lag_2)     0.000000
# 297      node_scrape_collector_duration_seconds(lag_2)     0.000000
# 296   node_schedstat_waiting_seconds_total_diff(lag_2)     0.000000
# 295        node_schedstat_timeslices_total_diff(lag_2)     0.000000
# 292                          node_procs_blocked(lag_2)     0.000000
# 291                node_network_iface_link_diff(lag_2)     0.000000
# 290                  node_network_iface_id_diff(lag_2)     0.000000
# 289               node_netstat_Tcp_OutSegs_diff(lag_2)     0.000000
# 192                    node_vmstat_pgfault_diff(lag_1)     0.000000
# 191                 node_timex_maxerror_seconds(lag_1)     0.000000
# 190       node_timex_frequency_adjustment_ratio(lag_1)     0.000000
# 189          node_timex_estimated_error_seconds(lag_1)     0.000000
# 188                      node_time_seconds_diff(lag_1)     0.000000
# 187      node_softnet_times_squeezed_total_diff(lag_1)     0.000000
# 186           node_softnet_processed_total_diff(lag_1)     0.000000
# 185                    node_softnet_backlog_len(lag_1)     0.000000
# 184                  node_sockstat_sockets_used(lag_1)     0.000000
# 183                 node_sockstat_UDP_mem_bytes(lag_1)     0.000000
# 182                    node_sockstat_TCP_orphan(lag_1)     0.000000
# 181                 node_sockstat_TCP_mem_bytes(lag_1)     0.000000
# 179      node_scrape_collector_duration_seconds(lag_1)     0.000000
# 178   node_schedstat_waiting_seconds_total_diff(lag_1)     0.000000
# 177        node_schedstat_timeslices_total_diff(lag_1)     0.000000
# 208  prometheus_http_response_size_bytes_bucket_dif...     0.000000
# 207  prometheus_http_request_duration_seconds_sum_d...     0.000000
# 206  prometheus_http_request_duration_seconds_count...     0.000000
# 205  prometheus_http_request_duration_seconds_bucke...     0.000000
# 204  prometheus_engine_query_samples_total_diff(lag_1)     0.000000
# 203  prometheus_engine_query_duration_seconds_sum_d...     0.000000
# 202  prometheus_engine_query_duration_seconds_count...     0.000000
# 201                   prometheus_engine_queries(lag_1)     0.000000
# 200           process_virtual_memory_bytes_diff(lag_1)     0.000000
# 199               process_resident_memory_bytes(lag_1)     0.000000
# 198                            process_open_fds(lag_1)     0.000000
# 196                    node_vmstat_pswpout_diff(lag_1)     0.000000
# 195                     node_vmstat_pswpin_diff(lag_1)     0.000000
# 194                    node_vmstat_pgpgout_diff(lag_1)     0.000000
# 193                     node_vmstat_pgpgin_diff(lag_1)     0.000000
# 224  prometheus_tsdb_isolation_high_watermark_diff(...     0.000000
# 221  prometheus_tsdb_head_max_time_seconds_diff(lag_1)     0.000000
# 220          prometheus_tsdb_head_max_time_diff(lag_1)     0.000000
# 219  prometheus_tsdb_head_chunks_storage_size_bytes...     0.000000
# 218            prometheus_tsdb_head_chunks_diff(lag_1)     0.000000
# 216       prometheus_tsdb_head_active_appenders(lag_1)     0.000000
# 215  prometheus_target_interval_length_seconds_sum_...     0.000000
# 214  prometheus_target_interval_length_seconds_coun...     0.000000
# 213   prometheus_target_interval_length_seconds(lag_1)     0.000000
# 211  prometheus_remote_storage_highest_timestamp_in...     0.000000
# 210  prometheus_http_response_size_bytes_sum_diff(l...     0.000000
# 209  prometheus_http_response_size_bytes_count_diff...     0.000000
# 240          go_memstats_alloc_bytes_total_diff(lag_2)     0.000000
# 239                               go_goroutines(lag_2)     0.000000
# 238             go_gc_duration_seconds_sum_diff(lag_2)     0.000000
# 237           go_gc_duration_seconds_count_diff(lag_2)     0.000000
# 236                      go_gc_duration_seconds(lag_2)     0.000000
# 235                     scrape_series_added_mod(lag_1)     0.000000
# 234                   scrape_series_added_isnan(lag_1)     0.000000
# 233                         scrape_series_added(lag_1)     0.000000
# 232                 scrape_samples_scraped_diff(lag_1)     0.000000
# 231  scrape_samples_post_metric_relabeling_diff(lag_1)     0.000000
# 230                     scrape_duration_seconds(lag_1)     0.000000
# 229  prometheus_tsdb_wal_storage_size_bytes_diff(la...     0.000000
# 228  prometheus_tsdb_wal_page_flushes_total_diff(la...     0.000000
# 227          prometheus_tsdb_reloads_total_diff(lag_1)     0.000000
# 226      prometheus_tsdb_mmap_chunks_total_diff(lag_1)     0.000000
# 225  prometheus_tsdb_isolation_low_watermark_diff(l...     0.000000
# 256  net_conntrack_listener_conn_accepted_total_dif...     0.000000
# 255                             go_threads_diff(lag_2)     0.000000
# 253                 go_memstats_stack_sys_bytes(lag_2)     0.000000
# 252                 go_memstats_other_sys_bytes(lag_2)     0.000000
# 251                   go_memstats_next_gc_bytes(lag_2)     0.000000
# 250            go_memstats_mspan_sys_bytes_diff(lag_2)     0.000000
# 249               go_memstats_mspan_inuse_bytes(lag_2)     0.000000
# 248              go_memstats_mallocs_total_diff(lag_2)     0.000000
# 247       go_memstats_last_gc_time_seconds_diff(lag_2)     0.000000
# 246             go_memstats_heap_released_bytes(lag_2)     0.000000
# 245                    go_memstats_heap_objects(lag_2)     0.000000
# 244                go_memstats_heap_inuse_bytes(lag_2)     0.000000
# 243                 go_memstats_heap_idle_bytes(lag_2)     0.000000
# 242                    go_memstats_gc_sys_bytes(lag_2)     0.000000
# 241        go_memstats_buck_hash_sys_bytes_diff(lag_2)     0.000000
# 272                    node_memory_Mapped_bytes(lag_2)     0.000000
# 271               node_memory_KernelStack_bytes(lag_2)     0.000000
# 270             node_memory_Inactive_file_bytes(lag_2)     0.000000
# 268              node_memory_Committed_AS_bytes(lag_2)     0.000000
# 267                   node_memory_Buffers_bytes(lag_2)     0.000000
# 265               node_memory_Active_file_bytes(lag_2)     0.000000
# 258            node_context_switches_total_diff(lag_2)     0.000000
# 257  net_conntrack_listener_conn_closed_total_diff(...     0.000000
# 288                node_netstat_Tcp_InSegs_diff(lag_2)     0.000000
# 287           node_netstat_IpExt_OutOctets_diff(lag_2)     0.000000
# 286            node_netstat_IpExt_InOctets_diff(lag_2)     0.000000
# 285                 node_memory_Writeback_bytes(lag_2)     0.000000
# 284               node_memory_VmallocUsed_bytes(lag_2)     0.000000
# 283               node_memory_Unevictable_bytes(lag_2)     0.000000
# 278                node_memory_SUnreclaim_bytes(lag_2)     0.000000
# 277                    node_memory_Percpu_bytes(lag_2)     0.000000
# 276                node_memory_PageTables_bytes(lag_2)     0.000000
# 275                   node_memory_Mlocked_bytes(lag_2)     0.000000
# 274                   node_memory_MemFree_bytes(lag_2)     0.000000
# 273              node_memory_MemAvailable_bytes(lag_2)     0.000000
# 352                   scrape_series_added_isnan(lag_2)     0.000000
# 351                         scrape_series_added(lag_2)     0.000000
# 350                 scrape_samples_scraped_diff(lag_2)     0.000000
# 349  scrape_samples_post_metric_relabeling_diff(lag_2)     0.000000
# 348                     scrape_duration_seconds(lag_2)     0.000000
# 346  prometheus_tsdb_wal_page_flushes_total_diff(la...     0.000000
# 345          prometheus_tsdb_reloads_total_diff(lag_2)     0.000000
# 344      prometheus_tsdb_mmap_chunks_total_diff(lag_2)     0.000000
# 343  prometheus_tsdb_isolation_low_watermark_diff(l...     0.000000
# 342  prometheus_tsdb_isolation_high_watermark_diff(...     0.000000
# 340  prometheus_tsdb_head_series_created_total_diff...     0.000000
# 339  prometheus_tsdb_head_max_time_seconds_diff(lag_2)     0.000000
# 338          prometheus_tsdb_head_max_time_diff(lag_2)     0.000000
# 337  prometheus_tsdb_head_chunks_storage_size_bytes...     0.000000
# 16                  go_memstats_other_sys_bytes(lag_0)     0.000000
# 14             go_memstats_mspan_sys_bytes_diff(lag_0)     0.000000
# 13                go_memstats_mspan_inuse_bytes(lag_0)     0.000000
# 12               go_memstats_mallocs_total_diff(lag_0)     0.000000
# 11        go_memstats_last_gc_time_seconds_diff(lag_0)     0.000000
# 10              go_memstats_heap_released_bytes(lag_0)     0.000000
# 9                      go_memstats_heap_objects(lag_0)     0.000000
# 8                  go_memstats_heap_inuse_bytes(lag_0)     0.000000
# 7                   go_memstats_heap_idle_bytes(lag_0)     0.000000
# 6                      go_memstats_gc_sys_bytes(lag_0)     0.000000
# 5          go_memstats_buck_hash_sys_bytes_diff(lag_0)     0.000000
# 4            go_memstats_alloc_bytes_total_diff(lag_0)     0.000000
# 3                                 go_goroutines(lag_0)     0.000000
# 2               go_gc_duration_seconds_sum_diff(lag_0)     0.000000
# 1             go_gc_duration_seconds_count_diff(lag_0)     0.000000
# 266             node_memory_AnonHugePages_bytes(lag_2)    -0.000015
# 293                          node_procs_running(lag_2)    -0.000015
# 298                     node_sockstat_TCP_alloc(lag_2)    -0.000015
# 294   node_schedstat_running_seconds_total_diff(lag_2)    -0.000029
# 63                  node_sockstat_TCP_mem_bytes(lag_0)    -0.000029
# 254                       go_memstats_sys_bytes(lag_2)    -0.000044
# 161                     node_memory_Shmem_bytes(lag_1)    -0.000044
# 264               node_memory_Active_anon_bytes(lag_2)    -0.000059
# 263                                  node_load5(lag_2)    -0.000059
# 136                       go_memstats_sys_bytes(lag_1)    -0.000059
# 38                    node_memory_MemFree_bytes(lag_0)    -0.000059
# 146               node_memory_Active_anon_bytes(lag_1)    -0.000059
# 15                    go_memstats_next_gc_bytes(lag_0)    -0.000059
# 162                      node_memory_Slab_bytes(lag_1)    -0.000073
# 197              process_cpu_seconds_total_diff(lag_1)    -0.000073
# 0                        go_gc_duration_seconds(lag_0)    -0.000088
# 28                node_memory_Active_anon_bytes(lag_0)    -0.000088
# 166               node_memory_VmallocUsed_bytes(lag_1)    -0.000088
# 282                  node_memory_SwapFree_bytes(lag_2)    -0.000088
# 279                     node_memory_Shmem_bytes(lag_2)    -0.000088
# 281                node_memory_SwapCached_bytes(lag_2)    -0.000088
# 169           node_netstat_IpExt_OutOctets_diff(lag_1)    -0.000088
# 151                     node_memory_Dirty_bytes(lag_1)    -0.000088
# 180                     node_sockstat_TCP_alloc(lag_1)    -0.000103
# 124                    go_memstats_gc_sys_bytes(lag_1)    -0.000103
# 58    node_schedstat_running_seconds_total_diff(lag_0)    -0.000103
# 29                node_memory_Active_file_bytes(lag_0)    -0.000103
# 261                             node_intr_total(lag_2)    -0.000117
# 163                node_memory_SwapCached_bytes(lag_1)    -0.000117
# 35                node_memory_KernelStack_bytes(lag_0)    -0.000117
# 95    prometheus_target_interval_length_seconds(lag_0)    -0.000117
# 259                       node_filefd_allocated(lag_2)    -0.000117
# 48                node_memory_VmallocUsed_bytes(lag_0)    -0.000117
# 94   prometheus_remote_storage_samples_in_total_dif...    -0.000117
# 92   prometheus_http_response_size_bytes_sum_diff(l...    -0.000117
# 44                       node_memory_Slab_bytes(lag_0)    -0.000132
# 42                 node_memory_SUnreclaim_bytes(lag_0)    -0.000132
# 269                     node_memory_Dirty_bytes(lag_2)    -0.000132
# 260                       node_forks_total_diff(lag_2)    -0.000132
# 62                      node_sockstat_TCP_alloc(lag_0)    -0.000132
# 34              node_memory_Inactive_file_bytes(lag_0)    -0.000132
# 109          prometheus_tsdb_reloads_total_diff(lag_0)    -0.000132
# 152             node_memory_Inactive_file_bytes(lag_1)    -0.000132
# 142                       node_forks_total_diff(lag_1)    -0.000132
# 66                   node_sockstat_sockets_used(lag_0)    -0.000132
# 31                    node_memory_Buffers_bytes(lag_0)    -0.000132
# 217  prometheus_tsdb_head_chunks_created_total_diff...    -0.000147
# 222  prometheus_tsdb_head_series_created_total_diff...    -0.000147
# 223            prometheus_tsdb_head_series_diff(lag_1)    -0.000147
# 280                      node_memory_Slab_bytes(lag_2)    -0.000147
# 347  prometheus_tsdb_wal_storage_size_bytes_diff(la...    -0.000147
# 341            prometheus_tsdb_head_series_diff(lag_2)    -0.000147
# 262                                  node_load1(lag_2)    -0.000147
# 212  prometheus_remote_storage_samples_in_total_dif...    -0.000147
# 100            prometheus_tsdb_head_chunks_diff(lag_0)    -0.000147
# 104  prometheus_tsdb_head_series_created_total_diff...    -0.000147
# 99   prometheus_tsdb_head_chunks_created_total_diff...    -0.000147
# 311                     node_vmstat_pgpgin_diff(lag_2)    -0.000147
# 330  prometheus_remote_storage_samples_in_total_dif...    -0.000147
# 335  prometheus_tsdb_head_chunks_created_total_diff...    -0.000147
# 336            prometheus_tsdb_head_chunks_diff(lag_2)    -0.000147
# (61, 2)
# 40

# %%
lista_metric_name_vector
lista_metric_name_reducida_IF=[]
lista_idx_reducida_IF=[]
ID=0
for metric_name in lista_metric_name_vector:
    DESCARTAR=False
    for metric_name_poco_importante in lista_features_poco_importantes:
        if metric_name.find(metric_name_poco_importante)>=0:
            DESCARTAR=True
            break
    if not DESCARTAR:
        lista_metric_name_reducida_IF.append(metric_name)
        lista_idx_reducida_IF.append(ID)
    ID+=1

# %%
len(lista_metric_name_reducida_IF)
# Out:
# 222

# %%
X_matrix_reducida      = X_matrix[:, lista_idx_reducida_IF]
X_correct_train        = X_matrix_reducida[idx_correct_train]
X_test                 = X_matrix_reducida[idx_test]

# %%
for contaminacion in [0.02, 0.015, 0.01, 0.008, 0.006, 0.004, 0.0035, 0.003, 0.002, 0.001, 0.0005]:
    N += 1
    model = IsolationForest(
        n_estimators=200, 
        max_samples='auto', 
        contamination=contaminacion, 
        random_state=SEED
    )
    model.fit(X_correct_train)
    scores = model.decision_function(X_test)
    Y_pred = model.predict(X_test)

    model_name = f'IF_reducido(contaminacion={contaminacion})'
    joblib.dump(model, f'{FOLDER_SALIDA}/models/{model_name}.joblib')
    

    df_result[f'result_({model_name})'] = float('nan')
    df_result[f'scores_({model_name})'] = float('nan')
    df_result.loc[idx_test, f'result_({model_name})'] = Y_pred
    df_result.loc[idx_test, f'scores_({model_name})'] = scores
    
    # Mapeo: Anomalía (-1) pasa a ser la clase positiva (1) para las métricas, 
    # y lo normal ('correct' / 1) pasa a ser la negativa (0 o -1 dependiendo del enfoque).
    # Usaremos 1 para Anomalía (Positivo) y 0 para Normal (Negativo) para facilitar scikit-learn.
    y_true = df_result.loc[idx_test, 'label'].apply(lambda x: 0 if x == 'correct' else 1)
    y_pred = df_result.loc[idx_test, f'result_({model_name})'].apply(lambda x: 0 if x == 1 else 1)
    
    # 1. Componentes de la matriz de confusión (con anomalía = positivo = 1)
    cm = confusion_matrix(y_true, y_pred, labels=[0, 1])
    tn, fp, fn, tp = cm.ravel()
    
    # 2. Cálculo de métricas
    acc = accuracy_score(y_true, y_pred)
    precision = precision_score(y_true, y_pred, zero_division=0)
    recall = recall_score(y_true, y_pred, zero_division=0)         # Sensibilidad / True Positive Rate
    specificity = tn / (tn + fp) if (tn + fp) > 0 else 0          # True Negative Rate
    f1 = f1_score(y_true, y_pred, zero_division=0)

    parametros={'contaminacion':contaminacion}
    # 3. Guardar en un diccionario de registro
    reg_resultado_algoritmo = {

        'test_name': model_name,
        'parametros': json.dumps(parametros),
        'TP': int(tp),
        'FP': int(fp),
        'TN': int(tn),
        'FN': int(fn),
        'accuracy': float(acc),
        'precision': float(precision),
        'recall': float(recall),
        'specificity': float(specificity),
        'f1_score': float(f1)
    }
    lista_result.append(reg_resultado_algoritmo)
    
    # 4. Visualizarla (Opcional: puedes comentar el show si son muchas iteraciones)
    disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=['Normal (0)', 'Anomalía (1)'])
    disp.plot(cmap='Blues')
    plt.title(f'Matriz de Confusión - Isolation Forest\n{model_name}')
    plt.show()

# Convertir la lista de registros en un DataFrame global para revisarlos cómodamente
df_anomaly_detection_summary = pd.DataFrame(lista_result)

# %%
df_anomaly_detection_summary
# Out:
#                             test_name                 parametros    TP  FP  \
# 0              IF(contaminacion=0.02)    {"contaminacion": 0.02}  3370  56
# 1             IF(contaminacion=0.015)   {"contaminacion": 0.015}  3370  47
# 2              IF(contaminacion=0.01)    {"contaminacion": 0.01}  3370  28
# 3             IF(contaminacion=0.008)   {"contaminacion": 0.008}  3370  22
# 4             IF(contaminacion=0.006)   {"contaminacion": 0.006}  3370  14
# 5             IF(contaminacion=0.004)   {"contaminacion": 0.004}  3370   7
# 6            IF(contaminacion=0.0035)  {"contaminacion": 0.0035}  3370   6
# 7             IF(contaminacion=0.003)   {"contaminacion": 0.003}  3370   6
# 8             IF(contaminacion=0.002)   {"contaminacion": 0.002}  3370   5
# 9             IF(contaminacion=0.001)   {"contaminacion": 0.001}  3370   2
# 10           IF(contaminacion=0.0005)  {"contaminacion": 0.0005}  3370   2
# 11    IF_reducido(contaminacion=0.02)    {"contaminacion": 0.02}  3370  60
# 12   IF_reducido(contaminacion=0.015)   {"contaminacion": 0.015}  3370  45
# 13    IF_reducido(contaminacion=0.01)    {"contaminacion": 0.01}  3370  30
# 14   IF_reducido(contaminacion=0.008)   {"contaminacion": 0.008}  3370  24
# 15   IF_reducido(contaminacion=0.006)   {"contaminacion": 0.006}  3369  18
# 16   IF_reducido(contaminacion=0.004)   {"contaminacion": 0.004}  3369  11
# 17  IF_reducido(contaminacion=0.0035)  {"contaminacion": 0.0035}  3369  11
# 18   IF_reducido(contaminacion=0.003)   {"contaminacion": 0.003}  3369  10
# 19   IF_reducido(contaminacion=0.002)   {"contaminacion": 0.002}  3367   7
# 20   IF_reducido(contaminacion=0.001)   {"contaminacion": 0.001}  3362   2
# 21  IF_reducido(contaminacion=0.0005)  {"contaminacion": 0.0005}  3360   0
#
#       TN  FN  accuracy  precision    recall  specificity  f1_score
# 0   3355   0  0.991742   0.983654  1.000000     0.983583  0.991760
# 1   3364   0  0.993069   0.986245  1.000000     0.986221  0.993075
# 2   3383   0  0.995871   0.991760  1.000000     0.991791  0.995863
# 3   3389   0  0.996756   0.993514  1.000000     0.993550  0.996747
# 4   3397   0  0.997935   0.995863  1.000000     0.995896  0.997927
# 5   3404   0  0.998968   0.997927  1.000000     0.997948  0.998963
# 6   3405   0  0.999115   0.998223  1.000000     0.998241  0.999111
# 7   3405   0  0.999115   0.998223  1.000000     0.998241  0.999111
# 8   3406   0  0.999263   0.998519  1.000000     0.998534  0.999259
# 9   3409   0  0.999705   0.999407  1.000000     0.999414  0.999703
# 10  3409   0  0.999705   0.999407  1.000000     0.999414  0.999703
# 11  3351   0  0.991152   0.982507  1.000000     0.982410  0.991176
# 12  3366   0  0.993364   0.986823  1.000000     0.986807  0.993368
# 13  3381   0  0.995576   0.991176  1.000000     0.991205  0.995569
# 14  3387   0  0.996461   0.992929  1.000000     0.992964  0.996452
# 15  3393   1  0.997198   0.994686  0.999703     0.994723  0.997188
# 16  3400   1  0.998230   0.996746  0.999703     0.996775  0.998222
# 17  3400   1  0.998230   0.996746  0.999703     0.996775  0.998222
# 18  3401   1  0.998378   0.997041  0.999703     0.997068  0.998370
# 19  3404   3  0.998525   0.997925  0.999110     0.997948  0.998517
# 20  3409   8  0.998525   0.999405  0.997626     0.999414  0.998515
# 21  3411  10  0.998525   1.000000  0.997033     1.000000  0.998514

# %%
df_anomaly_detection_summary.to_parquet(f'{FOLDER_SALIDA}/df_anomaly_detection_IF_summary.parquet', index=False,engine='fastparquet')
