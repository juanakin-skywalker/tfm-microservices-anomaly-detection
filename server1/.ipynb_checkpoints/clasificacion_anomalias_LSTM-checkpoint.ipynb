# %%
from timescale import TimescaleDBManager
from dotenv import load_dotenv
from sqlalchemy import create_engine
import pandas as pd
import os
import matplotlib.pyplot as plt
import numpy as np
import joblib
import json
import re
from functools import partial

from sklearn.model_selection import train_test_split
from sklearn.model_selection import GridSearchCV
from sklearn.ensemble import IsolationForest
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay,accuracy_score, precision_score, recall_score, f1_score,classification_report
from sklearn.metrics import classification_report
from sklearn.metrics import roc_auc_score, roc_curve, RocCurveDisplay
from sklearn.inspection import permutation_importance
from sklearn.preprocessing import LabelEncoder
from sklearn.preprocessing import StandardScaler


from tensorflow.keras import layers, models
from tensorflow.keras.models import Model
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Input, Dense,BatchNormalization, Dropout
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import Callback
from tensorflow.keras.callbacks import EarlyStopping,ReduceLROnPlateau
from tensorflow.keras.models import load_model

from scikeras.wrappers import KerasRegressor
from xgboost import XGBClassifier
from lightgbm import LGBMClassifier

import optuna
import tensorflow as tf
import seaborn as sns

# %%
load_dotenv()
user_env        = os.getenv("USER_DB")
pass_env        = os.getenv("PASS_DB")
host_env        = os.getenv("HOST_DB", "localhost")
port_env        = os.getenv("DB_PORT_EXPOSED", "5432")
db_env          = os.getenv("NAME_DB", "tfm_db")
FOLDER_SALIDA   = os.getenv("FOLDER_SALIDA")
FOLDER_TMP      = os.getenv("FOLDER_TMP")

SEED            = 100#int(os.getenv("SEED"))

db = TimescaleDBManager(
    user=user_env,
    password=pass_env,
    host=host_env,
    port=port_env,
    dbname=db_env
)
db.conectar()
conexion_postgresql = db.connection

#esto es para usar una conexion postgrews para pandas que da un warning indicando que solo esta testeado para sqlalchemy
engine = create_engine(f'postgresql+psycopg2://{user_env}:{pass_env}@{host_env}:{port_env}/{db_env}')
# Out:
# 🔌 [OK] Conexión establecida con TimescaleDB.

# %%
SQL='select * from vectores'
df = pd.read_sql(SQL, engine)

# %%
lista_label = df['label'].unique().tolist()

# %%
len(lista_label)
# Out:
# 54

# %%
df_result=df[ ['vector_id','execution_name','label'] ].copy()

# %%
df_result
# Out:
#        vector_id                    execution_name  \
# 0          90244  light-oauth2-data-1719592986.tar
# 1          90245  light-oauth2-data-1719592986.tar
# 2          90246  light-oauth2-data-1719592986.tar
# 3          90247  light-oauth2-data-1719592986.tar
# 4          90333  light-oauth2-data-1719594842.tar
# ...          ...                               ...
# 90185     180429  light-oauth2-data-1725866154.tar
# 90186     180430  light-oauth2-data-1725866154.tar
# 90187     180431  light-oauth2-data-1725866154.tar
# 90188     180432  light-oauth2-data-1725866154.tar
# 90189     180433  light-oauth2-data-1725866154.tar
#
#                                        label
# 0                                    correct
# 1                                    correct
# 2                                    correct
# 3                                    correct
# 4      invalid_code_verifier_format_PKCE_400
# ...                                      ...
# 90185                delete_user_404_no_user
# 90186     update_password_401_wrong_password
# 90187     update_password_404_user_not_found
# 90188          update_password_400_not_match
# 90189          update_password_400_not_match
#
# [90190 rows x 3 columns]

# %%
filename = f'{FOLDER_SALIDA}/lista_metric_name_vector.json'

with open(filename, "r", encoding="utf-8") as f:
    lista_metric_name_vector = json.load(f)

lista_limpia = [metrica.split('(')[0] for metrica in lista_metric_name_vector]

# 2. Contar los valores únicos totales
valores_unicos = set(lista_limpia)
N_metric_value = len(valores_unicos)

# %% [markdown]
# # <span style="color:#2ca02c">1. Recuperamos separación ya hecha en conjuntos de train, val y test</span>

# %%
SQL='select * from vectores_split'
df_split = pd.read_sql(SQL, engine)

# %%
df_result = pd.merge(df_result, df_split, on="vector_id", how="inner")

# %%
df_result
# Out:
#        vector_id                    execution_name  \
# 0          90244  light-oauth2-data-1719592986.tar
# 1          90245  light-oauth2-data-1719592986.tar
# 2          90246  light-oauth2-data-1719592986.tar
# 3          90247  light-oauth2-data-1719592986.tar
# 4          90333  light-oauth2-data-1719594842.tar
# ...          ...                               ...
# 90185     180429  light-oauth2-data-1725866154.tar
# 90186     180430  light-oauth2-data-1725866154.tar
# 90187     180431  light-oauth2-data-1725866154.tar
# 90188     180432  light-oauth2-data-1725866154.tar
# 90189     180433  light-oauth2-data-1725866154.tar
#
#                                        label split_type
# 0                                    correct       test
# 1                                    correct      train
# 2                                    correct      train
# 3                                    correct       test
# 4      invalid_code_verifier_format_PKCE_400      train
# ...                                      ...        ...
# 90185                delete_user_404_no_user      train
# 90186     update_password_401_wrong_password        val
# 90187     update_password_404_user_not_found      train
# 90188          update_password_400_not_match        val
# 90189          update_password_400_not_match       test
#
# [90190 rows x 4 columns]

# %%
dic_idx_train = {}
#dic_idx_resto = {}
dic_idx_val   = {}
dic_idx_test  = {}

# %%
for label in lista_label:
    idx_train = df_result[  (df_result['label']==label) & (df_result['split_type'] == 'train') ].index.values
    idx_val   = df_result[  (df_result['label']==label) & (df_result['split_type'] == 'val'  ) ].index.values
    idx_test  = df_result[  (df_result['label']==label) & (df_result['split_type'] == 'test') ].index.values
    dic_idx_train[label] = idx_train
    dic_idx_val[label]   = idx_val
    dic_idx_test[label]  = idx_test

# %% [markdown]
# <span style="color:#2ca02c"> Convetimos los vectores del df en una matriz, seran los datos que pasemos a los algoritmo   </span>

# %%
X_matrix = np.array(df['vector'].tolist())
X_matrix.shape
# Out:
# (90190, 354)

# %%
timesteps = 3

X_matrix_LSTM = X_matrix.reshape((X_matrix.shape[0], timesteps, N_metric_value))

# %%
X_matrix_LSTM.shape
# Out:
# (90190, 3, 118)

# %% [markdown]
# # <span style="color:#2ca02c">2. Preparacion de datos para entrenamiento/test</span>

# %%
idx_correct_train = dic_idx_train['correct']
idx_correct_val   = dic_idx_val['correct']
idx_correct_test  = dic_idx_test['correct']

# %%
N_datos_test_por_anomalia = int( len(idx_correct_test)  / (len(lista_label)-1) )

# %%
idx_test =idx_correct_test.copy()
for label in lista_label:
    if label=='correct':
        continue
    if len(dic_idx_test[label])<N_datos_test_por_anomalia:
        idx_test = np.concatenate((idx_test, dic_idx_test[label]))
    else:
        #idx_test.extend(dic_idx_test[label][:N_datos_test_por_anomalia])
        # Corrección: pon los dos arrays dentro de un paréntesis
        idx_test = np.concatenate((idx_test, dic_idx_test[label][:N_datos_test_por_anomalia]))
        
X_test  = X_matrix_LSTM[idx_test]

# %%
X_correct_train = X_matrix_LSTM[idx_correct_train]
X_correct_test  = X_matrix_LSTM[idx_correct_test]

# %%
df_result = pd.DataFrame({
    't_rel': df.loc[idx_test, 't_rel'],
    'execution_name': df.loc[idx_correct_test, 'execution_name'],
    'label': df.loc[idx_test, 'label']
})

# %%
df_result
# Out:
#        t_rel                    execution_name  \
# 0        5.0  light-oauth2-data-1719592986.tar
# 3       20.0  light-oauth2-data-1719592986.tar
# 13     580.0                               NaN
# 20     595.0                               NaN
# 24     565.0                               NaN
# ...      ...                               ...
# 90016   45.0  light-oauth2-data-1725858922.tar
# 90126    5.0  light-oauth2-data-1725866154.tar
# 90131   35.0  light-oauth2-data-1725866154.tar
# 90133   45.0  light-oauth2-data-1725866154.tar
# 90134   50.0  light-oauth2-data-1725866154.tar
#
#                                  label
# 0                              correct
# 3                              correct
# 13      code_verifier_missing_pkce_400
# 20        verification_failed_pkce_400
# 24     code_verifier_too_long_pkce_400
# ...                                ...
# 90016                          correct
# 90126                          correct
# 90131                          correct
# 90133                          correct
# 90134                          correct
#
# [6781 rows x 3 columns]

# %% [markdown]
# # <span style="color:#2ca02c">3. Recuperación del LSTM autoencoder calculado</span>

# %%
paquete_joblib= joblib.load('result/models/AE_LSTM.joblib')

# 2. Recuperar las variables y el modelo de Keras usando su ruta
lstm_ae_opt = paquete_joblib['model']

# %% [markdown]
# # <span style="color:#2ca02c">4. Clasificacion de anomalias</span>

# %% [markdown]
# ## <span style="color:#2ca02c">4.1. N/A</span>

# %% [markdown]
# ## <span style="color:#2ca02c">4.2. Clasificador Random Forest usando espacio latente del LSTM Auto Encoder</span>

# %%
idx_train = np.array([], dtype=int)
idx_test  = np.array([], dtype=int)

# %%
for label in lista_label:
    if label=='correct':
        continue
    idx_train_tmp = dic_idx_train[label]
    idx_train     = np.concatenate((idx_train , idx_train_tmp))
    idx_test_tmp  = dic_idx_test[label]
    idx_test      = np.concatenate((idx_test  , idx_test_tmp ))

# %%
X_anomalia_train = X_matrix_LSTM[idx_train]
X_anomalia_test  = X_matrix_LSTM[idx_test]

# %%
X_anomalia_test.shape
# Out:
# (14647, 3, 118)

# %%
Y_train_etiquetas = df.loc[idx_train , 'label']
Y_test_etiquetas  = df.loc[idx_test  , 'label']

# %%
# 1. Creamos una entrada explícita con la forma correcta de tus datos (timesteps, features)
encoder_inputs = Input(shape=(timesteps, N_metric_value))

# 2. Reutilizamos exactamente la capa LSTM del encoder de tu modelo ya entrenado (lstm_ae_opt.layers[0])
encoder_lstm_layer = lstm_ae_opt.layers[0]
encoder_outputs = encoder_lstm_layer(encoder_inputs)

# 3. Construimos el modelo funcional del encoder limpio y sin errores
encoder_model = Model(inputs=encoder_inputs, outputs=encoder_outputs, name='functional_encoder')

# %%
# 4. Ahora ya puedes extraer las características latentes de forma segura y directa
X_train_latente = encoder_model.predict(X_anomalia_train , verbose=0)
X_test_latente  = encoder_model.predict(X_anomalia_test  , verbose=0)

# %%
X_train_latente.shape
# Out:
# (43862, 128)

# %%
clf_anomalias = RandomForestClassifier(random_state=SEED, n_estimators=100)
clf_anomalias.fit(X_train_latente, Y_train_etiquetas)

# 5. Predecir y evaluar
Y_pred_tipos = clf_anomalias.predict(X_test_latente)

print("=== REPORTE DE CLASIFICACIÓN (USANDO ESPACIO LATENTE) ===")
print(classification_report(Y_test_etiquetas, Y_pred_tipos))
# Out:
# === REPORTE DE CLASIFICACIÓN (USANDO ESPACIO LATENTE) ===
#                                                precision    recall  f1-score   support
#
#            access_token_auth_header_error_401       0.00      0.00      0.00       290
#           access_token_authorization_form_401       0.00      0.00      0.00       297
#          access_token_client_id_not_found_404       0.02      0.01      0.01       307
#          access_token_client_secret_wrong_401       0.02      0.01      0.01       287
#              access_token_form_urlencoded_400       0.05      0.01      0.02       310
#           access_token_illegal_grant_type_400       0.03      0.01      0.01       306
# access_token_missing_authorization_header_400       0.02      0.01      0.01       299
#      authorization_code_client_id_missing_400       0.01      0.00      0.01       282
#      authorization_code_invalid_client_id_404       0.00      0.00      0.00       299
#       authorization_code_invalid_password_401       0.00      0.00      0.00       320
#  authorization_code_missing_response_type_400       0.00      0.00      0.00       277
#      authorization_code_response_not_code_400       0.00      0.00      0.00       263
#        code_challenge_invalid_format_pkce_400       0.02      0.00      0.01       266
#              code_challenge_too_long_pkce_400       0.03      0.01      0.02       276
#             code_challenge_too_short_pkce_400       0.00      0.00      0.00       283
#                code_verifier_missing_pkce_400       0.05      0.01      0.01       273
#               code_verifier_too_long_pkce_400       0.01      0.00      0.01       261
#              code_verifier_too_short_pkce_400       0.00      0.00      0.00       271
#                   delete_client_404_no_client       0.05      0.01      0.02       217
#                 delete_service_404_no_service       0.01      0.00      0.01       278
#                              delete_token_404       0.02      0.00      0.01       269
#                       delete_user_404_no_user       0.00      0.00      0.00       283
#                      get_client_404_no_client       0.07      0.04      0.05       328
#                   get_client_page_400_no_page       0.03      0.01      0.01       238
#                    get_service_404_no_service       0.07      0.03      0.04       314
#                  get_service_page_400_no_page       0.03      0.01      0.02       317
#                                 get_token_404       0.04      0.01      0.01       285
#                    get_token_page_400_no_page       0.04      0.01      0.02       266
#                          get_user_404_no_user       0.02      0.00      0.01       277
#                     get_user_page_400_no_page       0.00      0.00      0.00       287
#        invalid_code_challenge_method_pkce_400       0.00      0.00      0.00       286
#         invalid_code_verifier_format_PKCE_400       0.02      0.01      0.02       275
#             register_client_400_clientProfile       0.36      0.10      0.15        42
#                register_client_400_clientType       0.36      0.53      0.43       302
#                   register_client_404_no_user       0.24      0.14      0.18       340
#               register_service_400_service_id       0.14      0.02      0.03       173
#             register_service_400_service_type       0.03      0.01      0.01       286
#                  register_service_404_no_user       0.03      0.01      0.01       304
#                register_user_400_email_exists       0.04      0.01      0.02       286
#                 register_user_400_no_password       0.02      0.00      0.01       299
#           register_user_400_password_no_match       0.05      0.01      0.02       294
#                 register_user_400_user_exists       0.01      0.00      0.01       280
#               update_client_400_clientProfile       0.14      0.06      0.08       282
#                  update_client_400_clientType       0.00      0.00      0.00        65
#                    update_client_404_clientId       0.00      0.00      0.00       148
#                     update_client_404_ownerId       0.06      0.10      0.08       335
#                 update_password_400_not_match       0.04      0.77      0.08       542
#            update_password_401_wrong_password       0.04      0.01      0.01       264
#            update_password_404_user_not_found       0.02      0.00      0.01       260
#                 update_service_404_service_id       0.00      0.00      0.00       241
#                    update_service_404_user_id       0.00      0.00      0.00       247
#                       update_user_404_no_user       0.05      0.01      0.01       280
#                  verification_failed_pkce_400       0.03      0.01      0.02       290
#
#                                      accuracy                           0.05     14647
#                                     macro avg       0.04      0.04      0.03     14647
#                                  weighted avg       0.04      0.05      0.03     14647

# %% [markdown]
# ## <span style="color:#2ca02c">4.3. Clasificador Random Forest usando metricas originales +espacio latente del LSTM Auto Encoder</span>

# %%
print(X_anomalia_train.shape)
print(X_anomalia_test.shape)
# Out:
# (43862, 3, 118)
# (14647, 3, 118)

# %%
n_samples_train = X_anomalia_train.shape[0]
X_anomalia_train_2d = X_anomalia_train.reshape(n_samples_train, -1)

n_samples_test = X_anomalia_test.shape[0]
X_anomalia_test_2d = X_anomalia_test.reshape(n_samples_test, -1)

# %%
# 2. Concatenar las features originales con las features latentes (eje de columnas)
X_train_enriquecido = np.hstack((X_anomalia_train_2d, X_train_latente))
X_test_enriquecido = np.hstack((X_anomalia_test_2d, X_test_latente))

# 3. Entrenar el RandomForest con este dataset enriquecido
clf_anomalias.fit(X_train_enriquecido, Y_train_etiquetas)
Y_pred_tipos = clf_anomalias.predict(X_test_enriquecido)

print(classification_report(Y_test_etiquetas, Y_pred_tipos))
# Out:
#                                                precision    recall  f1-score   support
#
#            access_token_auth_header_error_401       0.46      0.53      0.49       290
#           access_token_authorization_form_401       0.54      0.60      0.57       297
#          access_token_client_id_not_found_404       0.57      0.62      0.59       307
#          access_token_client_secret_wrong_401       0.51      0.45      0.48       287
#              access_token_form_urlencoded_400       0.61      0.63      0.62       310
#           access_token_illegal_grant_type_400       0.52      0.55      0.53       306
# access_token_missing_authorization_header_400       0.55      0.50      0.52       299
#      authorization_code_client_id_missing_400       0.58      0.54      0.56       282
#      authorization_code_invalid_client_id_404       0.47      0.45      0.46       299
#       authorization_code_invalid_password_401       0.59      0.70      0.64       320
#  authorization_code_missing_response_type_400       0.63      0.61      0.62       277
#      authorization_code_response_not_code_400       0.60      0.52      0.56       263
#        code_challenge_invalid_format_pkce_400       0.58      0.60      0.59       266
#              code_challenge_too_long_pkce_400       0.59      0.59      0.59       276
#             code_challenge_too_short_pkce_400       0.59      0.58      0.58       283
#                code_verifier_missing_pkce_400       0.71      0.71      0.71       273
#               code_verifier_too_long_pkce_400       0.71      0.72      0.72       261
#              code_verifier_too_short_pkce_400       0.73      0.69      0.71       271
#                   delete_client_404_no_client       0.92      0.84      0.88       217
#                 delete_service_404_no_service       0.78      0.71      0.74       278
#                              delete_token_404       0.45      0.48      0.46       269
#                       delete_user_404_no_user       0.52      0.51      0.52       283
#                      get_client_404_no_client       0.86      0.96      0.91       328
#                   get_client_page_400_no_page       0.82      0.88      0.85       238
#                    get_service_404_no_service       0.68      0.76      0.72       314
#                  get_service_page_400_no_page       0.72      0.68      0.70       317
#                                 get_token_404       0.55      0.67      0.61       285
#                    get_token_page_400_no_page       0.55      0.59      0.57       266
#                          get_user_404_no_user       0.39      0.36      0.37       277
#                     get_user_page_400_no_page       0.37      0.38      0.37       287
#        invalid_code_challenge_method_pkce_400       0.62      0.49      0.55       286
#         invalid_code_verifier_format_PKCE_400       0.68      0.65      0.66       275
#             register_client_400_clientProfile       1.00      0.95      0.98        42
#                register_client_400_clientType       1.00      1.00      1.00       302
#                   register_client_404_no_user       0.99      1.00      1.00       340
#               register_service_400_service_id       0.83      0.58      0.68       173
#             register_service_400_service_type       0.74      0.83      0.78       286
#                  register_service_404_no_user       0.76      0.84      0.80       304
#                register_user_400_email_exists       0.68      0.62      0.65       286
#                 register_user_400_no_password       0.38      0.43      0.40       299
#           register_user_400_password_no_match       0.48      0.49      0.49       294
#                 register_user_400_user_exists       0.69      0.60      0.64       280
#               update_client_400_clientProfile       0.97      0.98      0.98       282
#                  update_client_400_clientType       0.95      0.95      0.95        65
#                    update_client_404_clientId       0.86      0.82      0.84       148
#                     update_client_404_ownerId       0.95      0.97      0.96       335
#                 update_password_400_not_match       0.83      0.92      0.87       542
#            update_password_401_wrong_password       0.59      0.42      0.49       264
#            update_password_404_user_not_found       0.54      0.58      0.56       260
#                 update_service_404_service_id       0.70      0.64      0.67       241
#                    update_service_404_user_id       0.79      0.70      0.74       247
#                       update_user_404_no_user       0.36      0.33      0.34       280
#                  verification_failed_pkce_400       0.75      0.70      0.73       290
#
#                                      accuracy                           0.66     14647
#                                     macro avg       0.67      0.66      0.66     14647
#                                  weighted avg       0.66      0.66      0.65     14647

# %% [markdown]
# ## <span style="color:#2ca02c">4.3. Clasificador Random Forest usando metricas originales +espacio latente del LSTM Auto Encoder</span>

# %%
# 2. Concatenar las features originales con las features latentes (eje de columnas)
X_train_enriquecido = np.hstack((X_anomalia_train, X_train_latente))
X_test_enriquecido = np.hstack((X_anomalia_test, X_test_latente))

# 3. Entrenar el RandomForest con este dataset enriquecido
clf_anomalias.fit(X_train_enriquecido, Y_train_etiquetas)
Y_pred_tipos = clf_anomalias.predict(X_test_enriquecido)

print(classification_report(Y_test_etiquetas, Y_pred_tipos))
# Out:
#                                                precision    recall  f1-score   support
#
#            access_token_auth_header_error_401       0.51      0.53      0.52       290
#           access_token_authorization_form_401       0.58      0.59      0.58       297
#          access_token_client_id_not_found_404       0.58      0.62      0.60       307
#          access_token_client_secret_wrong_401       0.58      0.52      0.55       287
#              access_token_form_urlencoded_400       0.59      0.65      0.62       310
#           access_token_illegal_grant_type_400       0.53      0.55      0.54       306
# access_token_missing_authorization_header_400       0.55      0.49      0.52       299
#      authorization_code_client_id_missing_400       0.65      0.63      0.64       282
#      authorization_code_invalid_client_id_404       0.53      0.54      0.54       299
#       authorization_code_invalid_password_401       0.58      0.71      0.64       320
#  authorization_code_missing_response_type_400       0.62      0.57      0.59       277
#      authorization_code_response_not_code_400       0.68      0.58      0.63       263
#        code_challenge_invalid_format_pkce_400       0.59      0.66      0.63       266
#              code_challenge_too_long_pkce_400       0.63      0.59      0.61       276
#             code_challenge_too_short_pkce_400       0.54      0.52      0.53       283
#                code_verifier_missing_pkce_400       0.68      0.74      0.71       273
#               code_verifier_too_long_pkce_400       0.76      0.70      0.73       261
#              code_verifier_too_short_pkce_400       0.74      0.68      0.71       271
#                   delete_client_404_no_client       0.93      0.86      0.89       217
#                 delete_service_404_no_service       0.80      0.71      0.75       278
#                              delete_token_404       0.49      0.54      0.52       269
#                       delete_user_404_no_user       0.55      0.52      0.54       283
#                      get_client_404_no_client       0.87      0.97      0.92       328
#                   get_client_page_400_no_page       0.83      0.85      0.84       238
#                    get_service_404_no_service       0.73      0.75      0.74       314
#                  get_service_page_400_no_page       0.70      0.72      0.71       317
#                                 get_token_404       0.54      0.66      0.60       285
#                    get_token_page_400_no_page       0.53      0.58      0.55       266
#                          get_user_404_no_user       0.38      0.39      0.38       277
#                     get_user_page_400_no_page       0.32      0.31      0.31       287
#        invalid_code_challenge_method_pkce_400       0.58      0.54      0.56       286
#         invalid_code_verifier_format_PKCE_400       0.71      0.66      0.68       275
#             register_client_400_clientProfile       1.00      0.95      0.98        42
#                register_client_400_clientType       1.00      1.00      1.00       302
#                   register_client_404_no_user       0.99      1.00      1.00       340
#               register_service_400_service_id       0.83      0.66      0.74       173
#             register_service_400_service_type       0.77      0.86      0.81       286
#                  register_service_404_no_user       0.83      0.86      0.84       304
#                register_user_400_email_exists       0.72      0.63      0.67       286
#                 register_user_400_no_password       0.41      0.47      0.44       299
#           register_user_400_password_no_match       0.52      0.51      0.51       294
#                 register_user_400_user_exists       0.73      0.61      0.66       280
#               update_client_400_clientProfile       0.97      0.98      0.98       282
#                  update_client_400_clientType       0.94      0.95      0.95        65
#                    update_client_404_clientId       0.87      0.84      0.86       148
#                     update_client_404_ownerId       0.96      0.97      0.96       335
#                 update_password_400_not_match       0.83      0.92      0.87       542
#            update_password_401_wrong_password       0.53      0.41      0.46       264
#            update_password_404_user_not_found       0.53      0.60      0.56       260
#                 update_service_404_service_id       0.68      0.68      0.68       241
#                    update_service_404_user_id       0.80      0.75      0.78       247
#                       update_user_404_no_user       0.40      0.33      0.36       280
#                  verification_failed_pkce_400       0.74      0.68      0.71       290
#
#                                      accuracy                           0.67     14647
#                                     macro avg       0.68      0.67      0.67     14647
#                                  weighted avg       0.67      0.67      0.67     14647

# %% [markdown]
# ## <span style="color:#2ca02c">4.4. Clasificador Random Forest usando metricas originales + error de reconstruccion</span>

# %%
# Out:
# (43862, 3, 118)

# %%
# 1. Reconstruir los datos con el autoencoder completo
X_train_reconstruido = autoencoder_final.predict(X_anomalia_train)
X_test_reconstruido = autoencoder_final.predict(X_anomalia_test)

# 2. Calcular el error cuadrático por cada característica (cuánto se equivocó la red en cada columna)
error_train = (X_anomalia_train - X_train_reconstruido) ** 2
error_test = (X_anomalia_test - X_test_reconstruido) ** 2


error_train_2d = error_train.reshape(n_samples_train, -1)
error_test_2d = error_test.reshape(n_samples_test, -1)


# 3. Concatenar las características originales + los errores de reconstrucción
X_train_con_error = np.hstack((X_anomalia_train_2d, error_train_2d))
X_test_con_error = np.hstack((X_anomalia_test_2d, error_test_2d))


# 4. Entrenar el clasificador
clf_anomalias.fit(X_train_con_error, Y_train_etiquetas)
Y_pred_tipos = clf_anomalias.predict(X_test_con_error)
# Out:
# 1371/1371 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step
# 458/458 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step

# %%
print(classification_report(Y_test_etiquetas, Y_pred_tipos))
# Out:
#                                                precision    recall  f1-score   support
#
#            access_token_auth_header_error_401       0.42      0.47      0.45       290
#           access_token_authorization_form_401       0.52      0.56      0.53       297
#          access_token_client_id_not_found_404       0.53      0.56      0.54       307
#          access_token_client_secret_wrong_401       0.50      0.45      0.47       287
#              access_token_form_urlencoded_400       0.57      0.59      0.58       310
#           access_token_illegal_grant_type_400       0.47      0.52      0.49       306
# access_token_missing_authorization_header_400       0.46      0.42      0.44       299
#      authorization_code_client_id_missing_400       0.54      0.49      0.51       282
#      authorization_code_invalid_client_id_404       0.45      0.45      0.45       299
#       authorization_code_invalid_password_401       0.55      0.63      0.59       320
#  authorization_code_missing_response_type_400       0.55      0.59      0.57       277
#      authorization_code_response_not_code_400       0.59      0.47      0.52       263
#        code_challenge_invalid_format_pkce_400       0.54      0.59      0.56       266
#              code_challenge_too_long_pkce_400       0.57      0.55      0.56       276
#             code_challenge_too_short_pkce_400       0.52      0.49      0.51       283
#                code_verifier_missing_pkce_400       0.66      0.71      0.69       273
#               code_verifier_too_long_pkce_400       0.69      0.69      0.69       261
#              code_verifier_too_short_pkce_400       0.74      0.66      0.70       271
#                   delete_client_404_no_client       0.90      0.84      0.87       217
#                 delete_service_404_no_service       0.73      0.67      0.70       278
#                              delete_token_404       0.43      0.48      0.45       269
#                       delete_user_404_no_user       0.51      0.48      0.50       283
#                      get_client_404_no_client       0.86      0.95      0.90       328
#                   get_client_page_400_no_page       0.81      0.87      0.84       238
#                    get_service_404_no_service       0.72      0.69      0.71       314
#                  get_service_page_400_no_page       0.60      0.62      0.61       317
#                                 get_token_404       0.53      0.61      0.57       285
#                    get_token_page_400_no_page       0.50      0.50      0.50       266
#                          get_user_404_no_user       0.32      0.32      0.32       277
#                     get_user_page_400_no_page       0.28      0.29      0.29       287
#        invalid_code_challenge_method_pkce_400       0.53      0.48      0.50       286
#         invalid_code_verifier_format_PKCE_400       0.64      0.65      0.65       275
#             register_client_400_clientProfile       1.00      0.95      0.98        42
#                register_client_400_clientType       1.00      1.00      1.00       302
#                   register_client_404_no_user       0.99      0.99      0.99       340
#               register_service_400_service_id       0.79      0.62      0.70       173
#             register_service_400_service_type       0.76      0.81      0.79       286
#                  register_service_404_no_user       0.79      0.81      0.80       304
#                register_user_400_email_exists       0.67      0.54      0.60       286
#                 register_user_400_no_password       0.38      0.47      0.42       299
#           register_user_400_password_no_match       0.49      0.53      0.51       294
#                 register_user_400_user_exists       0.69      0.62      0.65       280
#               update_client_400_clientProfile       0.95      0.98      0.96       282
#                  update_client_400_clientType       0.94      0.94      0.94        65
#                    update_client_404_clientId       0.86      0.84      0.85       148
#                     update_client_404_ownerId       0.95      0.95      0.95       335
#                 update_password_400_not_match       0.82      0.92      0.87       542
#            update_password_401_wrong_password       0.47      0.34      0.39       264
#            update_password_404_user_not_found       0.51      0.52      0.52       260
#                 update_service_404_service_id       0.62      0.64      0.63       241
#                    update_service_404_user_id       0.74      0.70      0.72       247
#                       update_user_404_no_user       0.33      0.27      0.30       280
#                  verification_failed_pkce_400       0.73      0.67      0.70       290
#
#                                      accuracy                           0.63     14647
#                                     macro avg       0.64      0.63      0.63     14647
#                                  weighted avg       0.63      0.63      0.63     14647
