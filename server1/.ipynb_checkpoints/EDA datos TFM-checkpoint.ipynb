# %%
from timescale import TimescaleDBManager
from dotenv import load_dotenv
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import os
from sqlalchemy import create_engine
from sqlalchemy import text 
from matplotlib.backends.backend_pdf import PdfPages
import sys
import json
import warnings
import traceback
import random

# %%
load_dotenv()
user_env        = os.getenv("USER_DB")
pass_env        = os.getenv("PASS_DB")
host_env        = os.getenv("HOST_DB", "localhost")
port_env        = os.getenv("DB_PORT_EXPOSED", "5432")
db_env          = os.getenv("NAME_DB", "tfm_db")
FOLDER_SALIDA   = os.getenv("FOLDER_SALIDA")

SEED            = os.getenv("SEED")

db = TimescaleDBManager(
    user=user_env,
    password=pass_env,
    host=host_env,
    port=port_env,
    dbname=db_env
)
db.conectar()
conexion_postgresql = db.connection

#esto es para usar una conexion postgrews para pandas que da un warning indicando que solo esta testeado para sqlalchemy
engine = create_engine(f'postgresql+psycopg2://{user_env}:{pass_env}@{host_env}:{port_env}/{db_env}')
# Out:
# 🔌 [OK] Conexión establecida con TimescaleDB.

# %%
SQL='select distinct(metric_name) from metricas'
df_metric_name = pd.read_sql(SQL, engine)
lista_metric_name=df_metric_name['metric_name'].to_list()

# %%
SQL='select distinct(execution_name) from metricas'
df_metric_name = pd.read_sql(SQL, engine)
lista_execution_name=df_metric_name['execution_name'].to_list()

# %% [markdown]
# # <span style="color:#2ca02c">1. Analisis de cantidad de datos por ejecucion (execution_name)</span>

# %%
# 1. Obtenemos el conteo de registros por ejecución
SQL = 'SELECT execution_name, COUNT(*) AS total_registros FROM metricas GROUP BY execution_name'
df_counts = pd.read_sql(SQL, engine)

# 2. Definimos el umbral (el máximo de registros encontrados)
umbral = df_counts['total_registros'].max()

# 3. Filtramos: seleccionamos las ejecuciones con MENOS registros que el máximo
df_anomalias = df_counts[df_counts['total_registros'] < umbral].copy()

# 4. Añadimos la columna de 'faltante'
df_anomalias['faltante_para_maximo'] = (umbral - df_anomalias['total_registros']).astype(int)

# 5. Añadimos la columna 'max_registros' al final
df_anomalias['max_registros'] = umbral

# 6. Ordenamos y generamos la lista
df_anomalias = df_anomalias.sort_values(by='total_registros', ascending=True)
lista_ejecuciones_descartadas = df_anomalias['execution_name'].tolist()

print(f"📋 Ejecuciones con menos registros que el máximo ({umbral:.0f}):\n")
df_anomalias
# Out:
# 📋 Ejecuciones con menos registros que el máximo (83420):
#                         execution_name  total_registros  faltante_para_maximo  \
# 1574  light-oauth2-data-1722478279.tar             9215                 74205
# 538   light-oauth2-data-1722474696.tar            15035                 68385
# 1362  light-oauth2-data-1722471120.tar            23765                 59655
# 1412  light-oauth2-data-1722467564.tar            39770                 43650
#
#       max_registros
# 1574          83420
# 538           83420
# 1362          83420
# 1412          83420

# %%
with open(f'result/lista_ejecuciones_descartadas.json', "w", encoding="utf-8") as f:
    json.dump(lista_ejecuciones_descartadas, f, ensure_ascii=False, indent=4)

# %% [markdown]
# Sólo 4 ejecuciones tienen una cantidad diferente de datos. Para analizar utiliar los datos en entrenamiento y predicciones puede ser conveniente no contar con esas ejecuciones.

# %% [markdown]
# ## <span style="color:#2ca02c">2. Analisis de cantidad de datos por metric_name</span>

# %%
SQL='select metric_name,count(*) from metricas group by metric_name'
df_counts = pd.read_sql(SQL, engine)


#1.convertir el resutado a dataframe
df_counts['count'] = df_counts['count'].astype(int)

# 2. Calcular la frecuencia y cambiar el nombre de la serie para evitar colisiones
frecuencias = df_counts['count'].value_counts()
frecuencias.name = 'Frecuencia Absoluta'

# 3. Ahora sí hacemos el reset_index de forma segura
tabla_valores_unicos = frecuencias.sort_index().reset_index()

# 4. Renombrar la columna que Pandas saca del índice viejo para que quede impecable
tabla_valores_unicos.columns = ['N', 'Frecuencia Absoluta']

# 5. Calcular el porcentaje que representa sobre el total
total_ejecuciones = len(df_counts)
tabla_valores_unicos['Porcentaje (%)'] = (
    (tabla_valores_unicos['Frecuencia Absoluta'] / total_ejecuciones) * 100
).map('{:.2f}%'.format)

# 6. Mostrar la tabla compacta y real
print(f"📋 RESUMEN DE VALORES ÚNICOS (Total Ejecuciones Analizadas: {total_ejecuciones})\n")
tabla_valores_unicos
# Out:
# 📋 RESUMEN DE VALORES ÚNICOS (Total Ejecuciones Analizadas: 485)
#         N  Frecuencia Absoluta Porcentaje (%)
# 0  298085                  485        100.00%

# %% [markdown]
# Todas las métricas tienen la misma cantidad de datos

# %% [markdown]
# # <span style="color:#2ca02c">3. Revisión de nulos</span>

# %%
SQL = """
SELECT 
    COUNT(*) AS total_registros,
    COUNT(*) - COUNT(metric_value) AS nulos_en_valores,
    COUNT(*) - COUNT(label) AS nulos_en_etiquetas,
    COUNT(*) - COUNT(time) AS nulos_en_tiempo,
    COUNT(*) - COUNT(grupo) AS nulos_en_grupo,
    COUNT(*) - COUNT(job) AS nulos_en_job
FROM metricas;
"""

df_nulos = pd.read_sql(SQL, engine)
df_nulos

#result=db.ejecutar_select_generica(SQL)
#print(result)
# Out:
#    total_registros  nulos_en_valores  nulos_en_etiquetas  nulos_en_tiempo  \
# 0        144571225                 0                   0                0
#
#    nulos_en_grupo  nulos_en_job
# 0        67665295             0

# %% [markdown]
# No tenemos nulos en tiempo, label, metric_value ni job. En el campo grupo la mitad de los datos es nulo.

# %%
metrica='prometheus_tsdb_wal_fsync_duration_seconds'

SQL = f"""
    SELECT 
        metric_name, 
        metric_value, 
        COUNT(*) AS frecuencia
    FROM metricas
    WHERE metric_name='{metrica}'
    GROUP BY metric_name, metric_value
    ORDER BY metric_name, frecuencia DESC;
"""

df_cardinalidad_valores = pd.read_sql(SQL, engine)
df_cardinalidad_valores
# Out:
#                                   metric_name  metric_value  frecuencia
# 0  prometheus_tsdb_wal_fsync_duration_seconds           NaN      298085

# %% [markdown]
# # <span style="color:#2ca02c">4. Revision de datos de cada métrica</span>

# %%
SQL = f"""SELECT 
            metric_name,
            COUNT(*) AS total_registros,
            SUM(CASE WHEN metric_value='nan' THEN 1 ELSE 0 END) AS N_nan,
            ROUND(100.0 * SUM(CASE WHEN  metric_value='nan' THEN 1 ELSE 0 END) / COUNT(*), 2) AS PERC_nan
        FROM metricas
        GROUP BY metric_name
        HAVING SUM(CASE WHEN metric_value='nan' THEN 1 ELSE 0 END) > 0
        ORDER BY metric_name,PERC_nan DESC;
    """
df=pd.read_sql(SQL, engine)
df
# Out:
#                                    metric_name  total_registros   n_nan  \
# 0     prometheus_engine_query_duration_seconds           298085   24045
# 1  prometheus_rule_evaluation_duration_seconds           298085  298085
# 2       prometheus_rule_group_duration_seconds           298085  298085
# 3    prometheus_sd_consul_rpc_duration_seconds           298085  298085
# 4     prometheus_sd_file_scan_duration_seconds           298085  298085
# 5    prometheus_sd_kuma_fetch_duration_seconds           298085  298085
# 6        prometheus_target_sync_length_seconds           298085   88064
# 7   prometheus_tsdb_wal_fsync_duration_seconds           298085  298085
#
#    perc_nan
# 0      8.07
# 1    100.00
# 2    100.00
# 3    100.00
# 4    100.00
# 5    100.00
# 6     29.54
# 7    100.00

# %%
lista_metricas_descartadas_NaN = df[df['perc_nan']==100.0]['metric_name'].to_list()
lista_metricas_descartadas_NaN
# Out:
# ['prometheus_rule_evaluation_duration_seconds',
#  'prometheus_rule_group_duration_seconds',
#  'prometheus_sd_consul_rpc_duration_seconds',
#  'prometheus_sd_file_scan_duration_seconds',
#  'prometheus_sd_kuma_fetch_duration_seconds',
#  'prometheus_tsdb_wal_fsync_duration_seconds']

# %% [markdown]
# ## <span style="color:#2ca02c">4.1. Revision de NaN en prometheus_engine_query_duration_seconds</spain>

# %%
metrica='prometheus_engine_query_duration_seconds'
SQL = f"""SELECT 
            execution_name,
            COUNT(*) AS total_registros,
            SUM(CASE WHEN metric_value='nan' THEN 1 ELSE 0 END) AS N_nan,
            ROUND(100.0 * SUM(CASE WHEN  metric_value='nan' THEN 1 ELSE 0 END) / COUNT(*), 2) AS PERC_nan
        FROM metricas
        WHERE metric_name='{metrica}'
        GROUP BY execution_name;
    """
df=pd.read_sql(SQL, engine)
df
# Out:
#                         execution_name  total_registros  n_nan  perc_nan
# 0     light-oauth2-data-1719592986.tar              172     14      8.14
# 1     light-oauth2-data-1719594842.tar              172     14      8.14
# 2     light-oauth2-data-1719598443.tar              172     14      8.14
# 3     light-oauth2-data-1719602043.tar              172     14      8.14
# 4     light-oauth2-data-1719605644.tar              172     14      8.14
# ...                                ...              ...    ...       ...
# 1731  light-oauth2-data-1725855291.tar              172     13      7.56
# 1732  light-oauth2-data-1725858922.tar              172     14      8.14
# 1733  light-oauth2-data-1725862507.tar              172     14      8.14
# 1734  light-oauth2-data-1725866154.tar              172     13      7.56
# 1735  light-oauth2-data-1725869703.tar              172     13      7.56
#
# [1736 rows x 4 columns]

# %%
metrica='prometheus_engine_query_duration_seconds'
SQL = f"""SELECT 
            label,
            COUNT(*) AS total_registros,
            SUM(CASE WHEN metric_value='nan' THEN 1 ELSE 0 END) AS N_nan,
            ROUND(100.0 * SUM(CASE WHEN  metric_value='nan' THEN 1 ELSE 0 END) / COUNT(*), 2) AS PERC_nan
        FROM metricas
        WHERE metric_name='{metrica}'
        GROUP BY label;
    """
df=pd.read_sql(SQL, engine)
df
# Out:
#                                             label  total_registros  n_nan  \
# 0           invalid_code_verifier_format_PKCE_400             5196      0
# 1            access_token_client_id_not_found_404             5196      0
# 2                 update_client_400_clientProfile             5205      0
# 3             access_token_authorization_form_401             5196      0
# 4                code_challenge_too_long_pkce_400             5196      0
# 5         authorization_code_invalid_password_401             5199      0
# 6             access_token_illegal_grant_type_400             5196      0
# 7        authorization_code_invalid_client_id_404             5199      0
# 8                   update_password_400_not_match             5196      0
# 9                   register_user_400_no_password             5196      0
# 10                   get_service_page_400_no_page             5199      0
# 11              register_client_400_clientProfile             5208      0
# 12             update_password_404_user_not_found             5196      0
# 13                                  get_token_404             5196      0
# 14                 code_verifier_missing_pkce_400             5196      0
# 15              register_service_400_service_type             5202      0
# 16         invalid_code_challenge_method_pkce_400             5196      0
# 17                register_service_400_service_id             5202      0
# 18              code_challenge_too_short_pkce_400             5196      0
# 19             access_token_auth_header_error_401             5196      0
# 20  access_token_missing_authorization_header_400             5196      0
# 21                    delete_client_404_no_client             5202      0
# 22                code_verifier_too_long_pkce_400             5196      0
# 23                      get_user_page_400_no_page             5196      0
# 24                   update_client_400_clientType             5205      0
# 25               code_verifier_too_short_pkce_400             5196      0
# 26                  update_service_404_service_id             5199      0
# 27                        update_user_404_no_user             5196      0
# 28                 register_client_400_clientType             5208   1477
# 29           access_token_client_secret_wrong_401             5196      0
# 30            register_user_400_password_no_match             5196      0
# 31       authorization_code_response_not_code_400             5199      0
# 32                       get_client_404_no_client             5202      0
# 33                           get_user_404_no_user             5196      0
# 34                        delete_user_404_no_user             5196      0
# 35                  register_user_400_user_exists             5196      0
# 36               access_token_form_urlencoded_400             5196      0
# 37             update_password_401_wrong_password             5196      0
# 38   authorization_code_missing_response_type_400             5199      0
# 39         code_challenge_invalid_format_pkce_400             5196      0
# 40                      update_client_404_ownerId             5205      0
# 41                     get_service_404_no_service             5199      0
# 42                     update_service_404_user_id             5199      0
# 43       authorization_code_client_id_missing_400             5199      0
# 44                   register_service_404_no_user             5199      0
# 45                  delete_service_404_no_service             5199      0
# 46                    register_client_404_no_user             5205      0
# 47                    get_client_page_400_no_page             5202      0
# 48                 register_user_400_email_exists             5196      0
# 49                               delete_token_404             5196      0
# 50                   verification_failed_pkce_400             5196      0
# 51                     get_token_page_400_no_page             5196      0
# 52                     update_client_404_clientId             5202      0
# 53                                        correct            22568  22568
#
#     perc_nan
# 0       0.00
# 1       0.00
# 2       0.00
# 3       0.00
# 4       0.00
# 5       0.00
# 6       0.00
# 7       0.00
# 8       0.00
# 9       0.00
# 10      0.00
# 11      0.00
# 12      0.00
# 13      0.00
# 14      0.00
# 15      0.00
# 16      0.00
# 17      0.00
# 18      0.00
# 19      0.00
# 20      0.00
# 21      0.00
# 22      0.00
# 23      0.00
# 24      0.00
# 25      0.00
# 26      0.00
# 27      0.00
# 28     28.36
# 29      0.00
# 30      0.00
# 31      0.00
# 32      0.00
# 33      0.00
# 34      0.00
# 35      0.00
# 36      0.00
# 37      0.00
# 38      0.00
# 39      0.00
# 40      0.00
# 41      0.00
# 42      0.00
# 43      0.00
# 44      0.00
# 45      0.00
# 46      0.00
# 47      0.00
# 48      0.00
# 49      0.00
# 50      0.00
# 51      0.00
# 52      0.00
# 53    100.00

# %% [markdown]
# La metrica='prometheus_engine_query_duration_seconds' tienen NaN en todos los datos etiquetados como correct, por lo que no sirve para usar algoritmos de deteccion de anomalias ya que no tenemos datos "normales" de esta métrica.

# %%
lista_metricas_descartadas_NaN.append('prometheus_engine_query_duration_seconds')

# %% [markdown]
# ## <span style="color:#2ca02c">4.2. Revision de NaN en prometheus_target_sync_length_seconds</spain>

# %%
metrica='prometheus_target_sync_length_seconds'
SQL = f"""SELECT 
            execution_name,
            COUNT(*) AS total_registros,
            SUM(CASE WHEN metric_value='nan' THEN 1 ELSE 0 END) AS N_nan,
            ROUND(100.0 * SUM(CASE WHEN  metric_value='nan' THEN 1 ELSE 0 END) / COUNT(*), 2) AS PERC_nan
        FROM metricas
        WHERE metric_name='{metrica}'
        GROUP BY execution_name;
    """
df=pd.read_sql(SQL, engine)
df
# Out:
#                         execution_name  total_registros  n_nan  perc_nan
# 0     light-oauth2-data-1719592986.tar              172     47     27.33
# 1     light-oauth2-data-1719594842.tar              172     47     27.33
# 2     light-oauth2-data-1719598443.tar              172     47     27.33
# 3     light-oauth2-data-1719602043.tar              172     47     27.33
# 4     light-oauth2-data-1719605644.tar              172     48     27.91
# ...                                ...              ...    ...       ...
# 1731  light-oauth2-data-1725855291.tar              172     56     32.56
# 1732  light-oauth2-data-1725858922.tar              172     62     36.05
# 1733  light-oauth2-data-1725862507.tar              172     57     33.14
# 1734  light-oauth2-data-1725866154.tar              172     65     37.79
# 1735  light-oauth2-data-1725869703.tar              172     58     33.72
#
# [1736 rows x 4 columns]

# %%
metrica='prometheus_target_sync_length_seconds'
SQL = f"""SELECT 
            label,
            COUNT(*) AS total_registros,
            SUM(CASE WHEN metric_value='nan' THEN 1 ELSE 0 END) AS N_nan,
            ROUND(100.0 * SUM(CASE WHEN  metric_value='nan' THEN 1 ELSE 0 END) / COUNT(*), 2) AS PERC_nan
        FROM metricas
        WHERE metric_name='{metrica}'
        GROUP BY label;
    """
df=pd.read_sql(SQL, engine)
df
# Out:
#                                             label  total_registros  n_nan  \
# 0           invalid_code_verifier_format_PKCE_400             5196    688
# 1            access_token_client_id_not_found_404             5196      0
# 2                 update_client_400_clientProfile             5205      0
# 3             access_token_authorization_form_401             5196      3
# 4                code_challenge_too_long_pkce_400             5196     17
# 5         authorization_code_invalid_password_401             5199      0
# 6             access_token_illegal_grant_type_400             5196      0
# 7        authorization_code_invalid_client_id_404             5199      0
# 8                   update_password_400_not_match             5196   5196
# 9                   register_user_400_no_password             5196   5196
# 10                   get_service_page_400_no_page             5199      0
# 11              register_client_400_clientProfile             5208      0
# 12             update_password_404_user_not_found             5196   5196
# 13                                  get_token_404             5196   5196
# 14                 code_verifier_missing_pkce_400             5196   4636
# 15              register_service_400_service_type             5202      0
# 16         invalid_code_challenge_method_pkce_400             5196      3
# 17                register_service_400_service_id             5202      0
# 18              code_challenge_too_short_pkce_400             5196      6
# 19             access_token_auth_header_error_401             5196      3
# 20  access_token_missing_authorization_header_400             5196      3
# 21                    delete_client_404_no_client             5202      0
# 22                code_verifier_too_long_pkce_400             5196   2590
# 23                      get_user_page_400_no_page             5196   5196
# 24                   update_client_400_clientType             5205      0
# 25               code_verifier_too_short_pkce_400             5196   2110
# 26                  update_service_404_service_id             5199      0
# 27                        update_user_404_no_user             5196   5196
# 28                 register_client_400_clientType             5208      0
# 29           access_token_client_secret_wrong_401             5196      0
# 30            register_user_400_password_no_match             5196   5196
# 31       authorization_code_response_not_code_400             5199      0
# 32                       get_client_404_no_client             5202      0
# 33                           get_user_404_no_user             5196   5196
# 34                        delete_user_404_no_user             5196   5196
# 35                  register_user_400_user_exists             5196   5196
# 36               access_token_form_urlencoded_400             5196      3
# 37             update_password_401_wrong_password             5196   5196
# 38   authorization_code_missing_response_type_400             5199      0
# 39         code_challenge_invalid_format_pkce_400             5196     62
# 40                      update_client_404_ownerId             5205      0
# 41                     get_service_404_no_service             5199      0
# 42                     update_service_404_user_id             5199      0
# 43       authorization_code_client_id_missing_400             5199      0
# 44                   register_service_404_no_user             5199      0
# 45                  delete_service_404_no_service             5199      0
# 46                    register_client_404_no_user             5205      0
# 47                    get_client_page_400_no_page             5202      0
# 48                 register_user_400_email_exists             5196   5196
# 49                               delete_token_404             5196   5196
# 50                   verification_failed_pkce_400             5196   5196
# 51                     get_token_page_400_no_page             5196   5196
# 52                     update_client_404_clientId             5202      0
# 53                                        correct            22568      0
#
#     perc_nan
# 0      13.24
# 1       0.00
# 2       0.00
# 3       0.06
# 4       0.33
# 5       0.00
# 6       0.00
# 7       0.00
# 8     100.00
# 9     100.00
# 10      0.00
# 11      0.00
# 12    100.00
# 13    100.00
# 14     89.22
# 15      0.00
# 16      0.06
# 17      0.00
# 18      0.12
# 19      0.06
# 20      0.06
# 21      0.00
# 22     49.85
# 23    100.00
# 24      0.00
# 25     40.61
# 26      0.00
# 27    100.00
# 28      0.00
# 29      0.00
# 30    100.00
# 31      0.00
# 32      0.00
# 33    100.00
# 34    100.00
# 35    100.00
# 36      0.06
# 37    100.00
# 38      0.00
# 39      1.19
# 40      0.00
# 41      0.00
# 42      0.00
# 43      0.00
# 44      0.00
# 45      0.00
# 46      0.00
# 47      0.00
# 48    100.00
# 49    100.00
# 50    100.00
# 51    100.00
# 52      0.00
# 53      0.00

# %% [markdown]
# La métrica='prometheus_target_sync_length_seconds' no tiene NaN en datos etiquetados como correctos, hay anomalías que tienen todos los valores de esta métrica NaN.
#
# Se sustituira los NaN por valores medios y se creara una caracteriastica que sera 1 si hay NaN y 0 si no lo es. Esta caracteristica parece varlosa para detectar algunas de las anomalias.

# %%
with open(f'result/lista_metricas_descartadas_NaN.json', "w", encoding="utf-8") as f:
    json.dump(lista_metricas_descartadas_NaN, f, ensure_ascii=False, indent=4)

# %% [markdown]
# # <span style="color:#2ca02c">5. Revision de datos de cada métrica</span>

# %%
una_ejecucion = 'light-oauth2-data-1725524098.tar'


SQL_check = f"""
SELECT COUNT(*) as muestras_metrica_ejecucion
FROM metricas
WHERE execution_name = '{una_ejecucion}'
  AND metric_name = 'go_gc_duration_seconds';
"""

df_var = pd.read_sql(SQL_check, engine)
df_var
# Out:
#    muestras_metrica_ejecucion
# 0                         172

# %%
lista_metricas_filtradas=lista_metric_name.copy()
lista_metricas_filtradas = [item for item in lista_metricas_filtradas if item not in lista_metricas_descartadas_NaN]

# %%
len(lista_metricas_filtradas)
# Out:
# 478

# %%
# Tu lista de métricas filtradas

# Convertimos la lista a una tupla (es el formato que espera SQL para el operador IN)
tuple_metricas = tuple(lista_metricas_filtradas)

# Usamos %s como marcador de posición (el driver de SQL hará el escape correcto)
# Nota: Si la lista solo tiene un elemento, la tupla debe definirse como (elemento,)
SQL = """
SELECT 
    metric_name,
    COUNT(*) AS N_muestras,
    MIN(metric_value) AS MIN,
    PERCENTILE_CONT(0.25) WITHIN GROUP (ORDER BY metric_value) AS Q1,
    PERCENTILE_CONT(0.50) WITHIN GROUP (ORDER BY metric_value) AS Q2,
    PERCENTILE_CONT(0.75) WITHIN GROUP (ORDER BY metric_value) AS Q3,
    MAX(metric_value) AS MAX,
    STDDEV(metric_value) AS STD_DEV
FROM 
    metricas
WHERE 
    metric_name IN %(metricas)s
GROUP BY 
    metric_name;
"""

# Lanzamos la consulta pasando el diccionario de parámetros
df_resumen_estadistico = pd.read_sql_query(SQL, engine, params={'metricas': tuple_metricas})
df_resumen_estadistico
# Out:
#                                metric_name  n_muestras         min  \
# 0                   go_gc_duration_seconds      298085    0.000050
# 1             go_gc_duration_seconds_count      298085    5.000000
# 2               go_gc_duration_seconds_sum      298085    0.000170
# 3                            go_goroutines      298085   31.000000
# 4                                  go_info      298085    1.000000
# ..                                     ...         ...         ...
# 473                scrape_duration_seconds      298085    0.002548
# 474  scrape_samples_post_metric_relabeling      298085  452.000000
# 475                 scrape_samples_scraped      298085  452.000000
# 476                    scrape_series_added      298085    0.000000
# 477                                     up      298085    1.000000
#
#              q1          q2           q3          max     std_dev
# 0      0.001177    0.002345     0.004553     0.025355    0.003533
# 1    314.000000  756.000000  1157.000000  7526.000000  475.301000
# 2      0.031020    0.069503     0.103603     2.241065    0.054989
# 3     33.000000   33.000000    33.000000    47.000000    0.529508
# 4      1.000000    1.000000     1.000000     1.000000    0.000000
# ..          ...         ...          ...          ...         ...
# 473    0.003125    0.003599     0.004656     0.093296    0.001699
# 474  475.000000  475.000000   475.000000   475.000000    6.263485
# 475  475.000000  475.000000   475.000000   475.000000    6.263485
# 476    0.000000    0.000000     0.000000    23.000000    1.750109
# 477    1.000000    1.000000     1.000000     1.000000    0.000000
#
# [478 rows x 8 columns]

# %%
with pd.option_context('display.max_rows', None, 'display.max_columns', None):
    display(df_resumen_estadistico)
# Out:
#                                            metric_name  n_muestras  \
# 0                               go_gc_duration_seconds      298085
# 1                         go_gc_duration_seconds_count      298085
# 2                           go_gc_duration_seconds_sum      298085
# 3                                        go_goroutines      298085
# 4                                              go_info      298085
# 5                              go_memstats_alloc_bytes      298085
# 6                        go_memstats_alloc_bytes_total      298085
# 7                      go_memstats_buck_hash_sys_bytes      298085
# 8                              go_memstats_frees_total      298085
# 9                             go_memstats_gc_sys_bytes      298085
# 10                        go_memstats_heap_alloc_bytes      298085
# 11                         go_memstats_heap_idle_bytes      298085
# 12                        go_memstats_heap_inuse_bytes      298085
# 13                            go_memstats_heap_objects      298085
# 14                     go_memstats_heap_released_bytes      298085
# 15                          go_memstats_heap_sys_bytes      298085
# 16                    go_memstats_last_gc_time_seconds      298085
# 17                           go_memstats_lookups_total      298085
# 18                           go_memstats_mallocs_total      298085
# 19                      go_memstats_mcache_inuse_bytes      298085
# 20                        go_memstats_mcache_sys_bytes      298085
# 21                       go_memstats_mspan_inuse_bytes      298085
# 22                         go_memstats_mspan_sys_bytes      298085
# 23                           go_memstats_next_gc_bytes      298085
# 24                         go_memstats_other_sys_bytes      298085
# 25                       go_memstats_stack_inuse_bytes      298085
# 26                         go_memstats_stack_sys_bytes      298085
# 27                               go_memstats_sys_bytes      298085
# 28                                          go_threads      298085
# 29           net_conntrack_dialer_conn_attempted_total      298085
# 30              net_conntrack_dialer_conn_closed_total      298085
# 31         net_conntrack_dialer_conn_established_total      298085
# 32              net_conntrack_dialer_conn_failed_total      298085
# 33          net_conntrack_listener_conn_accepted_total      298085
# 34            net_conntrack_listener_conn_closed_total      298085
# 35                                    node_arp_entries      298085
# 36                              node_boot_time_seconds      298085
# 37                         node_context_switches_total      298085
# 38                       node_cooling_device_cur_state      298085
# 39                       node_cooling_device_max_state      298085
# 40                        node_cpu_guest_seconds_total      298085
# 41                              node_cpu_seconds_total      298085
# 42                node_disk_discard_time_seconds_total      298085
# 43                   node_disk_discarded_sectors_total      298085
# 44                  node_disk_discards_completed_total      298085
# 45                     node_disk_discards_merged_total      298085
# 46         node_disk_flush_requests_time_seconds_total      298085
# 47                      node_disk_flush_requests_total      298085
# 48                                      node_disk_info      298085
# 49                                    node_disk_io_now      298085
# 50                     node_disk_io_time_seconds_total      298085
# 51            node_disk_io_time_weighted_seconds_total      298085
# 52                          node_disk_read_bytes_total      298085
# 53                   node_disk_read_time_seconds_total      298085
# 54                     node_disk_reads_completed_total      298085
# 55                        node_disk_reads_merged_total      298085
# 56                  node_disk_write_time_seconds_total      298085
# 57                    node_disk_writes_completed_total      298085
# 58                       node_disk_writes_merged_total      298085
# 59                       node_disk_written_bytes_total      298085
# 60                                       node_dmi_info      298085
# 61                         node_entropy_available_bits      298085
# 62                         node_entropy_pool_size_bits      298085
# 63                            node_exporter_build_info      298085
# 64                               node_filefd_allocated      298085
# 65                                 node_filefd_maximum      298085
# 66                         node_filesystem_avail_bytes      298085
# 67                        node_filesystem_device_error      298085
# 68                               node_filesystem_files      298085
# 69                          node_filesystem_files_free      298085
# 70                          node_filesystem_free_bytes      298085
# 71                            node_filesystem_readonly      298085
# 72                          node_filesystem_size_bytes      298085
# 73                                    node_forks_total      298085
# 74                               node_hwmon_chip_names      298085
# 75                                     node_intr_total      298085
# 76                                          node_load1      298085
# 77                                         node_load15      298085
# 78                                          node_load5      298085
# 79                       node_memory_Active_anon_bytes      298085
# 80                            node_memory_Active_bytes      298085
# 81                       node_memory_Active_file_bytes      298085
# 82                     node_memory_AnonHugePages_bytes      298085
# 83                         node_memory_AnonPages_bytes      298085
# 84                            node_memory_Bounce_bytes      298085
# 85                           node_memory_Buffers_bytes      298085
# 86                            node_memory_Cached_bytes      298085
# 87                           node_memory_CmaFree_bytes      298085
# 88                          node_memory_CmaTotal_bytes      298085
# 89                       node_memory_CommitLimit_bytes      298085
# 90                      node_memory_Committed_AS_bytes      298085
# 91                       node_memory_DirectMap1G_bytes      298085
# 92                       node_memory_DirectMap2M_bytes      298085
# 93                       node_memory_DirectMap4k_bytes      298085
# 94                             node_memory_Dirty_bytes      298085
# 95                     node_memory_FileHugePages_bytes      298085
# 96                     node_memory_FilePmdMapped_bytes      298085
# 97                 node_memory_HardwareCorrupted_bytes      298085
# 98                          node_memory_HugePages_Free      298085
# 99                          node_memory_HugePages_Rsvd      298085
# 100                         node_memory_HugePages_Surp      298085
# 101                        node_memory_HugePages_Total      298085
# 102                     node_memory_Hugepagesize_bytes      298085
# 103                          node_memory_Hugetlb_bytes      298085
# 104                    node_memory_Inactive_anon_bytes      298085
# 105                         node_memory_Inactive_bytes      298085
# 106                    node_memory_Inactive_file_bytes      298085
# 107                     node_memory_KReclaimable_bytes      298085
# 108                      node_memory_KernelStack_bytes      298085
# 109                           node_memory_Mapped_bytes      298085
# 110                     node_memory_MemAvailable_bytes      298085
# 111                          node_memory_MemFree_bytes      298085
# 112                         node_memory_MemTotal_bytes      298085
# 113                          node_memory_Mlocked_bytes      298085
# 114                     node_memory_NFS_Unstable_bytes      298085
# 115                       node_memory_PageTables_bytes      298085
# 116                           node_memory_Percpu_bytes      298085
# 117                     node_memory_SReclaimable_bytes      298085
# 118                       node_memory_SUnreclaim_bytes      298085
# 119                    node_memory_SecPageTables_bytes      298085
# 120                   node_memory_ShmemHugePages_bytes      298085
# 121                   node_memory_ShmemPmdMapped_bytes      298085
# 122                            node_memory_Shmem_bytes      298085
# 123                             node_memory_Slab_bytes      298085
# 124                       node_memory_SwapCached_bytes      298085
# 125                         node_memory_SwapFree_bytes      298085
# 126                        node_memory_SwapTotal_bytes      298085
# 127                       node_memory_Unaccepted_bytes      298085
# 128                      node_memory_Unevictable_bytes      298085
# 129                     node_memory_VmallocChunk_bytes      298085
# 130                     node_memory_VmallocTotal_bytes      298085
# 131                      node_memory_VmallocUsed_bytes      298085
# 132                     node_memory_WritebackTmp_bytes      298085
# 133                        node_memory_Writeback_bytes      298085
# 134                            node_memory_Zswap_bytes      298085
# 135                         node_memory_Zswapped_bytes      298085
# 136                        node_netstat_Icmp6_InErrors      298085
# 137                          node_netstat_Icmp6_InMsgs      298085
# 138                         node_netstat_Icmp6_OutMsgs      298085
# 139                         node_netstat_Icmp_InErrors      298085
# 140                           node_netstat_Icmp_InMsgs      298085
# 141                          node_netstat_Icmp_OutMsgs      298085
# 142                          node_netstat_Ip6_InOctets      298085
# 143                         node_netstat_Ip6_OutOctets      298085
# 144                        node_netstat_IpExt_InOctets      298085
# 145                       node_netstat_IpExt_OutOctets      298085
# 146                         node_netstat_Ip_Forwarding      298085
# 147                    node_netstat_TcpExt_ListenDrops      298085
# 148                node_netstat_TcpExt_ListenOverflows      298085
# 149               node_netstat_TcpExt_SyncookiesFailed      298085
# 150                 node_netstat_TcpExt_SyncookiesRecv      298085
# 151                 node_netstat_TcpExt_SyncookiesSent      298085
# 152                  node_netstat_TcpExt_TCPSynRetrans      298085
# 153                    node_netstat_TcpExt_TCPTimeouts      298085
# 154                       node_netstat_Tcp_ActiveOpens      298085
# 155                         node_netstat_Tcp_CurrEstab      298085
# 156                            node_netstat_Tcp_InErrs      298085
# 157                            node_netstat_Tcp_InSegs      298085
# 158                           node_netstat_Tcp_OutRsts      298085
# 159                           node_netstat_Tcp_OutSegs      298085
# 160                      node_netstat_Tcp_PassiveOpens      298085
# 161                       node_netstat_Tcp_RetransSegs      298085
# 162                      node_netstat_Udp6_InDatagrams      298085
# 163                         node_netstat_Udp6_InErrors      298085
# 164                          node_netstat_Udp6_NoPorts      298085
# 165                     node_netstat_Udp6_OutDatagrams      298085
# 166                     node_netstat_Udp6_RcvbufErrors      298085
# 167                     node_netstat_Udp6_SndbufErrors      298085
# 168                     node_netstat_UdpLite6_InErrors      298085
# 169                      node_netstat_UdpLite_InErrors      298085
# 170                       node_netstat_Udp_InDatagrams      298085
# 171                          node_netstat_Udp_InErrors      298085
# 172                           node_netstat_Udp_NoPorts      298085
# 173                      node_netstat_Udp_OutDatagrams      298085
# 174                      node_netstat_Udp_RcvbufErrors      298085
# 175                      node_netstat_Udp_SndbufErrors      298085
# 176                   node_network_address_assign_type      298085
# 177                               node_network_carrier      298085
# 178                 node_network_carrier_changes_total      298085
# 179            node_network_carrier_down_changes_total      298085
# 180              node_network_carrier_up_changes_total      298085
# 181                             node_network_device_id      298085
# 182                               node_network_dormant      298085
# 183                                 node_network_flags      298085
# 184                              node_network_iface_id      298085
# 185                            node_network_iface_link      298085
# 186                       node_network_iface_link_mode      298085
# 187                                  node_network_info      298085
# 188                             node_network_mtu_bytes      298085
# 189                      node_network_name_assign_type      298085
# 190                         node_network_net_dev_group      298085
# 191                         node_network_protocol_type      298085
# 192                   node_network_receive_bytes_total      298085
# 193              node_network_receive_compressed_total      298085
# 194                    node_network_receive_drop_total      298085
# 195                    node_network_receive_errs_total      298085
# 196                    node_network_receive_fifo_total      298085
# 197                   node_network_receive_frame_total      298085
# 198               node_network_receive_multicast_total      298085
# 199               node_network_receive_nohandler_total      298085
# 200                 node_network_receive_packets_total      298085
# 201                           node_network_speed_bytes      298085
# 202                  node_network_transmit_bytes_total      298085
# 203                node_network_transmit_carrier_total      298085
# 204                  node_network_transmit_colls_total      298085
# 205             node_network_transmit_compressed_total      298085
# 206                   node_network_transmit_drop_total      298085
# 207                   node_network_transmit_errs_total      298085
# 208                   node_network_transmit_fifo_total      298085
# 209                node_network_transmit_packets_total      298085
# 210                 node_network_transmit_queue_length      298085
# 211                                    node_network_up      298085
# 212                          node_nf_conntrack_entries      298085
# 213                    node_nf_conntrack_entries_limit      298085
# 214                        node_nf_conntrack_stat_drop      298085
# 215                  node_nf_conntrack_stat_early_drop      298085
# 216                       node_nf_conntrack_stat_found      298085
# 217                      node_nf_conntrack_stat_ignore      298085
# 218                      node_nf_conntrack_stat_insert      298085
# 219               node_nf_conntrack_stat_insert_failed      298085
# 220                     node_nf_conntrack_stat_invalid      298085
# 221              node_nf_conntrack_stat_search_restart      298085
# 222                                       node_os_info      298085
# 223                                    node_os_version      298085
# 224                             node_power_supply_info      298085
# 225                           node_power_supply_online      298085
# 226                                 node_procs_blocked      298085
# 227                                 node_procs_running      298085
# 228               node_schedstat_running_seconds_total      298085
# 229                    node_schedstat_timeslices_total      298085
# 230               node_schedstat_waiting_seconds_total      298085
# 231             node_scrape_collector_duration_seconds      298085
# 232                      node_scrape_collector_success      298085
# 233                               node_selinux_enabled      298085
# 234                          node_sockstat_FRAG6_inuse      298085
# 235                         node_sockstat_FRAG6_memory      298085
# 236                           node_sockstat_FRAG_inuse      298085
# 237                          node_sockstat_FRAG_memory      298085
# 238                           node_sockstat_RAW6_inuse      298085
# 239                            node_sockstat_RAW_inuse      298085
# 240                           node_sockstat_TCP6_inuse      298085
# 241                            node_sockstat_TCP_alloc      298085
# 242                            node_sockstat_TCP_inuse      298085
# 243                              node_sockstat_TCP_mem      298085
# 244                        node_sockstat_TCP_mem_bytes      298085
# 245                           node_sockstat_TCP_orphan      298085
# 246                               node_sockstat_TCP_tw      298085
# 247                           node_sockstat_UDP6_inuse      298085
# 248                       node_sockstat_UDPLITE6_inuse      298085
# 249                        node_sockstat_UDPLITE_inuse      298085
# 250                            node_sockstat_UDP_inuse      298085
# 251                              node_sockstat_UDP_mem      298085
# 252                        node_sockstat_UDP_mem_bytes      298085
# 253                         node_sockstat_sockets_used      298085
# 254                           node_softnet_backlog_len      298085
# 255                   node_softnet_cpu_collision_total      298085
# 256                         node_softnet_dropped_total      298085
# 257                node_softnet_flow_limit_count_total      298085
# 258                       node_softnet_processed_total      298085
# 259                    node_softnet_received_rps_total      298085
# 260                  node_softnet_times_squeezed_total      298085
# 261                         node_textfile_scrape_error      298085
# 262               node_time_clocksource_available_info      298085
# 263                 node_time_clocksource_current_info      298085
# 264                                  node_time_seconds      298085
# 265                      node_time_zone_offset_seconds      298085
# 266                 node_timex_estimated_error_seconds      298085
# 267              node_timex_frequency_adjustment_ratio      298085
# 268                      node_timex_loop_time_constant      298085
# 269                        node_timex_maxerror_seconds      298085
# 270                          node_timex_offset_seconds      298085
# 271                   node_timex_pps_calibration_total      298085
# 272                         node_timex_pps_error_total      298085
# 273                     node_timex_pps_frequency_hertz      298085
# 274                      node_timex_pps_jitter_seconds      298085
# 275                        node_timex_pps_jitter_total      298085
# 276                       node_timex_pps_shift_seconds      298085
# 277            node_timex_pps_stability_exceeded_total      298085
# 278                     node_timex_pps_stability_hertz      298085
# 279                                  node_timex_status      298085
# 280                             node_timex_sync_status      298085
# 281                      node_timex_tai_offset_seconds      298085
# 282                            node_timex_tick_seconds      298085
# 283                                    node_udp_queues      298085
# 284                                    node_uname_info      298085
# 285                               node_vmstat_oom_kill      298085
# 286                                node_vmstat_pgfault      298085
# 287                             node_vmstat_pgmajfault      298085
# 288                                 node_vmstat_pgpgin      298085
# 289                                node_vmstat_pgpgout      298085
# 290                                 node_vmstat_pswpin      298085
# 291                                node_vmstat_pswpout      298085
# 292                          process_cpu_seconds_total      298085
# 293                                    process_max_fds      298085
# 294                                   process_open_fds      298085
# 295                      process_resident_memory_bytes      298085
# 296                         process_start_time_seconds      298085
# 297                       process_virtual_memory_bytes      298085
# 298                   process_virtual_memory_max_bytes      298085
# 299                 prometheus_api_remote_read_queries      298085
# 300                              prometheus_build_info      298085
# 301  prometheus_config_last_reload_success_timestam...      298085
# 302           prometheus_config_last_reload_successful      298085
# 303                          prometheus_engine_queries      298085
# 304           prometheus_engine_queries_concurrent_max      298085
# 305     prometheus_engine_query_duration_seconds_count      298085
# 306       prometheus_engine_query_duration_seconds_sum      298085
# 307                prometheus_engine_query_log_enabled      298085
# 308         prometheus_engine_query_log_failures_total      298085
# 309              prometheus_engine_query_samples_total      298085
# 310    prometheus_http_request_duration_seconds_bucket      298085
# 311     prometheus_http_request_duration_seconds_count      298085
# 312       prometheus_http_request_duration_seconds_sum      298085
# 313                     prometheus_http_requests_total      298085
# 314         prometheus_http_response_size_bytes_bucket      298085
# 315          prometheus_http_response_size_bytes_count      298085
# 316            prometheus_http_response_size_bytes_sum      298085
# 317  prometheus_notifications_alertmanagers_discovered      298085
# 318             prometheus_notifications_dropped_total      298085
# 319            prometheus_notifications_queue_capacity      298085
# 320              prometheus_notifications_queue_length      298085
# 321                                   prometheus_ready      298085
# 322       prometheus_remote_storage_exemplars_in_total      298085
# 323  prometheus_remote_storage_highest_timestamp_in...      298085
# 324      prometheus_remote_storage_histograms_in_total      298085
# 325         prometheus_remote_storage_samples_in_total      298085
# 326  prometheus_remote_storage_string_interner_zero...      298085
# 327  prometheus_rule_evaluation_duration_seconds_count      298085
# 328    prometheus_rule_evaluation_duration_seconds_sum      298085
# 329       prometheus_rule_group_duration_seconds_count      298085
# 330         prometheus_rule_group_duration_seconds_sum      298085
# 331                prometheus_sd_azure_cache_hit_total      298085
# 332                 prometheus_sd_azure_failures_total      298085
# 333    prometheus_sd_consul_rpc_duration_seconds_count      298085
# 334      prometheus_sd_consul_rpc_duration_seconds_sum      298085
# 335            prometheus_sd_consul_rpc_failures_total      298085
# 336                   prometheus_sd_discovered_targets      298085
# 337            prometheus_sd_dns_lookup_failures_total      298085
# 338                    prometheus_sd_dns_lookups_total      298085
# 339                       prometheus_sd_failed_configs      298085
# 340               prometheus_sd_file_read_errors_total      298085
# 341     prometheus_sd_file_scan_duration_seconds_count      298085
# 342       prometheus_sd_file_scan_duration_seconds_sum      298085
# 343            prometheus_sd_file_watcher_errors_total      298085
# 344                  prometheus_sd_http_failures_total      298085
# 345              prometheus_sd_kubernetes_events_total      298085
# 346    prometheus_sd_kuma_fetch_duration_seconds_count      298085
# 347      prometheus_sd_kuma_fetch_duration_seconds_sum      298085
# 348            prometheus_sd_kuma_fetch_failures_total      298085
# 349     prometheus_sd_kuma_fetch_skipped_updates_total      298085
# 350                prometheus_sd_linode_failures_total      298085
# 351                 prometheus_sd_nomad_failures_total      298085
# 352               prometheus_sd_received_updates_total      298085
# 353                prometheus_sd_updates_delayed_total      298085
# 354                        prometheus_sd_updates_total      298085
# 355          prometheus_target_interval_length_seconds      298085
# 356    prometheus_target_interval_length_seconds_count      298085
# 357      prometheus_target_interval_length_seconds_sum      298085
# 358             prometheus_target_metadata_cache_bytes      298085
# 359           prometheus_target_metadata_cache_entries      298085
# 360  prometheus_target_scrape_pool_exceeded_label_l...      298085
# 361  prometheus_target_scrape_pool_exceeded_target_...      298085
# 362  prometheus_target_scrape_pool_reloads_failed_t...      298085
# 363        prometheus_target_scrape_pool_reloads_total      298085
# 364           prometheus_target_scrape_pool_sync_total      298085
# 365         prometheus_target_scrape_pool_target_limit      298085
# 366              prometheus_target_scrape_pool_targets      298085
# 367        prometheus_target_scrape_pools_failed_total      298085
# 368               prometheus_target_scrape_pools_total      298085
# 369  prometheus_target_scrapes_cache_flush_forced_t...      298085
# 370  prometheus_target_scrapes_exceeded_body_size_l...      298085
# 371  prometheus_target_scrapes_exceeded_native_hist...      298085
# 372  prometheus_target_scrapes_exceeded_sample_limi...      298085
# 373  prometheus_target_scrapes_exemplar_out_of_orde...      298085
# 374  prometheus_target_scrapes_sample_duplicate_tim...      298085
# 375  prometheus_target_scrapes_sample_out_of_bounds...      298085
# 376  prometheus_target_scrapes_sample_out_of_order_...      298085
# 377                prometheus_target_sync_failed_total      298085
# 378              prometheus_target_sync_length_seconds      298085
# 379        prometheus_target_sync_length_seconds_count      298085
# 380          prometheus_target_sync_length_seconds_sum      298085
# 381  prometheus_template_text_expansion_failures_total      298085
# 382          prometheus_template_text_expansions_total      298085
# 383            prometheus_treecache_watcher_goroutines      298085
# 384      prometheus_treecache_zookeeper_failures_total      298085
# 385                      prometheus_tsdb_blocks_loaded      298085
# 386  prometheus_tsdb_checkpoint_creations_failed_total      298085
# 387         prometheus_tsdb_checkpoint_creations_total      298085
# 388  prometheus_tsdb_checkpoint_deletions_failed_total      298085
# 389         prometheus_tsdb_checkpoint_deletions_total      298085
# 390                        prometheus_tsdb_clean_start      298085
# 391  prometheus_tsdb_compaction_chunk_range_seconds...      298085
# 392  prometheus_tsdb_compaction_chunk_range_seconds...      298085
# 393  prometheus_tsdb_compaction_chunk_range_seconds...      298085
# 394    prometheus_tsdb_compaction_chunk_samples_bucket      298085
# 395     prometheus_tsdb_compaction_chunk_samples_count      298085
# 396       prometheus_tsdb_compaction_chunk_samples_sum      298085
# 397  prometheus_tsdb_compaction_chunk_size_bytes_bu...      298085
# 398  prometheus_tsdb_compaction_chunk_size_bytes_count      298085
# 399    prometheus_tsdb_compaction_chunk_size_bytes_sum      298085
# 400  prometheus_tsdb_compaction_duration_seconds_bu...      298085
# 401  prometheus_tsdb_compaction_duration_seconds_count      298085
# 402    prometheus_tsdb_compaction_duration_seconds_sum      298085
# 403        prometheus_tsdb_compaction_populating_block      298085
# 404           prometheus_tsdb_compactions_failed_total      298085
# 405          prometheus_tsdb_compactions_skipped_total      298085
# 406                  prometheus_tsdb_compactions_total      298085
# 407        prometheus_tsdb_compactions_triggered_total      298085
# 408       prometheus_tsdb_data_replay_duration_seconds      298085
# 409  prometheus_tsdb_exemplar_exemplars_appended_total      298085
# 410      prometheus_tsdb_exemplar_exemplars_in_storage      298085
# 411  prometheus_tsdb_exemplar_last_exemplars_timest...      298085
# 412             prometheus_tsdb_exemplar_max_exemplars      298085
# 413  prometheus_tsdb_exemplar_out_of_order_exemplar...      298085
# 414  prometheus_tsdb_exemplar_series_with_exemplars...      298085
# 415              prometheus_tsdb_head_active_appenders      298085
# 416                        prometheus_tsdb_head_chunks      298085
# 417          prometheus_tsdb_head_chunks_created_total      298085
# 418          prometheus_tsdb_head_chunks_removed_total      298085
# 419     prometheus_tsdb_head_chunks_storage_size_bytes      298085
# 420     prometheus_tsdb_head_gc_duration_seconds_count      298085
# 421       prometheus_tsdb_head_gc_duration_seconds_sum      298085
# 422                      prometheus_tsdb_head_max_time      298085
# 423              prometheus_tsdb_head_max_time_seconds      298085
# 424                      prometheus_tsdb_head_min_time      298085
# 425              prometheus_tsdb_head_min_time_seconds      298085
# 426  prometheus_tsdb_head_out_of_order_samples_appe...      298085
# 427        prometheus_tsdb_head_samples_appended_total      298085
# 428                        prometheus_tsdb_head_series      298085
# 429          prometheus_tsdb_head_series_created_total      298085
# 430        prometheus_tsdb_head_series_not_found_total      298085
# 431          prometheus_tsdb_head_series_removed_total      298085
# 432      prometheus_tsdb_head_truncations_failed_total      298085
# 433             prometheus_tsdb_head_truncations_total      298085
# 434           prometheus_tsdb_isolation_high_watermark      298085
# 435            prometheus_tsdb_isolation_low_watermark      298085
# 436                   prometheus_tsdb_lowest_timestamp      298085
# 437           prometheus_tsdb_lowest_timestamp_seconds      298085
# 438       prometheus_tsdb_mmap_chunk_corruptions_total      298085
# 439                  prometheus_tsdb_mmap_chunks_total      298085
# 440         prometheus_tsdb_out_of_bound_samples_total      298085
# 441         prometheus_tsdb_out_of_order_samples_total      298085
# 442             prometheus_tsdb_reloads_failures_total      298085
# 443                      prometheus_tsdb_reloads_total      298085
# 444              prometheus_tsdb_retention_limit_bytes      298085
# 445            prometheus_tsdb_retention_limit_seconds      298085
# 446              prometheus_tsdb_size_retentions_total      298085
# 447        prometheus_tsdb_snapshot_replay_error_total      298085
# 448               prometheus_tsdb_storage_blocks_bytes      298085
# 449            prometheus_tsdb_symbol_table_size_bytes      298085
# 450              prometheus_tsdb_time_retentions_total      298085
# 451   prometheus_tsdb_tombstone_cleanup_seconds_bucket      298085
# 452    prometheus_tsdb_tombstone_cleanup_seconds_count      298085
# 453      prometheus_tsdb_tombstone_cleanup_seconds_sum      298085
# 454              prometheus_tsdb_too_old_samples_total      298085
# 455         prometheus_tsdb_vertical_compactions_total      298085
# 456          prometheus_tsdb_wal_completed_pages_total      298085
# 457              prometheus_tsdb_wal_corruptions_total      298085
# 458   prometheus_tsdb_wal_fsync_duration_seconds_count      298085
# 459     prometheus_tsdb_wal_fsync_duration_seconds_sum      298085
# 460             prometheus_tsdb_wal_page_flushes_total      298085
# 461                prometheus_tsdb_wal_segment_current      298085
# 462             prometheus_tsdb_wal_storage_size_bytes      298085
# 463  prometheus_tsdb_wal_truncate_duration_seconds_...      298085
# 464  prometheus_tsdb_wal_truncate_duration_seconds_sum      298085
# 465       prometheus_tsdb_wal_truncations_failed_total      298085
# 466              prometheus_tsdb_wal_truncations_total      298085
# 467            prometheus_tsdb_wal_writes_failed_total      298085
# 468             prometheus_web_federation_errors_total      298085
# 469           prometheus_web_federation_warnings_total      298085
# 470               promhttp_metric_handler_errors_total      298085
# 471         promhttp_metric_handler_requests_in_flight      298085
# 472             promhttp_metric_handler_requests_total      298085
# 473                            scrape_duration_seconds      298085
# 474              scrape_samples_post_metric_relabeling      298085
# 475                             scrape_samples_scraped      298085
# 476                                scrape_series_added      298085
# 477                                                 up      298085
#
#               min            q1            q2            q3           max  \
# 0    4.974600e-05  1.177333e-03  2.344854e-03  4.553375e-03  2.535489e-02
# 1    5.000000e+00  3.140000e+02  7.560000e+02  1.157000e+03  7.526000e+03
# 2    1.702370e-04  3.102036e-02  6.950255e-02  1.036026e-01  2.241065e+00
# 3    3.100000e+01  3.300000e+01  3.300000e+01  3.300000e+01  4.700000e+01
# 4    1.000000e+00  1.000000e+00  1.000000e+00  1.000000e+00  1.000000e+00
# 5    1.297302e+07  1.828640e+07  2.152126e+07  2.504211e+07  4.348970e+07
# 6    2.417214e+07  4.191865e+09  1.027846e+10  1.624335e+10  1.306203e+11
# 7    1.455307e+06  1.528171e+06  1.569547e+06  1.595691e+06  1.716363e+06
# 8    6.184800e+04  1.912456e+06  4.525423e+06  7.100929e+06  5.558204e+07
# 9    4.551368e+06  4.826616e+06  4.849312e+06  4.871792e+06  6.155024e+06
# 10   1.297302e+07  1.828640e+07  2.152126e+07  2.504211e+07  4.348970e+07
# 11   1.310720e+05  1.705574e+07  2.158592e+07  2.543616e+07  4.435149e+07
# 12   1.625293e+07  2.207744e+07  2.545254e+07  2.897510e+07  4.743168e+07
# 13   8.654900e+04  8.918100e+04  9.125400e+04  9.602200e+04  1.640040e+05
# 14   8.192000e+03  8.232960e+06  1.059226e+07  1.441792e+07  2.617344e+07
# 15   2.336358e+07  4.420403e+07  4.820173e+07  5.203558e+07  6.904218e+07
# 16   1.719592e+09  1.721149e+09  1.722752e+09  1.724311e+09  1.725870e+09
# 17   0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# 18   1.617850e+05  2.001878e+06  4.613224e+06  7.196688e+06  5.570354e+07
# 19   1.920000e+04  1.920000e+04  1.920000e+04  1.920000e+04  1.920000e+04
# 20   3.120000e+04  3.120000e+04  3.120000e+04  3.120000e+04  3.120000e+04
# 21   2.803920e+05  4.116000e+05  4.295760e+05  4.468800e+05  5.155920e+05
# 22   2.933280e+05  4.888800e+05  4.888800e+05  5.051760e+05  5.866560e+05
# 23   2.368400e+07  2.901553e+07  2.963359e+07  3.860068e+07  5.448059e+07
# 24   1.099181e+06  3.123309e+06  3.387237e+06  3.609621e+06  4.197245e+06
# 25   1.015808e+06  1.835008e+06  2.064384e+06  2.228224e+06  2.785280e+06
# 26   1.015808e+06  1.835008e+06  2.064384e+06  2.228224e+06  2.785280e+06
# 27   3.287169e+07  5.646465e+07  6.065895e+07  6.432897e+07  8.302620e+07
# 28   1.100000e+01  2.200000e+01  2.300000e+01  2.300000e+01  2.400000e+01
# 29   1.000000e+00  1.000000e+00  1.000000e+00  1.000000e+00  1.000000e+00
# 30   0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# 31   1.000000e+00  1.000000e+00  1.000000e+00  1.000000e+00  1.000000e+00
# 32   0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# 33   1.000000e+00  4.851000e+03  1.196000e+04  1.891600e+04  1.532610e+05
# 34   0.000000e+00  4.850000e+03  1.195900e+04  1.891500e+04  1.532600e+05
# 35   2.000000e+00  2.000000e+00  2.000000e+00  2.000000e+00  2.000000e+00
# 36   1.710946e+09  1.710946e+09  1.710946e+09  1.710946e+09  1.710946e+09
# 37   2.081523e+11  2.276994e+11  2.475509e+11  2.683214e+11  2.877964e+11
# 38   0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# 39   0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# 40   0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# 41   2.823262e+05  4.527556e+05  5.963505e+05  7.371216e+05  8.678274e+05
# 42   0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# 43   0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# 44   0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# 45   0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# 46   0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# 47   0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# 48   1.000000e+00  1.000000e+00  1.000000e+00  1.000000e+00  1.000000e+00
# 49   0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# 50   0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# 51   0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# 52   0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# 53   0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# 54   0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# 55   0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# 56   0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# 57   0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# 58   0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# 59   0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# 60   1.000000e+00  1.000000e+00  1.000000e+00  1.000000e+00  1.000000e+00
# 61   2.560000e+02  2.560000e+02  2.560000e+02  2.560000e+02  2.560000e+02
# 62   2.560000e+02  2.560000e+02  2.560000e+02  2.560000e+02  2.560000e+02
# 63   1.000000e+00  1.000000e+00  1.000000e+00  1.000000e+00  1.000000e+00
# 64   2.304000e+03  3.776000e+03  4.192000e+03  4.576000e+03  6.976000e+03
# 65   9.223372e+18  9.223372e+18  9.223372e+18  9.223372e+18  9.223372e+18
# 66   6.688887e+09  6.688887e+09  6.688887e+09  6.688887e+09  6.688887e+09
# 67   0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# 68   1.633032e+06  1.633032e+06  1.633032e+06  1.633032e+06  1.633032e+06
# 69   1.632617e+06  1.632619e+06  1.632731e+06  1.632826e+06  1.632832e+06
# 70   6.688887e+09  6.688887e+09  6.688887e+09  6.688887e+09  6.688887e+09
# 71   0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# 72   6.688899e+09  6.688899e+09  6.688899e+09  6.688899e+09  6.688899e+09
# 73   6.557197e+06  1.124782e+07  1.613935e+07  2.207987e+07  2.692634e+07
# 74   1.000000e+00  1.000000e+00  1.000000e+00  1.000000e+00  1.000000e+00
# 75   4.572705e+10  5.879971e+10  6.482131e+10  7.398534e+10  1.057312e+11
# 76   3.750000e+00  9.010000e+00  9.800000e+00  1.068000e+01  1.781000e+01
# 77   1.520000e+00  3.680000e+00  4.850000e+00  5.780000e+00  9.290000e+00
# 78   2.010000e+00  6.780000e+00  8.110000e+00  8.840000e+00  1.306000e+01
# 79   3.826647e+08  5.428183e+08  6.000804e+08  8.716165e+08  1.058140e+09
# 80   1.820582e+09  2.413883e+09  2.837377e+09  3.791135e+09  2.176766e+10
# 81   1.254285e+09  1.688334e+09  1.991930e+09  3.087266e+09  2.135946e+10
# 82   2.583691e+09  7.333741e+09  1.508901e+10  2.488481e+10  2.631297e+10
# 83   4.008182e+09  2.644180e+10  2.731654e+10  2.788242e+10  4.498246e+10
# 84   0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# 85   4.160389e+08  2.042495e+09  2.157142e+09  3.157840e+09  2.069587e+10
# 86   2.753147e+09  2.400437e+10  2.673971e+10  2.731476e+10  3.250622e+10
# 87   0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# 88   0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# 89   3.559198e+10  3.559198e+10  3.559198e+10  3.559198e+10  3.559198e+10
# 90   3.478639e+10  3.796136e+10  3.891644e+10  4.001479e+10  5.847708e+10
# 91   9.663676e+09  9.663676e+09  9.663676e+09  9.663676e+09  9.663676e+09
# 92   6.013164e+10  6.013164e+10  6.014842e+10  6.014842e+10  6.014842e+10
# 93   1.054736e+09  1.054736e+09  1.054736e+09  1.071514e+09  1.071514e+09
# 94   0.000000e+00  1.033011e+07  1.461043e+07  2.084864e+07  2.782691e+09
# 95   0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# 96   0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# 97   0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# 98   0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# 99   0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# 100  0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# 101  0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# 102  2.097152e+06  2.097152e+06  2.097152e+06  2.097152e+06  2.097152e+06
# 103  0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# 104  4.475175e+09  2.705416e+10  2.795013e+10  2.860250e+10  4.586659e+10
# 105  1.646110e+10  5.061378e+10  5.319923e+10  5.460963e+10  5.612664e+10
# 106  1.369137e+09  2.332510e+10  2.598866e+10  2.647189e+10  3.215361e+10
# 107  1.875730e+09  6.360769e+09  6.927430e+09  7.141663e+09  1.733718e+10
# 108  2.223309e+07  2.800026e+07  2.958950e+07  2.998272e+07  3.879731e+07
# 109  3.521987e+08  5.961482e+08  6.329180e+08  6.778225e+08  2.013831e+09
# 110  1.804816e+10  3.543871e+10  3.610304e+10  3.700947e+10  5.973089e+10
# 111  3.847905e+08  1.319346e+09  2.460058e+09  4.712178e+09  3.127400e+10
# 112  6.688901e+10  6.688901e+10  6.688901e+10  6.688901e+10  6.688901e+10
# 113  0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00  6.553600e+04
# 114  0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# 115  2.118042e+07  6.792397e+07  7.072154e+07  7.523533e+07  1.389855e+08
# 116  1.533542e+07  1.566310e+07  1.572864e+07  1.815347e+07  1.887437e+07
# 117  1.875730e+09  6.360769e+09  6.927430e+09  7.141663e+09  1.733718e+10
# 118  4.920812e+08  9.111757e+08  1.006531e+09  1.122865e+09  1.734996e+09
# 119  0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# 120  0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# 121  0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# 122  1.203425e+09  1.318969e+09  1.361531e+09  1.424253e+09  1.898480e+09
# 123  2.404151e+09  7.403868e+09  8.023499e+09  8.069849e+09  1.878270e+10
# 124  5.328896e+06  5.812224e+06  1.856307e+07  1.193820e+08  2.178294e+08
# 125  9.555640e+08  1.468674e+09  2.019717e+09  2.075873e+09  2.125828e+09
# 126  2.147480e+09  2.147480e+09  2.147480e+09  2.147480e+09  2.147480e+09
# 127  0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# 128  0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00  6.553600e+04
# 129  0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# 130  3.518437e+13  3.518437e+13  3.518437e+13  3.518437e+13  3.518437e+13
# 131  4.152115e+07  4.753818e+07  4.877517e+07  4.908646e+07  5.784781e+07
# 132  0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# 133  0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00  7.550157e+07
# 134  0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# 135  0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# 136  0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# 137  0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# 138  0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# 139  0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# 140  0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# 141  0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# 142  0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# 143  0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# 144  2.116000e+03  2.589500e+04  4.805500e+04  7.068800e+04  1.149280e+05
# 145  4.552100e+04  6.967480e+05  1.306720e+06  1.925990e+06  3.147096e+06
# 146  1.000000e+00  1.000000e+00  1.000000e+00  1.000000e+00  1.000000e+00
# 147  0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# 148  0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# 149  0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# 150  0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# 151  0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# 152  0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# 153  0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# 154  0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# 155  1.000000e+00  1.000000e+00  1.000000e+00  1.000000e+00  1.000000e+00
# 156  0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# 157  1.800000e+01  2.330000e+02  4.330000e+02  6.380000e+02  1.038000e+03
# 158  0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# 159  3.500000e+01  5.080000e+02  9.480000e+02  1.399000e+03  2.282000e+03
# 160  1.000000e+00  1.000000e+00  1.000000e+00  1.000000e+00  1.000000e+00
# 161  0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# 162  0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# 163  0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# 164  0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# 165  0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# 166  0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# 167  0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# 168  0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# 169  0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# 170  0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# 171  0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# 172  0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# 173  0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# 174  0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# 175  0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# 176  1.000000e+00  1.000000e+00  1.000000e+00  1.000000e+00  1.000000e+00
# 177  1.000000e+00  1.000000e+00  1.000000e+00  1.000000e+00  1.000000e+00
# 178  2.000000e+00  2.000000e+00  2.000000e+00  2.000000e+00  2.000000e+00
# 179  1.000000e+00  1.000000e+00  1.000000e+00  1.000000e+00  1.000000e+00
# 180  1.000000e+00  1.000000e+00  1.000000e+00  1.000000e+00  1.000000e+00
# 181  0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# 182  0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# 183  4.867000e+03  4.867000e+03  4.867000e+03  4.867000e+03  4.867000e+03
# 184  2.548000e+03  1.336300e+04  2.448900e+04  3.533500e+04  4.616200e+04
# 185  2.547000e+03  1.336200e+04  2.448800e+04  3.533400e+04  4.616100e+04
# ...
# 395  0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# 396  0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# 397  0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# 398  0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# 399  0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# 400  0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# 401  0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# 402  0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# 403  0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# 404  0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# 405  0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# 406  0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# 407  0.000000e+00  3.000000e+00  7.000000e+00  1.000000e+01  1.700000e+01
# 408  2.764890e-04  4.466140e-04  6.898350e-04  1.148577e-03  2.926995e-01
# 409  0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# 410  0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# 411  0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# 412  0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# 413  0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# 414  0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# 415  1.000000e+00  1.000000e+00  1.000000e+00  1.000000e+00  2.000000e+00
# 416  1.600000e+03  1.623000e+03  1.623000e+03  3.204000e+03  2.227900e+04
# 417  1.600000e+03  1.623000e+03  1.623000e+03  3.204000e+03  2.227900e+04
# 418  0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# 419  0.000000e+00  0.000000e+00  0.000000e+00  1.310720e+05  4.236739e+06
# 420  0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# 421  0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# 422  1.719592e+12  1.721149e+12  1.722752e+12  1.724311e+12  1.725870e+12
# 423  1.719592e+09  1.721149e+09  1.722752e+09  1.724311e+09  1.725870e+09
# 424  1.719592e+12  1.721149e+12  1.722751e+12  1.724310e+12  1.725869e+12
# 425  1.719592e+09  1.721149e+09  1.722751e+09  1.724310e+09  1.725869e+09
# 426  0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# 427  0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# 428  1.600000e+03  1.623000e+03  1.623000e+03  1.623000e+03  2.081000e+03
# 429  1.600000e+03  1.623000e+03  1.623000e+03  1.623000e+03  2.768000e+03
# 430  0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# 431  0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00  6.870000e+02
# 432  0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# 433  0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# 434  9.000000e+00  9.300000e+01  1.740000e+02  2.550000e+02  4.160000e+02
# 435  9.000000e+00  9.300000e+01  1.740000e+02  2.550000e+02  4.160000e+02
# 436  1.719592e+12  1.721149e+12  1.722751e+12  1.724310e+12  1.725869e+12
# 437  1.719592e+09  1.721149e+09  1.722751e+09  1.724310e+09  1.725869e+09
# 438  0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# 439  0.000000e+00  0.000000e+00  0.000000e+00  4.000000e+00  1.611000e+03
# 440  0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# 441  0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# 442  0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# 443  1.000000e+00  4.000000e+00  8.000000e+00  1.100000e+01  1.800000e+01
# 444  0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# 445  1.296000e+06  1.296000e+06  1.296000e+06  1.296000e+06  1.296000e+06
# 446  0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# 447  0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# 448  0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00  5.012016e+06
# 449  0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00  4.800000e+02
# 450  0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# 451  0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# 452  0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# 453  0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# 454  0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# 455  0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# 456  1.000000e+00  1.400000e+01  2.600000e+01  3.800000e+01  6.100000e+01
# 457  0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# 458  0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# 459  0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# 460  1.200000e+01  1.100000e+02  2.030000e+02  2.960000e+02  4.780000e+02
# 461  0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00  7.000000e+00
# 462  6.276900e+04  4.648580e+05  8.575600e+05  1.250033e+06  2.915738e+07
# 463  0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# 464  0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# 465  0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# 466  0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# 467  0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# 468  0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# 469  0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# 470  0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# 471  1.000000e+00  1.000000e+00  1.000000e+00  1.000000e+00  1.000000e+00
# 472  0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# 473  2.548499e-03  3.124508e-03  3.598722e-03  4.656313e-03  9.329599e-02
# 474  4.520000e+02  4.750000e+02  4.750000e+02  4.750000e+02  4.750000e+02
# 475  4.520000e+02  4.750000e+02  4.750000e+02  4.750000e+02  4.750000e+02
# 476  0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00  2.300000e+01
# 477  1.000000e+00  1.000000e+00  1.000000e+00  1.000000e+00  1.000000e+00
#
#           std_dev
# 0    3.533145e-03
# 1    4.753010e+02
# 2    5.498943e-02
# 3    5.295083e-01
# 4    0.000000e+00
# 5    5.188229e+06
# 6    6.968208e+09
# 7    4.593345e+04
# 8    3.019577e+06
# 9    5.628279e+04
# 10   5.188229e+06
# 11   6.872789e+06
# 12   5.244808e+06
# 13   6.550741e+03
# 14   4.229477e+06
# 15   5.884257e+06
# 16   1.819603e+06
# 17   0.000000e+00
# 18   3.020319e+06
# 19   0.000000e+00
# 20   0.000000e+00
# 21   2.817986e+04
# 22   3.372118e+04
# 23   4.573385e+06
# 24   4.456440e+05
# 25   2.742129e+05
# 26   2.742129e+05
# 27   6.453913e+06
# 28   1.713254e+00
# 29   0.000000e+00
# 30   0.000000e+00
# 31   0.000000e+00
# 32   0.000000e+00
# 33   8.132810e+03
# 34   8.132805e+03
# 35   0.000000e+00
# 36   0.000000e+00
# 37   2.321048e+10
# 38   0.000000e+00
# 39   0.000000e+00
# 40   0.000000e+00
# 41   1.673625e+05
# 42   0.000000e+00
# 43   0.000000e+00
# 44   0.000000e+00
# 45   0.000000e+00
# 46   0.000000e+00
# 47   0.000000e+00
# 48   0.000000e+00
# 49   0.000000e+00
# 50   0.000000e+00
# 51   0.000000e+00
# 52   0.000000e+00
# 53   0.000000e+00
# 54   0.000000e+00
# 55   0.000000e+00
# 56   0.000000e+00
# 57   0.000000e+00
# 58   0.000000e+00
# 59   0.000000e+00
# 60   0.000000e+00
# 61   0.000000e+00
# 62   0.000000e+00
# 63   0.000000e+00
# 64   5.644772e+02
# 65   0.000000e+00
# 66   0.000000e+00
# 67   0.000000e+00
# 68   0.000000e+00
# 69   9.082676e+01
# 70   0.000000e+00
# 71   0.000000e+00
# 72   0.000000e+00
# 73   6.065636e+06
# 74   0.000000e+00
# 75   1.236815e+10
# 76   1.333424e+00
# 77   1.311001e+00
# 78   1.645759e+00
# 79   1.749156e+08
# 80   2.232402e+09
# 81   2.277283e+09
# 82   8.086267e+09
# 83   1.629536e+09
# 84   0.000000e+00
# 85   2.684555e+09
# 86   4.844180e+09
# 87   0.000000e+00
# 88   0.000000e+00
# 89   0.000000e+00
# 90   1.463256e+09
# 91   0.000000e+00
# 92   8.311109e+06
# 93   8.311109e+06
# 94   5.455354e+07
# 95   0.000000e+00
# 96   0.000000e+00
# 97   0.000000e+00
# 98   0.000000e+00
# 99   0.000000e+00
# 100  0.000000e+00
# 101  0.000000e+00
# 102  0.000000e+00
# 103  0.000000e+00
# 104  1.679557e+09
# 105  4.484236e+09
# 106  4.413078e+09
# 107  1.428716e+09
# 108  1.656615e+06
# 109  8.522329e+07
# 110  1.691952e+09
# 111  2.874257e+09
# 112  0.000000e+00
# 113  1.200355e+02
# 114  0.000000e+00
# 115  9.350413e+06
# 116  1.215253e+06
# 117  1.428716e+09
# 118  1.548923e+08
# 119  0.000000e+00
# 120  0.000000e+00
# 121  0.000000e+00
# 122  7.234691e+07
# 123  1.522969e+09
# 124  7.396844e+07
# 125  3.098032e+08
# 126  0.000000e+00
# 127  0.000000e+00
# 128  1.200355e+02
# 129  0.000000e+00
# 130  2.554498e+01
# 131  1.573211e+06
# 132  0.000000e+00
# 133  4.246777e+05
# 134  0.000000e+00
# 135  0.000000e+00
# 136  0.000000e+00
# 137  0.000000e+00
# 138  0.000000e+00
# 139  0.000000e+00
# 140  0.000000e+00
# 141  0.000000e+00
# 142  0.000000e+00
# 143  0.000000e+00
# 144  2.577655e+04
# 145  7.078221e+05
# 146  0.000000e+00
# 147  0.000000e+00
# 148  0.000000e+00
# 149  0.000000e+00
# 150  0.000000e+00
# 151  0.000000e+00
# 152  0.000000e+00
# 153  0.000000e+00
# 154  0.000000e+00
# 155  0.000000e+00
# 156  0.000000e+00
# 157  2.330612e+02
# 158  0.000000e+00
# 159  5.131083e+02
# 160  0.000000e+00
# 161  0.000000e+00
# 162  0.000000e+00
# 163  0.000000e+00
# 164  0.000000e+00
# 165  0.000000e+00
# 166  0.000000e+00
# 167  0.000000e+00
# 168  0.000000e+00
# 169  0.000000e+00
# 170  0.000000e+00
# 171  0.000000e+00
# 172  0.000000e+00
# 173  0.000000e+00
# 174  0.000000e+00
# 175  0.000000e+00
# 176  0.000000e+00
# 177  0.000000e+00
# 178  0.000000e+00
# 179  0.000000e+00
# 180  0.000000e+00
# 181  0.000000e+00
# 182  0.000000e+00
# 183  0.000000e+00
# 184  1.263784e+04
# 185  1.263784e+04
# 186  0.000000e+00
# 187  0.000000e+00
# 188  0.000000e+00
# 189  0.000000e+00
# 190  0.000000e+00
# 191  0.000000e+00
# 192  0.000000e+00
# 193  0.000000e+00
# 194  0.000000e+00
# 195  0.000000e+00
# 196  0.000000e+00
# 197  0.000000e+00
# 198  0.000000e+00
# 199  0.000000e+00
# 200  0.000000e+00
# 201  0.000000e+00
# 202  0.000000e+00
# 203  0.000000e+00
# 204  0.000000e+00
# 205  0.000000e+00
# 206  0.000000e+00
# 207  0.000000e+00
# 208  0.000000e+00
# 209  0.000000e+00
# 210  0.000000e+00
# 211  0.000000e+00
# 212  0.000000e+00
# 213  0.000000e+00
# 214  0.000000e+00
# 215  0.000000e+00
# 216  0.000000e+00
# 217  0.000000e+00
# 218  0.000000e+00
# 219  0.000000e+00
# 220  0.000000e+00
# 221  0.000000e+00
# 222  0.000000e+00
# 223  2.779104e-11
# 224  0.000000e+00
# 225  0.000000e+00
# 226  8.026913e-01
# 227  5.893482e+00
# 228  2.010541e+05
# 229  1.052123e+09
# 230  7.933502e+04
# 231  3.567605e-04
# 232  0.000000e+00
# 233  0.000000e+00
# 234  0.000000e+00
# 235  0.000000e+00
# 236  0.000000e+00
# 237  0.000000e+00
# 238  0.000000e+00
# 239  0.000000e+00
# 240  0.000000e+00
# 241  1.665968e+01
# 242  0.000000e+00
# 243  2.837430e+02
# 244  1.162211e+06
# 245  5.746771e-01
# 246  0.000000e+00
# 247  0.000000e+00
# 248  0.000000e+00
# 249  0.000000e+00
# 250  0.000000e+00
# 251  3.189658e+02
# 252  1.306484e+06
# 253  1.166801e+00
# 254  1.532276e-02
# 255  0.000000e+00
# 256  3.693951e-01
# 257  0.000000e+00
# 258  3.232222e+08
# 259  0.000000e+00
# 260  2.186710e+02
# 261  0.000000e+00
# 262  0.000000e+00
# 263  0.000000e+00
# 264  1.819603e+06
# 265  0.000000e+00
# 266  2.893700e-05
# 267  7.940137e-07
# 268  0.000000e+00
# 269  1.840635e-02
# 270  0.000000e+00
# 271  0.000000e+00
# 272  0.000000e+00
# 273  0.000000e+00
# 274  0.000000e+00
# 275  0.000000e+00
# 276  0.000000e+00
# 277  0.000000e+00
# 278  0.000000e+00
# 279  0.000000e+00
# 280  0.000000e+00
# 281  0.000000e+00
# 282  2.175344e-14
# 283  0.000000e+00
# 284  0.000000e+00
# 285  0.000000e+00
# 286  8.083633e+10
# 287  1.582990e+07
# 288  3.824293e+08
# 289  3.506358e+09
# 290  5.640940e+04
# 291  5.415221e+05
# 292  1.084008e+01
# 293  0.000000e+00
# 294  9.671349e-01
# 295  6.015536e+06
# 296  1.819589e+06
# 297  6.123920e+07
# 298  0.000000e+00
# 299  0.000000e+00
# 300  0.000000e+00
# 301  1.819589e+06
# 302  0.000000e+00
# 303  3.895377e-02
# 304  0.000000e+00
# 305  8.132801e+03
# 306  7.259423e-03
# 307  0.000000e+00
# 308  0.000000e+00
# 309  8.325721e+04
# 310  4.661480e+01
# 311  4.661480e+01
# 312  1.468249e-01
# 313  0.000000e+00
# 314  4.661480e+01
# 315  4.661480e+01
# 316  3.927137e+05
# 317  0.000000e+00
# 318  0.000000e+00
# 319  0.000000e+00
# 320  0.000000e+00
# 321  0.000000e+00
# 322  0.000000e+00
# 323  1.819603e+06
# 324  0.000000e+00
# 325  7.474333e+04
# 326  0.000000e+00
# 327  0.000000e+00
# 328  0.000000e+00
# 329  0.000000e+00
# 330  0.000000e+00
# 331  0.000000e+00
# 332  0.000000e+00
# 333  0.000000e+00
# 334  0.000000e+00
# 335  0.000000e+00
# 336  0.000000e+00
# 337  0.000000e+00
# 338  0.000000e+00
# 339  0.000000e+00
# 340  0.000000e+00
# 341  0.000000e+00
# 342  0.000000e+00
# 343  0.000000e+00
# 344  0.000000e+00
# 345  0.000000e+00
# 346  0.000000e+00
# 347  0.000000e+00
# 348  0.000000e+00
# 349  0.000000e+00
# 350  0.000000e+00
# 351  0.000000e+00
# 352  0.000000e+00
# 353  0.000000e+00
# 354  0.000000e+00
# 355  8.270543e-03
# 356  9.322784e+01
# 357  4.661398e+02
# 358  0.000000e+00
# 359  0.000000e+00
# 360  0.000000e+00
# 361  0.000000e+00
# 362  0.000000e+00
# 363  0.000000e+00
# 364  0.000000e+00
# 365  0.000000e+00
# 366  0.000000e+00
# 367  0.000000e+00
# 368  0.000000e+00
# 369  0.000000e+00
# 370  0.000000e+00
# 371  0.000000e+00
# 372  0.000000e+00
# 373  0.000000e+00
# 374  0.000000e+00
# 375  0.000000e+00
# 376  0.000000e+00
# 377  0.000000e+00
# 378           NaN
# 379  0.000000e+00
# 380  3.698325e-04
# 381  0.000000e+00
# 382  0.000000e+00
# 383  0.000000e+00
# 384  0.000000e+00
# 385  4.802856e-02
# 386  0.000000e+00
# 387  0.000000e+00
# 388  0.000000e+00
# 389  0.000000e+00
# 390  0.000000e+00
# 391  0.000000e+00
# 392  0.000000e+00
# 393  0.000000e+00
# 394  0.000000e+00
# 395  0.000000e+00
# 396  0.000000e+00
# 397  0.000000e+00
# 398  0.000000e+00
# 399  0.000000e+00
# 400  0.000000e+00
# 401  0.000000e+00
# 402  0.000000e+00
# 403  0.000000e+00
# 404  0.000000e+00
# 405  0.000000e+00
# 406  0.000000e+00
# 407  3.896447e+00
# 408  7.068580e-03
# 409  0.000000e+00
# 410  0.000000e+00
# 411  0.000000e+00
# 412  0.000000e+00
# 413  0.000000e+00
# 414  0.000000e+00
# 415  7.806979e-02
# 416  8.581498e+02
# 417  8.581498e+02
# 418  0.000000e+00
# 419  1.157049e+05
# 420  0.000000e+00
# 421  0.000000e+00
# 422  1.819603e+09
# 423  1.819603e+06
# 424  1.819589e+09
# 425  1.819589e+06
# 426  0.000000e+00
# 427  0.000000e+00
# 428  1.278665e+01
# 429  2.826172e+01
# 430  0.000000e+00
# 431  1.649781e+01
# 432  0.000000e+00
# 433  0.000000e+00
# 434  9.322784e+01
# 435  9.322752e+01
# 436  1.819590e+09
# 437  1.819590e+06
# 438  0.000000e+00
# 439  6.669098e+02
# 440  0.000000e+00
# 441  0.000000e+00
# 442  0.000000e+00
# 443  3.896456e+00
# 444  0.000000e+00
# 445  0.000000e+00
# 446  0.000000e+00
# 447  0.000000e+00
# 448  1.203600e+05
# 449  1.152685e+01
# 450  0.000000e+00
# 451  0.000000e+00
# 452  0.000000e+00
# 453  0.000000e+00
# 454  0.000000e+00
# 455  0.000000e+00
# 456  1.375081e+01
# 457  0.000000e+00
# 458  0.000000e+00
# 459  0.000000e+00
# 460  1.070939e+02
# 461  1.681000e-01
# 462  7.968100e+05
# 463  0.000000e+00
# 464  0.000000e+00
# 465  0.000000e+00
# 466  0.000000e+00
# 467  0.000000e+00
# 468  0.000000e+00
# 469  0.000000e+00
# 470  0.000000e+00
# 471  0.000000e+00
# 472  0.000000e+00
# 473  1.698712e-03
# 474  6.263485e+00
# 475  6.263485e+00
# 476  1.750109e+00
# 477  0.000000e+00

# %%
df_resumen_estadistico.to_parquet(f'{FOLDER_SALIDA}/resumen_estadistico.parquet', index=False,engine='fastparquet')

# %%
df_resumen_estadistico = pd.read_parquet(f'{FOLDER_SALIDA}/resumen_estadistico.parquet', engine='fastparquet')

# %%
metricas_con_std_dev_nulo     = df_resumen_estadistico['std_dev']==0
df_metricas_filtradas = df_resumen_estadistico[~metricas_con_std_dev_nulo].reset_index(drop=True)
lista_metricas_con_std_dev_nulo = df_resumen_estadistico.loc[metricas_con_std_dev_nulo, 'metric_name'].tolist()

# %%
with open(f'result/lista_metricas_con_std_dev_nulo.json', "w", encoding="utf-8") as f:
    json.dump(lista_metricas_con_std_dev_nulo, f, ensure_ascii=False, indent=4)

# %%
df_metricas_filtradas
# Out:
#                                 metric_name  n_muestras           min  \
# 0                    go_gc_duration_seconds      298085  4.974600e-05
# 1              go_gc_duration_seconds_count      298085  5.000000e+00
# 2                go_gc_duration_seconds_sum      298085  1.702370e-04
# 3                             go_goroutines      298085  3.100000e+01
# 4                   go_memstats_alloc_bytes      298085  1.297302e+07
# ..                                      ...         ...           ...
# 151  prometheus_tsdb_wal_storage_size_bytes      298085  6.276900e+04
# 152                 scrape_duration_seconds      298085  2.548499e-03
# 153   scrape_samples_post_metric_relabeling      298085  4.520000e+02
# 154                  scrape_samples_scraped      298085  4.520000e+02
# 155                     scrape_series_added      298085  0.000000e+00
#
#                q1            q2            q3           max       std_dev
# 0    1.177333e-03  2.344854e-03  4.553375e-03  2.535489e-02  3.533145e-03
# 1    3.140000e+02  7.560000e+02  1.157000e+03  7.526000e+03  4.753010e+02
# 2    3.102036e-02  6.950255e-02  1.036026e-01  2.241065e+00  5.498943e-02
# 3    3.300000e+01  3.300000e+01  3.300000e+01  4.700000e+01  5.295083e-01
# 4    1.828640e+07  2.152126e+07  2.504211e+07  4.348970e+07  5.188229e+06
# ..            ...           ...           ...           ...           ...
# 151  4.648580e+05  8.575600e+05  1.250033e+06  2.915738e+07  7.968100e+05
# 152  3.124508e-03  3.598722e-03  4.656313e-03  9.329599e-02  1.698712e-03
# 153  4.750000e+02  4.750000e+02  4.750000e+02  4.750000e+02  6.263485e+00
# 154  4.750000e+02  4.750000e+02  4.750000e+02  4.750000e+02  6.263485e+00
# 155  0.000000e+00  0.000000e+00  0.000000e+00  2.300000e+01  1.750109e+00
#
# [156 rows x 8 columns]

# %%
lista_metricas_filtadas=df_metricas_filtradas['metric_name'].to_list()
df_metricas_filtradas.to_parquet(f'{FOLDER_SALIDA}/df_metricas_filtradas.parquet', index=False,engine='fastparquet')

# %%
with open(f'result/lista_metricas_filtradas.json', "w", encoding="utf-8") as f:
    json.dump(lista_metricas_filtadas, f, ensure_ascii=False, indent=4)

# %%
# 1. Configuración de estilo y limpieza de avisos
sns.set_theme(style="whitegrid")
warnings.simplefilter(action='ignore', category=FutureWarning)
warnings.simplefilter(action='ignore', category=UserWarning)

# Inicializamos la estructura para guardar las métricas sin variación
metricas_estaticas = set()

nombre_pdf = "result/informe_estructurado_metricas.pdf"
total_metricas = len(lista_metricas_filtadas)

print(f"🚀 Iniciando exportación masiva a {nombre_pdf}...")

# 2. Abrimos el contexto del PDF
with PdfPages(nombre_pdf) as pdf:
    
    for i, una_metrica in enumerate(lista_metricas_filtadas, 1):
        
        # 🚀 MENSAJE INTERACTIVO: Muestra el progreso actual sobreescribiendo la misma línea
        # Limitamos visualmente el nombre de la métrica a 45 caracteres para mantener limpia la consola
        sys.stdout.write(f"\r🔄 [{i}/{total_metricas}] Procesando: {una_metrica[:45]}...".ljust(80))
        sys.stdout.flush()
        
        # Query para traer los datos de la métrica actual
        SQL = f"""
        SELECT metric_value, label 
        FROM metricas 
        WHERE metric_name = '{una_metrica}';
        """
        
        try:
            df_var = pd.read_sql(text(SQL), engine)
            
            # Saltamos si la métrica está vacía
            if df_var.empty:
                continue
                
            df_var['metric_value'] = df_var['metric_value'].astype(float)
            df_var['label'] = df_var['label'].astype(str)

            # DETECCIÓN DE MÉTRICAS INVARIANTES:
            # Si todos los valores de la columna son idénticos, la guardamos 
            if df_var['metric_value'].nunique() <= 1:
                metricas_estaticas.add(una_metrica)
                #continue

            # Mapeo binario para el Histograma (correct vs el resto)
            df_var['label_binaria'] = df_var['label'].apply(lambda x: 'correct' if x == 'correct' else 'anomaly')

            orden_boxplot = list(df_var['label'].unique())

            # 3. Creamos la figura optimizada para el folio
            fig, axes = plt.subplots(2, 1, figsize=(11, 16), gridspec_kw={'height_ratios': [1, 3]})

            # --- GRÁFICO 1: HISTOGRAMA BINARIO (Arriba) ---
            sns.histplot(
                data=df_var, 
                x='metric_value', 
                hue='label_binaria',  
                hue_order=['correct', 'anomaly'],
                palette={'correct': '#2ecc71', 'anomaly': '#e74c3c'}, 
                kde=True, 
                ax=axes[0],
                element='step',
                stat='density',  
                common_norm=False,
                legend=True  
            )
            axes[0].set_title('Distribución Comparativa Binaria (Histograma)', fontsize=12, fontweight='bold')
            axes[0].set_xlabel('Valor de la Métrica')
            axes[0].set_ylabel('Densidad')

            # --- GRÁFICO 2: BOXPLOT MULTI-ETIQUETA ORDENADO (Abajo) ---
            sns.boxplot(
                data=df_var, 
                x='metric_value', 
                y='label',         
                order=orden_boxplot,  
                orient='h',
                palette='tab20', 
                ax=axes[1],
                hue='label',
                legend=False,
                width=0.7,          
                fliersize=3
            )
            axes[1].set_title('Dispersión Detallada por Escenario / Ataque', fontsize=12, fontweight='bold')
            axes[1].set_xlabel('Valor de la Métrica')
            axes[1].set_ylabel('Tipo de Escenario (Label)')
            axes[1].tick_params(axis='y', labelsize=8)

            # Título de la página actual
            fig.suptitle(f"📊 [Métrica {i}] ANÁLISIS DETALLADO: {una_metrica.upper()}", fontsize=14, fontweight='bold', y=1.01)
            
            plt.tight_layout()
            
            # Guardamos la página en el PDF y liberamos memoria
            pdf.savefig(fig, bbox_inches='tight')
            plt.close(fig)
            

    
        except Exception as e:
            error_details = traceback.format_exc()
            fig_err, ax_err = plt.subplots(figsize=(11, 8.5))
            fig_err.suptitle(f"⚠️ ERROR EN MÉTRICA: {una_metrica.upper()}", fontsize=14, fontweight='bold', color='darkred')
            ax_err.text(0.05, 0.95, f"Ocurrió un error al procesar:\n{str(e)}\n\nDetalle técnico (Traceback):", 
                        fontsize=10, fontweight='bold', va='top', transform=ax_err.transAxes)
            ax_err.text(0.05, 0.85, error_details, fontsize=8, va='top', family='monospace', transform=ax_err.transAxes)         
            ax_err.axis('off')
            
            pdf.savefig(fig_err, bbox_inches='tight')
            plt.close(fig_err)
            
            print(f"\n❌ Métrica {una_metrica} falló. Error registrado en el PDF.")

# Un salto de línea final para limpiar la consola al terminar el bucle
print("\n")
print(f"🎉 ¡Hecho! El archivo '{nombre_pdf}' se ha guardado correctamente.")
print(f"🚫 Lista completa de métricas invariantes detectadas: {list(metricas_estaticas)}")
# Out:
# 🚀 Iniciando exportación masiva a result/informe_estructurado_metricas.pdf...
# 🔄 [156/156] Procesando: scrape_series_added...
#
# 🎉 ¡Hecho! El archivo 'result/informe_estructurado_metricas.pdf' se ha guardado correctamente.
# 🚫 Lista completa de métricas invariantes detectadas: ['node_memory_VmallocTotal_bytes', 'node_timex_tick_seconds', 'node_os_version']

# %% [markdown]
# Estos boxplot confirman que las pruebas se se hacen siempre igual, primero el tramo sin anomalias y luego todas las anomalias en el mismo orden, aunque  parece que las pruebas no duran exactamente lo mismo y los outliers que aparecen en los boxplots indican que algunas pruebas se alargan en alguna situacion o que ha alguna ejecución anñomala

# %%
una_metrica = "PROMETHEUS_TSDB_WAL_STORAGE_SIZE_BYTES" # O la que quieras probar
una_ejecucion = "light-oauth2-data-1725524098.tar"

# 1. Traemos los datos de una ejecución concreta ordenados por tiempo
SQL = f"""
SELECT time, metric_value 
FROM metricas 
WHERE execution_name = '{una_ejecucion}' 
  AND metric_name = '{una_metrica}'
ORDER BY time ASC;
"""

df_test = pd.read_sql(text(SQL), engine)
df_test['metric_value'] = df_test['metric_value'].astype(float)

# 2. Calculamos la diferencia entre cada fila y la anterior (v_actual - v_anterior)
# La primera fila dará NaN, así que la eliminamos para no alterar el test
diferencias = df_test['metric_value'].diff().dropna()

# 3. VEREDICTO MATEMÁTICO
# Si todas las diferencias son mayores o iguales a cero (>= 0), es monótona creciente
es_monotona = (diferencias >= 0).all()

print(f"📊 Análisis de monotonía para: {una_metrica}")
print(f"¿Es estrictamente monótona creciente en esta ejecución?: {'SÍ, es un Contador (Counter) ✅' if es_monotona else 'NO, es un Indicador (Gauge) ❌'}")

# Si no es monótona, podemos ver cuántas veces ha bajado de valor
if not es_monotona:
    caidas = diferencias[diferencias < 0]
    print(f"   ➔ El valor disminuyó {len(caidas)} veces durante la simulación.")
    print(f"   ➔ La mayor caída registrada fue de {caidas.min()} unidades.")
# Out:
# 📊 Análisis de monotonía para: PROMETHEUS_TSDB_WAL_STORAGE_SIZE_BYTES
# ¿Es estrictamente monótona creciente en esta ejecución?: SÍ, es un Contador (Counter) ✅

# %%
#La celda siguiente hace  lo mismo con menos metricas, no con todas


# SQL_auditoria = """
# WITH calculado AS (
#     SELECT 
#         metric_name,
#         execution_name,
#         metric_value - LAG(metric_value) OVER(
#             PARTITION BY metric_name, execution_name 
#             ORDER BY time ASC
#         ) AS diferencia
#     FROM metricas
# )
# SELECT 
#     metric_name,
#     COUNT(DISTINCT execution_name) AS total_ejecuciones,
#     -- Contamos las ejecuciones donde NO hubo ninguna caída (diferencia < 0)
#     COUNT(DISTINCT execution_name) - COUNT(DISTINCT CASE WHEN diferencia < 0 THEN execution_name END) AS ejecuciones_monotonas
# FROM calculado
# GROUP BY metric_name;
# """

# print("⏳ Evaluando monotonía métrica a métrica en todas las ejecuciones...")
# df_auditoria = pd.read_sql(text(SQL_auditoria), engine)

# # 2. PROCESAMIENTO DE LA TABLA DE RESULTADOS
# # Creamos la tercera columna condicional: si las ejecuciones monótonas son iguales al total, es True
# df_auditoria['es_monotona_global'] = df_auditoria['ejecuciones_monotonas'] == df_auditoria['total_ejecuciones']

# # Traducimos a un mensaje más limpio para tu documentación del TFM
# df_auditoria['clasificacion_tipo'] = df_auditoria['es_monotona_global'].map(
#     {True: 'Monótona Creciente (Counter) ✅', False: 'Variable (Gauge) ❌'}
# )

# # Ordenamos para ver primero las problemáticas (las que actúan como reloj encubierto)
# df_resumen_monotonia = df_auditoria.sort_values(by='es_monotona_global', ascending=False).reset_index(drop=True)

# # 3. MOSTRAR RESULTADOS
# print(f"📊 Auditoría completada sobre {df_resumen_monotonia.shape[0]} métricas únicas.")
# display(df_resumen_monotonia)
# Out:
# ⏳ Evaluando monotonía métrica a métrica en todas las ejecuciones...
# 📊 Auditoría completada sobre 485 métricas únicas.
#                                       metric_name  total_ejecuciones  \
# 0                         node_sockstat_TCP_inuse               1736
# 1           prometheus_notifications_queue_length               1736
# 2      prometheus_rule_group_duration_seconds_sum               1736
# 3    prometheus_rule_group_duration_seconds_count               1736
# 4          prometheus_rule_group_duration_seconds               1736
# ..                                            ...                ...
# 480                node_memory_MemAvailable_bytes               1736
# 481                     node_memory_MemFree_bytes               1736
# 482                     node_memory_Mlocked_bytes               1736
# 483                  node_memory_PageTables_bytes               1736
# 484                        go_gc_duration_seconds               1736
#
#      ejecuciones_monotonas  es_monotona_global              clasificacion_tipo
# 0                     1736                True  Monótona Creciente (Counter) ✅
# 1                     1736                True  Monótona Creciente (Counter) ✅
# 2                     1736                True  Monótona Creciente (Counter) ✅
# 3                     1736                True  Monótona Creciente (Counter) ✅
# 4                     1736                True  Monótona Creciente (Counter) ✅
# ..                     ...                 ...                             ...
# 480                      0               False              Variable (Gauge) ❌
# 481                      0               False              Variable (Gauge) ❌
# 482                   1735               False              Variable (Gauge) ❌
# 483                      1               False              Variable (Gauge) ❌
# 484                      3               False              Variable (Gauge) ❌
#
# [485 rows x 5 columns]

# %%
# Lista para almacenar los diccionarios con los resultados de cada métrica
resultados_monotonia = []

print(f"⏳ Auditando monotonía para las {len(lista_metricas_filtadas)} métricas filtradas...")

# 1. Bucle que recorre únicamente tu lista de métricas limpias
for i, metrica in enumerate(lista_metricas_filtadas):
    texto_progreso = f'Calculando monotonia de métrica ({metrica})'
    print(f"\r{texto_progreso}".ljust(100), end='', flush=True)
    
    # Query optimizada: Traemos el valor y la ejecución ordenados cronológicamente
    SQL = f"""
    SELECT execution_name, metric_value 
    FROM metricas 
    WHERE metric_name = '{metrica}'
    ORDER BY execution_name, time ASC;
    """
    
    df_m = pd.read_sql(text(SQL), engine)
    
    if df_m.empty:
        continue
        
    df_m['metric_value'] = df_m['metric_value'].astype(float)
    
    # 2. Agrupamos por ejecución y calculamos la diferencia con el registro anterior
    # Usamos .diff() dentro de cada grupo para no mezclar ejecuciones distintas
    df_m['diferencia'] = df_m.groupby('execution_name')['metric_value'].diff()
    
    # Eliminamos los NaNs que genera el .diff() en la primera fila de cada ejecución
    df_m_limpio = df_m.dropna(subset=['diferencia'])
    
    # 3. Contamos ejecuciones totales implicadas en esta métrica
    lista_ejecuciones = df_m['execution_name'].unique()
    total_ejecuciones = len(lista_ejecuciones)
    
    # 4. Evaluamos cuáles de esas ejecuciones son monótonas
    # Una ejecución es monótona si TODAS sus diferencias son mayores o iguales a 0
    ejecuciones_monotonas = 0
    for ejecucion in lista_ejecuciones:
        df_ejec = df_m_limpio[df_m_limpio['execution_name'] == ejecucion]
        if (df_ejec['diferencia'] >= 0).all():
            ejecuciones_monotonas += 1
            
    # 5. Guardamos el balance de la métrica actual
    es_monotona_100 = (ejecuciones_monotonas == total_ejecuciones)
    
    resultados_monotonia.append({
        'metric_name': metrica,
        'total_ejecuciones': total_ejecuciones,
        'ejecuciones_monotonas': ejecuciones_monotonas,
        'es_monotona_100': es_monotona_100,
        'clasificacion_tipo': 'Monótona Creciente (Counter) ✅' if es_monotona_100 else 'Variable (Gauge) ❌'
    })
    
    # Pequeño chivato para ver el progreso en el Notebook
    if (i + 1) % 5 == 0 or (i + 1) == len(lista_metricas_filtadas):
        print(f"   ➔ Procesadas {i + 1}/{len(lista_metricas_filtadas)} métricas.")

# 6. Construimos el DataFrame final de resumen
df_resumen_monotonia = pd.DataFrame(resultados_monotonia)

# Ordenamos para tener los contadores (Counters) arriba del todo
df_resumen_monotonia = df_resumen_monotonia.sort_values(by='es_monotona_100', ascending=False).reset_index(drop=True)

print("\n🎉 ¡Auditoría completada con éxito!")
with pd.option_context('display.max_rows', None, 
                       'display.max_columns', None, 
                       'display.max_colwidth', None):
    
    display(df_resumen_monotonia)
# Out:
# ⏳ Auditando monotonía para las 156 métricas filtradas...
# Calculando monotonia de métrica (go_memstats_alloc_bytes)                                             ➔ Procesadas 5/156 métricas.
# Calculando monotonia de métrica (go_memstats_heap_alloc_bytes)                                        ➔ Procesadas 10/156 métricas.
# Calculando monotonia de métrica (go_memstats_heap_sys_bytes)                                          ➔ Procesadas 15/156 métricas.
# Calculando monotonia de métrica (go_memstats_next_gc_bytes)                                           ➔ Procesadas 20/156 métricas.
# Calculando monotonia de métrica (go_threads)                                                          ➔ Procesadas 25/156 métricas.
# Calculando monotonia de métrica (node_filefd_allocated)                                               ➔ Procesadas 30/156 métricas.
# Calculando monotonia de métrica (node_load15)                                                         ➔ Procesadas 35/156 métricas.
# Calculando monotonia de métrica (node_memory_AnonHugePages_bytes)                                     ➔ Procesadas 40/156 métricas.
# Calculando monotonia de métrica (node_memory_DirectMap2M_bytes)                                       ➔ Procesadas 45/156 métricas.
# Calculando monotonia de métrica (node_memory_Inactive_file_bytes)                                     ➔ Procesadas 50/156 métricas.
# Calculando monotonia de métrica (node_memory_MemFree_bytes)                                           ➔ Procesadas 55/156 métricas.
# Calculando monotonia de métrica (node_memory_SUnreclaim_bytes)                                        ➔ Procesadas 60/156 métricas.
# Calculando monotonia de métrica (node_memory_Unevictable_bytes)                                       ➔ Procesadas 65/156 métricas.
# Calculando monotonia de métrica (node_netstat_IpExt_OutOctets)                                        ➔ Procesadas 70/156 métricas.
# Calculando monotonia de métrica (node_os_version)                                                     ➔ Procesadas 75/156 métricas.
# Calculando monotonia de métrica (node_schedstat_waiting_seconds_total)                                ➔ Procesadas 80/156 métricas.
# Calculando monotonia de métrica (node_sockstat_TCP_orphan)                                            ➔ Procesadas 85/156 métricas.
# Calculando monotonia de métrica (node_softnet_dropped_total)                                          ➔ Procesadas 90/156 métricas.
# Calculando monotonia de métrica (node_timex_frequency_adjustment_ratio)                               ➔ Procesadas 95/156 métricas.
# Calculando monotonia de métrica (node_vmstat_pgpgin)                                                  ➔ Procesadas 100/156 métricas.
# Calculando monotonia de métrica (process_open_fds)                                                    ➔ Procesadas 105/156 métricas.
# Calculando monotonia de métrica (prometheus_engine_queries)                                           ➔ Procesadas 110/156 métricas.
# Calculando monotonia de métrica (prometheus_http_request_duration_seconds_count)                      ➔ Procesadas 115/156 métricas.
# Calculando monotonia de métrica (prometheus_remote_storage_highest_timestamp_in_seconds)              ➔ Procesadas 120/156 métricas.
# Calculando monotonia de métrica (prometheus_target_sync_length_seconds)                               ➔ Procesadas 125/156 métricas.
# Calculando monotonia de métrica (prometheus_tsdb_head_active_appenders)                               ➔ Procesadas 130/156 métricas.
# Calculando monotonia de métrica (prometheus_tsdb_head_max_time_seconds)                               ➔ Procesadas 135/156 métricas.
# Calculando monotonia de métrica (prometheus_tsdb_head_series_removed_total)                           ➔ Procesadas 140/156 métricas.
# Calculando monotonia de métrica (prometheus_tsdb_mmap_chunks_total)                                   ➔ Procesadas 145/156 métricas.
# Calculando monotonia de métrica (prometheus_tsdb_wal_page_flushes_total)                              ➔ Procesadas 150/156 métricas.
# Calculando monotonia de métrica (scrape_samples_scraped)                                              ➔ Procesadas 155/156 métricas.
# Calculando monotonia de métrica (scrape_series_added)                                                 ➔ Procesadas 156/156 métricas.
#
# 🎉 ¡Auditoría completada con éxito!
#                                                  metric_name  \
# 0                            node_schedstat_timeslices_total
# 1               prometheus_http_request_duration_seconds_sum
# 2                             node_memory_VmallocTotal_bytes
# 3                               process_virtual_memory_bytes
# 4    prometheus_config_last_reload_success_timestamp_seconds
# 5             prometheus_engine_query_duration_seconds_count
# 6               prometheus_engine_query_duration_seconds_sum
# 7                      prometheus_engine_query_samples_total
# 8            prometheus_http_request_duration_seconds_bucket
# 9             prometheus_http_request_duration_seconds_count
# 10                prometheus_http_response_size_bytes_bucket
# 11                               node_netstat_IpExt_InOctets
# 12                 prometheus_http_response_size_bytes_count
# 13                   prometheus_http_response_size_bytes_sum
# 14    prometheus_remote_storage_highest_timestamp_in_seconds
# 15                prometheus_remote_storage_samples_in_total
# 16           prometheus_target_interval_length_seconds_count
# 17             prometheus_target_interval_length_seconds_sum
# 18                     prometheus_target_sync_length_seconds
# 19                             node_memory_DirectMap4k_bytes
# 20                                process_start_time_seconds
# 21                              node_netstat_IpExt_OutOctets
# 22                             prometheus_tsdb_blocks_loaded
# 23                                        node_vmstat_pswpin
# 24                         node_softnet_times_squeezed_total
# 25                              node_softnet_processed_total
# 26                                node_softnet_dropped_total
# 27                                   node_timex_tick_seconds
# 28                                       node_vmstat_pgfault
# 29                                    node_vmstat_pgmajfault
# 30                                        node_vmstat_pgpgin
# 31                                       node_vmstat_pgpgout
# 32                                       node_vmstat_pswpout
# 33                                   node_netstat_Tcp_InSegs
# 34                      node_schedstat_waiting_seconds_total
# 35                              go_gc_duration_seconds_count
# 36                      node_schedstat_running_seconds_total
# 37                                 process_cpu_seconds_total
# 38                                           node_os_version
# 39                                   node_network_iface_link
# 40                                     node_network_iface_id
# 41                                  node_netstat_Tcp_OutSegs
# 42                             node_memory_DirectMap2M_bytes
# 43                 prometheus_target_sync_length_seconds_sum
# 44               prometheus_tsdb_compactions_triggered_total
# 45                  prometheus_tsdb_isolation_high_watermark
# 46                          prometheus_tsdb_lowest_timestamp
# 47                  prometheus_tsdb_lowest_timestamp_seconds
# 48                         prometheus_tsdb_mmap_chunks_total
# 49                               go_memstats_mspan_sys_bytes
# 50                             prometheus_tsdb_reloads_total
# 51                                 go_memstats_mallocs_total
# 52                          go_memstats_last_gc_time_seconds
# 53                      prometheus_tsdb_storage_blocks_bytes
# 54                   prometheus_tsdb_symbol_table_size_bytes
# 55                 prometheus_tsdb_wal_completed_pages_total
# 56                    prometheus_tsdb_wal_page_flushes_total
# 57                       prometheus_tsdb_wal_segment_current
# 58                    prometheus_tsdb_wal_storage_size_bytes
# 59                                   go_memstats_frees_total
# 60                           go_memstats_buck_hash_sys_bytes
# 61                             go_memstats_alloc_bytes_total
# 62                     scrape_samples_post_metric_relabeling
# 63                                    scrape_samples_scraped
# 64                                go_gc_duration_seconds_sum
# 65              prometheus_tsdb_data_replay_duration_seconds
# 66                   prometheus_tsdb_isolation_low_watermark
# 67                             prometheus_tsdb_head_min_time
# 68                                          node_forks_total
# 69                               prometheus_tsdb_head_chunks
# 70                 prometheus_tsdb_head_chunks_created_total
# 71            prometheus_tsdb_head_chunks_storage_size_bytes
# 72                             prometheus_tsdb_head_max_time
# 73                     prometheus_tsdb_head_max_time_seconds
# 74                                                go_threads
# 75                     prometheus_tsdb_head_min_time_seconds
# 76                               prometheus_tsdb_head_series
# 77                                         node_time_seconds
# 78                 prometheus_tsdb_head_series_created_total
# 79                 prometheus_tsdb_head_series_removed_total
# 80                                    node_cpu_seconds_total
# 81                               node_context_switches_total
# 82                  net_conntrack_listener_conn_closed_total
# 83                net_conntrack_listener_conn_accepted_total
# 84                                          process_open_fds
# 85                                   scrape_duration_seconds
# 86                                 prometheus_engine_queries
# 87                 prometheus_target_interval_length_seconds
# 88                               node_timex_maxerror_seconds
# 89                     node_timex_frequency_adjustment_ratio
# 90                     prometheus_tsdb_head_active_appenders
# 91                        node_timex_estimated_error_seconds
# 92                             process_resident_memory_bytes
# 93                                    go_gc_duration_seconds
# 94                                  node_softnet_backlog_len
# 95                                     go_memstats_sys_bytes
# 96                                  node_memory_Cached_bytes
# 97                                 node_memory_Buffers_bytes
# 98                               node_memory_AnonPages_bytes
# 99                           node_memory_AnonHugePages_bytes
# 100                            node_memory_Active_file_bytes
# 101                                 node_memory_Active_bytes
# 102                            node_memory_Active_anon_bytes
# 103                                               node_load5
# 104                                              node_load15
# 105                                               node_load1
# 106                                          node_intr_total
# 107                               node_filesystem_files_free
# 108                                    node_filefd_allocated
# 109                              go_memstats_stack_sys_bytes
# 110                               node_sockstat_sockets_used
# 111                            go_memstats_stack_inuse_bytes
# 112                              go_memstats_other_sys_bytes
# 113                                go_memstats_next_gc_bytes
# 114                            go_memstats_mspan_inuse_bytes
# 115                               go_memstats_heap_sys_bytes
# 116                          go_memstats_heap_released_bytes
# 117                                 go_memstats_heap_objects
# 118                             go_memstats_heap_inuse_bytes
# 119                              go_memstats_heap_idle_bytes
# 120                             go_memstats_heap_alloc_bytes
# 121                                 go_memstats_gc_sys_bytes
# 122                                  go_memstats_alloc_bytes
# 123                                            go_goroutines
# 124                           node_memory_Committed_AS_bytes
# 125                                  node_memory_Dirty_bytes
# 126                          node_memory_Inactive_anon_bytes
# 127                               node_memory_Inactive_bytes
# 128                              node_sockstat_UDP_mem_bytes
# 129                                    node_sockstat_UDP_mem
# 130                                 node_sockstat_TCP_orphan
# 131                              node_sockstat_TCP_mem_bytes
# 132                                    node_sockstat_TCP_mem
# 133                                  node_sockstat_TCP_alloc
# 134                   node_scrape_collector_duration_seconds
# 135                                       node_procs_running
# 136                                       node_procs_blocked
# 137                              node_memory_Writeback_bytes
# 138                            node_memory_VmallocUsed_bytes
# 139                            node_memory_Unevictable_bytes
# 140                               node_memory_SwapFree_bytes
# 141                             node_memory_SwapCached_bytes
# 142                                   node_memory_Slab_bytes
# 143                                  node_memory_Shmem_bytes
# 144                             node_memory_SUnreclaim_bytes
# 145                           node_memory_SReclaimable_bytes
# 146                                 node_memory_Percpu_bytes
# 147                             node_memory_PageTables_bytes
# 148                                node_memory_Mlocked_bytes
# 149                                node_memory_MemFree_bytes
# 150                           node_memory_MemAvailable_bytes
# 151                                 node_memory_Mapped_bytes
# 152                            node_memory_KernelStack_bytes
# 153                           node_memory_KReclaimable_bytes
# 154                          node_memory_Inactive_file_bytes
# 155                                      scrape_series_added
#
#      total_ejecuciones  ejecuciones_monotonas  es_monotona_100  \
# 0                 1736                   1736             True
# 1                 1736                   1736             True
# 2                 1736                   1736             True
# 3                 1736                   1736             True
# 4                 1736                   1736             True
# 5                 1736                   1736             True
# 6                 1736                   1736             True
# 7                 1736                   1736             True
# 8                 1736                   1736             True
# 9                 1736                   1736             True
# 10                1736                   1736             True
# 11                1736                   1736             True
# 12                1736                   1736             True
# 13                1736                   1736             True
# 14                1736                   1736             True
# 15                1736                   1736             True
# 16                1736                   1736             True
# 17                1736                   1736             True
# 18                1736                   1736             True
# 19                1736                   1736             True
# 20                1736                   1736             True
# 21                1736                   1736             True
# 22                1736                   1736             True
# 23                1736                   1736             True
# 24                1736                   1736             True
# 25                1736                   1736             True
# 26                1736                   1736             True
# 27                1736                   1736             True
# 28                1736                   1736             True
# 29                1736                   1736             True
# 30                1736                   1736             True
# 31                1736                   1736             True
# 32                1736                   1736             True
# 33                1736                   1736             True
# 34                1736                   1736             True
# 35                1736                   1736             True
# 36                1736                   1736             True
# 37                1736                   1736             True
# 38                1736                   1736             True
# 39                1736                   1736             True
# 40                1736                   1736             True
# 41                1736                   1736             True
# 42                1736                   1736             True
# 43                1736                   1736             True
# 44                1736                   1736             True
# 45                1736                   1736             True
# 46                1736                   1736             True
# 47                1736                   1736             True
# 48                1736                   1736             True
# 49                1736                   1736             True
# 50                1736                   1736             True
# 51                1736                   1736             True
# 52                1736                   1736             True
# 53                1736                   1736             True
# 54                1736                   1736             True
# 55                1736                   1736             True
# 56                1736                   1736             True
# 57                1736                   1736             True
# 58                1736                   1736             True
# 59                1736                   1736             True
# 60                1736                   1736             True
# 61                1736                   1736             True
# 62                1736                   1736             True
# 63                1736                   1736             True
# 64                1736                   1736             True
# 65                1736                   1736             True
# 66                1736                   1736             True
# 67                1736                   1736             True
# 68                1736                   1736             True
# 69                1736                   1736             True
# 70                1736                   1736             True
# 71                1736                   1736             True
# 72                1736                   1736             True
# 73                1736                   1736             True
# 74                1736                   1736             True
# 75                1736                   1736             True
# 76                1736                   1736             True
# 77                1736                   1736             True
# 78                1736                   1736             True
# 79                1736                   1736             True
# 80                1736                   1736             True
# 81                1736                   1736             True
# 82                1736                   1736             True
# 83                1736                   1736             True
# 84                1736                      0            False
# 85                1736                      0            False
# 86                1736                   1340            False
# 87                1736                      2            False
# 88                1736                      0            False
# 89                1736                     22            False
# 90                1736                   1726            False
# 91                1736                     33            False
# 92                1736                      1            False
# 93                1736                      3            False
# 94                1736                   1677            False
# 95                1736                   1733            False
# 96                1736                      1            False
# 97                1736                    107            False
# 98                1736                      0            False
# 99                1736                      0            False
# 100               1736                      0            False
# 101               1736                      0            False
# 102               1736                      1            False
# 103               1736                      1            False
# 104               1736                      3            False
# 105               1736                      0            False
# 106               1736                   1709            False
# 107               1736                   1727            False
# 108               1736                      0            False
# 109               1736                      0            False
# 110               1736                      3            False
# 111               1736                      0            False
# 112               1736                      0            False
# 113               1736                      0            False
# 114               1736                      1            False
# 115               1736                      0            False
# 116               1736                      0            False
# 117               1736                      0            False
# 118               1736                      0            False
# 119               1736                      0            False
# 120               1736                      0            False
# 121               1736                     56            False
# 122               1736                      0            False
# 123               1736                      0            False
# 124               1736                      0            False
# 125               1736                      0            False
# 126               1736                      0            False
# 127               1736                      0            False
# 128               1736                   1308            False
# 129               1736                   1308            False
# 130               1736                    130            False
# 131               1736                      0            False
# 132               1736                      0            False
# 133               1736                      0            False
# 134               1736                      0            False
# 135               1736                      0            False
# 136               1736                      0            False
# 137               1736                      0            False
# 138               1736                      0            False
# 139               1736                   1735            False
# 140               1736                    338            False
# 141               1736                    117            False
# 142               1736                      0            False
# 143               1736                      1            False
# 144               1736                      0            False
# 145               1736                      2            False
# 146               1736                   1727            False
# 147               1736                      1            False
# 148               1736                   1735            False
# 149               1736                      0            False
# 150               1736                      0            False
# 151               1736                      0            False
# 152               1736                      0            False
# 153               1736                      2            False
# 154               1736                      0            False
# 155               1736                      1            False
#
#                  clasificacion_tipo
# 0    Monótona Creciente (Counter) ✅
# 1    Monótona Creciente (Counter) ✅
# 2    Monótona Creciente (Counter) ✅
# 3    Monótona Creciente (Counter) ✅
# 4    Monótona Creciente (Counter) ✅
# 5    Monótona Creciente (Counter) ✅
# 6    Monótona Creciente (Counter) ✅
# 7    Monótona Creciente (Counter) ✅
# 8    Monótona Creciente (Counter) ✅
# 9    Monótona Creciente (Counter) ✅
# 10   Monótona Creciente (Counter) ✅
# 11   Monótona Creciente (Counter) ✅
# 12   Monótona Creciente (Counter) ✅
# 13   Monótona Creciente (Counter) ✅
# 14   Monótona Creciente (Counter) ✅
# 15   Monótona Creciente (Counter) ✅
# 16   Monótona Creciente (Counter) ✅
# 17   Monótona Creciente (Counter) ✅
# 18   Monótona Creciente (Counter) ✅
# 19   Monótona Creciente (Counter) ✅
# 20   Monótona Creciente (Counter) ✅
# 21   Monótona Creciente (Counter) ✅
# 22   Monótona Creciente (Counter) ✅
# 23   Monótona Creciente (Counter) ✅
# 24   Monótona Creciente (Counter) ✅
# 25   Monótona Creciente (Counter) ✅
# 26   Monótona Creciente (Counter) ✅
# 27   Monótona Creciente (Counter) ✅
# 28   Monótona Creciente (Counter) ✅
# 29   Monótona Creciente (Counter) ✅
# 30   Monótona Creciente (Counter) ✅
# 31   Monótona Creciente (Counter) ✅
# 32   Monótona Creciente (Counter) ✅
# 33   Monótona Creciente (Counter) ✅
# 34   Monótona Creciente (Counter) ✅
# 35   Monótona Creciente (Counter) ✅
# 36   Monótona Creciente (Counter) ✅
# 37   Monótona Creciente (Counter) ✅
# 38   Monótona Creciente (Counter) ✅
# 39   Monótona Creciente (Counter) ✅
# 40   Monótona Creciente (Counter) ✅
# 41   Monótona Creciente (Counter) ✅
# 42   Monótona Creciente (Counter) ✅
# 43   Monótona Creciente (Counter) ✅
# 44   Monótona Creciente (Counter) ✅
# 45   Monótona Creciente (Counter) ✅
# 46   Monótona Creciente (Counter) ✅
# 47   Monótona Creciente (Counter) ✅
# 48   Monótona Creciente (Counter) ✅
# 49   Monótona Creciente (Counter) ✅
# 50   Monótona Creciente (Counter) ✅
# 51   Monótona Creciente (Counter) ✅
# 52   Monótona Creciente (Counter) ✅
# 53   Monótona Creciente (Counter) ✅
# 54   Monótona Creciente (Counter) ✅
# 55   Monótona Creciente (Counter) ✅
# 56   Monótona Creciente (Counter) ✅
# 57   Monótona Creciente (Counter) ✅
# 58   Monótona Creciente (Counter) ✅
# 59   Monótona Creciente (Counter) ✅
# 60   Monótona Creciente (Counter) ✅
# 61   Monótona Creciente (Counter) ✅
# 62   Monótona Creciente (Counter) ✅
# 63   Monótona Creciente (Counter) ✅
# 64   Monótona Creciente (Counter) ✅
# 65   Monótona Creciente (Counter) ✅
# 66   Monótona Creciente (Counter) ✅
# 67   Monótona Creciente (Counter) ✅
# 68   Monótona Creciente (Counter) ✅
# 69   Monótona Creciente (Counter) ✅
# 70   Monótona Creciente (Counter) ✅
# 71   Monótona Creciente (Counter) ✅
# 72   Monótona Creciente (Counter) ✅
# 73   Monótona Creciente (Counter) ✅
# 74   Monótona Creciente (Counter) ✅
# 75   Monótona Creciente (Counter) ✅
# 76   Monótona Creciente (Counter) ✅
# 77   Monótona Creciente (Counter) ✅
# 78   Monótona Creciente (Counter) ✅
# 79   Monótona Creciente (Counter) ✅
# 80   Monótona Creciente (Counter) ✅
# 81   Monótona Creciente (Counter) ✅
# 82   Monótona Creciente (Counter) ✅
# 83   Monótona Creciente (Counter) ✅
# 84               Variable (Gauge) ❌
# 85               Variable (Gauge) ❌
# 86               Variable (Gauge) ❌
# 87               Variable (Gauge) ❌
# 88               Variable (Gauge) ❌
# 89               Variable (Gauge) ❌
# 90               Variable (Gauge) ❌
# 91               Variable (Gauge) ❌
# 92               Variable (Gauge) ❌
# 93               Variable (Gauge) ❌
# 94               Variable (Gauge) ❌
# 95               Variable (Gauge) ❌
# 96               Variable (Gauge) ❌
# 97               Variable (Gauge) ❌
# 98               Variable (Gauge) ❌
# 99               Variable (Gauge) ❌
# 100              Variable (Gauge) ❌
# 101              Variable (Gauge) ❌
# 102              Variable (Gauge) ❌
# 103              Variable (Gauge) ❌
# 104              Variable (Gauge) ❌
# 105              Variable (Gauge) ❌
# 106              Variable (Gauge) ❌
# 107              Variable (Gauge) ❌
# 108              Variable (Gauge) ❌
# 109              Variable (Gauge) ❌
# 110              Variable (Gauge) ❌
# 111              Variable (Gauge) ❌
# 112              Variable (Gauge) ❌
# 113              Variable (Gauge) ❌
# 114              Variable (Gauge) ❌
# 115              Variable (Gauge) ❌
# 116              Variable (Gauge) ❌
# 117              Variable (Gauge) ❌
# 118              Variable (Gauge) ❌
# 119              Variable (Gauge) ❌
# 120              Variable (Gauge) ❌
# 121              Variable (Gauge) ❌
# 122              Variable (Gauge) ❌
# 123              Variable (Gauge) ❌
# 124              Variable (Gauge) ❌
# 125              Variable (Gauge) ❌
# 126              Variable (Gauge) ❌
# 127              Variable (Gauge) ❌
# 128              Variable (Gauge) ❌
# 129              Variable (Gauge) ❌
# 130              Variable (Gauge) ❌
# 131              Variable (Gauge) ❌
# 132              Variable (Gauge) ❌
# 133              Variable (Gauge) ❌
# 134              Variable (Gauge) ❌
# 135              Variable (Gauge) ❌
# 136              Variable (Gauge) ❌
# 137              Variable (Gauge) ❌
# 138              Variable (Gauge) ❌
# 139              Variable (Gauge) ❌
# 140              Variable (Gauge) ❌
# 141              Variable (Gauge) ❌
# 142              Variable (Gauge) ❌
# 143              Variable (Gauge) ❌
# 144              Variable (Gauge) ❌
# 145              Variable (Gauge) ❌
# 146              Variable (Gauge) ❌
# 147              Variable (Gauge) ❌
# 148              Variable (Gauge) ❌
# 149              Variable (Gauge) ❌
# 150              Variable (Gauge) ❌
# 151              Variable (Gauge) ❌
# 152              Variable (Gauge) ❌
# 153              Variable (Gauge) ❌
# 154              Variable (Gauge) ❌
# 155              Variable (Gauge) ❌

# %%
df_resumen_monotonia.to_parquet(f'{FOLDER_SALIDA}/df_resumen_monotonia.parquet', index=False,engine='fastparquet')

# %%
lista_metricas_monotonas=df_resumen_monotonia[df_resumen_monotonia['es_monotona_100']]['metric_name'].to_list()

# %%
with open(f'result/lista_metricas_monotonas.json', "w", encoding="utf-8") as f:
    json.dump(lista_metricas_monotonas, f, ensure_ascii=False, indent=4)

# %%
len(lista_metricas_monotonas)
# Out:
# 84

# %%
# 1. Configuración global de estilos y supresión de alertas
sns.set_theme(style="whitegrid")
warnings.simplefilter(action='ignore', category=FutureWarning)
warnings.simplefilter(action='ignore', category=UserWarning)


nombre_pdf = f"{FOLDER_SALIDA}/analisis_metricas_monotonas_transformadas.pdf"
total_metricas = len(lista_metricas_monotonas)
lista_metricas_monotonas_invariantes=[]

print(f"🚀 Iniciando exportación masiva a {nombre_pdf}...")

# 3. Abrimos el gestor de contexto del PDF
with PdfPages(nombre_pdf) as pdf:
    
    for i, metrica in enumerate(lista_metricas_monotonas, 1):
        
        # Mensaje interactivo de progreso
        sys.stdout.write(f"\r🔄 [{i}/{total_metricas}] Procesando: {metrica[:50]}...".ljust(80))
        sys.stdout.flush()
        
        # 4. Consulta SQL optimizada descartando la primera muestra desestabilizadora
        SQL = f"""
        WITH ordenado AS (
            SELECT 
                time, 
                execution_name, 
                label,
                metric_value::float AS valor_bruto,
                LAG(metric_value::float) OVER (
                    PARTITION BY execution_name 
                    ORDER BY time ASC
                ) AS valor_anterior
            FROM metricas 
            WHERE metric_name = '{metrica}'
        )
        SELECT 
            time,
            execution_name,
            label,
            (valor_bruto - valor_anterior) AS metric_value
        FROM ordenado
        WHERE valor_anterior IS NOT NULL
        ORDER BY execution_name, time ASC;
        """
        
        try:
            df_diff = pd.read_sql(SQL, engine)
            
            if df_diff.empty:
                continue

            if df_diff['metric_value'].std() == 0:
                lista_metricas_monotonas_invariantes.append(f'{metrica}_diff')
            # Agrupamos las etiquetas para el histograma binario (correct vs resto)
            df_diff['label_binaria'] = df_diff['label'].apply(lambda x: 'correct' if x == 'correct' else 'anomaly')
                
            orden_boxplot = list(df_var['label'].unique())

            # 🚀 SOLUCIÓN AL SINGULAR MATRIX:
            # Comprobamos si la columna tiene variabilidad (desviación estándar > 0)
            # Si todos los deltas son 0 (o idénticos), desactivamos el KDE para que no rompa el álgebra lineal.
            tiene_varianza = df_diff['metric_value'].std() > 0

            # 5. Construcción de la figura con la asimetría GridSpec (1:3)
            fig = plt.figure(figsize=(15, 18))
            gs = fig.add_gridspec(2, 1, height_ratios=[1, 3]) 

            ax_hist = fig.add_subplot(gs[0])
            ax_box = fig.add_subplot(gs[1])

            # --- SUBGRÁFICO 1: HISTOGRAMA DE DENSIDAD BINARIO ---
            sns.histplot(
                data=df_diff, 
                x='metric_value', 
                hue='label_binaria',  
                hue_order=['correct', 'anomaly'],
                palette={'correct': '#2ecc71', 'anomaly': '#e74c3c'}, 
                kde=tiene_varianza, # 🚀 DINÁMICO: True si hay varianza, False si los datos son idénticos
                ax=ax_hist,
                element='step',
                stat='density',  
                common_norm=False,
                legend=True  
            )
            ax_hist.set_title(f'Histograma de Densidad Binario\n({metrica}_diff)', fontsize=14, fontweight='bold')
            ax_hist.set_xlabel('Delta (Valor actual - Anterior)', fontsize=12)
            ax_hist.set_ylabel('Densidad', fontsize=12)

            # --- SUBGRÁFICO 2: BOXPLOT HORIZONTAL EXTENDIDO ---
            sns.boxplot(
                data=df_diff, 
                x='metric_value',  
                y='label',         
                order=orden_boxplot,  
                hue='label',          
                legend=False,      
                ax=ax_box,
                palette='tab20'       
            )
            ax_box.set_title(f'Boxplot Horizontal({metrica}_diff)', fontsize=14, fontweight='bold')
            ax_box.set_xlabel('Delta (Valor actual - Anterior)', fontsize=12)
            ax_box.set_ylabel('Fase / Anomalía', fontsize=12)

            ax_box.set_yticklabels(ax_box.get_yticklabels(), fontsize=9.5)

            plt.subplots_adjust(
                hspace=0.25,      
                left=0.28,        
                right=0.95,       
                top=0.94, 
                bottom=0.06
            )

            # 6. Guardamos la figura actual como una página nueva en el PDF
            pdf.savefig(fig)
            plt.close(fig)
        except Exception as e:
            print("")
            print(f"❌ Error procesando la métrica {metrica}: {str(e)}")
            if 'fig' in locals():
                plt.close(fig)

print("\n✨ ¡Proceso completado con éxito! Tu PDF binario y ordenado está listo en: " + nombre_pdf)
# Out:
# 🚀 Iniciando exportación masiva a result/analisis_metricas_monotonas_transformadas.pdf...
# 🔄 [84/84] Procesando: net_conntrack_listener_conn_accepted_total...
# ✨ ¡Proceso completado con éxito! Tu PDF binario y ordenado está listo en: result/analisis_metricas_monotonas_transformadas.pdf

# %%
len(lista_metricas_monotonas_invariantes)
# Out:
# 20

# %% [markdown]
# # nos hemos quedado aqui

# %%
with open(f'result/lista_metricas_diff_invariantes.json', "w", encoding="utf-8") as f:
    json.dump(lista_metricas_monotonas_invariantes, f, ensure_ascii=False, indent=4)

# %%
len(metricas_con_std_dev_nulo)
# Out:
# 478

# %%
df_analisis_metricas                     = pd.DataFrame({'metric_name': lista_metric_name})
df_analisis_metricas['std_dev_nulo']     = df_analisis_metricas['metric_name'].isin(lista_metricas_con_std_dev_nulo)
df_analisis_metricas['valores_NAN']      = df_analisis_metricas['metric_name'].isin(lista_metricas_descartadas_NaN)
df_analisis_metricas['metrica_monotona'] = df_analisis_metricas['metric_name'].isin(lista_metricas_monotonas)
df_analisis_metricas['diff_invariante']  = df_analisis_metricas['metric_name'].isin([metrica_diff.replace("_diff", "") for metrica_diff in lista_metricas_monotonas_invariantes])

# %%
def clasificar_metrica(row):
    if row['std_dev_nulo']:
        result=''
    elif row['valores_NAN']:
        result=''
    elif not row['metrica_monotona']:
        result='normal'
    elif row['diff_invariante']:
        result=''
    else:
        result='diff'
    return result

def nombre_metrica(row):
    if row['clasificacion']=='normal':
        result=row['metric_name']
    elif row['clasificacion']=='diff':
        result=row['metric_name']+'_diff'
    else:
        result=''
    return result
        
        

df_analisis_metricas['clasificacion'] = df_analisis_metricas.apply(clasificar_metrica, axis=1)
df_analisis_metricas['metric_name_sel'] = df_analisis_metricas.apply(nombre_metrica, axis=1)

# %%
df_analisis_metricas
# Out:
#                                metric_name  std_dev_nulo  valores_NAN  \
# 0                   go_gc_duration_seconds         False        False
# 1             go_gc_duration_seconds_count         False        False
# 2               go_gc_duration_seconds_sum         False        False
# 3                            go_goroutines         False        False
# 4                                  go_info          True        False
# ..                                     ...           ...          ...
# 480                scrape_duration_seconds         False        False
# 481  scrape_samples_post_metric_relabeling         False        False
# 482                 scrape_samples_scraped         False        False
# 483                    scrape_series_added         False        False
# 484                                     up          True        False
#
#      metrica_monotona  diff_invariante clasificacion  \
# 0               False            False        normal
# 1                True            False          diff
# 2                True            False          diff
# 3               False            False        normal
# 4               False            False
# ..                ...              ...           ...
# 480             False            False        normal
# 481              True            False          diff
# 482              True            False          diff
# 483             False            False        normal
# 484             False            False
#
#                                 metric_name_sel
# 0                        go_gc_duration_seconds
# 1             go_gc_duration_seconds_count_diff
# 2               go_gc_duration_seconds_sum_diff
# 3                                 go_goroutines
# 4
# ..                                          ...
# 480                     scrape_duration_seconds
# 481  scrape_samples_post_metric_relabeling_diff
# 482                 scrape_samples_scraped_diff
# 483                         scrape_series_added
# 484
#
# [485 rows x 7 columns]

# %%
df_analisis_metricas['clasificacion'].value_counts()
# Out:
# clasificacion
#           349
# normal     72
# diff       64
# Name: count, dtype: int64

# %%
df_analisis_metricas.to_parquet(f'{FOLDER_SALIDA}/analisis_metricas.parquet', index=False,engine='fastparquet')

# %% [markdown]
# # <span style="color:#2ca02c">5. Análisis de correlacion y redundancia (multicolinealidad)</span>

# %%
NUM_EJECUCIONES_PRUEBA = 20
lista_ejecuciones_sel = np.random.choice(lista_execution_name, size=20, replace=False).tolist()
lista_metricas_sel    = df_analisis_metricas[df_analisis_metricas['metric_name_sel']!='']['metric_name'].to_list()
lista_metricas_sel_diff=  df_analisis_metricas[df_analisis_metricas['clasificacion']=='diff']['metric_name'].to_list()
tupla_ejecuciones = tuple(lista_ejecuciones_sel)
tupla_metricas = tuple(lista_metricas_sel)

# %%
SQL = f"""
SELECT execution_name, time, metric_name, metric_value
FROM metricas
WHERE execution_name IN {tupla_ejecuciones}
  AND metric_name IN {tupla_metricas}
  AND label = 'correct'
ORDER BY execution_name, metric_name, time ASC;
"""

print("⏳ Extrayendo datos de la base de datos...")
df = pd.read_sql(text(SQL), engine)
# Out:
# ⏳ Extrayendo datos de la base de datos...

# %%
df_pivot = df.pivot(
    index=['execution_name', 'time'],
    columns='metric_name',
    values='metric_value'
)

# %%
df_procesado = df_pivot.copy()
for metrica in lista_metricas_sel_diff:
    if metrica in df_procesado.columns:
        # Calculamos el delta temporal manteniendo el aislamiento por experimento
        df_procesado[f'{metrica}_diff'] = df_procesado.groupby('execution_name')[metrica].diff()
        df_procesado.drop(metrica, axis=1, inplace=True)   #borramos la metrica original
        
df_procesado.dropna(inplace=True)  #borramos todas las filas que tienen NaN, corresponden a la primera muestra

# %%
corr_matrix = df_procesado.corr().abs()

# 2. Extraemos el triángulo superior para evitar parejas duplicadas
upper_tri = corr_matrix.where(np.triu(np.ones(corr_matrix.shape), k=1).astype(bool))

# 3. Filtramos las que superen el umbral crítico del 95%
UMBRAL = 0.95
pares_redundantes = [
    (col, row, upper_tri.loc[row, col])
    for col in upper_tri.columns
    for row in upper_tri.index
    if upper_tri.loc[row, col] > UMBRAL
]

# 4. Construimos el DataFrame de resultados
df_redundancia = pd.DataFrame(pares_redundantes, columns=['Metrica_A', 'Metrica_B', 'Correlacion'])
df_redundancia = df_redundancia.sort_values(by='Correlacion', ascending=False).reset_index(drop=True)

# %%
df_redundancia
# Out:
#                                       Metrica_A  \
# 0                  go_memstats_heap_alloc_bytes
# 1                   go_memstats_stack_sys_bytes
# 2                node_memory_SReclaimable_bytes
# 3                   node_sockstat_TCP_mem_bytes
# 4                   node_sockstat_UDP_mem_bytes
# 5            prometheus_tsdb_reloads_total_diff
# 6                       node_vmstat_pswpin_diff
# 7                        node_memory_Slab_bytes
# 8                        node_memory_Slab_bytes
# 9         go_memstats_last_gc_time_seconds_diff
# 10                node_memory_Active_file_bytes
# 11               node_memory_MemAvailable_bytes
# 12                                   node_load5
# 13  prometheus_tsdb_wal_page_flushes_total_diff
# 14                 go_memstats_heap_inuse_bytes
# 15                 go_memstats_heap_inuse_bytes
# 16                        go_memstats_sys_bytes
# 17              node_memory_Inactive_file_bytes
# 18              node_memory_Inactive_anon_bytes
# 19              node_memory_AnonHugePages_bytes
# 20               node_memory_MemAvailable_bytes
# 21    node_schedstat_running_seconds_total_diff
# 22              node_memory_Inactive_file_bytes
#
#                                            Metrica_B  Correlacion
# 0                            go_memstats_alloc_bytes     1.000000
# 1                      go_memstats_stack_inuse_bytes     1.000000
# 2                     node_memory_KReclaimable_bytes     1.000000
# 3                              node_sockstat_TCP_mem     1.000000
# 4                              node_sockstat_UDP_mem     1.000000
# 5   prometheus_tsdb_compactions_triggered_total_diff     1.000000
# 6                        node_vmstat_pgmajfault_diff     0.998481
# 7                     node_memory_SReclaimable_bytes     0.997592
# 8                     node_memory_KReclaimable_bytes     0.997592
# 9                       go_memstats_frees_total_diff     0.995852
# 10                          node_memory_Active_bytes     0.995112
# 11                   node_memory_Inactive_anon_bytes     0.992432
# 12                                       node_load15     0.990088
# 13    prometheus_tsdb_wal_completed_pages_total_diff     0.989924
# 14                           go_memstats_alloc_bytes     0.981071
# 15                      go_memstats_heap_alloc_bytes     0.981071
# 16                        go_memstats_heap_sys_bytes     0.978072
# 17                        node_memory_Inactive_bytes     0.972527
# 18                       node_memory_AnonPages_bytes     0.971865
# 19                        node_filesystem_files_free     0.971505
# 20                       node_memory_AnonPages_bytes     0.967646
# 21                       node_cpu_seconds_total_diff     0.967475
# 22                          node_memory_Cached_bytes     0.953903

# %%
df_redundancia.to_parquet(f'{FOLDER_SALIDA}/df_redundancia.parquet', index=False,engine='fastparquet')

# %%
lista_metricas_redundantes=df_redundancia['Metrica_B'].to_list()

# %%
with open(f'result/lista_metricas_redundantes.json', "w", encoding="utf-8") as f:
    json.dump(lista_metricas_redundantes, f, ensure_ascii=False, indent=4)

# %%
df_analisis_metricas['redundante']=df_analisis_metricas['metric_name_sel'].isin(lista_metricas_redundantes)

# %%
df_analisis_metricas.loc[df_analisis_metricas['redundante'] & (df_analisis_metricas['metric_name_sel']!='') , 'metric_name_sel'] = ''

# %%
df_analisis_metricas.to_parquet(f'{FOLDER_SALIDA}/analisis_metricas.parquet', index=False,engine='fastparquet')

# %%
with pd.option_context('display.max_rows', None, 
                       'display.max_columns', None, 
                       'display.max_colwidth', None):
    display(df_analisis_metricas)
# Out:
#                                                                  metric_name  \
# 0                                                     go_gc_duration_seconds
# 1                                               go_gc_duration_seconds_count
# 2                                                 go_gc_duration_seconds_sum
# 3                                                              go_goroutines
# 4                                                                    go_info
# 5                                                    go_memstats_alloc_bytes
# 6                                              go_memstats_alloc_bytes_total
# 7                                            go_memstats_buck_hash_sys_bytes
# 8                                                    go_memstats_frees_total
# 9                                                   go_memstats_gc_sys_bytes
# 10                                              go_memstats_heap_alloc_bytes
# 11                                               go_memstats_heap_idle_bytes
# 12                                              go_memstats_heap_inuse_bytes
# 13                                                  go_memstats_heap_objects
# 14                                           go_memstats_heap_released_bytes
# 15                                                go_memstats_heap_sys_bytes
# 16                                          go_memstats_last_gc_time_seconds
# 17                                                 go_memstats_lookups_total
# 18                                                 go_memstats_mallocs_total
# 19                                            go_memstats_mcache_inuse_bytes
# 20                                              go_memstats_mcache_sys_bytes
# 21                                             go_memstats_mspan_inuse_bytes
# 22                                               go_memstats_mspan_sys_bytes
# 23                                                 go_memstats_next_gc_bytes
# 24                                               go_memstats_other_sys_bytes
# 25                                             go_memstats_stack_inuse_bytes
# 26                                               go_memstats_stack_sys_bytes
# 27                                                     go_memstats_sys_bytes
# 28                                                                go_threads
# 29                                 net_conntrack_dialer_conn_attempted_total
# 30                                    net_conntrack_dialer_conn_closed_total
# 31                               net_conntrack_dialer_conn_established_total
# 32                                    net_conntrack_dialer_conn_failed_total
# 33                                net_conntrack_listener_conn_accepted_total
# 34                                  net_conntrack_listener_conn_closed_total
# 35                                                          node_arp_entries
# 36                                                    node_boot_time_seconds
# 37                                               node_context_switches_total
# 38                                             node_cooling_device_cur_state
# 39                                             node_cooling_device_max_state
# 40                                              node_cpu_guest_seconds_total
# 41                                                    node_cpu_seconds_total
# 42                                      node_disk_discard_time_seconds_total
# 43                                         node_disk_discarded_sectors_total
# 44                                        node_disk_discards_completed_total
# 45                                           node_disk_discards_merged_total
# 46                               node_disk_flush_requests_time_seconds_total
# 47                                            node_disk_flush_requests_total
# 48                                                            node_disk_info
# 49                                                          node_disk_io_now
# 50                                           node_disk_io_time_seconds_total
# 51                                  node_disk_io_time_weighted_seconds_total
# 52                                                node_disk_read_bytes_total
# 53                                         node_disk_read_time_seconds_total
# 54                                           node_disk_reads_completed_total
# 55                                              node_disk_reads_merged_total
# 56                                        node_disk_write_time_seconds_total
# 57                                          node_disk_writes_completed_total
# 58                                             node_disk_writes_merged_total
# 59                                             node_disk_written_bytes_total
# 60                                                             node_dmi_info
# 61                                               node_entropy_available_bits
# 62                                               node_entropy_pool_size_bits
# 63                                                  node_exporter_build_info
# 64                                                     node_filefd_allocated
# 65                                                       node_filefd_maximum
# 66                                               node_filesystem_avail_bytes
# 67                                              node_filesystem_device_error
# 68                                                     node_filesystem_files
# 69                                                node_filesystem_files_free
# 70                                                node_filesystem_free_bytes
# 71                                                  node_filesystem_readonly
# 72                                                node_filesystem_size_bytes
# 73                                                          node_forks_total
# 74                                                     node_hwmon_chip_names
# 75                                                           node_intr_total
# 76                                                                node_load1
# 77                                                               node_load15
# 78                                                                node_load5
# 79                                             node_memory_Active_anon_bytes
# 80                                                  node_memory_Active_bytes
# 81                                             node_memory_Active_file_bytes
# 82                                           node_memory_AnonHugePages_bytes
# 83                                               node_memory_AnonPages_bytes
# 84                                                  node_memory_Bounce_bytes
# 85                                                 node_memory_Buffers_bytes
# 86                                                  node_memory_Cached_bytes
# 87                                                 node_memory_CmaFree_bytes
# 88                                                node_memory_CmaTotal_bytes
# 89                                             node_memory_CommitLimit_bytes
# 90                                            node_memory_Committed_AS_bytes
# 91                                             node_memory_DirectMap1G_bytes
# 92                                             node_memory_DirectMap2M_bytes
# 93                                             node_memory_DirectMap4k_bytes
# 94                                                   node_memory_Dirty_bytes
# 95                                           node_memory_FileHugePages_bytes
# 96                                           node_memory_FilePmdMapped_bytes
# 97                                       node_memory_HardwareCorrupted_bytes
# 98                                                node_memory_HugePages_Free
# 99                                                node_memory_HugePages_Rsvd
# 100                                               node_memory_HugePages_Surp
# 101                                              node_memory_HugePages_Total
# 102                                           node_memory_Hugepagesize_bytes
# 103                                                node_memory_Hugetlb_bytes
# 104                                          node_memory_Inactive_anon_bytes
# 105                                               node_memory_Inactive_bytes
# 106                                          node_memory_Inactive_file_bytes
# 107                                           node_memory_KReclaimable_bytes
# 108                                            node_memory_KernelStack_bytes
# 109                                                 node_memory_Mapped_bytes
# 110                                           node_memory_MemAvailable_bytes
# 111                                                node_memory_MemFree_bytes
# 112                                               node_memory_MemTotal_bytes
# 113                                                node_memory_Mlocked_bytes
# 114                                           node_memory_NFS_Unstable_bytes
# 115                                             node_memory_PageTables_bytes
# 116                                                 node_memory_Percpu_bytes
# 117                                           node_memory_SReclaimable_bytes
# 118                                             node_memory_SUnreclaim_bytes
# 119                                          node_memory_SecPageTables_bytes
# 120                                         node_memory_ShmemHugePages_bytes
# 121                                         node_memory_ShmemPmdMapped_bytes
# 122                                                  node_memory_Shmem_bytes
# 123                                                   node_memory_Slab_bytes
# 124                                             node_memory_SwapCached_bytes
# 125                                               node_memory_SwapFree_bytes
# 126                                              node_memory_SwapTotal_bytes
# 127                                             node_memory_Unaccepted_bytes
# 128                                            node_memory_Unevictable_bytes
# 129                                           node_memory_VmallocChunk_bytes
# 130                                           node_memory_VmallocTotal_bytes
# 131                                            node_memory_VmallocUsed_bytes
# 132                                           node_memory_WritebackTmp_bytes
# 133                                              node_memory_Writeback_bytes
# 134                                                  node_memory_Zswap_bytes
# 135                                               node_memory_Zswapped_bytes
# 136                                              node_netstat_Icmp6_InErrors
# 137                                                node_netstat_Icmp6_InMsgs
# 138                                               node_netstat_Icmp6_OutMsgs
# 139                                               node_netstat_Icmp_InErrors
# 140                                                 node_netstat_Icmp_InMsgs
# 141                                                node_netstat_Icmp_OutMsgs
# 142                                                node_netstat_Ip6_InOctets
# 143                                               node_netstat_Ip6_OutOctets
# 144                                              node_netstat_IpExt_InOctets
# 145                                             node_netstat_IpExt_OutOctets
# 146                                               node_netstat_Ip_Forwarding
# 147                                          node_netstat_TcpExt_ListenDrops
# 148                                      node_netstat_TcpExt_ListenOverflows
# 149                                     node_netstat_TcpExt_SyncookiesFailed
# 150                                       node_netstat_TcpExt_SyncookiesRecv
# 151                                       node_netstat_TcpExt_SyncookiesSent
# 152                                        node_netstat_TcpExt_TCPSynRetrans
# 153                                          node_netstat_TcpExt_TCPTimeouts
# 154                                             node_netstat_Tcp_ActiveOpens
# 155                                               node_netstat_Tcp_CurrEstab
# 156                                                  node_netstat_Tcp_InErrs
# 157                                                  node_netstat_Tcp_InSegs
# 158                                                 node_netstat_Tcp_OutRsts
# 159                                                 node_netstat_Tcp_OutSegs
# 160                                            node_netstat_Tcp_PassiveOpens
# 161                                             node_netstat_Tcp_RetransSegs
# 162                                            node_netstat_Udp6_InDatagrams
# 163                                               node_netstat_Udp6_InErrors
# 164                                                node_netstat_Udp6_NoPorts
# 165                                           node_netstat_Udp6_OutDatagrams
# 166                                           node_netstat_Udp6_RcvbufErrors
# 167                                           node_netstat_Udp6_SndbufErrors
# 168                                           node_netstat_UdpLite6_InErrors
# 169                                            node_netstat_UdpLite_InErrors
# 170                                             node_netstat_Udp_InDatagrams
# 171                                                node_netstat_Udp_InErrors
# 172                                                 node_netstat_Udp_NoPorts
# 173                                            node_netstat_Udp_OutDatagrams
# 174                                            node_netstat_Udp_RcvbufErrors
# 175                                            node_netstat_Udp_SndbufErrors
# 176                                         node_network_address_assign_type
# 177                                                     node_network_carrier
# 178                                       node_network_carrier_changes_total
# 179                                  node_network_carrier_down_changes_total
# 180                                    node_network_carrier_up_changes_total
# 181                                                   node_network_device_id
# 182                                                     node_network_dormant
# 183                                                       node_network_flags
# 184                                                    node_network_iface_id
# 185                                                  node_network_iface_link
# 186                                             node_network_iface_link_mode
# 187                                                        node_network_info
# 188                                                   node_network_mtu_bytes
# 189                                            node_network_name_assign_type
# 190                                               node_network_net_dev_group
# 191                                               node_network_protocol_type
# 192                                         node_network_receive_bytes_total
# 193                                    node_network_receive_compressed_total
# 194                                          node_network_receive_drop_total
# 195                                          node_network_receive_errs_total
# 196                                          node_network_receive_fifo_total
# 197                                         node_network_receive_frame_total
# 198                                     node_network_receive_multicast_total
# 199                                     node_network_receive_nohandler_total
# 200                                       node_network_receive_packets_total
# 201                                                 node_network_speed_bytes
# 202                                        node_network_transmit_bytes_total
# 203                                      node_network_transmit_carrier_total
# 204                                        node_network_transmit_colls_total
# 205                                   node_network_transmit_compressed_total
# 206                                         node_network_transmit_drop_total
# 207                                         node_network_transmit_errs_total
# 208                                         node_network_transmit_fifo_total
# 209                                      node_network_transmit_packets_total
# 210                                       node_network_transmit_queue_length
# 211                                                          node_network_up
# 212                                                node_nf_conntrack_entries
# 213                                          node_nf_conntrack_entries_limit
# 214                                              node_nf_conntrack_stat_drop
# 215                                        node_nf_conntrack_stat_early_drop
# 216                                             node_nf_conntrack_stat_found
# 217                                            node_nf_conntrack_stat_ignore
# 218                                            node_nf_conntrack_stat_insert
# 219                                     node_nf_conntrack_stat_insert_failed
# 220                                           node_nf_conntrack_stat_invalid
# 221                                    node_nf_conntrack_stat_search_restart
# 222                                                             node_os_info
# 223                                                          node_os_version
# 224                                                   node_power_supply_info
# 225                                                 node_power_supply_online
# 226                                                       node_procs_blocked
# 227                                                       node_procs_running
# 228                                     node_schedstat_running_seconds_total
# 229                                          node_schedstat_timeslices_total
# 230                                     node_schedstat_waiting_seconds_total
# 231                                   node_scrape_collector_duration_seconds
# 232                                            node_scrape_collector_success
# 233                                                     node_selinux_enabled
# 234                                                node_sockstat_FRAG6_inuse
# 235                                               node_sockstat_FRAG6_memory
# 236                                                 node_sockstat_FRAG_inuse
# 237                                                node_sockstat_FRAG_memory
# 238                                                 node_sockstat_RAW6_inuse
# 239                                                  node_sockstat_RAW_inuse
# 240                                                 node_sockstat_TCP6_inuse
# 241                                                  node_sockstat_TCP_alloc
# 242                                                  node_sockstat_TCP_inuse
# 243                                                    node_sockstat_TCP_mem
# 244                                              node_sockstat_TCP_mem_bytes
# 245                                                 node_sockstat_TCP_orphan
# 246                                                     node_sockstat_TCP_tw
# 247                                                 node_sockstat_UDP6_inuse
# 248                                             node_sockstat_UDPLITE6_inuse
# 249                                              node_sockstat_UDPLITE_inuse
# 250                                                  node_sockstat_UDP_inuse
# 251                                                    node_sockstat_UDP_mem
# 252                                              node_sockstat_UDP_mem_bytes
# 253                                               node_sockstat_sockets_used
# 254                                                 node_softnet_backlog_len
# 255                                         node_softnet_cpu_collision_total
# 256                                               node_softnet_dropped_total
# 257                                      node_softnet_flow_limit_count_total
# 258                                             node_softnet_processed_total
# 259                                          node_softnet_received_rps_total
# 260                                        node_softnet_times_squeezed_total
# 261                                               node_textfile_scrape_error
# 262                                     node_time_clocksource_available_info
# 263                                       node_time_clocksource_current_info
# 264                                                        node_time_seconds
# 265                                            node_time_zone_offset_seconds
# 266                                       node_timex_estimated_error_seconds
# 267                                    node_timex_frequency_adjustment_ratio
# 268                                            node_timex_loop_time_constant
# 269                                              node_timex_maxerror_seconds
# 270                                                node_timex_offset_seconds
# 271                                         node_timex_pps_calibration_total
# 272                                               node_timex_pps_error_total
# 273                                           node_timex_pps_frequency_hertz
# 274                                            node_timex_pps_jitter_seconds
# 275                                              node_timex_pps_jitter_total
# 276                                             node_timex_pps_shift_seconds
# 277                                  node_timex_pps_stability_exceeded_total
# 278                                           node_timex_pps_stability_hertz
# 279                                                        node_timex_status
# 280                                                   node_timex_sync_status
# 281                                            node_timex_tai_offset_seconds
# 282                                                  node_timex_tick_seconds
# 283                                                          node_udp_queues
# 284                                                          node_uname_info
# 285                                                     node_vmstat_oom_kill
# 286                                                      node_vmstat_pgfault
# 287                                                   node_vmstat_pgmajfault
# 288                                                       node_vmstat_pgpgin
# 289                                                      node_vmstat_pgpgout
# 290                                                       node_vmstat_pswpin
# 291                                                      node_vmstat_pswpout
# 292                                                process_cpu_seconds_total
# 293                                                          process_max_fds
# 294                                                         process_open_fds
# 295                                            process_resident_memory_bytes
# 296                                               process_start_time_seconds
# 297                                             process_virtual_memory_bytes
# 298                                         process_virtual_memory_max_bytes
# 299                                       prometheus_api_remote_read_queries
# 300                                                    prometheus_build_info
# 301                  prometheus_config_last_reload_success_timestamp_seconds
# 302                                 prometheus_config_last_reload_successful
# 303                                                prometheus_engine_queries
# 304                                 prometheus_engine_queries_concurrent_max
# 305                                 prometheus_engine_query_duration_seconds
# 306                           prometheus_engine_query_duration_seconds_count
# 307                             prometheus_engine_query_duration_seconds_sum
# 308                                      prometheus_engine_query_log_enabled
# 309                               prometheus_engine_query_log_failures_total
# 310                                    prometheus_engine_query_samples_total
# 311                          prometheus_http_request_duration_seconds_bucket
# 312                           prometheus_http_request_duration_seconds_count
# 313                             prometheus_http_request_duration_seconds_sum
# 314                                           prometheus_http_requests_total
# 315                               prometheus_http_response_size_bytes_bucket
# 316                                prometheus_http_response_size_bytes_count
# 317                                  prometheus_http_response_size_bytes_sum
# 318                        prometheus_notifications_alertmanagers_discovered
# 319                                   prometheus_notifications_dropped_total
# 320                                  prometheus_notifications_queue_capacity
# 321                                    prometheus_notifications_queue_length
# 322                                                         prometheus_ready
# 323                             prometheus_remote_storage_exemplars_in_total
# 324                   prometheus_remote_storage_highest_timestamp_in_seconds
# 325                            prometheus_remote_storage_histograms_in_total
# 326                               prometheus_remote_storage_samples_in_total
# 327  prometheus_remote_storage_string_interner_zero_reference_releases_total
# 328                              prometheus_rule_evaluation_duration_seconds
# 329                        prometheus_rule_evaluation_duration_seconds_count
# 330                          prometheus_rule_evaluation_duration_seconds_sum
# 331                                   prometheus_rule_group_duration_seconds
# 332                             prometheus_rule_group_duration_seconds_count
# 333                               prometheus_rule_group_duration_seconds_sum
# 334                                      prometheus_sd_azure_cache_hit_total
# 335                                       prometheus_sd_azure_failures_total
# 336                                prometheus_sd_consul_rpc_duration_seconds
# 337                          prometheus_sd_consul_rpc_duration_seconds_count
# 338                            prometheus_sd_consul_rpc_duration_seconds_sum
# 339                                  prometheus_sd_consul_rpc_failures_total
# 340                                         prometheus_sd_discovered_targets
# 341                                  prometheus_sd_dns_lookup_failures_total
# 342                                          prometheus_sd_dns_lookups_total
# 343                                             prometheus_sd_failed_configs
# 344                                     prometheus_sd_file_read_errors_total
# 345                                 prometheus_sd_file_scan_duration_seconds
# 346                           prometheus_sd_file_scan_duration_seconds_count
# 347                             prometheus_sd_file_scan_duration_seconds_sum
# 348                                  prometheus_sd_file_watcher_errors_total
# 349                                        prometheus_sd_http_failures_total
# 350                                    prometheus_sd_kubernetes_events_total
# 351                                prometheus_sd_kuma_fetch_duration_seconds
# 352                          prometheus_sd_kuma_fetch_duration_seconds_count
# 353                            prometheus_sd_kuma_fetch_duration_seconds_sum
# 354                                  prometheus_sd_kuma_fetch_failures_total
# 355                           prometheus_sd_kuma_fetch_skipped_updates_total
# 356                                      prometheus_sd_linode_failures_total
# 357                                       prometheus_sd_nomad_failures_total
# 358                                     prometheus_sd_received_updates_total
# 359                                      prometheus_sd_updates_delayed_total
# 360                                              prometheus_sd_updates_total
# 361                                prometheus_target_interval_length_seconds
# 362                          prometheus_target_interval_length_seconds_count
# 363                            prometheus_target_interval_length_seconds_sum
# 364                                   prometheus_target_metadata_cache_bytes
# 365                                 prometheus_target_metadata_cache_entries
# 366                prometheus_target_scrape_pool_exceeded_label_limits_total
# 367                prometheus_target_scrape_pool_exceeded_target_limit_total
# 368                       prometheus_target_scrape_pool_reloads_failed_total
# 369                              prometheus_target_scrape_pool_reloads_total
# 370                                 prometheus_target_scrape_pool_sync_total
# 371                               prometheus_target_scrape_pool_target_limit
# 372                                    prometheus_target_scrape_pool_targets
# 373                              prometheus_target_scrape_pools_failed_total
# 374                                     prometheus_target_scrape_pools_total
# 375                       prometheus_target_scrapes_cache_flush_forced_total
# 376                 prometheus_target_scrapes_exceeded_body_size_limit_total
# 377   prometheus_target_scrapes_exceeded_native_histogram_bucket_limit_total
# 378                    prometheus_target_scrapes_exceeded_sample_limit_total
# 379                    prometheus_target_scrapes_exemplar_out_of_order_total
# 380               prometheus_target_scrapes_sample_duplicate_timestamp_total
# 381                     prometheus_target_scrapes_sample_out_of_bounds_total
# 382                      prometheus_target_scrapes_sample_out_of_order_total
# 383                                      prometheus_target_sync_failed_total
# 384                                    prometheus_target_sync_length_seconds
# 385                              prometheus_target_sync_length_seconds_count
# 386                                prometheus_target_sync_length_seconds_sum
# 387                        prometheus_template_text_expansion_failures_total
# 388                                prometheus_template_text_expansions_total
# 389                                  prometheus_treecache_watcher_goroutines
# 390                            prometheus_treecache_zookeeper_failures_total
# 391                                            prometheus_tsdb_blocks_loaded
# 392                        prometheus_tsdb_checkpoint_creations_failed_total
# 393                               prometheus_tsdb_checkpoint_creations_total
# 394                        prometheus_tsdb_checkpoint_deletions_failed_total
# 395                               prometheus_tsdb_checkpoint_deletions_total
# 396                                              prometheus_tsdb_clean_start
# 397                    prometheus_tsdb_compaction_chunk_range_seconds_bucket
# 398                     prometheus_tsdb_compaction_chunk_range_seconds_count
# 399                       prometheus_tsdb_compaction_chunk_range_seconds_sum
# 400                          prometheus_tsdb_compaction_chunk_samples_bucket
# 401                           prometheus_tsdb_compaction_chunk_samples_count
# 402                             prometheus_tsdb_compaction_chunk_samples_sum
# 403                       prometheus_tsdb_compaction_chunk_size_bytes_bucket
# 404                        prometheus_tsdb_compaction_chunk_size_bytes_count
# 405                          prometheus_tsdb_compaction_chunk_size_bytes_sum
# 406                       prometheus_tsdb_compaction_duration_seconds_bucket
# 407                        prometheus_tsdb_compaction_duration_seconds_count
# 408                          prometheus_tsdb_compaction_duration_seconds_sum
# 409                              prometheus_tsdb_compaction_populating_block
# 410                                 prometheus_tsdb_compactions_failed_total
# 411                                prometheus_tsdb_compactions_skipped_total
# 412                                        prometheus_tsdb_compactions_total
# 413                              prometheus_tsdb_compactions_triggered_total
# 414                             prometheus_tsdb_data_replay_duration_seconds
# 415                        prometheus_tsdb_exemplar_exemplars_appended_total
# 416                            prometheus_tsdb_exemplar_exemplars_in_storage
# 417                prometheus_tsdb_exemplar_last_exemplars_timestamp_seconds
# 418                                   prometheus_tsdb_exemplar_max_exemplars
# 419                    prometheus_tsdb_exemplar_out_of_order_exemplars_total
# 420                prometheus_tsdb_exemplar_series_with_exemplars_in_storage
# 421                                    prometheus_tsdb_head_active_appenders
# 422                                              prometheus_tsdb_head_chunks
# 423                                prometheus_tsdb_head_chunks_created_total
# 424                                prometheus_tsdb_head_chunks_removed_total
# 425                           prometheus_tsdb_head_chunks_storage_size_bytes
# 426                           prometheus_tsdb_head_gc_duration_seconds_count
# 427                             prometheus_tsdb_head_gc_duration_seconds_sum
# 428                                            prometheus_tsdb_head_max_time
# 429                                    prometheus_tsdb_head_max_time_seconds
# 430                                            prometheus_tsdb_head_min_time
# 431                                    prometheus_tsdb_head_min_time_seconds
# 432                 prometheus_tsdb_head_out_of_order_samples_appended_total
# 433                              prometheus_tsdb_head_samples_appended_total
# 434                                              prometheus_tsdb_head_series
# 435                                prometheus_tsdb_head_series_created_total
# 436                              prometheus_tsdb_head_series_not_found_total
# 437                                prometheus_tsdb_head_series_removed_total
# 438                            prometheus_tsdb_head_truncations_failed_total
# 439                                   prometheus_tsdb_head_truncations_total
# 440                                 prometheus_tsdb_isolation_high_watermark
# 441                                  prometheus_tsdb_isolation_low_watermark
# 442                                         prometheus_tsdb_lowest_timestamp
# 443                                 prometheus_tsdb_lowest_timestamp_seconds
# 444                             prometheus_tsdb_mmap_chunk_corruptions_total
# 445                                        prometheus_tsdb_mmap_chunks_total
# 446                               prometheus_tsdb_out_of_bound_samples_total
# 447                               prometheus_tsdb_out_of_order_samples_total
# 448                                   prometheus_tsdb_reloads_failures_total
# 449                                            prometheus_tsdb_reloads_total
# 450                                    prometheus_tsdb_retention_limit_bytes
# 451                                  prometheus_tsdb_retention_limit_seconds
# 452                                    prometheus_tsdb_size_retentions_total
# 453                              prometheus_tsdb_snapshot_replay_error_total
# 454                                     prometheus_tsdb_storage_blocks_bytes
# 455                                  prometheus_tsdb_symbol_table_size_bytes
# 456                                    prometheus_tsdb_time_retentions_total
# 457                         prometheus_tsdb_tombstone_cleanup_seconds_bucket
# 458                          prometheus_tsdb_tombstone_cleanup_seconds_count
# 459                            prometheus_tsdb_tombstone_cleanup_seconds_sum
# 460                                    prometheus_tsdb_too_old_samples_total
# 461                               prometheus_tsdb_vertical_compactions_total
# 462                                prometheus_tsdb_wal_completed_pages_total
# 463                                    prometheus_tsdb_wal_corruptions_total
# 464                               prometheus_tsdb_wal_fsync_duration_seconds
# 465                         prometheus_tsdb_wal_fsync_duration_seconds_count
# 466                           prometheus_tsdb_wal_fsync_duration_seconds_sum
# 467                                   prometheus_tsdb_wal_page_flushes_total
# 468                                      prometheus_tsdb_wal_segment_current
# 469                                   prometheus_tsdb_wal_storage_size_bytes
# 470                      prometheus_tsdb_wal_truncate_duration_seconds_count
# 471                        prometheus_tsdb_wal_truncate_duration_seconds_sum
# 472                             prometheus_tsdb_wal_truncations_failed_total
# 473                                    prometheus_tsdb_wal_truncations_total
# 474                                  prometheus_tsdb_wal_writes_failed_total
# 475                                   prometheus_web_federation_errors_total
# 476                                 prometheus_web_federation_warnings_total
# 477                                     promhttp_metric_handler_errors_total
# 478                               promhttp_metric_handler_requests_in_flight
# 479                                   promhttp_metric_handler_requests_total
# 480                                                  scrape_duration_seconds
# 481                                    scrape_samples_post_metric_relabeling
# 482                                                   scrape_samples_scraped
# 483                                                      scrape_series_added
# 484                                                                       up
#
#      std_dev_nulo  valores_NAN  metrica_monotona  diff_invariante  \
# 0           False        False             False            False
# 1           False        False              True            False
# 2           False        False              True            False
# 3           False        False             False            False
# 4            True        False             False            False
# 5           False        False             False            False
# 6           False        False              True            False
# 7           False        False              True            False
# 8           False        False              True            False
# 9           False        False             False            False
# 10          False        False             False            False
# 11          False        False             False            False
# 12          False        False             False            False
# 13          False        False             False            False
# 14          False        False             False            False
# 15          False        False             False            False
# 16          False        False              True            False
# 17           True        False             False            False
# 18          False        False              True            False
# 19           True        False             False            False
# 20           True        False             False            False
# 21          False        False             False            False
# 22          False        False              True            False
# 23          False        False             False            False
# 24          False        False             False            False
# 25          False        False             False            False
# 26          False        False             False            False
# 27          False        False             False            False
# 28          False        False              True            False
# 29           True        False             False            False
# 30           True        False             False            False
# 31           True        False             False            False
# 32           True        False             False            False
# 33          False        False              True            False
# 34          False        False              True            False
# 35           True        False             False            False
# 36           True        False             False            False
# 37          False        False              True            False
# 38           True        False             False            False
# 39           True        False             False            False
# 40           True        False             False            False
# 41          False        False              True            False
# 42           True        False             False            False
# 43           True        False             False            False
# 44           True        False             False            False
# 45           True        False             False            False
# 46           True        False             False            False
# 47           True        False             False            False
# 48           True        False             False            False
# 49           True        False             False            False
# 50           True        False             False            False
# 51           True        False             False            False
# 52           True        False             False            False
# 53           True        False             False            False
# 54           True        False             False            False
# 55           True        False             False            False
# 56           True        False             False            False
# 57           True        False             False            False
# 58           True        False             False            False
# 59           True        False             False            False
# 60           True        False             False            False
# 61           True        False             False            False
# 62           True        False             False            False
# 63           True        False             False            False
# 64          False        False             False            False
# 65           True        False             False            False
# 66           True        False             False            False
# 67           True        False             False            False
# 68           True        False             False            False
# 69          False        False             False            False
# 70           True        False             False            False
# 71           True        False             False            False
# 72           True        False             False            False
# 73          False        False              True            False
# 74           True        False             False            False
# 75          False        False             False            False
# 76          False        False             False            False
# 77          False        False             False            False
# 78          False        False             False            False
# 79          False        False             False            False
# 80          False        False             False            False
# 81          False        False             False            False
# 82          False        False             False            False
# 83          False        False             False            False
# 84           True        False             False            False
# 85          False        False             False            False
# 86          False        False             False            False
# 87           True        False             False            False
# 88           True        False             False            False
# 89           True        False             False            False
# 90          False        False             False            False
# 91           True        False             False            False
# 92          False        False              True             True
# 93          False        False              True             True
# 94          False        False             False            False
# 95           True        False             False            False
# 96           True        False             False            False
# 97           True        False             False            False
# 98           True        False             False            False
# 99           True        False             False            False
# 100          True        False             False            False
# 101          True        False             False            False
# 102          True        False             False            False
# 103          True        False             False            False
# 104         False        False             False            False
# 105         False        False             False            False
# 106         False        False             False            False
# 107         False        False             False            False
# 108         False        False             False            False
# 109         False        False             False            False
# 110         False        False             False            False
# 111         False        False             False            False
# 112          True        False             False            False
# 113         False        False             False            False
# 114          True        False             False            False
# 115         False        False             False            False
# 116         False        False             False            False
# 117         False        False             False            False
# 118         False        False             False            False
# 119          True        False             False            False
# 120          True        False             False            False
# 121          True        False             False            False
# 122         False        False             False            False
# 123         False        False             False            False
# 124         False        False             False            False
# 125         False        False             False            False
# 126          True        False             False            False
# 127          True        False             False            False
# 128         False        False             False            False
# 129          True        False             False            False
# 130         False        False              True             True
# ...
# 283                                                                    False
# 284                                                                    False
# 285                                                                    False
# 286                                     node_vmstat_pgfault_diff       False
# 287                                                                     True
# 288                                      node_vmstat_pgpgin_diff       False
# 289                                     node_vmstat_pgpgout_diff       False
# 290                                      node_vmstat_pswpin_diff       False
# 291                                     node_vmstat_pswpout_diff       False
# 292                               process_cpu_seconds_total_diff       False
# 293                                                                    False
# 294                                             process_open_fds       False
# 295                                process_resident_memory_bytes       False
# 296                                                                    False
# 297                            process_virtual_memory_bytes_diff       False
# 298                                                                    False
# 299                                                                    False
# 300                                                                    False
# 301                                                                    False
# 302                                                                    False
# 303                                    prometheus_engine_queries       False
# 304                                                                    False
# 305                                                                    False
# 306          prometheus_engine_query_duration_seconds_count_diff       False
# 307            prometheus_engine_query_duration_seconds_sum_diff       False
# 308                                                                    False
# 309                                                                    False
# 310                   prometheus_engine_query_samples_total_diff       False
# 311         prometheus_http_request_duration_seconds_bucket_diff       False
# 312          prometheus_http_request_duration_seconds_count_diff       False
# 313            prometheus_http_request_duration_seconds_sum_diff       False
# 314                                                                    False
# 315              prometheus_http_response_size_bytes_bucket_diff       False
# 316               prometheus_http_response_size_bytes_count_diff       False
# 317                 prometheus_http_response_size_bytes_sum_diff       False
# 318                                                                    False
# 319                                                                    False
# 320                                                                    False
# 321                                                                    False
# 322                                                                    False
# 323                                                                    False
# 324  prometheus_remote_storage_highest_timestamp_in_seconds_diff       False
# 325                                                                    False
# 326              prometheus_remote_storage_samples_in_total_diff       False
# 327                                                                    False
# 328                                                                    False
# 329                                                                    False
# 330                                                                    False
# 331                                                                    False
# 332                                                                    False
# 333                                                                    False
# 334                                                                    False
# 335                                                                    False
# 336                                                                    False
# 337                                                                    False
# 338                                                                    False
# 339                                                                    False
# 340                                                                    False
# 341                                                                    False
# 342                                                                    False
# 343                                                                    False
# 344                                                                    False
# 345                                                                    False
# 346                                                                    False
# 347                                                                    False
# 348                                                                    False
# 349                                                                    False
# 350                                                                    False
# 351                                                                    False
# 352                                                                    False
# 353                                                                    False
# 354                                                                    False
# 355                                                                    False
# 356                                                                    False
# 357                                                                    False
# 358                                                                    False
# 359                                                                    False
# 360                                                                    False
# 361                    prometheus_target_interval_length_seconds       False
# 362         prometheus_target_interval_length_seconds_count_diff       False
# 363           prometheus_target_interval_length_seconds_sum_diff       False
# 364                                                                    False
# 365                                                                    False
# 366                                                                    False
# 367                                                                    False
# 368                                                                    False
# 369                                                                    False
# 370                                                                    False
# 371                                                                    False
# 372                                                                    False
# 373                                                                    False
# 374                                                                    False
# 375                                                                    False
# 376                                                                    False
# 377                                                                    False
# 378                                                                    False
# 379                                                                    False
# 380                                                                    False
# 381                                                                    False
# 382                                                                    False
# 383                                                                    False
# 384                                                                    False
# 385                                                                    False
# 386                                                                    False
# 387                                                                    False
# 388                                                                    False
# 389                                                                    False
# 390                                                                    False
# 391                                                                    False
# 392                                                                    False
# 393                                                                    False
# 394                                                                    False
# 395                                                                    False
# 396                                                                    False
# 397                                                                    False
# 398                                                                    False
# 399                                                                    False
# 400                                                                    False
# 401                                                                    False
# 402                                                                    False
# 403                                                                    False
# 404                                                                    False
# 405                                                                    False
# 406                                                                    False
# 407                                                                    False
# 408                                                                    False
# 409                                                                    False
# 410                                                                    False
# 411                                                                    False
# 412                                                                    False
# 413                                                                     True
# 414                                                                    False
# 415                                                                    False
# 416                                                                    False
# 417                                                                    False
# 418                                                                    False
# 419                                                                    False
# 420                                                                    False
# 421                        prometheus_tsdb_head_active_appenders       False
# 422                             prometheus_tsdb_head_chunks_diff       False
# 423               prometheus_tsdb_head_chunks_created_total_diff       False
# 424                                                                    False
# 425          prometheus_tsdb_head_chunks_storage_size_bytes_diff       False
# 426                                                                    False
# 427                                                                    False
# 428                           prometheus_tsdb_head_max_time_diff       False
# 429                   prometheus_tsdb_head_max_time_seconds_diff       False
# 430                                                                    False
# 431                                                                    False
# 432                                                                    False
# 433                                                                    False
# 434                             prometheus_tsdb_head_series_diff       False
# 435               prometheus_tsdb_head_series_created_total_diff       False
# 436                                                                    False
# 437                                                                    False
# 438                                                                    False
# 439                                                                    False
# 440                prometheus_tsdb_isolation_high_watermark_diff       False
# 441                 prometheus_tsdb_isolation_low_watermark_diff       False
# 442                                                                    False
# 443                                                                    False
# 444                                                                    False
# 445                       prometheus_tsdb_mmap_chunks_total_diff       False
# 446                                                                    False
# 447                                                                    False
# 448                                                                    False
# 449                           prometheus_tsdb_reloads_total_diff       False
# 450                                                                    False
# 451                                                                    False
# 452                                                                    False
# 453                                                                    False
# 454                                                                    False
# 455                                                                    False
# 456                                                                    False
# 457                                                                    False
# 458                                                                    False
# 459                                                                    False
# 460                                                                    False
# 461                                                                    False
# 462                                                                     True
# 463                                                                    False
# 464                                                                    False
# 465                                                                    False
# 466                                                                    False
# 467                  prometheus_tsdb_wal_page_flushes_total_diff       False
# 468                                                                    False
# 469                  prometheus_tsdb_wal_storage_size_bytes_diff       False
# 470                                                                    False
# 471                                                                    False
# 472                                                                    False
# 473                                                                    False
# 474                                                                    False
# 475                                                                    False
# 476                                                                    False
# 477                                                                    False
# 478                                                                    False
# 479                                                                    False
# 480                                      scrape_duration_seconds       False
# 481                   scrape_samples_post_metric_relabeling_diff       False
# 482                                  scrape_samples_scraped_diff       False
# 483                                          scrape_series_added       False
# 484                                                                    False

# %%
df_analisis_metricas[   df_analisis_metricas['redundante']==False  ]['clasificacion'].value_counts()# pendiente revisar esto ultimo porque creo que no lo he construido bien
# Out:
# clasificacion
#           349
# diff       59
# normal     57
# Name: count, dtype: int64

# %% [markdown]
# # <span style="color:#2ca02c">6. Análisis de tiempos  de las series</span>

# %%
df_analisis_metricas = pd.read_parquet(f'{FOLDER_SALIDA}/analisis_metricas.parquet', engine='fastparquet')

# %%
lista_metricas_sel=df_analisis_metricas[   df_analisis_metricas['metric_name_sel']!=''  ]['metric_name'].tolist()

# %%
#añadimos esta metrica que tiene valore NaN y que hemos vsito que permitia identificar anomalias
lista_metricas_sel.append('prometheus_engine_query_duration_seconds')

# %%
# Configuración inicial
dic_desalineadas = {}
todos_los_deltas_sanos = []
data_reporte = []

print("Iniciando procesamiento de ejecuciones...")

for N, execution_name in enumerate(lista_execution_name, 1):
    tuple_metricas = tuple(lista_metricas_sel)
    
    # 1. SQL Query
    SQL = """
        SELECT metric_name, time, metric_value
        FROM metricas 
        WHERE execution_name = %s 
          AND metric_name IN %s
        ORDER BY metric_name, time
    """
    df_exec = pd.read_sql(SQL, engine, params=(execution_name, tuple_metricas))
    
    # Asegurar tipo datetime
    df_exec['time'] = pd.to_datetime(df_exec['time'])

    # 2. Calcular segundos relativos
    df_exec['segundos'] = df_exec.groupby('metric_name')['time'].transform(
        lambda x: (x - x.min()).dt.total_seconds().astype(int)
    )
    
    # 3. Pivotar para validar alineación
    df_pivot = df_exec.pivot_table(index=df_exec.groupby('metric_name').cumcount(), 
                                   columns='metric_name', 
                                   values='segundos')
    
    # 4. Lógica de detección
    referencia = df_pivot.iloc[:, 0]
    metricas_malas = [col for col in df_pivot.columns if not df_pivot[col].equals(referencia)]
    
    # Guardar en diccionario y lista de reporte
    if metricas_malas:
        dic_desalineadas[execution_name] = metricas_malas
    else:
        # Acumular deltas solo para ejecuciones sanas
        deltas = df_exec.groupby('metric_name')['time'].diff().dt.total_seconds().dropna()
        todos_los_deltas_sanos.extend(deltas.tolist())
    
    # Preparar datos para el DataFrame final
    data_reporte.append({
        'execution_name': execution_name,
        'num_desalineadas': int(len(metricas_malas)),
        'metricas_desalineadas': ', '.join(metricas_malas)
    })
    
    print(f"Procesada: {execution_name} | N = {N:4d} | Desalineadas: {len(metricas_malas):3d}", end='\r')


df_alineacion = pd.DataFrame(data_reporte)
# Out:
# Iniciando procesamiento de ejecuciones...
# Procesada: light-oauth2-data-1725869703.tar | N = 1736 | Desalineadas:   0

# %%
if todos_los_deltas_sanos:
    fraccion_visualizacion = 1.0

    # Tomamos una muestra aleatoria del vector ya calculado
    datos_para_graficar = random.sample(todos_los_deltas_sanos, int(len(todos_los_deltas_sanos) * fraccion_visualizacion))
    
    # Graficamos con la muestra reducida
    plt.figure(figsize=(10, 6))
    ax = sns.countplot(x=pd.Series(datos_para_graficar), color='teal')
    
    plt.title(f'Distribución de intervalo de muestreo (Muestra del {int(fraccion_visualizacion*100)}% de los datos)')
    plt.xlabel('Segundos entre registros (dt)')
    plt.ylabel('Frecuencia de ocurrencia en la muestra')
    plt.grid(axis='y', alpha=0.3)
    plt.show()

    print(f"\nMedia de latencia: {np.mean(datos_para_graficar):.2f}s")
    print(f"Desviación estándar: {np.std(datos_para_graficar):.2f}s")
# Out:
# Media de latencia: 4.68s
# Desviación estándar: 0.60s

# %%
# 1. Creamos la estructura base con todas las ejecuciones (1740 filas)
df_alineacion = pd.DataFrame(lista_execution_name, columns=['execution_name'])

# 2. Convertimos el diccionario 'data' (que solo contiene las con problemas) a un DataFrame
df_problemas = pd.DataFrame(data) 

# 3. Hacemos un 'left join'. 
# Si el execution_name está en df_problemas, se trae los datos; si no, deja NaN.
df_alineacion = df_alineacion.merge(df_problemas, on='execution_name', how='left')

# 4. Rellenamos los huecos (NaN) para ejecuciones sin problemas:
# - num_desalineadas a 0 (y convertimos a entero)
# - metricas_desalineadas a cadena vacía
df_alineacion['num_desalineadas'] = df_alineacion['num_desalineadas'].fillna(0).astype(int)
df_alineacion['metricas_desalineadas'] = df_alineacion['metricas_desalineadas'].fillna('')

# Resultado: Tu tabla completa de auditoría de datos
df_alineacion[df_alineacion['num_desalineadas']!=0]
# Out:
#                        execution_name  num_desalineadas  \
# 803  light-oauth2-data-1722514683.tar               103
#
#                                  metricas_desalineadas
# 803  go_gc_duration_seconds_count, go_gc_duration_s...

# %%
df_alineacion.to_parquet(f'{FOLDER_SALIDA}/df_alineacion.parquet', index=False,engine='fastparquet')

# %% [markdown]
# # <span style="color:#2ca02c">7. Interpolacion de series</span>

# %%
def obtener_datos_ejecucion_metrica(execution_name, metric_name, engine):
    """
    Extrae todos los registros de una ejecución y métrica específica.
    """
    SQL = """
        SELECT time,instance,grupo,job,tags,label,metric_value
        FROM metricas 
        WHERE execution_name = %s 
          AND metric_name = %s
        ORDER BY time ASC
    """
    
    # Ejecutamos la consulta pasando los parámetros de forma segura
    df = pd.read_sql(SQL, engine, params=(execution_name, metric_name))
    
    # Convertimos la columna time a formato datetime
    df['time'] = pd.to_datetime(df['time'])
    
    return df

# %%
una_metrica=lista_metricas_sel[10]

# %%
una_metrica
# Out:
# 'go_memstats_heap_released_bytes'

# %%
set_descartadas = set(lista_ejecuciones_descartadas)
lista_ejecuciones_sel = [x for x in lista_execution_name if x not in set_descartadas]

# %%
una_ejecucion=lista_ejecuciones_sel[3]

# %%
# Ejemplo de uso:
df_serie = obtener_datos_ejecucion_metrica(una_ejecucion, una_metrica, engine)

# %%
# 2. Ordenamos por si acaso
df_serie = df_serie.sort_values('time')

# 3. Calculamos el tiempo relativo respecto al primer registro de toda la serie
inicio_global = df_serie['time'].min()
df_serie['tiempo_relativo'] = (df_serie['time'] - inicio_global).dt.total_seconds()

# %%
# --- 1. CONFIGURACIÓN ---
INTERVALO_VALOR = 5
INTERVALO_MUESTREO = f'{INTERVALO_VALOR}s'

# --- 2. PREPARACIÓN ---
# Aseguramos que 'time' es datetime y ordenamos
df_serie['time'] = pd.to_datetime(df_serie['time'])
df_serie = df_serie.sort_values('time')

# Filtramos solo las columnas que nos interesan
cols_a_mantener = ['time', 'metric_value', 'grupo', 'instance', 'job', 'label']
df_filtrado = df_serie[cols_a_mantener].copy()
df_filtrado['metric_value'] = df_filtrado['metric_value'].astype(float)

# --- 3. PROCESAMIENTO ---
# Establecemos el índice temporal
df_indexado = df_filtrado.set_index('time')

# Creamos el rango de muestreo regular
inicio, fin = df_indexado.index.min(), df_indexado.index.max()
rango_muestreo = pd.date_range(start=inicio, end=fin, freq=INTERVALO_MUESTREO)

# Reindexamos (genera los huecos para el nuevo muestreo)
df_reindexado = df_indexado.reindex(rango_muestreo)

# Interpolación ponderada por tiempo para la métrica numérica
#df_reindexado['metric_value'] = df_reindexado['metric_value'].interpolate(method='time')

#df_reindexado['metric_value'] = df_reindexado['metric_value'].interpolate(method='spline', order=1)
#df_reindexado['metric_value'] = df_reindexado['metric_value'].interpolate(method='linear')

df_reindexado['metric_value'] = df_reindexado['metric_value'].interpolate(
    method='linear', 
    limit=1, 
    limit_direction='both'
)

# Rellenamos metadatos de texto usando propagación (ffill/bfill)
columnas_texto = ['grupo', 'instance', 'job', 'label']
df_reindexado[columnas_texto] = df_reindexado[columnas_texto].ffill().bfill()

# --- 4. FINALIZACIÓN ---
df_final = df_reindexado.reset_index().rename(columns={'index': 'time'})
df_final['tiempo_relativo'] = (df_final['time'] - df_final['time'].min()).dt.total_seconds()

# df_final ya contiene tu dataset listo para el modelo

# %%
import pandas as pd

# --- 1. CONFIGURACIÓN ---
INTERVALO_VALOR = 5
INTERVALO_MUESTREO = f'{INTERVALO_VALOR}s'

# --- 2. PREPARACIÓN ---
# Aseguramos que 'time' es datetime y ordenamos
df_serie['time'] = pd.to_datetime(df_serie['time'])
df_serie = df_serie.sort_values('time')

# Filtramos solo las columnas que nos interesan
cols_a_mantener = ['time', 'metric_value', 'grupo', 'instance', 'job', 'label']
df_filtrado = df_serie[cols_a_mantener].copy()
df_filtrado['metric_value'] = df_filtrado['metric_value'].astype(float)

# --- 3. PROCESAMIENTO ---
# Establecemos el índice temporal
df_indexado = df_filtrado.set_index('time').sort_index()

# AJUSTE: Calculamos el final redondeando al siguiente múltiplo de 5 segundos
# Esto asegura que si tu último punto es 799, el rango llegue hasta 800
inicio = df_indexado.index.min()
ultimo_timestamp = df_indexado.index.max()
# Calculamos cuánto falta para el siguiente múltiplo de 5s
segundos_faltantes = INTERVALO_VALOR - (ultimo_timestamp.second % INTERVALO_VALOR)
fin = ultimo_timestamp + pd.Timedelta(seconds=segundos_faltantes)

rango_muestreo = pd.date_range(start=inicio, end=fin, freq=INTERVALO_MUESTREO)

# Creamos un DataFrame destino con el índice regular
df_target = pd.DataFrame(index=rango_muestreo)

# Utilizamos merge_asof
# direction='backward' asigna el último valor conocido. 
# Si quieres que el último punto no se "pierda", aseguramos que el rango cubra hasta el final.
df_final = pd.merge_asof(
    df_target, 
    df_indexado, 
    left_index=True, 
    right_index=True, 
    direction='backward'
)

# Ahora, para que NO se pierdan las anomalías que ocurren al final, 
# si hay un punto que estaba en el segundo 799, 
# el merge_asof lo arrastrará al 800 perfectamente.
df_final['metric_value'] = df_final['metric_value'].interpolate(method='linear')

# Rellenamos metadatos
columnas_texto = ['grupo', 'instance', 'job', 'label']
df_final[columnas_texto] = df_final[columnas_texto].ffill().bfill()

# --- 4. FINALIZACIÓN ---
df_final = df_final.reset_index().rename(columns={'index': 'time'})
df_final['tiempo_relativo'] = (df_final['time'] - df_final['time'].min()).dt.total_seconds()

# df_final ya contiene tu dataset listo para el modelo

# %%
df_serie
# Out:
#                          time        instance grupo         job tags  \
# 0   2024-06-28 19:00:33+00:00  localhost:9090  None  prometheus   {}
# 1   2024-06-28 19:00:38+00:00  localhost:9090  None  prometheus   {}
# 2   2024-06-28 19:00:43+00:00  localhost:9090  None  prometheus   {}
# 3   2024-06-28 19:00:48+00:00  localhost:9090  None  prometheus   {}
# 4   2024-06-28 19:00:53+00:00  localhost:9090  None  prometheus   {}
# ..                        ...             ...   ...         ...  ...
# 167 2024-06-28 19:13:28+00:00  localhost:9090  None  prometheus   {}
# 168 2024-06-28 19:13:33+00:00  localhost:9090  None  prometheus   {}
# 169 2024-06-28 19:13:37+00:00  localhost:9090  None  prometheus   {}
# 170 2024-06-28 19:13:42+00:00  localhost:9090  None  prometheus   {}
# 171 2024-06-28 19:13:47+00:00  localhost:9090  None  prometheus   {}
#
#                                   label  metric_value  tiempo_relativo
# 0                               correct      999424.0              0.0
# 1                               correct     4136960.0              5.0
# 2                               correct     3866624.0             10.0
# 3                               correct     3866624.0             15.0
# 4                               correct     3866624.0             20.0
# ..                                  ...           ...              ...
# 167  update_password_404_user_not_found     8544256.0            775.0
# 168  update_password_404_user_not_found     8544256.0            780.0
# 169       update_password_400_not_match     8544256.0            784.0
# 170       update_password_400_not_match     9256960.0            789.0
# 171       update_password_400_not_match     9256960.0            794.0
#
# [172 rows x 8 columns]

# %%
# Configuramos el tamaño del gráfico para mayor claridad
plt.figure(figsize=(12, 6))

# 1. Graficamos la serie original (con puntos para ver las muestras reales)
plt.plot(df_serie['tiempo_relativo'], df_serie['metric_value'], 
         'o-', label='Serie Original', color='blue', alpha=0.6, markersize=4)

# 2. Graficamos la serie interpolada (línea continua para ver el relleno)
plt.plot(df_final['tiempo_relativo'], df_final['metric_value'], 
         '--', label='Serie Interpolada (5s)', color='red', alpha=0.8)

# Detalles estéticos para el tribunal
plt.title('Comparativa: Serie Temporal Original vs. Interpolada (Muestreo 5s)')
plt.xlabel('Tiempo')
plt.ylabel('Valor de la Métrica')
plt.legend()
plt.grid(True, linestyle='--', alpha=0.7)

plt.show()

# %%
# Creamos dos subgráficos: uno encima del otro
fig, (ax1, ax2) = plt.subplots(2, 1, figsize=(12, 10), sharex=True)

# 1. Gráfico superior: Serie Original
ax1.plot(df_serie['tiempo_relativo'], df_serie['metric_value'], 
         'o-', label='Serie Original (Muestreo Irregular)', color='blue', markersize=5)
ax1.set_title('Muestreo Original')
ax1.set_ylabel('Valor')
ax1.grid(True, linestyle='--', alpha=0.6)
ax1.legend()

# 2. Gráfico inferior: Serie Interpolada
ax2.plot(df_final['tiempo_relativo'], df_final['metric_value'], 
         '.-', label='Serie Interpolada (5s regular)', color='red', markersize=3)
ax2.set_title('Serie Regularizada (Interpolación Lineal a 5s)')
ax2.set_xlabel('Tiempo')
ax2.set_ylabel('Valor')
ax2.grid(True, linestyle='--', alpha=0.6)
ax2.legend()

plt.tight_layout()
plt.show()

# %%
df_final
# Out:
#                          time  metric_value grupo        instance         job  \
# 0   2024-06-28 16:29:32+00:00      0.000711  None  localhost:9090  prometheus
# 1   2024-06-28 16:29:37+00:00      0.000711  None  localhost:9090  prometheus
# 2   2024-06-28 16:29:42+00:00      0.000711  None  localhost:9090  prometheus
# 3   2024-06-28 16:29:47+00:00      0.000711  None  localhost:9090  prometheus
# 4   2024-06-28 16:29:52+00:00      0.000711  None  localhost:9090  prometheus
# ..                        ...           ...   ...             ...         ...
# 156 2024-06-28 16:42:32+00:00      0.161635  None  localhost:9090  prometheus
# 157 2024-06-28 16:42:37+00:00      0.161635  None  localhost:9090  prometheus
# 158 2024-06-28 16:42:42+00:00      0.161635  None  localhost:9090  prometheus
# 159 2024-06-28 16:42:47+00:00      0.171535  None  localhost:9090  prometheus
# 160 2024-06-28 16:42:52+00:00      0.171535  None  localhost:9090  prometheus
#
#                                   label  tiempo_relativo
# 0                               correct              0.0
# 1                               correct              5.0
# 2                               correct             10.0
# 3                               correct             15.0
# 4                               correct             20.0
# ..                                  ...              ...
# 156  update_password_404_user_not_found            780.0
# 157  update_password_404_user_not_found            785.0
# 158       update_password_400_not_match            790.0
# 159       update_password_400_not_match            795.0
# 160       update_password_400_not_match            800.0
#
# [161 rows x 7 columns]

# %%
df_serie
# Out:
#                          time        instance grupo         job tags  \
# 0   2024-06-28 16:29:32+00:00  localhost:9090  None  prometheus   {}
# 1   2024-06-28 16:29:37+00:00  localhost:9090  None  prometheus   {}
# 2   2024-06-28 16:29:42+00:00  localhost:9090  None  prometheus   {}
# 3   2024-06-28 16:29:47+00:00  localhost:9090  None  prometheus   {}
# 4   2024-06-28 16:29:52+00:00  localhost:9090  None  prometheus   {}
# ..                        ...             ...   ...         ...  ...
# 167 2024-06-28 16:42:32+00:00  localhost:9090  None  prometheus   {}
# 168 2024-06-28 16:42:37+00:00  localhost:9090  None  prometheus   {}
# 169 2024-06-28 16:42:41+00:00  localhost:9090  None  prometheus   {}
# 170 2024-06-28 16:42:46+00:00  localhost:9090  None  prometheus   {}
# 171 2024-06-28 16:42:51+00:00  localhost:9090  None  prometheus   {}
#
#                                   label  metric_value  tiempo_relativo
# 0                               correct      0.000711              0.0
# 1                               correct      0.000711              5.0
# 2                               correct      0.000711             10.0
# 3                               correct      0.000711             15.0
# 4                               correct      0.000711             20.0
# ..                                  ...           ...              ...
# 167  update_password_404_user_not_found      0.161635            780.0
# 168  update_password_404_user_not_found      0.161635            785.0
# 169       update_password_400_not_match      0.161635            789.0
# 170       update_password_400_not_match      0.171535            794.0
# 171       update_password_400_not_match      0.171535            799.0
#
# [172 rows x 8 columns]
