# %%
from timescale import TimescaleDBManager
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 from timescale import TimescaleDBManager
#
# File D:\backup onedrive gva\PERSONAL\master_bigdata_VIU\TFM\tfm-microservices-anomaly-detection\server1\timescale.py:2
#       1 import os
# ----> 2 import psycopg2
#       3 from psycopg2 import OperationalError
#       4 from psycopg2.extras import RealDictCursor
#
# ModuleNotFoundError: No module named 'psycopg2'

# %%
import psycopg2
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 import psycopg2
#
# ModuleNotFoundError: No module named 'psycopg2'

# %%
# !pip install psycopg2-binary
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
#    ---------------------------------------- 0.0/2.8 MB ? eta -:--:--
#    ---------------------- ----------------- 1.6/2.8 MB 12.2 MB/s eta 0:00:01
#    ---------------------------------------- 2.8/2.8 MB 11.8 MB/s  0:00:00
# ...
# ERROR: Could not install packages due to an OSError: [WinError 5] Acceso denegado: 'C:\\Users\\juana\\AppData\\Roaming\\Python\\Python314\\site-packages\\psycopg2\\_psycopg.cp314-win_amd64.pyd'
# Check the permissions.
#
#
# [notice] A new release of pip is available: 26.0.1 -> 26.1.2
# [notice] To update, run: python.exe -m pip install --upgrade pip
